# %% [markdown]
# 此 .ipynb为按照行级，获得预测正确和错误的不同行级元素的贡献值分布。根据统计分析结果。
# <br>打印出 <br>
# [('returnstatement', 'return ( insertions . size () > 0 || ! unresolvedInsertions . isEmpty () || deletions . size () > 0 );', tensor(0.0590, dtype=torch.float64)), ('MethodDeclaration', 'public boolean areInsertionsOrDeletionsQueued () {', tensor(0.1059, dtype=torch.float64))]<br>[('行级语句类型','对应的行级语句','贡献值')]<br>
# 1<br>
# 索引<br>
# 根据上述的txt，挑出实例，不用挑太多

# %% [markdown]
# 将每个实例中的类别贡献值与统计分析中的绝对值均值进行大小比较，大于绝对值均值的保留

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

import torch
import torch.nn as nn
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import AdamW, get_linear_schedule_with_warmup
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, TensorDataset


from captum.attr import visualization as viz
from captum.attr import LayerConductance, LayerIntegratedGradients
from captum.attr import configure_interpretable_embedding_layer, remove_interpretable_embedding_layer

# 解决服务器挂掉的问题
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device = torch.device( "cpu")

# %%
MAX_LEN = 1024
MAX_EPOCHS = 10
BATCH_SIZE = 4
LEARNING_RATE = 1e-5
NUM_CLASSES = 2
WEIGTH_DECAY = 1e-3

# %%
def retrieve_test_data():
    test_param = pd.read_json("D:/leitx/data/param/test.json")
    test_return = pd.read_json("D:/leitx/data/return/test.json")
    test_summary = pd.read_json("D:/leitx/data/summary/test.json")
    test_df = pd.concat([test_summary,test_param, test_return], axis=0)
    test_df = test_df.reset_index(drop=True)
    return test_df
test_df = retrieve_test_data()

# %%
def get_lines_count(df):
    line_counts = []
    for i in range(len(df)):
        string = df.loc[i]['new_code_raw']
        line_count = len(string.split('\n'))
        line_counts.append(line_count)
    df['line_counts'] = line_counts
    return df
test_df = get_lines_count(test_df)
test_df.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  line_counts
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...            6
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...            4
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...           28
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...            4
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...           16

# %%
df_clean = test_df
df_clean.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  line_counts
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...            6
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...            4
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...           28
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...            4
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...           16

# %%
code_list = df_clean['new_code_raw']

# %%
code_list[0]
# Out:
# '  private static EmbeddedElasticsearchNode create(Settings settings) {\n    // ensure PainlessPlugin is installed or otherwise scripted fields would not work\n    Node node = new LocalNode(settings, Arrays.asList(Netty4Plugin.class, PainlessPlugin.class));\n    return new EmbeddedElasticsearchNode(node);\n  }\n'

# %%
df_clean.loc[0]['new_code_raw']
# Out:
# '  private static EmbeddedElasticsearchNode create(Settings settings) {\n    // ensure PainlessPlugin is installed or otherwise scripted fields would not work\n    Node node = new LocalNode(settings, Arrays.asList(Netty4Plugin.class, PainlessPlugin.class));\n    return new EmbeddedElasticsearchNode(node);\n  }\n'

# %%
len(df_clean)
# Out:
# 3944

# %%
model = torch.load('D:/leitx/save_model/save_GCBmodel.pt',map_location=torch.device('cuda:0'))
# model = torch.load('D:/BERT_learing/CCDP/for_captum/save_model/save_GCBmodel.pt',map_location=torch.device('cpu'))

model.to(device)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_5632\3715315584.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load('D:/leitx/save_model/save_GCBmodel.pt',map_location=torch.device('cuda:0'))
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())  #输出为True，则安装无误
# Out:
# 2.5.0
# 11.8
# True

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
tokenizer = RobertaTokenizer.from_pretrained("D:/leitx/tokenizer/graphcodebert")
# Out:
# C:\ProgramData\anaconda3\envs\leitx\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
model.roberta.embeddings
# Out:
# RobertaEmbeddings(
#   (word_embeddings): Embedding(50265, 768, padding_idx=1)
#   (position_embeddings): Embedding(514, 768, padding_idx=1)
#   (token_type_embeddings): Embedding(1, 768)
#   (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
model.roberta.encoder.layer[0]
# Out:
# RobertaLayer(
#   (attention): RobertaAttention(
#     (self): RobertaSelfAttention(
#       (query): Linear(in_features=768, out_features=768, bias=True)
#       (key): Linear(in_features=768, out_features=768, bias=True)
#       (value): Linear(in_features=768, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (output): RobertaSelfOutput(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (intermediate): RobertaIntermediate(
#     (dense): Linear(in_features=768, out_features=3072, bias=True)
#     (intermediate_act_fn): GELUActivation()
#   )
#   (output): RobertaOutput(
#     (dense): Linear(in_features=3072, out_features=768, bias=True)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
input_embeddings = model.get_input_embeddings()

# %%
# predict和squad_pos_forward_func可以合成一个
def predict(inputs, position_ids=None, attention_mask=None):
    output = model(inputs,
                   position_ids=position_ids,
                  attention_mask=attention_mask )
    
    prediction = output.logits
    prediction_1 = nn.functional.softmax(prediction, dim=1)
    prediction = prediction_1.max(1).values
    out = torch.argmax(prediction_1, dim=-1)
    # prediction：每个输入样本的最大预测概率。
    # out：预测的类别标签。
    # prediction_1：所有类别的预测概率。    
    return prediction,out,prediction_1

# %%
def squad_pos_forward_func(inputs,position_ids=None, attention_mask=None, position=0):
    pred ,_,_= predict(inputs,
                     position_ids=position_ids,
                   attention_mask=attention_mask)
    return pred

# %%
ref_token_id = tokenizer.pad_token_id # 0
sep_token_id = tokenizer.sep_token_id # 101
cls_token_id = tokenizer.cls_token_id # 102
ref_token_id,sep_token_id,cls_token_id
# Out:
# (1, 2, 0)

# %%
# 注意长度
def truncate(ids,len_tru = 512):
    return ids[:len_tru] if len(ids) > len_tru else ids

# %%
# 这是单个数据的处理方式，应该要想数据集应该怎么处理
def construct_input_ref_pair(comment,AST_type,  ref_token_id, sep_token_id, cls_token_id):
    comment = tokenizer.encode(comment, add_special_tokens=False,truncation=True,max_length=512)
    AST_type = tokenizer.encode(AST_type, add_special_tokens=False,truncation=True,max_length=512)
    # construct input token ids
    input_ids = [cls_token_id] + comment + [sep_token_id] + AST_type + [sep_token_id]

    # construct reference token ids 
    ref_input_ids = [cls_token_id] + [ref_token_id] * len(comment) + [sep_token_id] + \
        [ref_token_id] * len(AST_type) + [sep_token_id]
    input_ids = truncate(input_ids)
    ref_input_ids = truncate(ref_input_ids)
    return torch.tensor([input_ids], device=device), torch.tensor([ref_input_ids], device=device), len(comment)

def construct_input_ref_token_type_pair(input_ids, sep_ind=0):
    seq_len = input_ids.size(1)
    token_type_ids = torch.tensor([[0 if i <= sep_ind else 1 for i in range(seq_len)]], device=device)
    ref_token_type_ids = torch.zeros_like(token_type_ids, device=device)# * -1
    return token_type_ids, ref_token_type_ids

def construct_input_ref_pos_id_pair(input_ids):
    seq_length = input_ids.size(1)
    position_ids = torch.arange(seq_length, dtype=torch.long, device=device)
    # we could potentially also use random permutation with `torch.randperm(seq_length, device=device)`
    ref_position_ids = torch.zeros(seq_length, dtype=torch.long, device=device)

    position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
    ref_position_ids = ref_position_ids.unsqueeze(0).expand_as(input_ids)
    return position_ids, ref_position_ids

def construct_attention_mask(input_ids):
    return torch.ones_like(input_ids)

def construct_whole_bert_embeddings(input_ids, ref_input_ids, \
                                    token_type_ids=None, ref_token_type_ids=None, \
                                    position_ids=None, ref_position_ids=None):
    input_embeddings = model.roberta.embeddings(input_ids, token_type_ids=token_type_ids, position_ids=position_ids)
    ref_input_embeddings = model.roberta.embeddings(ref_input_ids, token_type_ids=ref_token_type_ids, position_ids=ref_position_ids)
    
    return input_embeddings, ref_input_embeddings

# %%
def input_data_list(AST_list,comment_list):
    input_ids_all = []
    ref_input_ids_all = []
    position_ids_all = []
    attention_mask_all = []
    token_type_ids_all = []
    all_tokens_all = []
    for i in range(len(AST_list)):
        input_ids, ref_input_ids, comment_len = construct_input_ref_pair(comment_list[i],AST_list[i], ref_token_id,\
                                                                         sep_token_id, cls_token_id)
        token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, comment_len)
        position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
        attention_mask = construct_attention_mask(input_ids)
        
        indices = input_ids[0].detach().tolist()
        
        all_tokens = []                                       ###
        for _, token in enumerate(indices):
            all_tokens.append(tokenizer.decode([token]))
        
        input_ids_all.append(input_ids)
        ref_input_ids_all.append(ref_input_ids)
        position_ids_all.append(position_ids)
        attention_mask_all.append(attention_mask)
        token_type_ids_all.append(token_type_ids)
        all_tokens_all.append(all_tokens)

    return input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,token_type_ids_all,all_tokens_all

# %%
# 前k个贡献最高的word 和 token_type 和 position
# return value为归因贡献值  indices为词对应的索引  top_tokens为 词或位置或token_type
def get_topk_attributed_tokens(attrs,all_token_t, k=5):
    values_max, indices_max = torch.topk(attrs, k)
    top_tokens_max = [all_token_t[idx] for idx in indices_max]
    values_min, indices_min = torch.topk(attrs, k, largest=False)
    top_tokens_min = [all_token_t[idx] for idx in indices_min] 
    
    return top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min

# %%
import re
import string

def split_punctuation(s):
    # 使用正则表达式匹配连续的标点符号或者字母和标点符号之间的位置
    splits = re.finditer(r'(?<=\w)(?=[{}])|(?<=[{}])(?=\w)'.format(string.punctuation, string.punctuation), s)
    
    # 获取所有分割位置
    split_positions = [match.start() for match in splits]
    
    # 在分割位置插入空格
    for pos in reversed(split_positions):
        s = s[:pos] + ' ' + s[pos:]
        
    s = s.replace("< s >", "<s>")
    s = s.replace("</ s >", "</s>")
    return s

# %%
# 从 all_tokens 还原为 原单词 ，并且计算归因值
def get_restore_words(code,comment,input_ids,all_tokens,attribution_num):
    all_tokens_decode = tokenizer.decode(input_ids)
    len_all_tokens_decode = len(all_tokens_decode) + 4
    # 使用decode获得的序列，去掉分词之后的空格    例 ' a' -> 'a'
    all_tokens_clean = []
    for token in all_tokens:
        s_without_leading_space = token.lstrip()
        all_tokens_clean.append(s_without_leading_space)
#     print('all_tokens_clean:\n',all_tokens_clean)
#     print('all_tokens_clean:\n',len(all_tokens_clean))
    

    # 获得 code_comment_baseline
    code = tokenizer.encode(code, add_special_tokens=False,truncation=True,max_length=512)
    comment = tokenizer.encode(comment, add_special_tokens=False,truncation=True,max_length=512)
    code_decode = tokenizer.decode(code)
    comment_decode = tokenizer.decode(comment)
    
    code_comment_baseline = tokenizer.decode(tokenizer.cls_token_id) + ' '+ comment_decode \
                            + ' '+ tokenizer.decode(tokenizer.sep_token_id) + ' ' + code_decode \
                            + ' ' + tokenizer.decode(tokenizer.sep_token_id)
    
    code_comment_baseline = code_comment_baseline[:len_all_tokens_decode]
    code_comment_baseline = split_punctuation(code_comment_baseline)
    code_comment_baseline = code_comment_baseline.split()

#     print('code_comment_baseline:\n',code_comment_baseline)
#     print('code_comment_baseline_len:\n',len(code_comment_baseline))

    
    # 获得 相邻有几个token合并在一块的列表times  为了以后再计算attribute时求和
    times = []
    token_index = 0
    for code_comment in code_comment_baseline:
        temp = ''
        time = 0
        while temp != code_comment:
            temp = temp + all_tokens_clean[token_index]
            token_index = token_index + 1
            time = time + 1
        times.append(time)
#     print('times:\n',times)
    
    attribute_sum = []
    start = 0
    for time in times:
        end = start + time
        attribute = sum(attribution_num[start:end]) / time
        attribute_sum.append(attribute)
        start = end
#     print('attribute_sum:\n',attribute_sum)
    return code_comment_baseline ,attribute_sum

# %%
def get_line_code_and_attribute(code,code_all_tokens,attributions_num):
    # 特殊符号前  加空格
    code = split_punctuation(code)
    
    # 把  行前空格去掉  便于单词与行之间匹配
    code = [line.lstrip() for line in code.splitlines()]
    code = '\n'.join(code)  
    code_lineList = code.split('\n')
    code_lineList = [' '.join(x.split()) for x in code_lineList]
    # 有空行，把空行去掉
    code_lineList = [item for item in code_lineList if item != '']
    
    attribute = []
    i = 0  
    for code_line in code_lineList:
        count = 0
        if i < len(code_all_tokens):
            temp = code_all_tokens[i]
            attr = attributions_num[i]
            i = i + 1
        while((i < len(code_all_tokens)) and(temp != code_line)):
            attr = attr + attributions_num[i]
            temp = temp + ' ' + code_all_tokens[i]
            i = i + 1
            count = count + 1
        attribute.append(attr/count)

    return code_lineList,attribute

# %%
def remove_before_and_including(lst, element):
    if element in lst:
        index = lst.index(element)
        lst_c = lst[index+1:]
        if element in lst_c:
            lst_c.remove(element)
        return lst_c
    else:
        return lst
    
def remove_after_including(lst, element):
    if element in lst:
        index = lst.index(element)
        return lst[:index + 1]
    else:
        return lst

# %%
def final_all_attribute(code,all_tokens,attributions_num):
    # 删除 all_token 列表中的<s>注释</s>  </s>
    code_all_tokens = remove_before_and_including(all_tokens,'</s>')
    comment_all_tokens = remove_after_including(all_tokens,'</s>')  
    index = all_tokens.index('</s>')
    attribute_comment = attributions_num[:index+1]
#     print(attribute_comment)
    
    attribute_code = attributions_num[index+1:-1]
#     print(attribute_code,len(attribute_code))
    code_lineList_token,attribute_num_code = get_line_code_and_attribute(code,code_all_tokens,attribute_code)
##     print(attribute_num_code)
    attribute_num_code = torch.stack(attribute_num_code)
    
    new_all_tokens = comment_all_tokens + code_lineList_token
    attributions_num_all = torch.cat((attribute_comment, attribute_num_code))
    return new_all_tokens,attributions_num_all,code_lineList_token,attribute_num_code

# %%
from captum.attr import LayerIntegratedGradients
from captum.attr import visualization as viz

lig = LayerIntegratedGradients(squad_pos_forward_func,input_embeddings)

# %%
def interpret_sentence_2(code,comment,old_code,input_ids,ref_input_ids, token_type_ids,\
                         position_ids, attention_mask, all_tokens):
    pre ,out,_ = predict(input_ids,  position_ids=position_ids,attention_mask=attention_mask)
  
    attributions_ig, delta_ig = lig.attribute(input_ids, baselines=ref_input_ids,\
                           additional_forward_args=(position_ids,attention_mask,0),return_convergence_delta=True,internal_batch_size=8)
    
    attributions = attributions_ig.sum(dim=2).squeeze(0)
    attributions = attributions / torch.norm(attributions)
#     print(delta_ig)
#     print(attributions)
    try:
        all_tokens ,attributions = get_restore_words(code,comment,input_ids[0],all_tokens,attributions)     # 合并为一个单词
        attributions = torch.tensor(attributions)

        # code_lineList_token 和 attribute_num_code 用于后续统计分析
        new_all_tokens,attributions_num_all,code_lineList_token,attribute_num_code = final_all_attribute(code,all_tokens,attributions)

        return out,code_lineList_token,attribute_num_code
    except Exception as e:
        print("解析错误")
        return -1,_,_

# %%
def interpret_sentence_2(code,comment,old_code,input_ids,ref_input_ids, token_type_ids,\
                         position_ids, attention_mask, all_tokens, ground_lable):
    pre ,out,_ = predict(input_ids,  position_ids=position_ids,attention_mask=attention_mask)
    if out == 1:
        sen_type = 'Consis'
    else:
        sen_type = 'Inconsis'
    pre = pre.item()
    pre = "{:.3f}".format(pre)
    pre = float(pre) 
    pre ,sen_type
    
    attributions_ig, delta_ig = lig.attribute(input_ids, baselines=ref_input_ids,\
                           additional_forward_args=(position_ids,attention_mask,0),return_convergence_delta=True,internal_batch_size=8)
    
    attributions = attributions_ig.sum(dim=2).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    try:
        all_tokens ,attributions = get_restore_words(code,comment,input_ids[0],all_tokens,attributions)     # 合并为一个单词
        attributions = torch.tensor(attributions)

        # code_lineList_token 和 attribute_num_code 用于后续统计分析
        new_all_tokens,attributions_num_all,code_lineList_token,attribute_num_code = final_all_attribute(code,all_tokens,attributions) 
        
        
        
        return out,code_lineList_token,attribute_num_code,\
                attributions_num_all, new_all_tokens, pre, ground_lable, sen_type, delta_ig
    except Exception as e:
        print("解析错误")
        return -1, _, _,_,_,_,_,_,_

def add_attributions_to_visualizer(attributions, all_tokens, pre, ground_lable, sen_type, delta, vis_data_records):
    # storing couple samples in an array for visualization purposes
    vis_data_records.append(viz.VisualizationDataRecord(
                            attributions,
                            pre,
                            sen_type,
                            ground_lable,
                            sen_type,
                            attributions.sum(),
                            all_tokens,
                            delta))

# %% [markdown]
# 判断行级贡献值分布情况，将一些特殊语句变为一个具有代表性的词

# %%
# 单个示例获取各种statement 的函数
def get_ifstatement(code_line,attribution_num):
    pattern = re.compile(r'\bif\b')    
    code_contains_if = [(i, s) for i, s in enumerate(code_line) if pattern.search(s)]   
    attr_contains_if = [attribution_num[code_contains_if[i][0]] for i in range(len(code_contains_if))]
    merged_list = [('ifstatement', s, attr) for (_, s), attr in zip(code_contains_if, attr_contains_if)]
    return merged_list
def get_forstatement(code_line,attribution_num):
    pattern = re.compile(r'\bfor\b')    
    code_contains_for = [(i, s) for i, s in enumerate(code_line) if pattern.search(s)]   
    attr_contains_for = [attribution_num[code_contains_for[i][0]] for i in range(len(code_contains_for))]
    merged_list = [('forstatement', s, attr) for (_, s), attr in zip(code_contains_for, attr_contains_for)]
    return merged_list
def get_whilestatement(code_line,attribution_num):
    pattern = re.compile(r'\bwhile\b')    
    code_contains_while = [(i, s) for i, s in enumerate(code_line) if pattern.search(s)]   
    attr_contains_while = [attribution_num[code_contains_while[i][0]] for i in range(len(code_contains_while))]
    merged_list = [('whilestatement', s, attr) for (_, s), attr in zip(code_contains_while, attr_contains_while)]
    return merged_list
def get_variableDeclaration(code_line,attribution_num):
    pattern = re.compile(r'\bnew\b')    
    code_contains_new = [(i, s) for i, s in enumerate(code_line) if pattern.search(s)]       
    attr_contains_new = [attribution_num[code_contains_new[i][0]] for i in range(len(code_contains_new))]
    merged_list = [('variableDeclaration', s, attr) for (_, s), attr in zip(code_contains_new, attr_contains_new)]
    return merged_list
def get_expression(code_line,attribution_num):
    code_contains_exp = [(i, s) for i, s in enumerate(code_line) if '=' in s]
    attr_contains_exp = [attribution_num[code_contains_exp[i][0]] for i in range(len(code_contains_exp))]  
    merged_list = [('expression', s, attr) for (_, s), attr in zip(code_contains_exp, attr_contains_exp)]
    return merged_list
def get_try_catch(code_line,attribution_num):
    pattern = re.compile(r'\btry\b')    
    code_contains_try_catch = [(i, s) for i, s in enumerate(code_line) if pattern.search(s)] 
    attr_contains_try_catch = [attribution_num[code_contains_try_catch[i][0]] for i in range(len(code_contains_try_catch))]
    merged_list = [('trystatement', s, attr) for (_, s), attr in zip(code_contains_try_catch, attr_contains_try_catch)]
    return merged_list
def get_return(code_line,attribution_num):
    pattern = re.compile(r'\breturn\b')    
    code_contains_return = [(i, s) for i, s in enumerate(code_line) if pattern.search(s)]
    attr_contains_return = [attribution_num[code_contains_return[i][0]] for i in range(len(code_contains_return))]
    merged_list = [('returnstatement', s, attr) for (_, s), attr in zip(code_contains_return, attr_contains_return)]
    return merged_list
def get_MethodDeclaration(code_line,attribution_num):
    code_contains_Method = [code_line[0]]
    attr_contains_Method = [attribution_num[0]]
    merged_list = list(zip(['MethodDeclaration'],code_line, attribution_num))
    return merged_list

# %%
# 集成到数据集中 , 对返回值进行数据分析 , 六个列表试着画小提琴图
from itertools import chain

def get_all_statement(code_line_list,attribution_num_list):
    type_code_attr = []
    for (code_line,attribution_num) in zip(code_line_list,attribution_num_list):
#         print(code_line,attribution_num)
        merged_list_if = get_ifstatement(code_line,attribution_num)
        merged_list_for = get_forstatement(code_line,attribution_num)
        merged_list_while = get_whilestatement(code_line,attribution_num)
        merged_list_new = get_variableDeclaration(code_line,attribution_num)
        merged_listexp = get_expression(code_line,attribution_num)
        merged_list_try_catch = get_try_catch(code_line,attribution_num)
        merged_list_return = get_return(code_line,attribution_num)
        merged_list_Method = get_MethodDeclaration(code_line,attribution_num)
        
        conditions = [
            merged_list_if,
            merged_list_for,
            merged_list_while,
            merged_list_new,
            merged_listexp,
            merged_list_try_catch,
            merged_list_return ,
            merged_list_Method
        ]
        # 合并上述非空的列表
        merged_conditions = list(chain(*[lst for lst in conditions if lst]))
        type_code_attr.append(merged_conditions)
        
    return type_code_attr

# %%
def analyse_line_attribution(df):
    code_list = list(df['new_code_raw'])
    comment_list = list(df['old_comment_raw'])
    code_list_old = list(df['old_code_raw'])
    ground_lable = list(df['label'])
    
    input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,\
    token_type_ids_all,all_tokens_all= input_data_list(code_list,comment_list)
    
    code_lineList_token_true = []
    attribute_num_code_true = []
    index_true = []
    picture_true = []
    code_lineList_token_false = []
    attribute_num_code_false = []
    index_false = []
    picture_false = []

    for i in range(len(code_list)): 
        out,code_lineList_token,attribute_num_code,\
        attributions_num_all, new_all_tokens, pre_all, ground_lable_all, sen_type_all, delta_ig_all \
        = interpret_sentence_2(code_list[i],comment_list[i],\
                               code_list_old[i],input_ids_all[i],\
                               ref_input_ids_all[i], token_type_ids_all[i],\
                               position_ids_all[i],attention_mask_all[i], all_tokens_all[i],ground_lable[i])
        if out != -1:
            if out == ground_lable[i]:
                index_true.append(i)
                picture_true.append((attributions_num_all, new_all_tokens, pre_all, ground_lable_all, sen_type_all, delta_ig_all))
                code_lineList_token_true.append(code_lineList_token)
                attribute_num_code_true.append(attribute_num_code)
            else :
                index_false.append(i)
                picture_false.append((attributions_num_all, new_all_tokens, pre_all, ground_lable_all, sen_type_all, delta_ig_all))
                code_lineList_token_false.append(code_lineList_token)
                attribute_num_code_false.append(attribute_num_code)
    return index_true,index_false,code_lineList_token_true,attribute_num_code_true,picture_true,\
           code_lineList_token_false,attribute_num_code_false,picture_false

# %%
index_true,index_false,code_lineList_token_true,attribute_num_code_true,picture_true,\
code_lineList_token_false,attribute_num_code_false,picture_false\
= analyse_line_attribution(df_clean)
# Out:
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误
# 解析错误

# %%
len(index_true),len(code_lineList_token_true),len(attribute_num_code_true)
# Out:
# (2140, 2140, 2140)

# %%
# average_list 为 均值的元组 (类型名，均值)
def get_filter_pair(list_pair,average_list_1,average_list_2,index_all,picture_data):

    type_dict_0 = dict(average_list_1)
    type_dict_1 = dict(average_list_2)

    # 过滤符合条件的子列表，并记录被删除的索引
    filtered_nested_statements = []
    removed_indices = []
    
    for index, sublist in enumerate(list_pair):
        if all(stmt_type in type_dict_0 and value > (type_dict_0[stmt_type]/4) for stmt_type, _, value in sublist if stmt_type in type_dict_0):
            filtered_nested_statements.append(sublist)
        elif all(stmt_type in type_dict_1 and value < (type_dict_1[stmt_type]/4) for stmt_type, _, value in sublist if stmt_type in type_dict_1):
            filtered_nested_statements.append(sublist)
        else:
            removed_indices.append(index)
        
    picture_data_t = [picture_data[i] for i in range(len(picture_data)) if i not in removed_indices]
    index_all_t = [index_all[i] for i in range(len(index_all)) if i not in removed_indices]
  
    return filtered_nested_statements,index_all_t,picture_data_t

# %% [markdown]
# true

# %%
type_code_attr_true= get_all_statement(code_lineList_token_true,attribute_num_code_true)

# %%
len(index_true),len(type_code_attr_true)
# Out:
# (2140, 2140)

# %%
# 由均值而来 iqr
# 4
# type_list_true = [
#     ('MethodDeclaration',0.143),
#     ('variableDeclaration',0.087),
#     ('trystatement',0.102),
#     ('returnstatement',0.129)
# ]
type_list_true = [
    ('MethodDeclaration',0.143),
    ('returnstatement',0.129)
]
type_list_true_0 = [
    ('MethodDeclaration',-0.143),
    ('returnstatement',-0.129)
]

# %%
# 由均值而来 Winsorization 
type_list_true_1 = [
    ('MethodDeclaration',0.182),
    ('variableDeclaration',0.09),
    ('trystatement',0.100),
    ('returnstatement',0.144)
]

# %%
filtered_statements_true,filter_true_index,picture_data_true\
= get_filter_pair(type_code_attr_true, type_list_true,type_list_true_0,index_true,picture_true)

# %%
len(filter_true_index)
# Out:
# 278

# %%
len(picture_data_true)
# Out:
# 278

# %%
filter_true_index
# Out:
# [1,
#  3,
#  13,
#  38,
#  44,
#  71,
#  78,
#  85,
#  89,
#  96,
#  110,
#  114,
#  140,
#  143,
#  144,
#  146,
#  176,
#  205,
#  223,
#  226,
#  248,
#  261,
#  265,
#  269,
#  278,
#  284,
#  302,
#  341,
#  343,
#  345,
#  378,
#  402,
#  420,
#  429,
#  441,
#  449,
#  451,
#  459,
#  469,
#  504,
#  519,
#  520,
#  528,
#  540,
#  547,
#  553,
#  587,
#  601,
#  607,
#  610,
#  624,
#  626,
#  628,
#  641,
#  648,
#  656,
#  680,
#  688,
#  693,
#  708,
#  719,
#  725,
#  758,
#  772,
#  783,
#  785,
#  793,
#  799,
#  808,
#  836,
#  852,
#  877,
#  904,
#  908,
#  913,
#  917,
#  933,
#  946,
#  1008,
#  1013,
#  1038,
#  1049,
#  1062,
#  1076,
#  1098,
#  1130,
#  1140,
#  1197,
#  1199,
#  1209,
#  1236,
#  1273,
#  1299,
#  1348,
#  1358,
#  1387,
#  1411,
#  1421,
#  1468,
#  1476,
#  1486,
#  1544,
#  1566,
#  1633,
#  1679,
#  1719,
#  1747,
#  1774,
#  1803,
#  1828,
#  1840,
#  1843,
#  1855,
#  1880,
#  1895,
#  1910,
#  1925,
#  1927,
#  1968,
#  2017,
#  2023,
#  2106,
#  2116,
#  2125,
#  2127,
#  2132,
#  2141,
#  2152,
#  2164,
#  2168,
#  2176,
#  2183,
#  2184,
#  2204,
#  2205,
#  2206,
#  2212,
#  2216,
#  2274,
#  2280,
#  2281,
#  2301,
#  2313,
#  2318,
#  2326,
#  2390,
#  2405,
#  2406,
#  2426,
#  2449,
#  2452,
#  2470,
#  2484,
#  2500,
#  2506,
#  2518,
#  2522,
#  2540,
#  2576,
#  2594,
#  2598,
#  2606,
#  2612,
#  2617,
#  2622,
#  2631,
#  2644,
#  2674,
#  2690,
#  2692,
#  2722,
#  2724,
#  2741,
#  2750,
#  2755,
#  2764,
#  2766,
#  2828,
#  2831,
#  2832,
#  2836,
#  2842,
#  2848,
#  2872,
#  2878,
#  2916,
#  2920,
#  2951,
#  2960,
#  2971,
#  2973,
#  2987,
#  2999,
#  3030,
#  3035,
#  3048,
#  3056,
#  3060,
#  3084,
#  3093,
#  3126,
#  3130,
#  3148,
#  3175,
#  3180,
#  3188,
#  3194,
#  3208,
#  3216,
#  3224,
#  3226,
#  3229,
#  3234,
#  3245,
#  3256,
#  3265,
#  3272,
#  3274,
#  3282,
#  3283,
#  3333,
#  3334,
#  3347,
#  3351,
#  3352,
#  3381,
#  3386,
#  3397,
#  3398,
#  3404,
#  3411,
#  3426,
#  3429,
#  3444,
#  3450,
#  3472,
#  3486,
#  3498,
#  3506,
#  3509,
#  3514,
#  3530,
#  3538,
#  3546,
#  3557,
#  3560,
#  3561,
#  3564,
#  3566,
#  3571,
#  3573,
#  3576,
#  3596,
#  3616,
#  3628,
#  3642,
#  3648,
#  3670,
#  3671,
#  3682,
#  3702,
#  3704,
#  3745,
#  3753,
#  3794,
#  3800,
#  3804,
#  3808,
#  3832,
#  3854,
#  3865,
#  3867,
#  3888,
#  3897,
#  3904,
#  3908,
#  3914,
#  3936]

# %%
filtered_statements_true
# Out:
# [[('returnstatement',
#    'return ( insertions . size () > 0 || ! unresolvedInsertions . isEmpty () || deletions . size () > 0 );',
#    tensor(0.0590, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean areInsertionsOrDeletionsQueued () {',
#    tensor(0.1059, dtype=torch.float64))],
#  [('returnstatement',
#    'return Lists . transform ( type . getFieldList (), GET _ TYPE );',
#    tensor(0.0479, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static List < RelDataType > getFieldTypeList ( final RelDataType type ) {',
#    tensor(0.0580, dtype=torch.float64))],
#  [('returnstatement',
#    'return Float . valueOf ( getOptional (" kylin . hbase . region . cut ", " 5 . 0 "));',
#    tensor(0.0979, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public float getKylinHBaseRegionCut () {',
#    tensor(0.0519, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( txtSkipURL == null ) {',
#    tensor(0.0103, dtype=torch.float64)),
#   ('ifstatement',
#    'if ( Model . getSingleton (). getOptionsParam (). getViewParam (). getWmUiHandlingOption () == 0 ) {',
#    tensor(-0.0152, dtype=torch.float64)),
#   ('variableDeclaration',
#    'txtSkipURL = new ZapTextArea ();',
#    tensor(0.0419, dtype=torch.float64)),
#   ('variableDeclaration',
#    'txtSkipURL . setFont ( new java . awt . Font (" Default ", java . awt . Font . PLAIN , 11 ));',
#    tensor(-0.0112, dtype=torch.float64)),
#   ('variableDeclaration',
#    'txtSkipURL . setSize ( new java . awt . Dimension ( 290 , 52 ));',
#    tensor(-0.0028, dtype=torch.float64)),
#   ('expression',
#    'if ( txtSkipURL == null ) {',
#    tensor(0.0103, dtype=torch.float64)),
#   ('expression',
#    'txtSkipURL = new ZapTextArea ();',
#    tensor(0.0419, dtype=torch.float64)),
#   ('expression',
#    'if ( Model . getSingleton (). getOptionsParam (). getViewParam (). getWmUiHandlingOption () == 0 ) {',
#    tensor(-0.0152, dtype=torch.float64)),
#   ('returnstatement',
#    'return txtSkipURL ;',
#    tensor(-0.0457, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private ZapTextArea getTxtSkipURL () {',
#    tensor(-0.0554, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return addRow ( new Object [] { value });',
#    tensor(-0.1363, dtype=torch.float64)),
#   ('returnstatement',
#    'return addRow ( new Object [] { value });',
#    tensor(-0.1363, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public RowSetBuilder addSingleCol ( Object value ) {',
#    tensor(-0.1104, dtype=torch.float64))],
#  [('returnstatement',
#    'return m _ node2 ;',
#    tensor(-0.1638, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Node getSecondNode () {',
#    tensor(-0.0897, dtype=torch.float64))],
#  [('returnstatement',
#    'return viewFetcher . getCurrentViews ( RadioButton . class );',
#    tensor(-0.0678, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ArrayList < RadioButton > getCurrentRadioButtons () {',
#    tensor(-0.0884, dtype=torch.float64))],
#  [('returnstatement',
#    'return totalBytesServerReceived ;',
#    tensor(0.1468, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Deprecated', tensor(0.4687, dtype=torch.float64))],
#  [('returnstatement',
#    'return createFeatureService ( defaultEndpointUrl );',
#    tensor(0.0364, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public FeatureService createFeatureService () {',
#    tensor(0.0370, dtype=torch.float64))],
#  [('returnstatement',
#    'return service . findAll ();',
#    tensor(0.0610, dtype=torch.float64)),
#   ('MethodDeclaration', '@ GET', tensor(0.1201, dtype=torch.float64))],
#  [('returnstatement', 'return null ;', tensor(0.0960, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Element writeSchema ( Class javaType , Types types ) throws Exception {',
#    tensor(0.0939, dtype=torch.float64))],
#  [('returnstatement',
#    'return JSON . writeValueAsString ( object );',
#    tensor(0.0903, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static String asJson ( Object object ) throws IOException {',
#    tensor(0.1465, dtype=torch.float64))],
#  [('returnstatement',
#    'return Bitmap . createBitmap (',
#    tensor(0.0423, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(0.0560, dtype=torch.float64))],
#  [('expression',
#    'return getPrefetchSize () == 0 ? prefetchExtension . get () == 0 : dispatched . size () - prefetchExtension . get () >= info . getPrefetchSize ();',
#    tensor(0.0912, dtype=torch.float64)),
#   ('returnstatement',
#    'return getPrefetchSize () == 0 ? prefetchExtension . get () == 0 : dispatched . size () - prefetchExtension . get () >= info . getPrefetchSize ();',
#    tensor(0.0912, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean isFull () {',
#    tensor(0.0494, dtype=torch.float64))],
#  [('returnstatement',
#    'return InternalUtils . symbol ( node );',
#    tensor(0.0545, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static final Element elementFromUse ( ExpressionTree node ) {',
#    tensor(0.0907, dtype=torch.float64))],
#  [('returnstatement',
#    'return fromLogical ( schema , value . getDecimalValue (). orElse ( null ));',
#    tensor(0.0749, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Struct fromLogical ( Schema schema , SpecialValueDecimal value ) {',
#    tensor(0.1133, dtype=torch.float64))],
#  [('returnstatement', 'return method ;', tensor(0.2402, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Method getMethod () {',
#    tensor(0.2737, dtype=torch.float64))],
#  [('returnstatement', 'return label ;', tensor(-0.0627, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public CyclicCoreLabel label () {',
#    tensor(-0.2132, dtype=torch.float64))],
#  [('returnstatement',
#    'return PredicateOperation . create ( Ops . IS _ NOT _ NULL , left );',
#    tensor(0.0708, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Predicate isNotNull ( Expression <?> left ) {',
#    tensor(0.0537, dtype=torch.float64))],
#  [('returnstatement',
#    'return "[" + name + " " + state + "]";',
#    tensor(0.0502, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(0.8518, dtype=torch.float64))],
#  [('returnstatement',
#    'return createSequenceService ( defaultEndpointUrl );',
#    tensor(0.0371, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public SequenceService createSequenceService () {',
#    tensor(0.1486, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new Stream < T >( new RepeatingObjectIterator < T >( object ), null ) ;',
#    tensor(0.0720, dtype=torch.float64)),
#   ('returnstatement',
#    'return new Stream < T >( new RepeatingObjectIterator < T >( object ), null ) ;',
#    tensor(0.0720, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static < T > Stream < T > from ( T object ) {',
#    tensor(0.1230, dtype=torch.float64))],
#  [('returnstatement',
#    'return withAttributes . getAttributes (). get ( this );',
#    tensor(0.0853, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public char get ( WithAttributes withAttributes ) {',
#    tensor(0.1585, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new ColorPaintContext ( getRGB (), cm );',
#    tensor(0.0461, dtype=torch.float64)),
#   ('returnstatement',
#    'return new ColorPaintContext ( getRGB (), cm );',
#    tensor(0.0461, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public synchronized PaintContext createContext ( ColorModel cm , Rectangle r ,',
#    tensor(0.0379, dtype=torch.float64))],
#  [('returnstatement',
#    'return SimpleReaderBuilder . build ( container (), schema , rowIndex );',
#    tensor(0.0892, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected RowSetReader buildReader ( ReaderIndex rowIndex ) {',
#    tensor(0.0775, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return matcher ( t , t , null , new HashMap < String , Tree >(), new VariableStrings ());',
#    tensor(0.0672, dtype=torch.float64)),
#   ('returnstatement',
#    'return matcher ( t , t , null , new HashMap < String , Tree >(), new VariableStrings ());',
#    tensor(0.0672, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public TregexMatcher matcher ( Tree t ) {',
#    tensor(0.0515, dtype=torch.float64))],
#  [('trystatement', 'try {', tensor(0.0287, dtype=torch.float64)),
#   ('returnstatement',
#    'return toString (- 1 );',
#    tensor(0.1709, dtype=torch.float64)),
#   ('returnstatement', 'return null ;', tensor(0.1237, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public String toString () {',
#    tensor(0.0754, dtype=torch.float64))],
#  [('expression',
#    'ComponentType compType = factory . createComponentType ();',
#    tensor(0.0154, dtype=torch.float64)),
#   ('returnstatement',
#    'return introspect ( implClass , compType );',
#    tensor(0.0426, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ComponentType introspect ( Class <?> implClass ) throws ConfigurationLoadException {',
#    tensor(0.0638, dtype=torch.float64))],
#  [('returnstatement', 'return entity ;', tensor(-0.1595, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public final Entity getEntity () {',
#    tensor(-0.3120, dtype=torch.float64))],
#  [('expression',
#    'return mode == Mode . PARTITION ? window . isClosedForPartition () : window . isClosed ();',
#    tensor(-0.0431, dtype=torch.float64)),
#   ('returnstatement',
#    'return mode == Mode . PARTITION ? window . isClosedForPartition () : window . isClosed ();',
#    tensor(-0.0431, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(-0.5555, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new CnfHelper ( rexBuilder , - 1 ). pull ( node );',
#    tensor(0.0494, dtype=torch.float64)),
#   ('returnstatement',
#    'return new CnfHelper ( rexBuilder , - 1 ). pull ( node );',
#    tensor(0.0494, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static RexNode pullFactors ( RexBuilder rexBuilder , RexNode node ) {',
#    tensor(0.0453, dtype=torch.float64))],
#  [('returnstatement',
#    'return inspector ;',
#    tensor(0.2561, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public VariableInspector variableInspector () {',
#    tensor(0.1484, dtype=torch.float64))],
#  [('returnstatement',
#    'return put ( value , false );',
#    tensor(0.1768, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(0.7600, dtype=torch.float64))],
#  [('returnstatement', 'return null ;', tensor(0.0921, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public File getGeneratedOutput ()',
#    tensor(0.1068, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( txtReverseProxyHttpsPort == null ) {',
#    tensor(0.0245, dtype=torch.float64)),
#   ('variableDeclaration',
#    'txtReverseProxyHttpsPort = new ZapTextField ();',
#    tensor(0.0710, dtype=torch.float64)),
#   ('expression',
#    'if ( txtReverseProxyHttpsPort == null ) {',
#    tensor(0.0245, dtype=torch.float64)),
#   ('expression',
#    'txtReverseProxyHttpsPort = new ZapTextField ();',
#    tensor(0.0710, dtype=torch.float64)),
#   ('returnstatement',
#    'return txtReverseProxyHttpsPort ;',
#    tensor(0.0781, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private ZapTextField getTxtReverseProxyHttpsPort () {',
#    tensor(0.0951, dtype=torch.float64))],
#  [('returnstatement',
#    'return mutableDirectBuffer ;',
#    tensor(-0.0998, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public MutableDirectBuffer buffer () {',
#    tensor(-0.1914, dtype=torch.float64))],
#  [('returnstatement',
#    'return this . parent ;',
#    tensor(-0.1310, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(-0.5919, dtype=torch.float64))],
#  [('returnstatement',
#    'return evictionConfig ;',
#    tensor(-0.0822, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public EvictionConfig getEvictionConfig () {',
#    tensor(-0.0630, dtype=torch.float64))],
#  [('returnstatement',
#    'return withAttributes . getAttributes (). get ( this );',
#    tensor(0.0625, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public float get ( WithAttributes withAttributes ) {',
#    tensor(0.1005, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new Insets ( 0 , 0 , 0 , 0 );',
#    tensor(-0.0382, dtype=torch.float64)),
#   ('returnstatement',
#    'return new Insets ( 0 , 0 , 0 , 0 );',
#    tensor(-0.0382, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Insets getBorderInsets ( Component c ) {',
#    tensor(-0.1141, dtype=torch.float64))],
#  [('expression',
#    'Object value = literal . getValue2 ();',
#    tensor(0.1297, dtype=torch.float64)),
#   ('returnstatement',
#    'return String . valueOf ( value );',
#    tensor(0.0614, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private static String literalValue ( RexLiteral literal ) {',
#    tensor(0.0359, dtype=torch.float64))],
#  [('returnstatement', 'return owner ;', tensor(0.0535, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public User getOwner () {',
#    tensor(0.1949, dtype=torch.float64))],
#  [('returnstatement',
#    'return rightValue ;',
#    tensor(0.0560, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Float getRightValue () {',
#    tensor(0.0528, dtype=torch.float64))],
#  [('returnstatement',
#    'return mSmsCbMessage . isEmergencyMessage ();',
#    tensor(0.0874, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean isEmergencyAlertMessage () {',
#    tensor(0.0535, dtype=torch.float64))],
#  [('returnstatement',
#    'return ensureArrayListOrNull ( viewFetcher . getCurrentViews ( CheckBox . class ));',
#    tensor(0.0477, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ArrayList < CheckBox > getCurrentCheckBoxes () {',
#    tensor(0.0435, dtype=torch.float64))],
#  [('returnstatement',
#    'return PredicateOperation . create ( Ops . AND , left , right );',
#    tensor(0.0537, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Predicate and ( Predicate left , Predicate right ){',
#    tensor(0.0517, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( null != ostatus && ! RealizationStatusEnum . READY . equals ( ostatus )) {',
#    tensor(0.0005, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new BadRequestException ( String . format ( msg . getDISABLE _ NOT _ READY _ CUBE (), cubeName , ostatus ));',
#    tensor(inf, dtype=torch.float64)),
#   ('expression',
#    'Message msg = MsgPicker . getMsg ();',
#    tensor(0.0130, dtype=torch.float64)),
#   ('expression',
#    'String cubeName = cube . getName ();',
#    tensor(-0.0004, dtype=torch.float64)),
#   ('expression',
#    'RealizationStatusEnum ostatus = cube . getStatus ();',
#    tensor(-0.0039, dtype=torch.float64)),
#   ('expression',
#    'if ( null != ostatus && ! RealizationStatusEnum . READY . equals ( ostatus )) {',
#    tensor(0.0005, dtype=torch.float64)),
#   ('returnstatement',
#    'return getCubeManager (). updateCubeStatus ( cube , RealizationStatusEnum . DISABLED );',
#    tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public CubeInstance disableCube ( CubeInstance cube ) throws IOException {',
#    tensor(0.0754, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( instance != null ) {',
#    tensor(0.0525, dtype=torch.float64)),
#   ('expression',
#    'Jenkins instance = Jenkins . getInstance ();',
#    tensor(0.0537, dtype=torch.float64)),
#   ('expression',
#    'if ( instance != null ) {',
#    tensor(0.0525, dtype=torch.float64)),
#   ('returnstatement',
#    'return ( ScalewayCloud ) instance . getCloud ( cloudName );',
#    tensor(0.0535, dtype=torch.float64)),
#   ('returnstatement', 'return null ;', tensor(0.0415, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ScalewayCloud getCloud () {',
#    tensor(0.0888, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( action != null ) {',
#    tensor(0.0480, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new NoSuchElementException (" No previous result available ");',
#    tensor(0.1082, dtype=torch.float64)),
#   ('expression',
#    'ResultAction <? extends BuildResult > action = getPreviousAction ();',
#    tensor(0.0449, dtype=torch.float64)),
#   ('expression',
#    'if ( action != null ) {',
#    tensor(0.0480, dtype=torch.float64)),
#   ('returnstatement',
#    'return action . getResult ();',
#    tensor(0.0906, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public BuildResult getPreviousResult () {',
#    tensor(0.0883, dtype=torch.float64))],
#  [('returnstatement',
#    'return ( EReference ) topicEClass . getEStructuralFeatures (). get ( 1 );',
#    tensor(0.0463, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public EReference getTopic _ Comments () {',
#    tensor(0.2436, dtype=torch.float64))],
#  [('returnstatement',
#    'return addPropertiesToURI ( uri . toString (), properties );',
#    tensor(-0.0567, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static String addPropertiesToURI ( URI uri , Map < String , String > properties ) throws Exception {',
#    tensor(-0.0382, dtype=torch.float64))],
#  [('returnstatement',
#    'return copyXmlIds ()? null : EcoreUtil . generateUUID ();',
#    tensor(0.0622, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected String getNewIdFor ( EObject element _ p ) {',
#    tensor(0.1340, dtype=torch.float64))],
#  [('returnstatement',
#    'return sessionFactory ;',
#    tensor(0.0983, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public SessionFactoryImpl getEntityManagerFactory () {',
#    tensor(0.0422, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new Command <>(',
#    tensor(0.0367, dtype=torch.float64)),
#   ('variableDeclaration',
#    'map (" cookies ", new TypeToken < List < Cookie >>() {}. getType ()));',
#    tensor(0.0290, dtype=torch.float64)),
#   ('returnstatement',
#    'return new Command <>(',
#    tensor(0.0367, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Command < List < Cookie >> getAllCookies () {',
#    tensor(0.0554, dtype=torch.float64))],
#  [('returnstatement',
#    'return currentPosition ;',
#    tensor(-0.0425, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public int getPosition () {',
#    tensor(-0.0619, dtype=torch.float64))],
#  [('returnstatement',
#    'return this . of . filter ( key );',
#    tensor(-0.0954, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ArrayList filterContent ( String key ) {',
#    tensor(-0.1651, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( enumNumber == null ) {',
#    tensor(-0.0797, dtype=torch.float64)),
#   ('expression',
#    'if ( enumNumber == null ) {',
#    tensor(-0.0797, dtype=torch.float64)),
#   ('returnstatement', 'return null ;', tensor(-0.0490, dtype=torch.float64)),
#   ('returnstatement',
#    'return enumNumber . value ();',
#    tensor(-0.1965, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Double getEnumNumber () {',
#    tensor(-0.0643, dtype=torch.float64))],
#  [('returnstatement',
#    'return bodyParams ;',
#    tensor(-0.0634, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ParameterList getBodyParams ()',
#    tensor(-0.1476, dtype=torch.float64))],
#  [('returnstatement',
#    'return sync . tryReadLock ();',
#    tensor(0.0980, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean tryLock () {',
#    tensor(0.0692, dtype=torch.float64))],
#  [('returnstatement', 'return job ;', tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public final Job <?, ?> getProject () {',
#    tensor(0.0602, dtype=torch.float64))],
#  [('returnstatement',
#    'return createVariationService ( defaultEndpointUrl );',
#    tensor(0.0576, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public VariationService createVariationService () {',
#    tensor(0.1804, dtype=torch.float64))],
#  [('returnstatement',
#    'return setCopy ( text , null );',
#    tensor(0.0906, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public TimeOfDay setCopy ( String text ) {',
#    tensor(0.0386, dtype=torch.float64))],
#  [('variableDeclaration',
#    'throw new InternalErrorException ( e );',
#    tensor(-0.0005, dtype=torch.float64)),
#   ('expression',
#    'final JobInstance jobInstance = jobService . getJobInstance ( jobId );',
#    tensor(0.0204, dtype=torch.float64)),
#   ('trystatement', 'try {', tensor(0.0505, dtype=torch.float64)),
#   ('returnstatement',
#    'return jobService . getJobInstance ( jobId );',
#    tensor(0.0484, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public JobInstance cancel (@ PathVariable String jobId ) {',
#    tensor(0.0909, dtype=torch.float64))],
#  [('returnstatement',
#    'return this . groups ;',
#    tensor(0.0780, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'final public Map getGroups () {',
#    tensor(0.0474, dtype=torch.float64))],
#  [('returnstatement',
#    'return bottomValue ;',
#    tensor(-0.0583, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Float getBottomValue () {',
#    tensor(-0.1423, dtype=torch.float64))],
#  [('returnstatement',
#    'return this . a _ href _ all ;',
#    tensor(-0.1307, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ArrayList getAllAHRefs () {',
#    tensor(-0.1110, dtype=torch.float64))],
#  [('returnstatement',
#    'return this . fullName ;',
#    tensor(0.0697, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public String getName () {',
#    tensor(0.1510, dtype=torch.float64))],
#  [('returnstatement',
#    'return ( JtdsConnection ) statement . getConnection ();',
#    tensor(0.1101, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private JtdsConnection getConnection () throws SQLException {',
#    tensor(0.0742, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( txtProxyPort == null ) {',
#    tensor(0.0237, dtype=torch.float64)),
#   ('variableDeclaration',
#    'txtProxyPort = new ZapTextField ();',
#    tensor(0.0413, dtype=torch.float64)),
#   ('expression',
#    'if ( txtProxyPort == null ) {',
#    tensor(0.0237, dtype=torch.float64)),
#   ('expression',
#    'txtProxyPort = new ZapTextField ();',
#    tensor(0.0413, dtype=torch.float64)),
#   ('returnstatement',
#    'return txtProxyPort ;',
#    tensor(0.0357, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private ZapTextField getTxtProxyPort () {',
#    tensor(0.0558, dtype=torch.float64))],
#  [('variableDeclaration',
#    'ParameterList result = new ParameterList ();',
#    tensor(0.0453, dtype=torch.float64)),
#   ('variableDeclaration',
#    'String queryString = new URL ( url ). getQuery ();',
#    tensor(0.0370, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new OAuthException (" Malformed URL ", mue );',
#    tensor(0.0531, dtype=torch.float64)),
#   ('expression',
#    'ParameterList result = new ParameterList ();',
#    tensor(0.0453, dtype=torch.float64)),
#   ('expression',
#    'String queryString = new URL ( url ). getQuery ();',
#    tensor(0.0370, dtype=torch.float64)),
#   ('trystatement', 'try', tensor(inf, dtype=torch.float64)),
#   ('returnstatement', 'return result ;', tensor(0.0598, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ParameterList getQueryStringParams ()',
#    tensor(0.0860, dtype=torch.float64))],
#  [('returnstatement', 'return job ;', tensor(-inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Job <?, ?> getOwner () {',
#    tensor(-0.1151, dtype=torch.float64))],
#  [('returnstatement',
#    'return withAttributes . getAttributes (). get ( this );',
#    tensor(-0.0792, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean get ( WithAttributes withAttributes ) {',
#    tensor(-0.0387, dtype=torch.float64))],
#  [('whilestatement',
#    'throw new CertificateEncodingException (" Exception while encoding certificate : " + e . toString ());',
#    tensor(-0.0129, dtype=torch.float64)),
#   ('variableDeclaration',
#    'return new ASN1InputStream ( cert . getEncoded ()). readObject ();',
#    tensor(0.0440, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new CertificateEncodingException (" Exception while encoding certificate : " + e . toString ());',
#    tensor(-0.0129, dtype=torch.float64)),
#   ('trystatement', 'try', tensor(inf, dtype=torch.float64)),
#   ('returnstatement',
#    'return new ASN1InputStream ( cert . getEncoded ()). readObject ();',
#    tensor(0.0440, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private ASN1Object toASN1Object (',
#    tensor(0.0596, dtype=torch.float64))],
#  [('returnstatement',
#    'return ( ConnectionJDBC ) statement . getConnection ();',
#    tensor(0.1233, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private ConnectionJDBC getConnection () throws SQLException {',
#    tensor(0.1081, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( schema . getDefault () != null ) {',
#    tensor(0.0620, dtype=torch.float64)),
#   ('expression',
#    'if ( schema . getDefault () != null ) {',
#    tensor(0.0620, dtype=torch.float64)),
#   ('returnstatement',
#    'return schema . getDefault (). toString ();',
#    tensor(inf, dtype=torch.float64)),
#   ('returnstatement',
#    'return getPropertyDefaultValue ( schema );',
#    tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public String toDefaultValue ( Schema schema ) {',
#    tensor(0.0581, dtype=torch.float64))],
#  [('returnstatement',
#    'return LogicalAggregate . create ( rel ,',
#    tensor(0.0532, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static RelNode createDistinctRel ( RelNode rel ) {',
#    tensor(0.0492, dtype=torch.float64))],
#  [('returnstatement',
#    'return this . author ;',
#    tensor(-0.1124, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public String getAuthor () {',
#    tensor(-0.1873, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( activity != null )',
#    tensor(0.0495, dtype=torch.float64)),
#   ('whilestatement',
#    'while ( activityStackIterator . hasNext ()){',
#    tensor(0.0280, dtype=torch.float64)),
#   ('variableDeclaration',
#    'ArrayList < Activity > activities = new ArrayList < Activity >();',
#    tensor(0.0062, dtype=torch.float64)),
#   ('expression',
#    'ArrayList < Activity > activities = new ArrayList < Activity >();',
#    tensor(0.0062, dtype=torch.float64)),
#   ('expression',
#    'Iterator < WeakReference < Activity >> activityStackIterator = activityStack . iterator ();',
#    tensor(-0.0049, dtype=torch.float64)),
#   ('expression',
#    'Activity activity = activityStackIterator . next (). get ();',
#    tensor(0.0327, dtype=torch.float64)),
#   ('expression',
#    'if ( activity != null )',
#    tensor(0.0495, dtype=torch.float64)),
#   ('returnstatement',
#    'return activities ;',
#    tensor(-0.0888, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ArrayList < Activity > getAllOpenedActivities ()',
#    tensor(-0.0625, dtype=torch.float64))],
#  [('forstatement',
#    'for ( X x : this ) {',
#    tensor(0.0396, dtype=torch.float64)),
#   ('returnstatement', 'return visitor ;', tensor(0.1084, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public < V extends Visitor <? super X >> V visit ( V visitor )',
#    tensor(0.1264, dtype=torch.float64))],
#  [('returnstatement',
#    'return mVideoCallProvider ;',
#    tensor(0.0683, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public VideoCallProvider getVideoCallProvider () {',
#    tensor(0.1093, dtype=torch.float64))],
#  [('returnstatement', 'return error ;', tensor(0.1130, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public final FacebookException getError () {',
#    tensor(0.0661, dtype=torch.float64))],
#  [('returnstatement',
#    'return Material . getMaterial ( raw . toUpperCase ());',
#    tensor(-0.0433, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Material asMaterialFromName () {',
#    tensor(-0.0479, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( rollerInstance == null ) {',
#    tensor(0.0106, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new IllegalStateException (" Roller Weblogger has not been bootstrapped yet ");',
#    tensor(0.0646, dtype=torch.float64)),
#   ('expression',
#    'if ( rollerInstance == null ) {',
#    tensor(0.0106, dtype=torch.float64)),
#   ('returnstatement',
#    'return rollerInstance ;',
#    tensor(0.0359, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static final Weblogger getRoller () {',
#    tensor(0.0691, dtype=torch.float64))],
#  [('returnstatement',
#    'return ( Graph ) executeSparqlQuery (( Query ) query , defaultGraph );',
#    tensor(0.0628, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Deprecated', tensor(0.1721, dtype=torch.float64))],
#  [('expression',
#    'ApiResponse < Order > resp = placeOrderWithHttpInfo ( order );',
#    tensor(0.0785, dtype=torch.float64)),
#   ('returnstatement',
#    'return resp . getData ();',
#    tensor(0.0825, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Order placeOrder ( Order order ) throws ApiException {',
#    tensor(0.1093, dtype=torch.float64))],
#  [('expression',
#    'ApiResponse < OuterComposite > resp = fakeOuterCompositeSerializeWithHttpInfo ( outerComposite );',
#    tensor(0.0495, dtype=torch.float64)),
#   ('returnstatement',
#    'return resp . getData ();',
#    tensor(0.0719, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public OuterComposite fakeOuterCompositeSerialize ( OuterComposite outerComposite ) throws ApiException {',
#    tensor(0.1139, dtype=torch.float64))],
#  [('returnstatement',
#    'return filter ( all (),',
#    tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Iterable < ProviderMetadata <?, ?, ?, ?>> boundedByIso3166Code ( String iso3166Code , ApiType type ) {',
#    tensor(0.0439, dtype=torch.float64))],
#  [('variableDeclaration',
#    'BorrowedConnectionProxy handler = new BorrowedConnectionProxy ( logicalConnection );',
#    tensor(0.0269, dtype=torch.float64)),
#   ('expression',
#    'BorrowedConnectionProxy handler = new BorrowedConnectionProxy ( logicalConnection );',
#    tensor(0.0269, dtype=torch.float64)),
#   ('returnstatement',
#    'return ( Connection ) Proxy . newProxyInstance (',
#    tensor(0.0467, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Connection generateProxy ( LogicalConnectionImpl logicalConnection ) {',
#    tensor(0.0542, dtype=torch.float64))],
#  [('returnstatement',
#    'return ( ExecutableElement ) TreeInfo . symbol (( JCTree ) node . getMethodSelect ());',
#    tensor(0.0324, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static final ExecutableElement elementFromUse ( MethodInvocationTree node ) {',
#    tensor(0.1795, dtype=torch.float64))],
#  [('returnstatement',
#    'return brokerRequest ;',
#    tensor(-0.0460, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public BrokerRequest optimize ( BrokerRequest brokerRequest ) {',
#    tensor(-0.0479, dtype=torch.float64))],
#  [('returnstatement',
#    'return session . getFactory (). getMetamodel (). collectionPersister ( role );',
#    tensor(0.0590, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private CollectionPersister getPersister ( SharedSessionContractImplementor session ) {',
#    tensor(0.0575, dtype=torch.float64))],
#  [('expression',
#    'this . bitNames = bitNames ;',
#    tensor(0.0392, dtype=torch.float64)),
#   ('expression',
#    'bitCount = bitNames . length ;',
#    tensor(-0.0848, dtype=torch.float64)),
#   ('returnstatement', 'return this ;', tensor(0.0439, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ClusterFixtureBuilder withBits ( String ... bitNames ) {',
#    tensor(0.0363, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new CaseForEqBuilder < T >( this , new ConstantImpl < T >( other ));',
#    tensor(0.1002, dtype=torch.float64)),
#   ('returnstatement',
#    'return new CaseForEqBuilder < T >( this , new ConstantImpl < T >( other ));',
#    tensor(0.1002, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public CaseForEqBuilder < T > when ( T other ){',
#    tensor(0.0508, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( corRel != null ) {',
#    tensor(0.0627, dtype=torch.float64)),
#   ('variableDeclaration',
#    'cm = new CorelMapBuilder (). build ( Util . first ( root , corRel ));',
#    tensor(0.0479, dtype=torch.float64)),
#   ('expression', 'currentRel = corRel ;', tensor(0.0437, dtype=torch.float64)),
#   ('expression',
#    'if ( corRel != null ) {',
#    tensor(0.0627, dtype=torch.float64)),
#   ('expression',
#    'cm = new CorelMapBuilder (). build ( Util . first ( root , corRel ));',
#    tensor(0.0479, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private void setCurrent ( RelNode root , Correlate corRel ) {',
#    tensor(0.0548, dtype=torch.float64))],
#  [('expression',
#    'this . timeout = timeout ;',
#    tensor(0.0275, dtype=torch.float64)),
#   ('returnstatement', 'return this ;', tensor(0.0384, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public FluentWait < T > withTimeout ( Duration timeout ) {',
#    tensor(0.0527, dtype=torch.float64))],
#  [('returnstatement',
#    'return parse ( memberID , isClassMember , null );',
#    tensor(-0.1335, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static MemberID parse ( String memberID , boolean isClassMember ) {',
#    tensor(-0.0820, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new RestDownloadRequestor ( url , requestMethod , fileFolder , filename , isRange , isDeleteOld );',
#    tensor(0.0670, dtype=torch.float64)),
#   ('returnstatement',
#    'return new RestDownloadRequestor ( url , requestMethod , fileFolder , filename , isRange , isDeleteOld );',
#    tensor(0.0670, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static DownloadRequest createDownloadRequest ( String url , RequestMethod requestMethod , String fileFolder , String filename , boolean isRange , boolean isDeleteOld ) {',
#    tensor(0.0362, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( sendingXchgForCurrFrag != null ) {',
#    tensor(0.0137, dtype=torch.float64)),
#   ('ifstatement',
#    'if ( dependency == ParallelizationDependency . RECEIVER _ DEPENDS _ ON _ SENDER ) {',
#    tensor(0.0018, dtype=torch.float64)),
#   ('ifstatement',
#    '} else if ( dependency == ParallelizationDependency . SENDER _ DEPENDS _ ON _ RECEIVER ) {',
#    tensor(-0.0057, dtype=torch.float64)),
#   ('forstatement',
#    'for ( Wrapper currentFragment : planningSet ) {',
#    tensor(0.0124, dtype=torch.float64)),
#   ('forstatement',
#    '// for DeMux Exchanges where the Sender of the current fragment depends on the receiver of the parent fragment .',
#    tensor(0.0012, dtype=torch.float64)),
#   ('expression',
#    'ExchangeFragmentPair sendingXchgForCurrFrag = currentFragment . getNode (). getSendingExchangePair ();',
#    tensor(0.0121, dtype=torch.float64)),
#   ('expression',
#    'if ( sendingXchgForCurrFrag != null ) {',
#    tensor(0.0137, dtype=torch.float64)),
#   ('expression',
#    'ParallelizationDependency dependency = sendingXchgForCurrFrag . getExchange (). getParallelizationDependency ();',
#    tensor(0.0018, dtype=torch.float64)),
#   ('expression',
#    'Wrapper receivingFragmentWrapper = planningSet . get ( sendingXchgForCurrFrag . getNode ());',
#    tensor(0.0029, dtype=torch.float64)),
#   ('expression',
#    'if ( dependency == ParallelizationDependency . RECEIVER _ DEPENDS _ ON _ SENDER ) {',
#    tensor(0.0018, dtype=torch.float64)),
#   ('expression',
#    '} else if ( dependency == ParallelizationDependency . SENDER _ DEPENDS _ ON _ RECEIVER ) {',
#    tensor(-0.0057, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private void constructFragmentDependencyGraph ( Fragment rootFragment , PlanningSet planningSet ) {',
#    tensor(0.0597, dtype=torch.float64))],
#  [('returnstatement', 'return this ;', tensor(-0.0788, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Builder transformer ( SchemaGeneratorPostProcessing schemaGeneratorPostProcessing ) {',
#    tensor(-0.0518, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new Stream < T >( new RepeatingObjectIterator < T >( object ), null ) ;',
#    tensor(-0.0606, dtype=torch.float64)),
#   ('returnstatement',
#    'return new Stream < T >( new RepeatingObjectIterator < T >( object ), null ) ;',
#    tensor(-0.0606, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static < T > Stream < T > from ( T object ) {',
#    tensor(-0.1395, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new Stream < T >( new RepeatingObjectIterator < T >( object ), null ) ;',
#    tensor(0.1198, dtype=torch.float64)),
#   ('returnstatement',
#    'return new Stream < T >( new RepeatingObjectIterator < T >( object ), null ) ;',
#    tensor(0.1198, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static < T > Stream < T > from ( T object ) {',
#    tensor(0.0901, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( fieldType == null ) {',
#    tensor(0.0372, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new IllegalArgumentException (" Field type must not be null ");',
#    tensor(0.0215, dtype=torch.float64)),
#   ('variableDeclaration',
#    'return append0 ( new TextField ( iChrono , field , iLocale , true ));',
#    tensor(0.0521, dtype=torch.float64)),
#   ('expression',
#    'if ( fieldType == null ) {',
#    tensor(0.0372, dtype=torch.float64)),
#   ('expression',
#    'DateTimeField field = fieldType . getField ( iChronoUTC );',
#    tensor(0.0192, dtype=torch.float64)),
#   ('returnstatement',
#    'return append0 ( new TextField ( iChrono , field , iLocale , true ));',
#    tensor(0.0521, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public DateTimeFormatterBuilder appendShortText ( DateTimeFieldType fieldType ) {',
#    tensor(0.1116, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( scheme == null || (! scheme . equalsIgnoreCase (" http ") && ! scheme . equalsIgnoreCase (" https "))) {',
#    tensor(-0.0029, dtype=torch.float64)),
#   ('ifstatement',
#    'if ( maxChildren > 0 ) {',
#    tensor(-inf, dtype=torch.float64)),
#   ('variableDeclaration',
#    'startURI = new URI ( url , true );',
#    tensor(-0.0225, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new ApiException ( ApiException . Type . BAD _ FORMAT );',
#    tensor(-0.0104, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new ApiException ( ApiException . Type . BAD _ FORMAT );',
#    tensor(-inf, dtype=torch.float64)),
#   ('variableDeclaration',
#    'Target target = new Target ( startNode );',
#    tensor(-inf, dtype=torch.float64)),
#   ('variableDeclaration',
#    'MaxChildrenFetchFilter maxChildrenFetchFilter = new MaxChildrenFetchFilter ();',
#    tensor(-inf, dtype=torch.float64)),
#   ('variableDeclaration',
#    'MaxChildrenParseFilter maxChildrenParseFilter = new MaxChildrenParseFilter ();',
#    tensor(-inf, dtype=torch.float64)),
#   ('variableDeclaration',
#    'objs = new Object [] {',
#    tensor(-inf, dtype=torch.float64)),
#   ('expression',
#    'startURI = new URI ( url , true );',
#    tensor(-0.0225, dtype=torch.float64)),
#   ('expression',
#    'SiteNode startNode = Model . getSingleton (). getSession (). getSiteTree (). findNode ( startURI );',
#    tensor(-0.0053, dtype=torch.float64)),
#   ('expression',
#    'String scheme = startURI . getScheme ();',
#    tensor(-0.0009, dtype=torch.float64)),
#   ('expression',
#    'if ( scheme == null || (! scheme . equalsIgnoreCase (" http ") && ! scheme . equalsIgnoreCase (" https "))) {',
#    tensor(-0.0029, dtype=torch.float64)),
#   ('expression',
#    'Target target = new Target ( startNode );',
#    tensor(-inf, dtype=torch.float64)),
#   ('expression', 'Object [] objs = null ;', tensor(-inf, dtype=torch.float64)),
#   ('expression',
#    'MaxChildrenFetchFilter maxChildrenFetchFilter = new MaxChildrenFetchFilter ();',
#    tensor(-inf, dtype=torch.float64)),
#   ('expression',
#    'MaxChildrenParseFilter maxChildrenParseFilter = new MaxChildrenParseFilter ();',
#    tensor(-inf, dtype=torch.float64)),
#   ('expression', 'objs = new Object [] {', tensor(-inf, dtype=torch.float64)),
#   ('trystatement', 'try {', tensor(-0.0396, dtype=torch.float64)),
#   ('returnstatement',
#    'return extension . startScan ( target . getDisplayName (), target , user , objs );',
#    tensor(-inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private int scanURL ( String url , User user , int maxChildren ) throws ApiException {',
#    tensor(-0.0438, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return writeImportList ( out , ( String []) imports . toArray ( new String [ 0 ]));',
#    tensor(-0.0396, dtype=torch.float64)),
#   ('returnstatement',
#    'return writeImportList ( out , ( String []) imports . toArray ( new String [ 0 ]));',
#    tensor(-0.0396, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected int writeImportList ( PrintWriter out , List < String > imports ) {',
#    tensor(-0.0452, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new FilePendingMessageCursor ( name , tmpStorage );',
#    tensor(0.0989, dtype=torch.float64)),
#   ('returnstatement',
#    'return new FilePendingMessageCursor ( name , tmpStorage );',
#    tensor(0.0989, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public PendingMessageCursor getSubscriberPendingMessageCursor ( String clientId , String name , Store tmpStorage , int maxBatchSize , Subscription sub ) {',
#    tensor(0.0381, dtype=torch.float64))],
#  [('returnstatement',
#    'return snapshot ( null , version );',
#    tensor(0.0444, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public CalciteSchema createSnapshot ( SchemaVersion version ) {',
#    tensor(0.0505, dtype=torch.float64))],
#  [('MethodDeclaration',
#    'public void setInto ( ReadWritablePeriod duration , Object object ) {',
#    tensor(0.0515, dtype=torch.float64))],
#  [('returnstatement',
#    'return itemCollection . contains ( item . toLowerCase ());',
#    tensor(-0.0571, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private static boolean containsItem ( Collection < String > itemCollection , String item ) {',
#    tensor(-0.0814, dtype=torch.float64))],
#  [('returnstatement',
#    'return setCopy ( text , null );',
#    tensor(0.0966, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public TimeOfDay setCopy ( String text ) {',
#    tensor(0.0371, dtype=torch.float64))],
#  [('expression',
#    'ApiResponse < Client > resp = call123testSpecialTagsWithHttpInfo ( body );',
#    tensor(-0.0563, dtype=torch.float64)),
#   ('returnstatement',
#    'return resp . getData ();',
#    tensor(-0.0433, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Client call123testSpecialTags ( Client body ) throws ApiException {',
#    tensor(-0.0441, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( entCfg == null ) {',
#    tensor(0.0763, dtype=torch.float64)),
#   ('variableDeclaration',
#    'return new EntityInfo ( entityClass , entityName , isRelationAudited );',
#    tensor(0.0365, dtype=torch.float64)),
#   ('expression',
#    'EntityConfiguration entCfg = enversService . getEntitiesConfigurations (). get ( entityName );',
#    tensor(0.0112, dtype=torch.float64)),
#   ('expression',
#    'boolean isRelationAudited = true ;',
#    tensor(0.0264, dtype=torch.float64)),
#   ('expression',
#    'if ( entCfg == null ) {',
#    tensor(0.0763, dtype=torch.float64)),
#   ('expression',
#    'entCfg = enversService . getEntitiesConfigurations (). getNotVersionEntityConfiguration ( entityName );',
#    tensor(0.0329, dtype=torch.float64)),
#   ('expression',
#    'isRelationAudited = false ;',
#    tensor(0.0455, dtype=torch.float64)),
#   ('expression',
#    'final Class entityClass = ReflectionTools . loadClass ( entCfg . getEntityClassName (), enversService . getClassLoaderService () );',
#    tensor(0.0217, dtype=torch.float64)),
#   ('returnstatement',
#    'return new EntityInfo ( entityClass , entityName , isRelationAudited );',
#    tensor(0.0365, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected EntityInfo getEntityInfo ( EnversService enversService , String entityName ) {',
#    tensor(0.0832, dtype=torch.float64))],
#  [('returnstatement',
#    'return add ( instant , years );',
#    tensor(-0.1878, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public long addWrapped ( long instant , int years ) {',
#    tensor(-0.1039, dtype=torch.float64))],
#  [('returnstatement',
#    'return filter ( all (),',
#    tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Iterable < ProviderMetadata <?, ?, ?, ?>> collocatedWith ( ProviderMetadata <?, ?, ?, ?> providerMetadata ,',
#    tensor(0.0566, dtype=torch.float64))],
#  [('variableDeclaration',
#    'java . util . List < Pair > queryParams = new java . util . ArrayList < Pair >();',
#    tensor(0.0058, dtype=torch.float64)),
#   ('variableDeclaration',
#    'java . util . Map < String , String > headerParams = new java . util . HashMap < String , String >();',
#    tensor(0.0038, dtype=torch.float64)),
#   ('variableDeclaration',
#    'java . util . Map < String , Object > formParams = new java . util . HashMap < String , Object >();',
#    tensor(-0.0015, dtype=torch.float64)),
#   ('variableDeclaration',
#    'String [] authNames = new String [] { };',
#    tensor(-0.0110, dtype=torch.float64)),
#   ('expression',
#    'Object postBody = body ;',
#    tensor(0.0014, dtype=torch.float64)),
#   ('expression',
#    'byte [] postBinaryBody = null ;',
#    tensor(0.0229, dtype=torch.float64)),
#   ('expression',
#    'String path = "/ user / createWithList ". replaceAll ("\\\\{ format\\\\}"," json ");',
#    tensor(0.0065, dtype=torch.float64)),
#   ('expression',
#    'java . util . List < Pair > queryParams = new java . util . ArrayList < Pair >();',
#    tensor(0.0058, dtype=torch.float64)),
#   ('expression',
#    'java . util . Map < String , String > headerParams = new java . util . HashMap < String , String >();',
#    tensor(0.0038, dtype=torch.float64)),
#   ('expression',
#    'java . util . Map < String , Object > formParams = new java . util . HashMap < String , Object >();',
#    tensor(-0.0015, dtype=torch.float64)),
#   ('expression',
#    'final String [] accepts = {',
#    tensor(-0.0037, dtype=torch.float64)),
#   ('expression',
#    'final String accept = apiClient . selectHeaderAccept ( accepts );',
#    tensor(-0.0010, dtype=torch.float64)),
#   ('expression',
#    'final String [] contentTypes = {',
#    tensor(-0.0004, dtype=torch.float64)),
#   ('expression',
#    'final String contentType = apiClient . selectHeaderContentType ( contentTypes );',
#    tensor(-0.0018, dtype=torch.float64)),
#   ('expression',
#    'String [] authNames = new String [] { };',
#    tensor(-0.0110, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public void createUsersWithListInput ( java . util . List < User > body ) throws ApiException {',
#    tensor(0.0448, dtype=torch.float64))],
#  [('expression',
#    'boolean found = searcher . searchWithTimeoutFor ( Button . class , regex , expectedMinimumNumberOfMatches , true );',
#    tensor(-0.0491, dtype=torch.float64)),
#   ('returnstatement', 'return found ;', tensor(-0.0477, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean searchButton ( String regex , int expectedMinimumNumberOfMatches ) {',
#    tensor(-0.0658, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( itemComposition == null || itemComposition . getName () == null || (! allowNote && itemComposition . getNote () != - 1 ))',
#    tensor(0.0450, dtype=torch.float64)),
#   ('expression',
#    'ItemComposition itemComposition = getItemComposition ( itemId );',
#    tensor(0.0221, dtype=torch.float64)),
#   ('expression',
#    'if ( itemComposition == null || itemComposition . getName () == null || (! allowNote && itemComposition . getNote () != - 1 ))',
#    tensor(0.0450, dtype=torch.float64)),
#   ('returnstatement', 'return null ;', tensor(inf, dtype=torch.float64)),
#   ('returnstatement',
#    'return itemStats . get ( canonicalize ( itemId ));',
#    tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ItemStats getItemStats ( int itemId , boolean allowNote )',
#    tensor(0.0390, dtype=torch.float64))],
#  [('returnstatement',
#    'return shouldDelayIdentityInserts ( requiresImmediateIdAccess , isPartOfTransaction ( source ), source . getHibernateFlushMode (), persister );',
#    tensor(0.0533, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private static boolean shouldDelayIdentityInserts ( boolean requiresImmediateIdAccess , EventSource source , EntityPersister persister ) {',
#    tensor(0.0389, dtype=torch.float64))],
#  [('returnstatement',
#    'return super . isValid ( litmus , context )',
#    tensor(0.0355, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean isValid ( Litmus litmus , Context context ) {',
#    tensor(0.0373, dtype=torch.float64))],
#  [('returnstatement',
#    'return soloClick . clickInList ( line , listIndex );',
#    tensor(0.0434, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ArrayList < TextView > clickInList ( int line , int listIndex ) {',
#    tensor(0.0405, dtype=torch.float64))],
#  [('returnstatement',
#    'return super . get ( instant ) + iOffset ;',
#    tensor(-0.0415, dtype=torch.float64)),
#   ('MethodDeclaration',
# ...
#    tensor(0.1004, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Deprecated', tensor(0.9122, dtype=torch.float64))],
#  [('returnstatement',
#    'return Math . toDegrees ( mOrientation . getRotationX ());',
#    tensor(0.1188, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public double getRotX () {',
#    tensor(0.0762, dtype=torch.float64))],
#  [('returnstatement',
#    'return type . isEntityType () && ( ( EntityType ) type ). isLogicalOneToOne ();',
#    tensor(-0.0514, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private boolean isLogicalOneToOne ( Type type ) {',
#    tensor(-0.0437, dtype=torch.float64))],
#  [('expression',
#    'return mode == Mode . PARTITION ? window . isClosedForPartition () : window . isClosed ();',
#    tensor(0.0509, dtype=torch.float64)),
#   ('returnstatement',
#    'return mode == Mode . PARTITION ? window . isClosedForPartition () : window . isClosed ();',
#    tensor(0.0509, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(1.1090, dtype=torch.float64))],
#  [('returnstatement', 'return false ;', tensor(-0.0602, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean isAggregator () {',
#    tensor(-0.0402, dtype=torch.float64))],
#  [('returnstatement',
#    'return keyToAdapterCache ;',
#    tensor(-0.0951, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected Map < Object , ComponentAdapter <?>> getComponentKeyToAdapterCache () {',
#    tensor(-0.0814, dtype=torch.float64))],
#  [('returnstatement',
#    'return defaultValueGenerator . get ();',
#    tensor(-0.0345, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Object defaultValue () {',
#    tensor(-0.1680, dtype=torch.float64))],
#  [('returnstatement',
#    'return getValue ();',
#    tensor(-0.1161, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Deprecated', tensor(-0.8550, dtype=torch.float64))],
#  [('returnstatement',
#    'return ( ConnectionJDBC ) statement . getConnection ();',
#    tensor(0.0538, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private ConnectionJDBC getConnection () throws SQLException {',
#    tensor(0.1181, dtype=torch.float64))],
#  [('returnstatement', 'return usage ;', tensor(0.3702, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Double getUsage () {',
#    tensor(0.0658, dtype=torch.float64))],
#  [('returnstatement',
#    'return m _ ps . getServiceReference ();',
#    tensor(-0.1675, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public ServiceReference getServiceReference () {',
#    tensor(-0.1006, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( call . getAlias () != null ) {',
#    tensor(0.0091, dtype=torch.float64)),
#   ('variableDeclaration',
#    'final SqlNodeList selectList = new SqlNodeList ( SqlParserPos . ZERO );',
#    tensor(0.0174, dtype=torch.float64)),
#   ('variableDeclaration',
#    'return new SqlSelect ( SqlParserPos . ZERO , null , selectList , sourceTable ,',
#    tensor(inf, dtype=torch.float64)),
#   ('expression',
#    'final SqlNodeList selectList = new SqlNodeList ( SqlParserPos . ZERO );',
#    tensor(0.0174, dtype=torch.float64)),
#   ('expression',
#    'SqlNode sourceTable = call . getTargetTable ();',
#    tensor(0.0225, dtype=torch.float64)),
#   ('expression',
#    'if ( call . getAlias () != null ) {',
#    tensor(0.0091, dtype=torch.float64)),
#   ('expression', 'sourceTable =', tensor(inf, dtype=torch.float64)),
#   ('returnstatement',
#    'return new SqlSelect ( SqlParserPos . ZERO , null , selectList , sourceTable ,',
#    tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected SqlSelect createSourceSelectForDelete ( SqlDelete call ) {',
#    tensor(0.0427, dtype=torch.float64))],
#  [('returnstatement', 'return null ;', tensor(0.0416, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public T caseCustomersType ( CustomersType object ) {',
#    tensor(0.1380, dtype=torch.float64))],
#  [('forstatement',
#    'for ( X x : this ) {',
#    tensor(-0.0051, dtype=torch.float64)),
#   ('returnstatement', 'return visitor ;', tensor(0.1268, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public < V extends Visitor <? super X >> V visit ( V visitor ) {',
#    tensor(0.1509, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( rollerInstance == null ) {',
#    tensor(0.0734, dtype=torch.float64)),
#   ('variableDeclaration',
#    'throw new IllegalStateException ( STR );',
#    tensor(0.1854, dtype=torch.float64)),
#   ('expression',
#    'if ( rollerInstance == null ) {',
#    tensor(0.0734, dtype=torch.float64)),
#   ('returnstatement',
#    'return rollerInstance ;',
#    tensor(0.0559, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static final Weblogger getRoller () {',
#    tensor(0.0558, dtype=torch.float64))],
#  [('expression', 'int hash = NUM ;', tensor(0.0336, dtype=torch.float64)),
#   ('expression',
#    'hash = hash * NUM + (( mGroupId == null ) ? NUM : mGroupId . hashCode ());',
#    tensor(0.0280, dtype=torch.float64)),
#   ('expression',
#    'hash = hash * NUM + mPwPairs . hashCode ();',
#    tensor(inf, dtype=torch.float64)),
#   ('returnstatement', 'return hash ;', tensor(inf, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(1.0007, dtype=torch.float64))],
#  [('returnstatement', 'return date ;', tensor(-0.0726, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public LocalDate getDate () {',
#    tensor(-0.1081, dtype=torch.float64))],
#  [('returnstatement',
#    'return super . initCause ( cause );',
#    tensor(-0.1936, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Throwable initCause ( Throwable cause ) {',
#    tensor(-0.1144, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return new StringTemplate ( template , args );',
#    tensor(0.0628, dtype=torch.float64)),
#   ('returnstatement',
#    'return new StringTemplate ( template , args );',
#    tensor(0.0628, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static StringTemplate stringTemplate ( Template template , ImmutableList <?> args ) {',
#    tensor(0.0629, dtype=torch.float64))],
#  [('variableDeclaration',
#    'return this . add ( new LabelPipe ());',
#    tensor(-0.1469, dtype=torch.float64)),
#   ('returnstatement',
#    'return this . add ( new LabelPipe ());',
#    tensor(-0.1469, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public GremlinPipeline < S , String > label () {',
#    tensor(-0.1116, dtype=torch.float64))],
#  [('returnstatement',
#    'return !( object instanceof ComponentObservable ) || asComponentObservable ( object ). observe ();',
#    tensor(0.0552, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'static boolean observe (@ Nullable final Object object ) {',
#    tensor(0.0701, dtype=torch.float64))],
#  [('returnstatement',
#    'return getter . getView ( Button . class , index );',
#    tensor(0.1060, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Button getButton ( int index ) {',
#    tensor(0.0873, dtype=torch.float64))],
#  [('returnstatement',
#    'return searchFor ( EditText . class , regex , 1 , scroll );',
#    tensor(0.0447, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean searchForEditText ( String regex , boolean scroll ) {',
#    tensor(0.0528, dtype=torch.float64))],
#  [('forstatement',
#    'for ( Iterator iterator = objects . iterator (); iterator . hasNext (); ) {',
#    tensor(0.0378, dtype=torch.float64)),
#   ('variableDeclaration',
#    'Set interfaces = new HashSet ();',
#    tensor(0.1030, dtype=torch.float64)),
#   ('expression',
#    'Set interfaces = new HashSet ();',
#    tensor(0.1030, dtype=torch.float64)),
#   ('expression',
#    'for ( Iterator iterator = objects . iterator (); iterator . hasNext (); ) {',
#    tensor(0.0378, dtype=torch.float64)),
#   ('expression',
#    'Object o = iterator . next ();',
#    tensor(0.0414, dtype=torch.float64)),
#   ('expression',
#    'Class clazz = o . getClass ();',
#    tensor(0.0256, dtype=torch.float64)),
#   ('returnstatement',
#    'return interfaces ;',
#    tensor(0.1219, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Set getAllInterfaces ( List objects ) {',
#    tensor(0.1729, dtype=torch.float64))],
#  [('returnstatement',
#    'return config . getClient (). login ( username , password );',
#    tensor(-0.0916, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Processor', tensor(-0.6517, dtype=torch.float64))],
#  [('returnstatement',
#    'return Status . OK _ STATUS ;',
#    tensor(-0.1353, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public IStatus doit () {',
#    tensor(-0.0642, dtype=torch.float64))],
#  [('returnstatement',
#    'return getStringPayload ();',
#    tensor(-0.1044, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Deprecated', tensor(-0.3034, dtype=torch.float64))],
#  [('returnstatement',
#    'return sContext ;',
#    tensor(0.1221, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Context getContext () {',
#    tensor(0.1414, dtype=torch.float64))],
#  [('returnstatement',
#    'return _ contents ;',
#    tensor(0.0353, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected final List < SyntaxTreeNode > getContents () {',
#    tensor(0.1986, dtype=torch.float64))],
#  [('expression',
#    'PingResult info = client . ping ( configuration );',
#    tensor(0.0816, dtype=torch.float64)),
#   ('returnstatement', 'return info ;', tensor(0.0378, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public PingResult performCheck ( PingConfiguration configuration ) {',
#    tensor(0.1298, dtype=torch.float64))],
#  [('returnstatement',
#    'return doDecodeStaticImage ( encodedImage . getInputStream (), encodedImage . getSampleSize ());',
#    tensor(0.0355, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'CloseableReference < Bitmap > decodeFromEncodedImage ( EncodedImage encodedImage ) {',
#    tensor(0.0593, dtype=torch.float64))],
#  [('returnstatement',
#    'return IN _ SUBQUERY _ THRESHOLD ;',
#    tensor(0.0784, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'protected int getInSubqueryThreshold () {',
#    tensor(0.1010, dtype=torch.float64))],
#  [('returnstatement',
#    'return dccHandler . sendChatRequest ( sender );',
#    tensor(0.0379, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Chat dccSendChatRequest ( User sender , int timeout ) throws IOException , SocketTimeoutException {',
#    tensor(0.0522, dtype=torch.float64))],
#  [('returnstatement',
#    'return measure ;',
#    tensor(-0.3595, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Number getMeasure () {',
#    tensor(-0.2269, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( isBuildingActions ()) {',
#    tensor(0.0159, dtype=torch.float64)),
#   ('variableDeclaration',
#    'action . addAction ( new ClickAndHoldAction ( jsonMouse , ( Locatable ) target ));',
#    tensor(0.0704, dtype=torch.float64)),
#   ('returnstatement', 'return this ;', tensor(0.0636, dtype=torch.float64)),
#   ('returnstatement',
#    'return moveToElement ( target ). clickAndHold ();',
#    tensor(0.0809, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public Actions clickAndHold ( WebElement target ) {',
#    tensor(0.0789, dtype=torch.float64))],
#  [('returnstatement',
#    'return hasDataFetcherImpl ( coordinates , dataFetcherMap , systemDataFetcherMap );',
#    tensor(0.0708, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean hasDataFetcher ( FieldCoordinates coordinates ) {',
#    tensor(0.0410, dtype=torch.float64))],
#  [('returnstatement', 'return error ;', tensor(0.0470, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public final FacebookRequestError getError () {',
#    tensor(0.2470, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( txtReverseProxyIp == null ) {',
#    tensor(0.0119, dtype=torch.float64)),
#   ('variableDeclaration',
#    'txtReverseProxyIp = new ZapTextField ();',
#    tensor(0.0624, dtype=torch.float64)),
#   ('expression',
#    'if ( txtReverseProxyIp == null ) {',
#    tensor(0.0119, dtype=torch.float64)),
#   ('expression',
#    'txtReverseProxyIp = new ZapTextField ();',
#    tensor(0.0624, dtype=torch.float64)),
#   ('returnstatement',
#    'return txtReverseProxyIp ;',
#    tensor(0.0404, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private ZapTextField getTxtReverseProxyIp () {',
#    tensor(0.0398, dtype=torch.float64))],
#  [('expression',
#    'return (( method . getAnnotation ( RequiresPermissions . class ) != null ) || ( method . getAnnotation ( RequiresRoles . class ) != null ));',
#    tensor(0.0574, dtype=torch.float64)),
#   ('returnstatement',
#    'return (( method . getAnnotation ( RequiresPermissions . class ) != null ) || ( method . getAnnotation ( RequiresRoles . class ) != null ));',
#    tensor(0.0574, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public boolean matches ( Method method , Class targetClass ) {',
#    tensor(0.0487, dtype=torch.float64))],
#  [('returnstatement',
#    'return ( IProject ) managedProject . getOwner ();',
#    tensor(-0.0369, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'private IProject getProject () {',
#    tensor(-0.1006, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( stringRep == null ) {',
#    tensor(0.0018, dtype=torch.float64)),
#   ('expression',
#    'if ( stringRep == null ) {',
#    tensor(0.0018, dtype=torch.float64)),
#   ('expression',
#    'stringRep = toString ( true );',
#    tensor(0.0109, dtype=torch.float64)),
#   ('returnstatement',
#    'return stringRep ;',
#    tensor(0.0378, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Override', tensor(0.9776, dtype=torch.float64))],
#  [('returnstatement',
#    'return SqlKind . OTHER ;',
#    tensor(-0.0575, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public SqlKind getKind () {',
#    tensor(-0.0434, dtype=torch.float64))],
#  [('ifstatement',
#    'if ( negation == null ){',
#    tensor(0.0555, dtype=torch.float64)),
#   ('expression',
#    'if ( negation == null ){',
#    tensor(0.0555, dtype=torch.float64)),
#   ('expression',
#    'negation = multiply (- 1 );',
#    tensor(0.0855, dtype=torch.float64)),
#   ('returnstatement',
#    'return negation ;',
#    tensor(0.1148, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public NumberExpression < T > negate (){',
#    tensor(0.1592, dtype=torch.float64))],
#  [('returnstatement',
#    'return subselectsByEntityKey . get ( key );',
#    tensor(0.0474, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public SubselectFetch getSubselect ( EntityKey key ) {',
#    tensor(0.0453, dtype=torch.float64))],
#  [('expression',
#    'Query query = GSON . fromJson ( queryString , Query . class );',
#    tensor(0.0758, dtype=torch.float64)),
#   ('returnstatement', 'return query ;', tensor(0.1066, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Query parse ( String queryString , BulletConfig config ) {',
#    tensor(0.0881, dtype=torch.float64))],
#  [('returnstatement',
#    'return validator . newValidationError ( call ,',
#    tensor(0.0343, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public EigenbaseException newValidationSignatureError () {',
#    tensor(0.0404, dtype=torch.float64))],
#  [('returnstatement',
#    'return CloseableReference . cloneOrNull ( mBitmapReference );',
#    tensor(0.0825, dtype=torch.float64)),
#   ('MethodDeclaration', '@ Nullable', tensor(0.5671, dtype=torch.float64))],
#  [('expression',
#    'final InstrumentedHttpClientConnectionManager manager = createConnectionManager ( registry , name );',
#    tensor(0.0208, dtype=torch.float64)),
#   ('expression',
#    'final CloseableHttpClient client = createClient ( manager , name );',
#    tensor(0.0564, dtype=torch.float64)),
#   ('returnstatement', 'return client ;', tensor(0.1011, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public CloseableHttpClient build ( String name ) {',
#    tensor(0.0902, dtype=torch.float64))],
#  [('ifstatement', 'if ( iNotPrinter ) {', tensor(0.0940, dtype=torch.float64)),
#   ('returnstatement', 'return null ;', tensor(0.0478, dtype=torch.float64)),
#   ('returnstatement',
#    'return toFormatter (). getPrinter ();',
#    tensor(0.1014, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public PeriodPrinter toPrinter () {',
#    tensor(0.0712, dtype=torch.float64))],
#  [('returnstatement',
#    'return hide ( null );',
#    tensor(-0.2922, dtype=torch.float64)),
#   ('MethodDeclaration',
#    'public static Internal hide () {',
#    tensor(-0.2383, dtype=torch.float64))]]

# %%
def filter_len(filtered_statements,filter_index,picture_data):
    filtered_st = []
    index = []
    picture_d = []
    for i in range(len(filtered_statements)): 
        if len(filtered_statements[i]) > 2:
            filtered_st.append(filtered_statements[i])
            index.append(filter_index[i])
            picture_d.append(picture_data[i])
    return filtered_st,index ,picture_d

# %%
filtered_statements_true_new,filter_true_index_new,filter_picture_data_true \
= filter_len(filtered_statements_true,filter_true_index,picture_data_true)

# %%
vis_data_records_ig = []
for attributions_num_all, new_all_tokens, pre, ground_lable, sen_type, delta_ig in filter_picture_data_true:    
    add_attributions_to_visualizer(attributions_num_all, new_all_tokens, pre, ground_lable, sen_type, delta_ig,vis_data_records_ig)
            
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>Consis (1.00)</b></text></td><td><text style="padding-right:2em"><b>Consis</b></text></td><td><text style="padding-right:2em"><b>-inf</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> This                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> method                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> initializes                    </font></mark><mark style="background-color: hsl(0, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> jTextArea                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> private ZapTextArea getTxtSkipURL () {                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> if ( txtSkipURL == null ) {                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> txtSkipURL = new ZapTextArea ();                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> txtSkipURL . setFont ( new java . awt . Font (" Default ", java . awt . Font . PLAIN , 11 ));                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> if ( Model . getSingleton (). getOptionsParam (). getViewParam (). getWmUiHandlingOption () == 0 ) {                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> txtSkipURL . setSize ( new java . awt . Dimension ( 290 , 52 ));                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> return txtSkipURL ;                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>1</b></text></td><td ...

# %% [markdown]
# false

# %%
type_code_attr_false= get_all_statement(code_lineList_token_false,attribute_num_code_false)

# %%
len(index_false),len(type_code_attr_false)
# Out:
# (999, 999)

# %%
# 由均值而来 iqr
# 4
# type_list_false = [
#     ('MethodDeclaration',0.176),
#     ('whilestatement',0.100),
#     ('trystatement',0.102),
#     ('returnstatement',0.139)
# ]
type_list_false = [
    ('MethodDeclaration',0.176),
    ('returnstatement',0.139)
]
type_list_false_0 = [
    ('MethodDeclaration',-0.176),
    ('returnstatement',-0.139)
]

# %%
# 由均值而来 Winsorization 
type_list_false_1 = [
    ('MethodDeclaration',0.21),
    ('whilestatement',0.106),
    ('trystatement',0.094),
    ('returnstatement',0.159)
]

# %%
filtered_statements_false,filter_false_index,picture_data_false\
= get_filter_pair(type_code_attr_false, type_list_false,type_list_false_0,index_false,picture_false)

# %%
len(picture_data_false)
# Out:
# 113

# %%
filter_false_index
# Out:
# [5,
#  6,
#  14,
#  59,
#  97,
#  121,
#  211,
#  250,
#  324,
#  346,
#  349,
#  386,
#  446,
#  482,
#  499,
#  505,
#  513,
#  539,
#  573,
#  605,
#  615,
#  645,
#  667,
#  673,
#  704,
#  724,
#  728,
#  741,
#  806,
#  839,
#  848,
#  881,
#  935,
#  955,
#  963,
#  984,
#  1003,
#  1016,
#  1110,
#  1135,
#  1149,
#  1220,
#  1353,
#  1361,
#  1375,
#  1496,
#  1516,
#  1589,
#  1590,
#  1596,
#  1624,
#  1723,
#  1779,
#  1831,
#  1875,
#  1926,
#  1936,
#  1944,
#  1991,
#  2010,
#  2012,
#  2036,
#  2177,
#  2229,
#  2230,
#  2238,
#  2243,
#  2285,
#  2310,
#  2317,
#  2371,
#  2465,
#  2498,
#  2549,
#  2569,
#  2641,
#  2649,
#  2715,
#  2718,
#  2807,
#  2925,
#  2926,
#  2961,
#  3010,
#  3025,
#  3038,
#  3042,
#  3099,
#  3161,
#  3183,
#  3295,
#  3301,
#  3374,
#  3387,
#  3421,
#  3461,
#  3466,
#  3467,
#  3487,
#  3491,
#  3526,
#  3539,
#  3550,
#  3625,
#  3643,
#  3655,
#  3698,
#  3701,
#  3728,
#  3733,
#  3806,
#  3817,
#  3893]

# %%
len(filter_false_index)
# Out:
# 113

# %%
filtered_statements_false_new,filter_false_index_new,filter_picture_data_false \
= filter_len(filtered_statements_false,filter_false_index,picture_data_false)

# %%
vis_data_records_ig = []
for attributions_num_all, new_all_tokens, pre, ground_lable, sen_type, delta_ig in picture_data_false:    
    add_attributions_to_visualizer(attributions_num_all, new_all_tokens, pre, ground_lable, sen_type, delta_ig,vis_data_records_ig)
            
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>Consis (1.00)</b></text></td><td><text style="padding-right:2em"><b>Consis</b></text></td><td><text style="padding-right:2em"><b>inf</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> Construct                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> value                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> data                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> attribute                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> CloudEvents                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> .                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> public Struct ceDataAttribute () {                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> return recordParser . data ();                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>Inconsis (1.00)</b></text></td><td><text style="padding-right:2em"><b>Inconsis</b></text></td><td><text style="padding-right:2em"><b>-inf</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(120, 75%, 88%); opacity:1.0;                     ...
