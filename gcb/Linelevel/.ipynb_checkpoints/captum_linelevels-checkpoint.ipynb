# %% [markdown]
# 此 .ipynb为按照行级进行分析可解释性的过程 , 最终显示行级的代码

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

import torch
import torch.nn as nn
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import AdamW, get_linear_schedule_with_warmup
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, TensorDataset


from captum.attr import visualization as viz
from captum.attr import LayerConductance, LayerIntegratedGradients
from captum.attr import configure_interpretable_embedding_layer, remove_interpretable_embedding_layer

# 解决服务器挂掉的问题
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device( "cpu")

# %%
MAX_LEN = 1024
MAX_EPOCHS = 10
BATCH_SIZE = 4
LEARNING_RATE = 1e-5
NUM_CLASSES = 2
WEIGTH_DECAY = 1e-3

# %%
def retrieve_test_data():
    test_param = pd.read_json("D:/BERT_learing/code_comment_inconsistency_detection/data/param/test.json")
    test_return = pd.read_json("D:/BERT_learing/code_comment_inconsistency_detection/data/return/test.json")
    test_summary = pd.read_json("D:/BERT_learing/code_comment_inconsistency_detection/data/summary/test.json")
    test_df = pd.concat([test_summary,test_param, test_return], axis=0)
    test_df = test_df.reset_index(drop=True)
    return test_df
test_df = retrieve_test_data()

# %%
def get_lines_count(df):
    line_counts = []
    for i in range(len(df)):
        string = df.loc[i]['new_code_raw']
        line_count = len(string.split('\n'))
        line_counts.append(line_count)
    df['line_counts'] = line_counts
    return df
test_df = get_lines_count(test_df)
test_df.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  line_counts
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...            6
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...            4
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...           28
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...            4
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...           16

# %%
df_clean = test_df
df_clean.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  line_counts
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...            6
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...            4
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...           28
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...            4
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...           16

# %%
code_list = df_clean['new_code_raw']

# %%
code_list[0]
# Out:
# '  private static EmbeddedElasticsearchNode create(Settings settings) {\n    // ensure PainlessPlugin is installed or otherwise scripted fields would not work\n    Node node = new LocalNode(settings, Arrays.asList(Netty4Plugin.class, PainlessPlugin.class));\n    return new EmbeddedElasticsearchNode(node);\n  }\n'

# %%
df_clean.loc[0]['new_code_raw']
# Out:
# '  private static EmbeddedElasticsearchNode create(Settings settings) {\n    // ensure PainlessPlugin is installed or otherwise scripted fields would not work\n    Node node = new LocalNode(settings, Arrays.asList(Netty4Plugin.class, PainlessPlugin.class));\n    return new EmbeddedElasticsearchNode(node);\n  }\n'

# %%
len(df_clean)
# Out:
# 3944

# %%
# model = torch.load('save_GCBmodel.pt',map_location=torch.device('cuda:0'))
model = torch.load('D:/BERT_learing/CCDP/for_captum/save_model/save_GCBmodel.pt',map_location=torch.device('cpu'))

model.to(device)
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())  #输出为True，则安装无误
# Out:
# 2.3.1+cpu
# None
# False

# %%
device
# Out:
# device(type='cpu')

# %%
tokenizer = RobertaTokenizer.from_pretrained("D:/BERT_learing/code_comment_inconsistency_detection/graphcodebert")

# %%
model.roberta.embeddings
# Out:
# RobertaEmbeddings(
#   (word_embeddings): Embedding(50265, 768, padding_idx=1)
#   (position_embeddings): Embedding(514, 768, padding_idx=1)
#   (token_type_embeddings): Embedding(1, 768)
#   (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
model.roberta.encoder.layer[0]
# Out:
# RobertaLayer(
#   (attention): RobertaAttention(
#     (self): RobertaSelfAttention(
#       (query): Linear(in_features=768, out_features=768, bias=True)
#       (key): Linear(in_features=768, out_features=768, bias=True)
#       (value): Linear(in_features=768, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (output): RobertaSelfOutput(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (intermediate): RobertaIntermediate(
#     (dense): Linear(in_features=768, out_features=3072, bias=True)
#     (intermediate_act_fn): GELUActivation()
#   )
#   (output): RobertaOutput(
#     (dense): Linear(in_features=3072, out_features=768, bias=True)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
input_embeddings = model.get_input_embeddings()

# %%
# predict和squad_pos_forward_func可以合成一个
def predict(inputs, position_ids=None, attention_mask=None):
    output = model(inputs,
                   position_ids=position_ids,
                  attention_mask=attention_mask )
    
    prediction = output.logits
    prediction_1 = nn.functional.softmax(prediction, dim=1)
    prediction = prediction_1.max(1).values
    out = torch.argmax(prediction_1, dim=-1)
    # prediction：每个输入样本的最大预测概率。
    # out：预测的类别标签。
    # prediction_1：所有类别的预测概率。    
    return prediction,out,prediction_1

# %%
def squad_pos_forward_func(inputs,position_ids=None, attention_mask=None, position=0):
    pred ,_,_= predict(inputs,
                     position_ids=position_ids,
                   attention_mask=attention_mask)
    return pred

# %%
ref_token_id = tokenizer.pad_token_id # 0
sep_token_id = tokenizer.sep_token_id # 101
cls_token_id = tokenizer.cls_token_id # 102
ref_token_id,sep_token_id,cls_token_id
# Out:
# (1, 2, 0)

# %%
# 注意长度
def truncate(ids,len_tru = 512):
    return ids[:len_tru] if len(ids) > len_tru else ids

# %%
# 这是单个数据的处理方式，应该要想数据集应该怎么处理
def construct_input_ref_pair(comment,AST_type,  ref_token_id, sep_token_id, cls_token_id):
    comment = tokenizer.encode(comment, add_special_tokens=False,truncation=True,max_length=512)
    AST_type = tokenizer.encode(AST_type, add_special_tokens=False,truncation=True,max_length=512)
    # construct input token ids
    input_ids = [cls_token_id] + comment + [sep_token_id] + AST_type + [sep_token_id]

    # construct reference token ids 
    ref_input_ids = [cls_token_id] + [ref_token_id] * len(comment) + [sep_token_id] + \
        [ref_token_id] * len(AST_type) + [sep_token_id]
    input_ids = truncate(input_ids)
    ref_input_ids = truncate(ref_input_ids)
    return torch.tensor([input_ids], device=device), torch.tensor([ref_input_ids], device=device), len(comment)

def construct_input_ref_token_type_pair(input_ids, sep_ind=0):
    seq_len = input_ids.size(1)
    token_type_ids = torch.tensor([[0 if i <= sep_ind else 1 for i in range(seq_len)]], device=device)
    ref_token_type_ids = torch.zeros_like(token_type_ids, device=device)# * -1
    return token_type_ids, ref_token_type_ids

def construct_input_ref_pos_id_pair(input_ids):
    seq_length = input_ids.size(1)
    position_ids = torch.arange(seq_length, dtype=torch.long, device=device)
    # we could potentially also use random permutation with `torch.randperm(seq_length, device=device)`
    ref_position_ids = torch.zeros(seq_length, dtype=torch.long, device=device)

    position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
    ref_position_ids = ref_position_ids.unsqueeze(0).expand_as(input_ids)
    return position_ids, ref_position_ids

def construct_attention_mask(input_ids):
    return torch.ones_like(input_ids)

def construct_whole_bert_embeddings(input_ids, ref_input_ids, \
                                    token_type_ids=None, ref_token_type_ids=None, \
                                    position_ids=None, ref_position_ids=None):
    input_embeddings = model.roberta.embeddings(input_ids, token_type_ids=token_type_ids, position_ids=position_ids)
    ref_input_embeddings = model.roberta.embeddings(ref_input_ids, token_type_ids=ref_token_type_ids, position_ids=ref_position_ids)
    
    return input_embeddings, ref_input_embeddings

# %%
# 前k个贡献最高的word 和 token_type 和 position
# return value为归因贡献值  indices为词对应的索引  top_tokens为 词或位置或token_type
def get_topk_attributed_tokens(attrs,all_token_t, k=5):
    values_max, indices_max = torch.topk(attrs, k)
    top_tokens_max = [all_token_t[idx] for idx in indices_max]
    values_min, indices_min = torch.topk(attrs, k, largest=False)
    top_tokens_min = [all_token_t[idx] for idx in indices_min] 
    
    return top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min

# %%
import re
import string

def split_punctuation(s):
    # 使用正则表达式匹配连续的标点符号或者字母和标点符号之间的位置
    splits = re.finditer(r'(?<=\w)(?=[{}])|(?<=[{}])(?=\w)'.format(string.punctuation, string.punctuation), s)
    
    # 获取所有分割位置
    split_positions = [match.start() for match in splits]
    
    # 在分割位置插入空格
    for pos in reversed(split_positions):
        s = s[:pos] + ' ' + s[pos:]
        
    s = s.replace("< s >", "<s>")
    s = s.replace("</ s >", "</s>")
    return s

# %%
# 从 all_tokens 还原为 原单词 ，并且计算归因值
def get_restore_words(code,comment,input_ids,all_tokens,attribution_num):
    all_tokens_decode = tokenizer.decode(input_ids)
    len_all_tokens_decode = len(all_tokens_decode) + 4
    # 使用decode获得的序列，去掉分词之后的空格    例 ' a' -> 'a'
    all_tokens_clean = []
    for token in all_tokens:
        s_without_leading_space = token.lstrip()
        all_tokens_clean.append(s_without_leading_space)
#     print('all_tokens_clean:\n',all_tokens_clean)
#     print('all_tokens_clean:\n',len(all_tokens_clean))
    

    # 获得 code_comment_baseline
    code = tokenizer.encode(code, add_special_tokens=False,truncation=True,max_length=512)
    comment = tokenizer.encode(comment, add_special_tokens=False,truncation=True,max_length=512)
    code_decode = tokenizer.decode(code)
    comment_decode = tokenizer.decode(comment)
    
    code_comment_baseline = tokenizer.decode(tokenizer.cls_token_id) + ' '+ comment_decode \
                            + ' '+ tokenizer.decode(tokenizer.sep_token_id) + ' ' + code_decode \
                            + ' ' + tokenizer.decode(tokenizer.sep_token_id)
    
    code_comment_baseline = code_comment_baseline[:len_all_tokens_decode]
    code_comment_baseline = split_punctuation(code_comment_baseline)
    code_comment_baseline = code_comment_baseline.split()

#     print('code_comment_baseline:\n',code_comment_baseline)
#     print('code_comment_baseline_len:\n',len(code_comment_baseline))

    
    # 获得 相邻有几个token合并在一块的列表times  为了以后再计算attribute时求和
    times = []
    token_index = 0
    for code_comment in code_comment_baseline:
        temp = ''
        time = 0
        while temp != code_comment:
            temp = temp + all_tokens_clean[token_index]
            token_index = token_index + 1
            time = time + 1
        times.append(time)
#     print('times:\n',times)
    
    attribute_sum = []
    start = 0
    for time in times:
        end = start + time
        attribute = sum(attribution_num[start:end]) / time
        attribute_sum.append(attribute)
        start = end
#     print('attribute_sum:\n',attribute_sum)
    return code_comment_baseline ,attribute_sum

# %%
def get_line_code_and_attribute(code,code_all_tokens,attributions_num):
    # 特殊符号前  加空格
    code = split_punctuation(code)
    
    # 把  行前空格去掉  便于单词与行之间匹配
    code = [line.lstrip() for line in code.splitlines()]
    code = '\n'.join(code)  
    code_lineList = code.split('\n')
    code_lineList = [' '.join(x.split()) for x in code_lineList]
    # 有空行，把空行去掉
    code_lineList = [item for item in code_lineList if item != '']
    
    attribute = []
    i = 0  
    for code_line in code_lineList:
        count = 0
        if i < len(code_all_tokens):
            temp = code_all_tokens[i]
            attr = attributions_num[i]
            i = i + 1
        while((i < len(code_all_tokens)) and(temp != code_line)):
            attr = attr + attributions_num[i]
            temp = temp + ' ' + code_all_tokens[i]
            i = i + 1
            count = count + 1
        attribute.append(attr/count)

    return code_lineList,attribute

# %%
def remove_before_and_including(lst, element):
    if element in lst:
        index = lst.index(element)
        lst_c = lst[index+1:]
        if element in lst_c:
            lst_c.remove(element)
        return lst_c
    else:
        return lst
    
def remove_after_including(lst, element):
    if element in lst:
        index = lst.index(element)
        return lst[:index + 1]
    else:
        return lst

# %%
def final_all_attribute(code,all_tokens,attributions_num):
    # 删除 all_token 列表中的<s>注释</s>  </s>
    code_all_tokens = remove_before_and_including(all_tokens,'</s>')
    comment_all_tokens = remove_after_including(all_tokens,'</s>')  
    index = all_tokens.index('</s>')
    attribute_comment = attributions_num[:index+1]
#     print(attribute_comment)
    
    attribute_code = attributions_num[index+1:-1]
#     print(attribute_code,len(attribute_code))
    code_lineList_token,attribute_num_code = get_line_code_and_attribute(code,code_all_tokens,attribute_code)
##     print(attribute_num_code)
    attribute_num_code = torch.stack(attribute_num_code)
    
    new_all_tokens = comment_all_tokens + code_lineList_token
    attributions_num_all = torch.cat((attribute_comment, attribute_num_code))

#     attributions_num_all = attribute_comment + attribute_num_code
#     print(len(attribute_comment),len(attribute_num_code))
#     print(new_all_tokens)
    return new_all_tokens,attributions_num_all,code_lineList_token,attribute_num_code

# %%
from captum.attr import LayerIntegratedGradients
from captum.attr import visualization as viz

lig = LayerIntegratedGradients(squad_pos_forward_func,input_embeddings)

vis_data_records_ig = []

def interpret_sentence(code,comment,old_code,input_ids,ref_input_ids, token_type_ids,\
                       position_ids, attention_mask, all_tokens, ground_lable,vis_data_records):
    pre ,out,_ = predict(input_ids, position_ids=position_ids,attention_mask=attention_mask)
    if out == 1:
        sen_type = 'pos'
    else:
        sen_type = 'nag'
    pre = pre.item()
    pre = "{:.3f}".format(pre)
    pre = float(pre) 
    pre ,sen_type
    
    attributions_ig, delta_ig = lig.attribute(input_ids, baselines=ref_input_ids,\
                           additional_forward_args=(position_ids,attention_mask,0),return_convergence_delta=True,internal_batch_size=8)
    
    attributions = attributions_ig.sum(dim=2).squeeze(0)
    attributions = attributions / torch.norm(attributions)
#     print(delta_ig)
#     print(attributions)
    all_tokens ,attributions = get_restore_words(code,comment,input_ids[0],all_tokens,attributions)     # 合并为一个单词
    attributions = torch.tensor(attributions)
    print(all_tokens)
    # code_lineList_token 和 attribute_num_code 用于后续统计分析
    new_all_tokens,attributions_num_all,code_lineList_token,attribute_num_code= final_all_attribute(code,all_tokens,attributions)
    
    add_attributions_to_visualizer(attributions_num_all, new_all_tokens, pre, ground_lable, sen_type, delta_ig, vis_data_records)

    top_tokens_max, values_max, indices_max,top_tokens_min,\
    values_min,indices_min = get_topk_attributed_tokens(attributions_num_all,new_all_tokens)

    return top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min,\
           code,old_code,code_lineList_token,attribute_num_code

def add_attributions_to_visualizer(attributions, all_tokens, pre, ground_lable, sen_type, delta, vis_data_records):

    # storing couple samples in an array for visualization purposes
    vis_data_records.append(viz.VisualizationDataRecord(
                            attributions,
                            pre,
                            pre,
                            ground_lable,
                            sen_type,
                            attributions.sum(),
                            all_tokens,
                            delta))

# %%
def interpret_sentence_2(code,comment,old_code,input_ids,ref_input_ids, token_type_ids,\
                         position_ids, attention_mask, all_tokens, ground_lable,vis_data_records):
    pre ,out,_ = predict(input_ids,  position_ids=position_ids,attention_mask=attention_mask)
    if out == 1:
        sen_type = 'pos'
    else:
        sen_type = 'nag'
    pre = pre.item()
    pre = "{:.3f}".format(pre)
    pre = float(pre) 
    pre ,sen_type
    
    attributions_ig, delta_ig = lig.attribute(input_ids, baselines=ref_input_ids,\
                           additional_forward_args=(position_ids,attention_mask,0),return_convergence_delta=True,internal_batch_size=8)
    
    attributions = attributions_ig.sum(dim=2).squeeze(0)
    attributions = attributions / torch.norm(attributions)
#     print(delta_ig)
#     print(attributions)
    try:
        all_tokens ,attributions = get_restore_words(code,comment,input_ids[0],all_tokens,attributions)     # 合并为一个单词
        attributions = torch.tensor(attributions)
#         print(all_tokens)


        # code_lineList_token 和 attribute_num_code 用于后续统计分析
        new_all_tokens,attributions_num_all,code_lineList_token,attribute_num_code = final_all_attribute(code,all_tokens,attributions)
        print(new_all_tokens)

        add_attributions_to_visualizer(attributions_num_all, new_all_tokens, pre, ground_lable, sen_type, delta_ig, vis_data_records)

        top_tokens_max, values_max, indices_max,top_tokens_min,\
        values_min,indices_min = get_topk_attributed_tokens(attributions_num_all,new_all_tokens)

        return top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min,\
               code,old_code,code_lineList_token,attribute_num_code
    except Exception as e:
#         pass
        print("解析错误")
        return _, _, _,_,_,_,_,_,_,_

def add_attributions_to_visualizer(attributions, all_tokens, pre, ground_lable, sen_type, delta, vis_data_records):

    # storing couple samples in an array for visualization purposes
    vis_data_records.append(viz.VisualizationDataRecord(
                            attributions,
                            pre,
                            pre,
                            ground_lable,
                            sen_type,
                            attributions.sum(),
                            all_tokens,
                            delta))

# %%
AST_list = []
for i in range(10): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])

AST_list_old = []
for i in range(10): 
    AST_list_old.append(df_clean.loc[i,'old_code_raw'])    

comment_list = []
for i in range(10): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])

ground_lable = []
for i in range(10): 
    ground_lable.append(df_clean.loc[i,'label'])

print(AST_list[2])
print(comment_list[2])
print(ground_lable[2])

def input_data_list(AST_list,comment_list):
    input_ids_all = []
    ref_input_ids_all = []
    position_ids_all = []
    attention_mask_all = []
    token_type_ids_all = []
    all_tokens_all = []
    for i in range(len(AST_list)):
        input_ids, ref_input_ids, comment_len = construct_input_ref_pair(comment_list[i],AST_list[i], ref_token_id,\
                                                                         sep_token_id, cls_token_id)
        token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, comment_len)
        position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
        attention_mask = construct_attention_mask(input_ids)
        
        indices = input_ids[0].detach().tolist()
        
        all_tokens = []                                       ###
        for _, token in enumerate(indices):
            all_tokens.append(tokenizer.decode([token]))
        
        input_ids_all.append(input_ids)
        ref_input_ids_all.append(ref_input_ids)
        position_ids_all.append(position_ids)
        attention_mask_all.append(attention_mask)
        token_type_ids_all.append(token_type_ids)
        all_tokens_all.append(all_tokens)

    return input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,token_type_ids_all,all_tokens_all
# Out:
#   private byte[] marshalAggregatorValues(long superstep) {
#     if (superstep == INPUT_SUPERSTEP) {
#       return new byte[0];
#     }
#
#     ByteArrayOutputStream outputStream = new ByteArrayOutputStream();
#     DataOutputStream output = new DataOutputStream(outputStream);
#     for (Entry<String, AggregatorWrapper<Writable>> entry :
#         getAggregatorMap().entrySet()) {
#       if (entry.getValue().isChanged()) {
#         try {
#           output.writeUTF(entry.getKey());
#           entry.getValue().getCurrentAggregatedValue().write(output);
#         } catch (IOException e) {
#           throw new IllegalStateException("Failed to marshall aggregator " +
#               "with IOException " + entry.getKey(), e);
#         }
#       }
#     }
#
#     if (LOG.isInfoEnabled()) {
#       LOG.info(
#           "marshalAggregatorValues: Finished assembling aggregator values");
#     }
#     return outputStream.toByteArray();
#   }
#
#
# Marshal the aggregator values of to a JSONArray that will later be aggregated by master.
# 1

# %%
input_ids_all,ref_input_ids_all,position_ids_all,\
attention_mask_all,token_type_ids_all,all_tokens_all= input_data_list(AST_list,comment_list)
# print(input_ids_all[1])
# print(ref_input_ids_all[1])
# print(input_ids_all[1])

# %%
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min,code,old_code,_,_ \
    = interpret_sentence_2(AST_list[i],comment_list[i],AST_list_old[i],input_ids_all[i],ref_input_ids_all[i],\
                           token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], all_tokens_all[i],\
                           ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
          {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    print('对比以下代码查看代码更改位置') 
    print(f'新代码：{code}')
    print(f'旧代码代码：{old_code}')
# Out:
# ['<s>', 'Creates', 'elastic', 'node', 'as', 'single', 'member', 'of', 'a', 'cluster', '.', '</s>', 'private static EmbeddedElasticsearchNode create ( Settings settings ) {', '// ensure PainlessPlugin is installed or otherwise scripted fields would not work', 'Node node = new LocalNode ( settings , Arrays . asList ( Netty4Plugin . class , PainlessPlugin . class ));', 'return new EmbeddedElasticsearchNode ( node );', '}']
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['node', 'Node node = new LocalNode ( settings , Arrays . asList ( Netty4Plugin . class , PainlessPlugin . class ));', 'as', 'Creates', '}']
# , tensor([0.5053, 0.3945, 0.3350, 0.2292, 0.2088], dtype=torch.float64)
# , tensor([ 3, 14,  4,  1, 16])
# ,['single', '.', 'elastic', '<s>', '</s>']
# ,tensor([-0.0588, -0.0073, -0.0007,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([ 5, 10,  2,  0, 11])
#
# 对比以下代码查看代码更改位置
# 新代码：  private static EmbeddedElasticsearchNode create(Settings settings) {
#     // ensure PainlessPlugin is installed or otherwise scripted fields would not work
#     Node node = new LocalNode(settings, Arrays.asList(Netty4Plugin.class, PainlessPlugin.class));
#     return new EmbeddedElasticsearchNode(node);
#   }
#
# 旧代码代码：  public static EmbeddedElasticsearchNode create() {
#     File data = Files.createTempDir();
#     data.deleteOnExit();
#     File home = Files.createTempDir();
#     home.deleteOnExit();
#
#     Settings settings = Settings.builder()
#         .put("node.name", "fake-elastic")
#         .put("path.home", home.getAbsolutePath())
#         .put("path.data", data.getAbsolutePath())
#         .put("http.type", "netty4")
#         .put("network.host", "localhost")
#         .build();
#
#     return create(settings);
#   }
#
# ['<s>', 'Check', 'whether', 'any', 'insertion', 'or', 'deletion', 'actions', 'are', 'currently', 'queued', '.', '</s>', 'public boolean areInsertionsOrDeletionsQueued () {', 'return ( insertions . size () > 0 || ! unresolvedInsertions . isEmpty () || deletions . size () > 0 );', '}']
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return ( insertions . size () > 0 || ! unresolvedInsertions . isEmpty () || deletions . size () > 0 );', '}', 'public boolean areInsertionsOrDeletionsQueued () {', '.', 'Check']
# , tensor([1.3703, 1.3703, 0.4957, 0.1785, 0.0662], dtype=torch.float64)
# , tensor([14, 15, 13, 11,  1])
# ,['currently', 'are', 'queued', 'deletion', 'actions']
# ,tensor([-0.4641, -0.3795, -0.1887, -0.1276, -0.1268], dtype=torch.float64)
# ,tensor([ 9,  8, 10,  6,  7])
#
# 对比以下代码查看代码更改位置
# 新代码：	public boolean areInsertionsOrDeletionsQueued() {
# 		return ( insertions.size() > 0 || ! unresolvedInsertions.isEmpty() || deletions.size() > 0 );
# 	}
#
# 旧代码代码：	public boolean areInsertionsOrDeletionsQueued() {
# 		return ( insertions.size() > 0 || deletions.size() > 0 );
# 	}
#
# ['<s>', 'Marshal', 'the', 'aggregator', 'values', 'of', 'to', 'a', 'JSONArray', 'that', 'will', 'later', 'be', 'aggregated', 'by', 'master', '.', '</s>', 'private byte [] marshalAggregatorValues ( long superstep ) {', 'if ( superstep == INPUT _ SUPERSTEP ) {', 'return new byte [ 0 ];', '}', 'ByteArrayOutputStream outputStream = new ByteArrayOutputStream ();', 'DataOutputStream output = new DataOutputStream ( outputStream );', 'for ( Entry < String , AggregatorWrapper < Writable >> entry :', 'getAggregatorMap (). entrySet ()) {', 'if ( entry . getValue (). isChanged ()) {', 'try {', 'output . writeUTF ( entry . getKey ());', 'entry . getValue (). getCurrentAggregatedValue (). write ( output );', '} catch ( IOException e ) {', 'throw new IllegalStateException (" Failed to marshall aggregator " +', '" with IOException " + entry . getKey (), e );', '}', '}', '}', 'if ( LOG . isInfoEnabled ()) {', 'LOG . info (', '" marshalAggregatorValues : Finished assembling aggregator values ");', '}', 'return outputStream . toByteArray ();', '}']
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['" marshalAggregatorValues : Finished assembling aggregator values ");', '}', '}', 'return outputStream . toByteArray ();', '}']
# , tensor([0.3775, 0.1585, 0.1559, 0.1319, 0.1277], dtype=torch.float64)
# , tensor([38, 41, 35, 40, 33])
# ,['JSONArray', 'private byte [] marshalAggregatorValues ( long superstep ) {', 'aggregator', 'to', 'if ( superstep == INPUT _ SUPERSTEP ) {']
# ,tensor([-0.6067, -0.4750, -0.3445, -0.3417, -0.3414], dtype=torch.float64)
# ,tensor([ 8, 18,  3,  6, 19])
#
# 对比以下代码查看代码更改位置
# 新代码：  private byte[] marshalAggregatorValues(long superstep) {
#     if (superstep == INPUT_SUPERSTEP) {
#       return new byte[0];
#     }
#
#     ByteArrayOutputStream outputStream = new ByteArrayOutputStream();
#     DataOutputStream output = new DataOutputStream(outputStream);
#     for (Entry<String, AggregatorWrapper<Writable>> entry :
#         getAggregatorMap().entrySet()) {
#       if (entry.getValue().isChanged()) {
#         try {
#           output.writeUTF(entry.getKey());
#           entry.getValue().getCurrentAggregatedValue().write(output);
#         } catch (IOException e) {
#           throw new IllegalStateException("Failed to marshall aggregator " +
#               "with IOException " + entry.getKey(), e);
#         }
#       }
#     }
#
#     if (LOG.isInfoEnabled()) {
#       LOG.info(
#           "marshalAggregatorValues: Finished assembling aggregator values");
#     }
#     return outputStream.toByteArray();
#   }
#
#
# 旧代码代码：  private JSONArray marshalAggregatorValues(long superstep) {
#     JSONArray aggregatorArray = new JSONArray();
#     if ((superstep == INPUT_SUPERSTEP) || (aggregatorInUse.size() == 0)) {
#       return aggregatorArray;
#     }
#
#     for (String name : aggregatorInUse) {
#       try {
#         Aggregator<Writable> aggregator = getAggregatorMap().get(name);
#         ByteArrayOutputStream outputStream =
#             new ByteArrayOutputStream();
#         DataOutput output = new DataOutputStream(outputStream);
#         aggregator.getAggregatedValue().write(output);
#
#         JSONObject aggregatorObj = new JSONObject();
#         aggregatorObj.put(AGGREGATOR_NAME_KEY, name);
#         aggregatorObj.put(AGGREGATOR_CLASS_NAME_KEY,
#             aggregator.getClass().getName());
#         aggregatorObj.put(
#             AGGREGATOR_VALUE_KEY,
#             Base64.encodeBytes(outputStream.toByteArray()));
#         aggregatorArray.put(aggregatorObj);
#         if (LOG.isInfoEnabled()) {
#           LOG.info("marshalAggregatorValues: " +
#               "Found aggregatorObj " +
#               aggregatorObj + ", value (" +
#               aggregator.getAggregatedValue() + ")");
#         }
#       } catch (JSONException e) {
#         throw new IllegalStateException("Failed to marshall aggregator " +
#             "with JSONException " + name, e);
#       } catch (IOException e) {
#         throw new IllegalStateException("Failed to marshall aggregator " +
#             "with IOException " + name, e);
#       }
#     }
#
#     if (LOG.isInfoEnabled()) {
#       LOG.info("marshalAggregatorValues: Finished assembling " +
#           "aggregator values in JSONArray - " + aggregatorArray);
#     }
#     aggregatorInUse.clear();
#     return aggregatorArray;
#   }
#
# ['<s>', 'Returns', 'a', 'list', 'of', 'the', 'types', 'of', 'the', 'fields', 'in', 'a', 'given', 'struct', 'type', '.', '</s>', 'public static List < RelDataType > getFieldTypeList ( final RelDataType type ) {', 'return Lists . transform ( type . getFieldList (), GET _ TYPE );', '}']
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static List < RelDataType > getFieldTypeList ( final RelDataType type ) {', 'return Lists . transform ( type . getFieldList (), GET _ TYPE );', '}', 'Returns', '.']
# , tensor([0.9506, 0.8789, 0.2771, 0.2655, 0.1346], dtype=torch.float64)
# , tensor([17, 18, 19,  1, 15])
# ,['of', 'types', 'fields', 'of', 'list']
# ,tensor([-0.5202, -0.3841, -0.2053, -0.1404, -0.0700], dtype=torch.float64)
# ,tensor([4, 6, 9, 7, 3])
#
# 对比以下代码查看代码更改位置
# 新代码：  public static List<RelDataType> getFieldTypeList(final RelDataType type) {
#     return Lists.transform(type.getFieldList(), GET_TYPE);
#   }
#
# 旧代码代码：  public static List<RelDataType> getFieldTypeList(final RelDataType type) {
#     return new AbstractList<RelDataType>() {
#       public RelDataType get(int index) {
#         return type.getFieldList().get(index).getType();
#       }
#
#       public int size() {
#         return type.getFieldCount();
#       }
#     };
#   }
# ['<s>', 'Create', 'an', 'instance', 'based', 'on', 'current', 'maven', 'profile', '(', 'as', 'defined', 'by', '-', 'Pit', ').', '</s>', 'static MongoDatabasePolicy create () {', 'final MongoClient client ;', 'if ( MongoAssertions . useMongo ()) {', '// use to real client ( connects to mongo )', 'client = new MongoClient ();', '} else if ( MongoAssertions . useFongo ()) {', '// in - memory DB ( fake Mongo )', 'client = new Fongo ( MongoDatabasePolicy . class . getSimpleName ()). getMongo ();', '} else {', 'throw new UnsupportedOperationException (" I can only connect to Mongo or Fongo instances ");', '}', 'return new MongoDatabasePolicy ( client );', '}']
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['} else if ( MongoAssertions . useFongo ()) {', '-', 'instance', '// use to real client ( connects to mongo )', 'if ( MongoAssertions . useMongo ()) {']
# , tensor([0.3821, 0.3418, 0.2589, 0.2169, 0.1859], dtype=torch.float64)
# , tensor([22, 13,  3, 20, 19])
# ,['maven', 'Pit', 'final MongoClient client ;', 'on', '} else {']
# ,tensor([-0.7654, -0.6907, -0.1799, -0.1489, -0.0766], dtype=torch.float64)
# ,tensor([ 7, 14, 18,  5, 25])
#
# 对比以下代码查看代码更改位置
# 新代码：  static MongoDatabasePolicy create() {
#     final MongoClient client;
#     if (MongoAssertions.useMongo()) {
#       // use to real client (connects to mongo)
#       client = new MongoClient();
#     } else if (MongoAssertions.useFongo()) {
#       // in-memory DB (fake Mongo)
#       client = new Fongo(MongoDatabasePolicy.class.getSimpleName()).getMongo();
#     } else {
#       throw new UnsupportedOperationException("I can only connect to Mongo or Fongo instances");
#     }
#
#     return new MongoDatabasePolicy(client);
#   }
#
#
# 旧代码代码：  static MongoDatabaseRule create() {
#     final MongoClient client;
#     if (MongoAssertions.useMongo()) {
#       // use to real client (connects to mongo)
#       client = new MongoClient();
#     } else if (MongoAssertions.useFongo()) {
#       // in-memory DB (fake Mongo)
#       client = new Fongo(MongoDatabaseRule.class.getSimpleName()).getMongo();
#     } else {
#       throw new UnsupportedOperationException("I can only connect to Mongo or Fongo instances");
#     }
#
#     return new MongoDatabaseRule(client);
#   }
#
# ['<s>', 'Construct', 'the', 'value', 'of', 'the', 'data', 'attribute', 'of', 'CloudEvents', '.', '</s>', 'public Struct ceDataAttribute () {', 'return recordParser . data ();', '}']
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public Struct ceDataAttribute () {', 'return recordParser . data ();', 'attribute', 'Construct', '}']
# , tensor([1.6234, 0.8875, 0.2736, 0.2083, 0.1951], dtype=torch.float64)
# , tensor([12, 13,  7,  1, 14])
# ,['of', 'value', '<s>', '</s>', 'CloudEvents']
# ,tensor([-0.0818, -0.0782,  0.0000,  0.0000,  0.0246], dtype=torch.float64)
# ,tensor([ 8,  3,  0, 11,  9])
#
# 对比以下代码查看代码更改位置
# 新代码：    public Struct ceDataAttribute() {
#         return recordParser.data();
#     }
#
# 旧代码代码：    public Struct ceDataAttribute() {
#         Struct data = new Struct(ceDataAttributeSchema());
#         if (recordParser.before() != null) {
#             data.put(Envelope.FieldName.BEFORE, recordParser.before());
#         }
#         if (recordParser.after() != null) {
#             data.put(Envelope.FieldName.AFTER, recordParser.after());
#         }
#         return data;
#     }

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)

# %%
# 理解了代码和注释的语义，但是由于缺少上下文 导致预测结果出错
# 可以使用
df_clean.loc[9]
# Out:
# id                                     OpenAPITools_openapi_generator-2184-FirstSente...
# label                                                                                  0
# comment_type                                                                     Summary
# old_comment_raw                                      Return the name of the oneOf schema
# old_comment_subtokens                      [return, the, name, of, the, one, of, schema]
# new_comment_raw                                      Return the name of the oneOf schema
# new_comment_subtokens                      [return, the, name, of, the, one, of, schema]
# span_minimal_diff_comment_subtokens                                                   []
# old_code_raw                               public String toOneOfName(List<String> nam...
# old_code_subtokens                     [public, string, to, one, of, name, (, list, <...
# new_code_raw                               public String toOneOfName(List<String> nam...
# new_code_subtokens                     [public, string, to, one, of, name, (, list, <...
# span_diff_code_subtokens               [<KEEP>, public, string, to, one, of, name, (,...
# token_diff_code_subtokens              [<KEEP>, public, <KEEP>, string, <KEEP>, to, <...
# line_counts                                                                            8
# Name: 9, dtype: object

# %%
AST_list = []
for i in range(10,30): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])
    
AST_list_old = []
for i in range(10,30): 
    AST_list_old.append(df_clean.loc[i,'old_code_raw'])   
    
comment_list = []
for i in range(10,30): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])

ground_lable = []
for i in range(10,30): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,\
attention_mask_all,token_type_ids_all,all_tokens_all = input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min,code,old_code,_,_ \
    = interpret_sentence_2(AST_list[i],comment_list[i],AST_list_old[i],input_ids_all[i],ref_input_ids_all[i],\
                           token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], all_tokens_all[i],\
                           ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
          {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    print('对比以下代码查看代码更改位置') 
    print(f'新代码：{code}')
    print(f'旧代码代码：{old_code}')
# Out:
# ['<s>', 'Returns', 'the', 'providers', 'that', 'are', 'bound', 'to', 'the', 'same', 'location', 'as', 'the', 'given', 'ISO', '3166', 'code', 'and', 'of', 'the', 'given', 'type', '.', '</s>', 'public static Iterable < ProviderMetadata > boundedByIso3166Code ( String iso3166Code ,', 'TypeToken <? extends Wrapper > contextWrappableAs ) {', 'return filter ( all (), Predicates . and ( ProviderPredicates . boundedByIso3166Code ( iso3166Code ), ProviderPredicates', '. contextWrappableAs ( contextWrappableAs )));', '}']
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return filter ( all (), Predicates . and ( ProviderPredicates . boundedByIso3166Code ( iso3166Code ), ProviderPredicates', 'TypeToken <? extends Wrapper > contextWrappableAs ) {', 'Returns', '. contextWrappableAs ( contextWrappableAs )));', 'same']
# , tensor([1.7156, 0.4971, 0.4571, 0.3338, 0.3224], dtype=torch.float64)
# , tensor([26, 25,  1, 27,  9])
# ,['public static Iterable < ProviderMetadata > boundedByIso3166Code ( String iso3166Code ,', 'ISO', '3166', 'as', 'are']
# ,tensor([-0.4098, -0.2619, -0.1956, -0.1707, -0.1283], dtype=torch.float64)
# ,tensor([24, 14, 15, 11,  5])
#
# 对比以下代码查看代码更改位置
# 新代码：   public static Iterable<ProviderMetadata> boundedByIso3166Code(String iso3166Code,
#             TypeToken<? extends Wrapper> contextWrappableAs) {
#       return filter(all(), Predicates.and(ProviderPredicates.boundedByIso3166Code(iso3166Code), ProviderPredicates
#                .contextWrappableAs(contextWrappableAs)));
#    }
#
#
# 旧代码代码：   public static Iterable<ProviderMetadata<?, ?, ?, ?>> boundedByIso3166Code(String iso3166Code, ApiType type) {
#       return filter(all(),
#             Predicates.and(ProviderPredicates.boundedByIso3166Code(iso3166Code), ProviderPredicates.type(type)));
#    }
#
# 解析错误
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Only', 'the', 'views', 'are', 'mirrored', '.', '</s>', 'public boolean isMirrored () {', 'if (! fMirroringEnabled )', 'return false ;', 'Object property = getProperty ( MIRRORED );', 'return property instanceof Boolean && ( Boolean ) property ;', '}']
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['if (! fMirroringEnabled )', 'views', '}', '<s>', '</s>']
# , tensor([0.5251, 0.0821, 0.0676, 0.0000, 0.0000], dtype=torch.float64)
# , tensor([ 9,  3, 13,  0,  7])
# ,['mirrored', 'return property instanceof Boolean && ( Boolean ) property ;', 'Object property = getProperty ( MIRRORED );', 'the', 'return false ;']
# ,tensor([-0.3492, -0.1883, -0.1309, -0.1168, -0.0972], dtype=torch.float64)
# ,tensor([ 5, 12, 11,  2, 10])
#
# 对比以下代码查看代码更改位置
# 新代码：	public boolean isMirrored() {
# 		if (!fMirroringEnabled)
# 			return false;
# 		Object property = getProperty(MIRRORED);
# 		return property instanceof Boolean && (Boolean) property;
# 	}
#
#
# 旧代码代码：	public boolean isMirrored() {
# 		Object property = getProperty(MIRRORED);
# 		return property instanceof Boolean && (Boolean) property;
# 	}
#
# ['<s>', 'HBase', 'region', 'cut', 'size', ',', 'in', 'GB', '</s>', 'public float getKylinHBaseRegionCut () {', 'return Float . valueOf ( getOptional (" kylin . hbase . region . cut ", " 5 . 0 "));', '}']
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return Float . valueOf ( getOptional (" kylin . hbase . region . cut ", " 5 . 0 "));', 'public float getKylinHBaseRegionCut () {', 'in', 'cut', 'size']
# , tensor([2.8897, 0.3537, 0.1796, 0.1370, 0.1094], dtype=torch.float64)
# , tensor([10,  9,  6,  3,  4])
# ,['GB', 'HBase', ',', 'region', '<s>']
# ,tensor([-0.3601, -0.1782, -0.0656, -0.0384,  0.0000], dtype=torch.float64)
# ,tensor([7, 1, 5, 2, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public float getKylinHBaseRegionCut() {
#         return Float.valueOf(getOptional("kylin.hbase.region.cut", "5.0"));
#     }
#
# 旧代码代码：    public float getKylinHBaseRegionCut() {
#         return Float.valueOf(getOptional("kylin.hbase.region.cut", "1.0"));
#     }
#
# ['<s>', 'Build', 'a', 'Ravioli', 'client', '</s>', 'public Lob build () {', 'return new Lob ( this );', '}']
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public Lob build () {', 'Ravioli', 'client', 'return new Lob ( this );', '<s>']
# , tensor([0.5179, 0.4121, 0.1617, 0.1231, 0.0000], dtype=torch.float64)
# , tensor([6, 3, 4, 7, 0])
# ,['Build', '}', 'a', '<s>', '</s>']
# ,tensor([-0.6778, -0.1896, -0.0339,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([1, 8, 2, 0, 5])
#
# 对比以下代码查看代码更改位置
# 新代码：        public Lob build() {
#             return new Lob(this);
#         }
#
#
# 旧代码代码：        public Ravioli build() {
#             return new Ravioli(this);
#         }
#
# 解析错误
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Create', 'a', 'web', 'page', 'using', 'the', 'given', 'template', ',', 'SecurityContext', 'and', 'model', 'data', '.', '</s>', 'public static Viewable create ( final boolean authEnabled , final String templateName , final SecurityContext sc ) {', 'return new ViewableWithPermissions ( authEnabled , templateName , sc , true , null );', '}']
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['SecurityContext', 'return new ViewableWithPermissions ( authEnabled , templateName , sc , true , null );', 'and', 'template', 'data']
# , tensor([0.6211, 0.3100, 0.2363, 0.0821, 0.0567], dtype=torch.float64)
# , tensor([10, 17, 11,  8, 13])
# ,['using', 'given', 'public static Viewable create ( final boolean authEnabled , final String templateName , final SecurityContext sc ) {', 'the', 'page']
# ,tensor([-0.2963, -0.2077, -0.1524, -0.1010, -0.0862], dtype=torch.float64)
# ,tensor([ 5,  7, 16,  6,  4])
#
# 对比以下代码查看代码更改位置
# 新代码：  public static Viewable create(final boolean authEnabled, final String templateName, final SecurityContext sc) {
#     return new ViewableWithPermissions(authEnabled, templateName, sc, true, null);
#   }
#
# 旧代码代码：  public static Viewable create(final String templateName, final SecurityContext sc, final Object model) {
#     return new ViewableWithPermissions(templateName, sc, true, model);
#   }
#
# ['<s>', 'Loads', 'item', 'sprite', 'from', 'game', ',', 'makes', 'transparent', ',', 'and', 'generates', 'image', '</s>', 'private BufferedImage loadImage ( int itemId , int quantity , boolean stackable )', '{', 'SpritePixels sprite = client . get (). createItemSprite ( itemId , quantity , 1 , SpritePixels . DEFAULT _ SHADOW _ COLOR ,', 'stackable ? 1 : 0 , false , CLIENT _ DEFAULT _ ZOOM );', 'return sprite . toBufferedImage ();', '}']
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['stackable ? 1 : 0 , false , CLIENT _ DEFAULT _ ZOOM );', 'sprite', 'from', 'SpritePixels sprite = client . get (). createItemSprite ( itemId , quantity , 1 , SpritePixels . DEFAULT _ SHADOW _ COLOR ,', 'makes']
# , tensor([0.7855, 0.5283, 0.4187, 0.3388, 0.3333], dtype=torch.float64)
# , tensor([17,  3,  4, 16,  7])
# ,['private BufferedImage loadImage ( int itemId , int quantity , boolean stackable )', 'and', '<s>', '</s>', 'item']
# ,tensor([-0.4023, -0.0168,  0.0000,  0.0000,  0.0160], dtype=torch.float64)
# ,tensor([14, 10,  0, 13,  2])
#
# 对比以下代码查看代码更改位置
# 新代码：	private BufferedImage loadImage(int itemId, int quantity, boolean stackable)
# 	{
# 		SpritePixels sprite = client.get().createItemSprite(itemId, quantity, 1, SpritePixels.DEFAULT_SHADOW_COLOR,
# 			stackable ? 1 : 0, false, CLIENT_DEFAULT_ZOOM);
# 		return sprite.toBufferedImage();
# 	}
#
# 旧代码代码：	private AsyncBufferedImage loadImage(int itemId, int quantity, boolean stackable)
# 	{
# 		AsyncBufferedImage img = new AsyncBufferedImage(36, 32, BufferedImage.TYPE_INT_ARGB);
# 		clientThread.invokeLater(() ->
# 		{
# 			if (client.getGameState().ordinal() < GameState.LOGIN_SCREEN.ordinal())
# 			{
# 				return false;
# 			}
# 			SpritePixels sprite = client.createItemSprite(itemId, quantity, 1, SpritePixels.DEFAULT_SHADOW_COLOR,
# 				stackable ? 1 : 0, false, CLIENT_DEFAULT_ZOOM);
# 			if (sprite == null)
# 			{
# 				return false;
# 			}
# 			sprite.toBufferedImage(img);
# 			img.changed();
# 			return true;
# 		});
# 		return img;
# 	}
# 解析错误
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[1.6683e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Given', 'a', 'Class', 'of', 'something', 'that', 'extends', 'AsyncSupport', ',', 'it', 'tries', 'to', 'return', 'an', 'instance', 'of', 'that', 'class', '.', '</s>', 'public AsyncSupport newCometSupport ( final Class <? extends AsyncSupport > targetClass ) {', 'try {', 'return ( AsyncSupport ) targetClass . getDeclaredConstructor ( new Class []{ AtmosphereConfig . class })', '. newInstance ( config );', '} catch ( final Exception e ) {', 'logger . error (" Failed to create comet support class : {}, error : {}", targetClass , e );', 'logger . error (" Switching to BlockingIO ");', 'return new BlockingIOCometSupport ( config );', '}', '}']
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return ( AsyncSupport ) targetClass . getDeclaredConstructor ( new Class []{ AtmosphereConfig . class })', '. newInstance ( config );', 'instance', 'logger . error (" Switching to BlockingIO ");', 'something']
# , tensor([0.7969, 0.2248, 0.1927, 0.1810, 0.1639], dtype=torch.float64)
# , tensor([23, 24, 15, 27,  5])
# ,['extends', 'public AsyncSupport newCometSupport ( final Class <? extends AsyncSupport > targetClass ) {', 'a', '.', ',']
# ,tensor([-0.7854, -0.1156, -0.0498, -0.0213, -0.0191], dtype=torch.float64)
# ,tensor([ 7, 21,  2, 19,  9])
#
# 对比以下代码查看代码更改位置
# 新代码：    public AsyncSupport newCometSupport(final Class<? extends AsyncSupport> targetClass) {
#         try {
#             return (AsyncSupport) targetClass.getDeclaredConstructor(new Class[]{AtmosphereConfig.class})
#                     .newInstance(config);
#         } catch (final Exception e) {
#             logger.error("Failed to create comet support class: {}, error: {}", targetClass, e);
#             logger.error("Switching to BlockingIO");
#
#             return new BlockingIOCometSupport(config);
#         }
#     }
#
# 旧代码代码：    public AsyncSupport newCometSupport(final Class<? extends AsyncSupport> targetClass) {
#         try {
#             return targetClass.getDeclaredConstructor(new Class[]{AtmosphereConfig.class})
#                     .newInstance(config);
#         } catch (final Exception e) {
#             logger.error("Failed to create comet support class: {}, error: {}", targetClass, e);
#             logger.error("Switching to BlockingIO");
#
#             return new BlockingIOCometSupport(config);
#         }
#     }
#
# ['<s>', 'Add', 'a', 'tag', 'to', 'the', 'set', 'of', 'filters', '</s>', 'public boolean add ( String tagId , String category ) {', 'return isCategoryValid ( category ) && mSelectedTopics . add ( tagId );', '}']
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return isCategoryValid ( category ) && mSelectedTopics . add ( tagId );', 'public boolean add ( String tagId , String category ) {', '}', 'set', 'filters']
# , tensor([1.2837, 0.9665, 0.0863, 0.0479, 0.0372], dtype=torch.float64)
# , tensor([11, 10, 12,  6,  8])
# ,['to', 'tag', 'Add', 'the', 'of']
# ,tensor([-0.2543, -0.0821, -0.0707, -0.0333, -0.0294], dtype=torch.float64)
# ,tensor([4, 3, 1, 5, 7])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean add(String tagId, String category) {
#         return isCategoryValid(category) && mSelectedTopics.add(tagId);
#     }
#
#
# 旧代码代码：    public boolean add(Tag tag) {
#         return isCategoryValid(tag.getCategory()) && mSelectedTopics.add(tag);
#     }
#
# ['<s>', 'Allow', 'to', 'print', 'directives', '.', '</s>', 'public Options includeDirectives ( boolean flag ) {', 'return new Options ( this . includeIntrospectionTypes , this . includeScalars , this . includeExtendedScalars , this . includeSchemaDefinition , this . useAstDefinitions , this . descriptionsAsHashComments , directive -> flag , this . comparatorRegistry );', '}']
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return new Options ( this . includeIntrospectionTypes , this . includeScalars , this . includeExtendedScalars , this . includeSchemaDefinition , this . useAstDefinitions , this . descriptionsAsHashComments , directive -> flag , this . comparatorRegistry );', 'Allow', 'directives', '}', 'public Options includeDirectives ( boolean flag ) {']
# , tensor([1.5814, 0.6700, 0.5714, 0.2345, 0.2111], dtype=torch.float64)
# , tensor([8, 1, 4, 9, 7])
# ,['to', 'print', '<s>', '</s>', '.']
# ,tensor([-0.0869, -0.0051,  0.0000,  0.0000,  0.0751], dtype=torch.float64)
# ,tensor([2, 3, 0, 6, 5])
#
# 对比以下代码查看代码更改位置
# 新代码：        public Options includeDirectives(boolean flag) {
#             return new Options(this.includeIntrospectionTypes, this.includeScalars, this.includeExtendedScalars, this.includeSchemaDefinition, this.useAstDefinitions, this.descriptionsAsHashComments, directive -> flag, this.comparatorRegistry);
#         }
#
# 旧代码代码：        public Options includeDirectives(boolean flag) {
#             return new Options(this.includeIntrospectionTypes, this.includeScalars, this.includeExtendedScalars, this.includeSchemaDefinition, flag, this.useAstDefinitions, this.descriptionsAsHashComments, this.comparatorRegistry);
#         }
#
# ['<s>', 'Return', 'the', 'list', 'of', 'module', 'prefixes', 'that', 'are', 'defined', 'for', 'this', 'web', 'application', ',', 'creating', 'it', 'if', 'necessary', '.', '</s>', 'public static String [] getModulePrefixes ( ServletContext context ) {', 'return ( String []) context . getAttribute ( Globals . MODULE _ PREFIXES _ KEY );', '}']
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['}', 'application', '.', 'web', ',']
# , tensor([0.1090, 0.0544, 0.0445, 0.0284, 0.0061], dtype=torch.float64)
# , tensor([23, 13, 19, 12, 14])
# ,['public static String [] getModulePrefixes ( ServletContext context ) {', 'return ( String []) context . getAttribute ( Globals . MODULE _ PREFIXES _ KEY );', 'are', 'Return', 'this']
# ,tensor([-0.4402, -0.2437, -0.0862, -0.0639, -0.0447], dtype=torch.float64)
# ,tensor([21, 22,  8,  1, 11])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static String[] getModulePrefixes(ServletContext context) {
#         return (String[]) context.getAttribute(Globals.MODULE_PREFIXES_KEY);
#     }
#
#
# 旧代码代码：    public synchronized static String[] getModulePrefixes(ServletContext context) {
#         // TODO Move prefix list initialization to ActionServlet.init() and unsynchronize
#         // this method in Struts 1.2
#
#         String prefixes[] = (String[]) context.getAttribute(PREFIXES_KEY);
#         if (prefixes != null) {
#             return (prefixes);
#         }
#
#         ArrayList list = new ArrayList();
#         Enumeration names = context.getAttributeNames();
#         while (names.hasMoreElements()) {
#             String name = (String) names.nextElement();
#             if (!name.startsWith(Globals.MODULE_KEY)) {
#                 continue;
#             }
#             String prefix = name.substring(Globals.MODULE_KEY.length());
#             if (prefix.length() > 0) {
#                 list.add(prefix);
#             }
#         }
#         prefixes = (String[]) list.toArray(new String[list.size()]);
#         context.setAttribute(PREFIXES_KEY, prefixes);
#         return (prefixes);
#
#     }
#
# ['<s>', 'Build', 'the', 'column', 'writer', ',', 'and', 'any', 'nested', 'content', ',', 'returning', 'the', 'built', 'column', 'writer', 'as', 'a', 'generic', 'object', 'writer', '.', '</s>', 'private ObjectWriter buildColumn ( ParentShim parent , ColumnMetadata colSchema ) {', 'if ( colSchema . isMultiList ()) {', 'return buildRepeatedList ( parent , colSchema );', '} else if ( colSchema . isMap ()) {', 'return buildMap ( parent , colSchema );', '} else if ( isSingleList ( colSchema )) {', 'return buildSingleList ( parent , colSchema );', '} else if ( colSchema . isVariant ()) {', 'return buildVariant ( parent , colSchema );', '} else if ( colSchema . isDict ()) {', 'return buildDict ( parent , colSchema );', '} else {', 'return buildPrimitive ( parent , colSchema );', '}', '}']
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return buildRepeatedList ( parent , colSchema );', 'writer', 'a', '} else if ( colSchema . isDict ()) {', 'object']
# , tensor([0.4109, 0.3572, 0.3554, 0.3306, 0.2678], dtype=torch.float64)
# , tensor([25,  4, 17, 32, 19])
# ,['private ObjectWriter buildColumn ( ParentShim parent , ColumnMetadata colSchema ) {', 'nested', ',', 'writer', 'writer']
# ,tensor([-0.7314, -0.4292, -0.3095, -0.2349, -0.1584], dtype=torch.float64)
# ,tensor([23,  8,  5, 15, 20])
#
# 对比以下代码查看代码更改位置
# 新代码：  private ObjectWriter buildColumn(ParentShim parent, ColumnMetadata colSchema) {
#     if (colSchema.isMultiList()) {
#       return buildRepeatedList(parent, colSchema);
#     } else if (colSchema.isMap()) {
#       return buildMap(parent, colSchema);
#     } else if (isSingleList(colSchema)) {
#       return buildSingleList(parent, colSchema);
#     } else if (colSchema.isVariant()) {
#       return buildVariant(parent, colSchema);
#     } else if (colSchema.isDict()) {
#       return buildDict(parent, colSchema);
#     } else {
#       return buildPrimitive(parent, colSchema);
#     }
#   }
#
# 旧代码代码：  private ObjectWriter buildColumn(ParentShim parent, ColumnMetadata colSchema) {
#     if (colSchema.isMultiList()) {
#       return buildRepeatedList(parent, colSchema);
#     } else if (colSchema.isMap()) {
#       return buildMap(parent, colSchema);
#     } else if (isSingleList(colSchema)) {
#       return buildSingleList(parent, colSchema);
#     } else if (colSchema.isVariant()) {
#       return buildVariant(parent, colSchema);
#     } else {
#       return buildPrimitive(parent, colSchema);
#     }
#   }
# 解析错误
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# , tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# , tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# 解析错误
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.0947e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Returns', 'true', 'if', ',', 'the', 'lockClient', 'is', 'keeping', 'the', 'lock', 'for', 'the', 'lockPath', '</s>', 'private boolean isKeepLock ( String serverName , String lockPath ) {', 'try {', 'if ( zkClient . checkExists (). forPath ( lockPath ) != null ) {', 'byte [] data = zkClient . getData (). forPath ( lockPath );', 'String lockServerName = new String ( data , Charset . forName (" UTF - 8 "));', 'return lockServerName . equalsIgnoreCase ( serverName );', '}', '} catch ( Exception e ) {', 'logger . error (" fail to get the serverName for the path : " + lockPath , e );', '}', 'return false ;', '}']
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['the', 'the', 'keeping', 'the', 'if']
# , tensor([0.6909, 0.3591, 0.3551, 0.2327, 0.1259], dtype=torch.float64)
# , tensor([ 5,  9,  8, 12,  3])
# ,['lockClient', 'Returns', ',', 'if ( zkClient . checkExists (). forPath ( lockPath ) != null ) {', 'byte [] data = zkClient . getData (). forPath ( lockPath );']
# ,tensor([-0.1936, -0.1583, -0.1417, -0.1368, -0.1368], dtype=torch.float64)
# ,tensor([ 6,  1,  4, 17, 18])
#
# 对比以下代码查看代码更改位置
# 新代码：
#     private boolean isKeepLock(String serverName, String lockPath) {
#         try {
#             if (zkClient.checkExists().forPath(lockPath) != null) {
#                 byte[] data = zkClient.getData().forPath(lockPath);
#                 String lockServerName = new String(data, Charset.forName("UTF-8"));
#                 return lockServerName.equalsIgnoreCase(serverName);
#             }
#         } catch (Exception e) {
#             logger.error("fail to get the serverName for the path: " + lockPath, e);
#         }
#         return false;
#     }
#
#
# 旧代码代码：
#     private boolean isKeepLock(String lockClient, String lockPath) {
#         try {
#             if (zkClient.checkExists().forPath(lockPath) != null) {
#                 byte[] data = zkClient.getData().forPath(lockPath);
#                 String lockServerName = new String(data, Charset.forName("UTF-8"));
#                 return lockServerName.equalsIgnoreCase(lockClient);
#             }
#         } catch (Exception e) {
#             logger.error("fail to get the lockClient for the path: " + lockPath, e);
#         }
#         return false;
#     }
#
# ['<s>', 'Returns', 'the', 'difference', 'between', 'this', 'field', 'property', 'instant', 'and', 'the', 'one', 'passed', 'in', ',', 'in', 'the', 'units', 'of', 'this', 'field', '.', '</s>', 'public long getDifferenceAsLong ( ReadableInstant instant ) {', 'if ( instant == null ) {', 'return getField (). getDifferenceAsLong ( getMillis (), DateTimeUtils . currentTimeMillis ());', '}', 'return getField (). getDifferenceAsLong ( getMillis (), instant . getMillis ());', '}']
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return getField (). getDifferenceAsLong ( getMillis (), DateTimeUtils . currentTimeMillis ());', 'in', '}', '}', 'of']
# , tensor([0.2687, 0.1277, 0.1153, 0.1023, 0.0901], dtype=torch.float64)
# , tensor([25, 15, 28, 26, 18])
# ,['units', 'if ( instant == null ) {', 'public long getDifferenceAsLong ( ReadableInstant instant ) {', 'the', 'property']
# ,tensor([-0.7685, -0.2745, -0.2510, -0.1823, -0.1470], dtype=torch.float64)
# ,tensor([17, 24, 23, 16,  7])
#
# 对比以下代码查看代码更改位置
# 新代码：    public long getDifferenceAsLong(ReadableInstant instant) {
#         if (instant == null) {
#             return getField().getDifferenceAsLong(getMillis(), DateTimeUtils.currentTimeMillis());
#         }
#         return getField().getDifferenceAsLong(getMillis(), instant.getMillis());
#     }
#
# 旧代码代码：    public long getDifferenceAsLong(ReadableInstant instant) {
#         if (instant == null) {
#             return getField().getDifferenceAsLong(getReadableInstant().getMillis(), DateTimeUtils.currentTimeMillis());
#         }
#         return getField().getDifferenceAsLong(getReadableInstant().getMillis(), instant.getMillis());
#     }
#
# ['<s>', 'Unsubscribes', 'the', 'resource', 'from', 'this', 'channel', ',', 'if', 'it', 'exists', '.', '</s>', 'public ResourceRepo removeResource ( Resource resource ) {', 'if (( this . resourceRepos == null ) || ( resource == null )) {', 'return null ;', '}', 'ResourceRepo doomed = null ;', 'for ( ResourceRepo rc : this . resourceRepos ) {', 'if ( resource . equals ( rc . getResourceRepoPK (). getResource ())) {', 'doomed = rc ;', 'break ;', '}', '}', 'if ( doomed != null ) {', 'this . resourceRepos . remove ( doomed );', '}', 'return doomed ;', '}']
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['from', 'channel', 'resource', 'this', 'if (( this . resourceRepos == null ) || ( resource == null )) {']
# , tensor([0.4935, 0.4718, 0.4108, 0.3161, 0.2691], dtype=torch.float64)
# , tensor([ 4,  6,  3,  5, 14])
# ,['public ResourceRepo removeResource ( Resource resource ) {', 'return doomed ;', '.', 'this . resourceRepos . remove ( doomed );', '}']
# ,tensor([-0.3792, -0.2531, -0.1858, -0.1598, -0.1263], dtype=torch.float64)
# ,tensor([13, 27, 11, 25, 28])
#
# 对比以下代码查看代码更改位置
# 新代码：    public ResourceRepo removeResource(Resource resource) {
#         if ((this.resourceRepos == null) || (resource == null)) {
#             return null;
#         }
#
#         ResourceRepo doomed = null;
#
#         for (ResourceRepo rc : this.resourceRepos) {
#             if (resource.equals(rc.getResourceRepoPK().getResource())) {
#                 doomed = rc;
#                 break;
#             }
#         }
#
#         if (doomed != null) {
#             this.resourceRepos.remove(doomed);
#         }
#
#         return doomed;
#     }
#
#
# 旧代码代码：    public ResourceChannel removeResource(Resource resource) {
#         if ((this.resourceChannels == null) || (resource == null)) {
#             return null;
#         }
#
#         ResourceChannel doomed = null;
#
#         for (ResourceChannel rc : this.resourceChannels) {
#             if (resource.equals(rc.getResourceChannelPK().getResource())) {
#                 doomed = rc;
#                 break;
#             }
#         }
#
#         if (doomed != null) {
#             this.resourceChannels.remove(doomed);
#         }
#
#         return doomed;
#     }
#
# 解析错误
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.2066e-05]], grad_fn=<SoftmaxBackward0>)

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>nag</b></text></td><td><text style="padding-right:2em"><b>3.12</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(120, 75%, 78%); opacity:1.0;                     line-height:1.75"><font color="black"> Returns                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> providers                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> that                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> are                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> bound                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> to                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> same                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> location                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> as                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> given                    </font></mark><mark style="background-color: hsl(0, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> ISO                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> 3166                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> code                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height ...

# %%
len(vis_data_records_ig)
# Out:
# 14

# %%
AST_list = []
for i in range(30,60): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])
    
AST_list_old = []
for i in range(30,60): 
    AST_list_old.append(df_clean.loc[i,'old_code_raw'])   
    
comment_list = []
for i in range(30,60): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])

ground_lable = []
for i in range(30,60): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,\
attention_mask_all,token_type_ids_all,all_tokens_all = input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min,code,old_code,_,_ \
    = interpret_sentence_2(AST_list[i],comment_list[i],AST_list_old[i],input_ids_all[i],ref_input_ids_all[i],\
                           token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], all_tokens_all[i],\
                           ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
          {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    print('对比以下代码查看代码更改位置') 
    print(f'新代码：{code}')
    print(f'旧代码代码：{old_code}')
# Out:
# ['<s>', 'Checks', 'if', 'a', 'flag', 'is', 'set', '.', '</s>', 'public boolean isFlagSet ( int flagsToCheck ) {', 'return ( flags & flagsToCheck ) != 0 ;', '}']
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['flag', '.', 'a', 'set', '<s>']
# , tensor([0.1035, 0.0717, 0.0455, 0.0182, 0.0000], dtype=torch.float64)
# , tensor([4, 7, 3, 6, 0])
# ,['public boolean isFlagSet ( int flagsToCheck ) {', 'return ( flags & flagsToCheck ) != 0 ;', '}', 'Checks', 'is']
# ,tensor([-1.4496, -0.2912, -0.2912, -0.0321, -0.0098], dtype=torch.float64)
# ,tensor([ 9, 10, 11,  1,  5])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean isFlagSet(int flagsToCheck) {
#         return (flags & flagsToCheck) != 0;
#     }
#
#
# 旧代码代码：    public boolean isFlagSet(int flag) {
#         return (flags & flag) != 0;
#     }
#
# 解析错误
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.3699e-05]], grad_fn=<SoftmaxBackward0>)
# 解析错误
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[1.0679e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# 解析错误
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Returns', 'a', 'List', 'containing', 'all', 'the', 'child', 'nodes', 'of', 'this', 'node', '.', '</s>', 'protected final Vector getContents () {', 'return _ contents ;', '}']
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Returns', 'protected final Vector getContents () {', 'nodes', '.', 'containing']
# , tensor([0.6879, 0.2965, 0.2574, 0.1522, 0.1509], dtype=torch.float64)
# , tensor([ 1, 14,  8, 12,  4])
# ,['return _ contents ;', '}', 'List', '<s>', '</s>']
# ,tensor([-0.3815, -0.1949, -0.0364,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([15, 16,  3,  0, 13])
#
# 对比以下代码查看代码更改位置
# 新代码：    protected final Vector getContents() {
#         return _contents;
#     }
#
#
# 旧代码代码：    protected final List<SyntaxTreeNode> getContents() {
#         return _contents;
#     }
#
# ['<s>', 'Constructs', 'a', 'new', 'PTBTokenizer', 'that', 'makes', 'CoreLabel', 'tokens', '.', '</s>', 'public static PTBTokenizer < CoreLabel > newPTBTokenizer ( Reader r , boolean tokenizeNLs , boolean invertible ) {', 'return new PTBTokenizer <>( r , tokenizeNLs , invertible , false , new CoreLabelTokenFactory ());', '}']
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static PTBTokenizer < CoreLabel > newPTBTokenizer ( Reader r , boolean tokenizeNLs , boolean invertible ) {', 'Constructs', 'return new PTBTokenizer <>( r , tokenizeNLs , invertible , false , new CoreLabelTokenFactory ());', 'PTBTokenizer', 'that']
# , tensor([0.7783, 0.6486, 0.5558, 0.4316, 0.2584], dtype=torch.float64)
# , tensor([11,  1, 12,  4,  5])
# ,['a', 'makes', '<s>', '</s>', '}']
# ,tensor([-0.0380, -0.0280,  0.0000,  0.0000,  0.0074], dtype=torch.float64)
# ,tensor([ 2,  6,  0, 10, 13])
#
# 对比以下代码查看代码更改位置
# 新代码：  public static PTBTokenizer<CoreLabel> newPTBTokenizer(Reader r, boolean tokenizeNLs, boolean invertible) {
#     return new PTBTokenizer<>(r, tokenizeNLs, invertible, false, new CoreLabelTokenFactory());
#   }
#
# 旧代码代码：  public static PTBTokenizer<CoreLabel> newPTBTokenizer(Reader r, boolean tokenizeNLs, boolean invertible) {
#     return new PTBTokenizer<CoreLabel>(r, tokenizeNLs, invertible, false, new CoreLabelTokenFactory());
#   }
#
# 解析错误
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Expr', ':', 'left', '.', 'endsWith', '(', 'right', ')', '</s>', 'public static EBoolean endsWith ( Expr < String > left , String right ) {', 'return factory . createBoolean ( Ops . ENDSWITH , left , factory . createConstant ( right ));', '}']
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return factory . createBoolean ( Ops . ENDSWITH , left , factory . createConstant ( right ));', 'public static EBoolean endsWith ( Expr < String > left , String right ) {', 'right', 'left', '}']
# , tensor([1.8428, 0.7170, 0.4696, 0.4616, 0.1731], dtype=torch.float64)
# , tensor([11, 10,  7,  3, 12])
# ,['endsWith', 'Expr', '.', ')', '<s>']
# ,tensor([-0.3600, -0.1227, -0.0796, -0.0274,  0.0000], dtype=torch.float64)
# ,tensor([5, 1, 4, 8, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static EBoolean endsWith(Expr<String> left, String right) {
#         return factory.createBoolean(Ops.ENDSWITH, left, factory.createConstant(right));
#     }
#
# 旧代码代码：    public static EBoolean endsWith(Expr<String> left, String right) {
#         return createBoolean(Ops.ENDSWITH, left, createConstant(right));
#     }
#
# ['<s>', 'This', 'method', 'initializes', 'jTextArea', '</s>', 'private ZapTextArea getTxtSkipURL () {', 'if ( txtSkipURL == null ) {', 'txtSkipURL = new ZapTextArea ();', 'txtSkipURL . setFont ( new java . awt . Font (" Default ", java . awt . Font . PLAIN , 11 ));', 'if ( Model . getSingleton (). getOptionsParam (). getViewParam (). getWmUiHandlingOption () == 0 ) {', 'txtSkipURL . setSize ( new java . awt . Dimension ( 290 , 52 ));', '}', '}', 'return txtSkipURL ;', '}']
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['txtSkipURL = new ZapTextArea ();', 'if ( txtSkipURL == null ) {', '<s>', '</s>', 'This']
# , tensor([ 0.3412,  0.0321,  0.0000,  0.0000, -0.0129], dtype=torch.float64)
# , tensor([8, 7, 0, 5, 1])
# ,['jTextArea', 'txtSkipURL . setFont ( new java . awt . Font (" Default ", java . awt . Font . PLAIN , 11 ));', 'if ( Model . getSingleton (). getOptionsParam (). getViewParam (). getWmUiHandlingOption () == 0 ) {', 'initializes', 'private ZapTextArea getTxtSkipURL () {']
# ,tensor([-0.6774, -0.5152, -0.3963, -0.3844, -0.3300], dtype=torch.float64)
# ,tensor([ 4,  9, 10,  3,  6])
#
# 对比以下代码查看代码更改位置
# 新代码：    private ZapTextArea getTxtSkipURL() {
#         if (txtSkipURL == null) {
#             txtSkipURL = new ZapTextArea();
#             txtSkipURL.setFont(new java.awt.Font("Default", java.awt.Font.PLAIN, 11));
#     	    if (Model.getSingleton().getOptionsParam().getViewParam().getWmUiHandlingOption() == 0) {
#     	    	txtSkipURL.setSize(new java.awt.Dimension(290,52));
#     	    }
#         }
#         return txtSkipURL;
#     }
#
# 旧代码代码：    private JTextArea getTxtSkipURL() {
#         if (txtSkipURL == null) {
#             txtSkipURL = new JTextArea();
#             txtSkipURL.setFont(new java.awt.Font("Default", java.awt.Font.PLAIN, 11));
#     	    if (Model.getSingleton().getOptionsParam().getViewParam().getWmUiHandlingOption() == 0) {
#     	    	txtSkipURL.setSize(new java.awt.Dimension(290,52));
#     	    }
#         }
#         return txtSkipURL;
#     }
# 解析错误
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Determines', 'if', 'a', 'specified', 'set', 'of', 'columns', 'from', 'a', 'specified', 'relational', 'expression', 'are', 'unique', '.', '</s>', 'public static Boolean areColumnsUnique ( RelNode rel , BitSet columns ) {', 'final BuiltInMetadata . ColumnUniqueness metadata =', 'rel . metadata ( BuiltInMetadata . ColumnUniqueness . class );', 'return metadata . areColumnsUnique ( columns , false );', '}']
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['rel . metadata ( BuiltInMetadata . ColumnUniqueness . class );', 'public static Boolean areColumnsUnique ( RelNode rel , BitSet columns ) {', 'return metadata . areColumnsUnique ( columns , false );', 'if', '.']
# , tensor([1.3604, 0.3299, 0.2888, 0.1495, 0.1445], dtype=torch.float64)
# , tensor([19, 17, 20,  2, 15])
# ,['columns', 'specified', 'relational', 'set', 'a']
# ,tensor([-0.1375, -0.0837, -0.0733, -0.0531, -0.0502], dtype=torch.float64)
# ,tensor([ 7,  4, 11,  5,  3])
#
# 对比以下代码查看代码更改位置
# 新代码：  public static Boolean areColumnsUnique(RelNode rel, BitSet columns) {
#     final BuiltInMetadata.ColumnUniqueness metadata =
#         rel.metadata(BuiltInMetadata.ColumnUniqueness.class);
#     return metadata.areColumnsUnique(columns, false);
#   }
#
# 旧代码代码：  public static Boolean areColumnsUnique(RelNode rel, BitSet columns) {
#     return (Boolean) rel.getCluster().getMetadataProvider().getRelMetadata(
#         rel,
#         "areColumnsUnique",
#         new Object[]{columns, false});
#   }
#
# ['<s>', 'Observes', 'connectivity', 'with', 'the', 'Internet', 'with', 'default', 'settings', '.', '</s>', 'public static Observable < Boolean > observeInternetConnectivity () {', 'return observeInternetConnectivity ( DEFAULT _ INITIAL _ PING _ INTERVAL _ IN _ MS ,', 'DEFAULT _ PING _ INTERVAL _ IN _ MS , DEFAULT _ PING _ HOST , DEFAULT _ PING _ PORT ,', 'DEFAULT _ PING _ TIMEOUT _ IN _ MS , new DefaultErrorHandler ());', '}']
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['DEFAULT _ PING _ INTERVAL _ IN _ MS , DEFAULT _ PING _ HOST , DEFAULT _ PING _ PORT ,', 'public static Observable < Boolean > observeInternetConnectivity () {', '}', 'DEFAULT _ PING _ TIMEOUT _ IN _ MS , new DefaultErrorHandler ());', 'with']
# , tensor([0.5332, 0.5204, 0.4639, 0.3806, 0.1530], dtype=torch.float64)
# , tensor([13, 11, 15, 14,  3])
# ,['return observeInternetConnectivity ( DEFAULT _ INITIAL _ PING _ INTERVAL _ IN _ MS ,', 'default', 'settings', 'Observes', 'connectivity']
# ,tensor([-0.4362, -0.1942, -0.1024, -0.0636, -0.0289], dtype=torch.float64)
# ,tensor([12,  7,  8,  1,  2])
#
# 对比以下代码查看代码更改位置
# 新代码：  public static Observable<Boolean> observeInternetConnectivity() {
#     return observeInternetConnectivity(DEFAULT_INITIAL_PING_INTERVAL_IN_MS,
#         DEFAULT_PING_INTERVAL_IN_MS, DEFAULT_PING_HOST, DEFAULT_PING_PORT,
#         DEFAULT_PING_TIMEOUT_IN_MS, new DefaultErrorHandler());
#   }
#
# 旧代码代码：  public static Observable<Boolean> observeInternetConnectivity() {
#     return observeInternetConnectivity(DEFAULT_INITIAL_PING_INTERVAL_IN_MS,
#         DEFAULT_PING_INTERVAL_IN_MS, DEFAULT_PING_HOST, DEFAULT_PING_PORT,
#         DEFAULT_PING_TIMEOUT_IN_MS, new DefaultSocketErrorHandler());
#   }
#
# ['<s>', 'Expr', ':', 'left', '.', 'endsWith', '(', 'right', ')', '(', 'ignore', 'case', ')', '</s>', 'public static EBoolean endsWith ( Expr < String > left , String right ) {', 'return operationFactory . createBoolean ( Ops . ENDSWITH , left , exprFactory', '. createConstant ( right ));', '}']
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['left', 'return operationFactory . createBoolean ( Ops . ENDSWITH , left , exprFactory', 'public static EBoolean endsWith ( Expr < String > left , String right ) {', 'right', 'endsWith']
# , tensor([0.4439, 0.4149, 0.3264, 0.2750, 0.2489], dtype=torch.float64)
# , tensor([ 3, 15, 14,  7,  5])
# ,['Expr', '. createConstant ( right ));', '}', '<s>', '</s>']
# ,tensor([-0.4323, -0.2991, -0.2651,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([ 1, 16, 17,  0, 13])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static EBoolean endsWith(Expr<String> left, String right) {
#         return operationFactory.createBoolean(Ops.ENDSWITH, left, exprFactory
#                 .createConstant(right));
#     }
#
# 旧代码代码：    public static EBoolean endsWith(Expr<String> left, String right, boolean caseSensitive) {
#         if (caseSensitive){
#             return endsWith(left, right);
#         }else{
#             return operationFactory.createBoolean(Ops.ENDSWITH_IC, left, exprFactory.createConstant(right));
#         }
#     }
#
# ['<s>', 'Create', 'RelNode', 'tree', 'that', 'produces', 'a', 'list', 'of', 'correlated', 'variables', '.', '</s>', 'private Frame getFrame ( RelNode r , boolean safe ) {', 'final Frame frame = map . get ( r );', 'if ( frame == null && safe ) {', 'return new Frame ( r , r , ImmutableSortedMap . of (),', 'identityMap ( r . getRowType (). getFieldCount ()));', '}', 'return frame ;', '}']
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['private Frame getFrame ( RelNode r , boolean safe ) {', 'final Frame frame = map . get ( r );', 'that', 'identityMap ( r . getRowType (). getFieldCount ()));', 'correlated']
# , tensor([0.6960, 0.4762, 0.3787, 0.3199, 0.3138], dtype=torch.float64)
# , tensor([13, 14,  4, 17,  9])
# ,['tree', 'a', 'variables', 'produces', '}']
# ,tensor([-0.2792, -0.1562, -0.1361, -0.0976, -0.0519], dtype=torch.float64)
# ,tensor([ 3,  6, 10,  5, 18])
#
# 对比以下代码查看代码更改位置
# 新代码：  private Frame getFrame(RelNode r, boolean safe) {
#     final Frame frame = map.get(r);
#     if (frame == null && safe) {
#       return new Frame(r, r, ImmutableSortedMap.of(),
#           identityMap(r.getRowType().getFieldCount()));
#     }
#     return frame;
#   }
#
# 旧代码代码：  private Frame getFrame(RelNode r, boolean safe) {
#     final Frame frame = map.get(r);
#     if (frame == null && safe) {
#       return new Frame(r, r, ImmutableSortedMap.<CorDef, Integer>of(),
#           identityMap(r.getRowType().getFieldCount()));
#     }
#     return frame;
#   }
#
# ['<s>', 'The', '#', 'add', '(', 'Object', '...)', 'method', 'uses', 'Java', 'variable', '-', 'length', 'arguments', 'to', 'pass', 'a', 'row', 'of', 'values', '.', '</s>', 'public RowSetBuilder addSingleCol ( Object value ) {', 'return addRow ( new Object [] { value });', '}']
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['variable', 'add', '-', 'arguments', '...)']
# , tensor([0.2750, 0.1325, 0.1157, 0.0922, 0.0820], dtype=torch.float64)
# , tensor([10,  3, 11, 13,  6])
# ,['public RowSetBuilder addSingleCol ( Object value ) {', 'return addRow ( new Object [] { value });', 'uses', 'method', 'row']
# ,tensor([-1.6130, -1.3023, -0.2885, -0.2685, -0.2350], dtype=torch.float64)
# ,tensor([22, 23,  8,  7, 17])
#
# 对比以下代码查看代码更改位置
# 新代码：  public RowSetBuilder addSingleCol(Object value) {
#     return addRow(new Object[] { value });
#   }
#
# 旧代码代码：  public RowSetBuilder addSingleCol(Object value) {
#     return add(new Object[] { value });
#   }
#
# ['<s>', 'Clone', 'the', 'state', 'of', 'this', 'query', 'to', 'a', 'new', 'JPAQuery', 'instance', 'with', 'the', 'given', 'EntityManager', '</s>', 'public JPAQuery clone ( EntityManager entityManager ){', 'return new JPAQuery ( new DefaultSessionHolder ( entityManager ), getTemplates (), getMetadata (). clone ());', '}']
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return new JPAQuery ( new DefaultSessionHolder ( entityManager ), getTemplates (), getMetadata (). clone ());', 'Clone', 'EntityManager', 'public JPAQuery clone ( EntityManager entityManager ){', 'of']
# , tensor([2.0525, 0.3852, 0.3058, 0.3018, 0.2048], dtype=torch.float64)
# , tensor([18,  1, 15, 17,  4])
# ,['state', 'to', 'query', '<s>', '</s>']
# ,tensor([-0.4289, -0.0487, -0.0334,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([ 3,  7,  6,  0, 16])
#
# 对比以下代码查看代码更改位置
# 新代码：    public JPAQuery clone(EntityManager entityManager){
#         return new JPAQuery(new DefaultSessionHolder(entityManager), getTemplates(), getMetadata().clone());
#     }
#
# 旧代码代码：    public JPAQuery clone(EntityManager entityManager){
#         return new JPAQuery(new DefaultSessionHolder(entityManager), templates, getMetadata().clone());
#     }
# 解析错误
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Retrieve', 'the', 'fetch', 'descriptor', 'associated', 'with', 'the', 'given', 'entity', 'key', '.', '</s>', 'public SubselectFetch getSubselect ( EntityKey key ) {', 'return subselectsByEntityKey . get ( key );', '}']
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Retrieve', 'return subselectsByEntityKey . get ( key );', 'fetch', '.', 'the']
# , tensor([0.9182, 0.2864, 0.2320, 0.0647, 0.0580], dtype=torch.float64)
# , tensor([ 1, 14,  3, 11,  7])
# ,['public SubselectFetch getSubselect ( EntityKey key ) {', 'descriptor', '<s>', '</s>', 'given']
# ,tensor([-0.1046, -0.0460,  0.0000,  0.0000,  0.0159], dtype=torch.float64)
# ,tensor([13,  4,  0, 12,  8])
#
# 对比以下代码查看代码更改位置
# 新代码：	public SubselectFetch getSubselect(EntityKey key) {
# 		return subselectsByEntityKey.get( key );
# 	}
#
# 旧代码代码：	public SubselectFetch getSubselect(EntityKey key) {
# 		return (SubselectFetch) subselectsByEntityKey.get(key);
# 	}
#
# ['<s>', 'Adds', 'a', 'menu', 'item', 'to', 'the', 'bar', 'containing', 'SafeHtml', ',', 'that', 'will', 'fire', 'the', 'given', 'command', 'when', 'it', 'is', 'selected', '.', '</s>', 'public MenuItem addItem ( String text , boolean asHTML , Command cmd ) {', 'return addItem ( new MenuItem ( text , asHTML , cmd ));', '}']
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['SafeHtml', ',', 'containing', 'Adds', 'return addItem ( new MenuItem ( text , asHTML , cmd ));']
# , tensor([0.2906, 0.2116, 0.1474, 0.1321, 0.1194], dtype=torch.float64)
# , tensor([ 9, 10,  8,  1, 24])
# ,['public MenuItem addItem ( String text , boolean asHTML , Command cmd ) {', 'item', 'command', 'fire', 'menu']
# ,tensor([-1.6453, -0.4040, -0.1514, -0.1497, -0.0982], dtype=torch.float64)
# ,tensor([23,  4, 16, 13,  3])
#
# 对比以下代码查看代码更改位置
# 新代码：  public MenuItem addItem(String text, boolean asHTML, Command cmd) {
#     return addItem(new MenuItem(text, asHTML, cmd));
#   }
#
# 旧代码代码：  public MenuItem addItem(SafeHtml html, ScheduledCommand cmd) {
#     return addItem(new MenuItem(html, Roles.getMenuitemRole(), false, cmd));
#   }
#
# ['<s>', 'Provided', 'we', '#', 'supportsInsertSelectIdentity', ',', 'then', 'attach', 'the', '"', 'select', 'identity', '"', 'clause', 'to', 'the', 'insert', 'statement', '.', '</s>', 'public String appendIdentitySelectToInsert ( String insertString ) {', 'return getIdentityColumnSupport (). appendIdentitySelectToInsert ( insertString );', '}']
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           [',', 'statement', 'the', 'to', 'insert']
# , tensor([0.1141, 0.0841, 0.0689, 0.0660, 0.0500], dtype=torch.float64)
# , tensor([ 5, 17, 15, 14, 16])
# ,['supportsInsertSelectIdentity', '#', 'return getIdentityColumnSupport (). appendIdentitySelectToInsert ( insertString );', 'public String appendIdentitySelectToInsert ( String insertString ) {', 'attach']
# ,tensor([-1.5098, -0.4313, -0.4003, -0.1147, -0.0633], dtype=torch.float64)
# ,tensor([ 4,  3, 21, 20,  7])
#
# 对比以下代码查看代码更改位置
# 新代码：	public String appendIdentitySelectToInsert(String insertString) {
# 		return getIdentityColumnSupport().appendIdentitySelectToInsert( insertString );
# 	}
#
# 旧代码代码：	public String appendIdentitySelectToInsert(String insertString) {
# 		return insertString;
# 	}
#
# 解析错误
# 第20个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Create', 'and', 'return', 'a', 'new', 'Field', 'instance', 'that', 'is', 'a', 'copy', 'of', 'this', 'field', 'but', 'with', 'the', 'given', 'default', 'value', '.', '</s>', 'public Field withDefault ( boolean defaultValue ) {', 'return new Field ( name (), displayName (), type (), width , description (), importance (), dependents ,', '() -> Boolean . valueOf ( defaultValue ), validator , recommender );', '}']
# 第21个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['() -> Boolean . valueOf ( defaultValue ), validator , recommender );', 'given', 'return', 'new', 'value']
# , tensor([0.4475, 0.1045, 0.1040, 0.0446, 0.0036], dtype=torch.float64)
# , tensor([25, 18,  3,  5, 20])
# ,['public Field withDefault ( boolean defaultValue ) {', 'with', 'instance', 'default', 'this']
# ,tensor([-1.2973, -0.2412, -0.2180, -0.2030, -0.1492], dtype=torch.float64)
# ,tensor([23, 16,  7, 19, 13])
#
# 对比以下代码查看代码更改位置
# 新代码：    public Field withDefault(boolean defaultValue) {
#         return new Field(name(), displayName(), type(), width, description(), importance(), dependents,
#                 () -> Boolean.valueOf(defaultValue), validator, recommender);
#     }
#
# 旧代码代码：    public Field withDefault(boolean defaultValue) {
#         return Field.create(name(), description(), defaultValue);
#     }
#
# 解析错误
# 第22个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Waits', 'for', 'a', 'given', 'view', '.', '</s>', 'public boolean waitForView ( View view , int timeout ){', 'return waitForView ( view , timeout , true , false );', '}']
# 第23个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['}', '.', 'for', 'public boolean waitForView ( View view , int timeout ){', 'Waits']
# , tensor([0.3654, 0.1115, 0.0671, 0.0204, 0.0190], dtype=torch.float64)
# , tensor([10,  6,  2,  8,  1])
# ,['a', 'return waitForView ( view , timeout , true , false );', 'view', 'given', '<s>']
# ,tensor([-0.1954, -0.0611, -0.0401, -0.0252,  0.0000], dtype=torch.float64)
# ,tensor([3, 9, 5, 4, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：	public boolean waitForView(View view, int timeout){
# 		return waitForView(view, timeout, true, false);
# 	}
#
# 旧代码代码：	public boolean waitForView(View view, int timeout){
# 		return waitForView(view, timeout, true);
# 	}
#
# ['<s>', 'Checks', 'if', 'a', 'flag', 'is', 'set', '.', '</s>', 'public boolean isFlagSet ( int flagsToCheck ) {', 'return isFlagSet ( flags , flagsToCheck );', '}']
# 第24个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return isFlagSet ( flags , flagsToCheck );', '}', 'flag', 'if', '.']
# , tensor([0.5636, 0.2391, 0.0964, 0.0761, 0.0596], dtype=torch.float64)
# , tensor([10, 11,  4,  2,  7])
# ,['public boolean isFlagSet ( int flagsToCheck ) {', 'a', 'Checks', 'is', 'set']
# ,tensor([-0.5474, -0.4287, -0.4109, -0.3230, -0.1748], dtype=torch.float64)
# ,tensor([9, 3, 1, 5, 6])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean isFlagSet(int flagsToCheck) {
#         return isFlagSet(flags, flagsToCheck);
#     }
#
#
# 旧代码代码：    public boolean isFlagSet(int flag) {
#         return (flags & flag) != 0;
#     }
#
# ['<s>', 'Return', 'the', 'length', 'of', 'this', 'String', '</s>', 'public ENumber < Integer > length () {', 'if ( length == null ) {', 'length = ONumber . create ( Integer . class , Ops . STRING _ LENGTH , this );', '}', 'return length ;', '}']
# 第25个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['length = ONumber . create ( Integer . class , Ops . STRING _ LENGTH , this );', 'if ( length == null ) {', '}', '<s>', '</s>']
# , tensor([0.0984, 0.0663, 0.0489, 0.0000, 0.0000], dtype=torch.float64)
# , tensor([10,  9, 13,  0,  7])
# ,['String', 'public ENumber < Integer > length () {', 'of', 'return length ;', 'Return']
# ,tensor([-0.1264, -0.0397, -0.0355, -0.0332, -0.0189], dtype=torch.float64)
# ,tensor([ 6,  8,  4, 12,  1])
#
# 对比以下代码查看代码更改位置
# 新代码：    public ENumber<Integer> length() {
#         if (length == null) {
#             length = ONumber.create(Integer.class, Ops.STRING_LENGTH, this);
#         }
#         return length;
#     }
#
# 旧代码代码：    public ENumber<Long> length() {
#         if (length == null) {
#             length = ONumber.create(Long.class, Ops.STRING_LENGTH, this);
#         }
#         return length;
#     }
# ['<s>', 'Parses', 'a', 'Specification', 'out', 'of', 'the', 'query', 'string', '.', '</s>', 'public static Query parse ( String queryString , BulletConfig config ) {', 'Query query = GSON . fromJson ( queryString , Query . class );', 'query . configure ( config );', 'return query ;', '}']
# 第26个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static Query parse ( String queryString , BulletConfig config ) {', 'Query query = GSON . fromJson ( queryString , Query . class );', 'query . configure ( config );', 'Specification', 'of']
# , tensor([1.0087, 0.9318, 0.6806, 0.5471, 0.2613], dtype=torch.float64)
# , tensor([11, 12, 13,  3,  5])
# ,['return query ;', '}', 'Parses', 'a', '<s>']
# ,tensor([-0.3106, -0.3094, -0.2589, -0.1860,  0.0000], dtype=torch.float64)
# ,tensor([14, 15,  1,  2,  0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static Query parse(String queryString, BulletConfig config) {
#         Query query = GSON.fromJson(queryString, Query.class);
#         query.configure(config);
#         return query;
#     }
#
#
# 旧代码代码：    public static Specification parse(String queryString, BulletConfig config) {
#         Specification specification = GSON.fromJson(queryString, Specification.class);
#         specification.configure(config);
#         return specification;
#     }
#
# ['<s>', 'Expr', ':', 'left', '.', 'startsWith', '(', 'right', ')', '</s>', 'public static EBoolean startsWith ( Expr < String > left , Expr < String > right ) {', 'return factory . createBoolean ( Ops . STARTSWITH , left , right );', '}']
# 第27个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['startsWith', 'public static EBoolean startsWith ( Expr < String > left , Expr < String > right ) {', 'return factory . createBoolean ( Ops . STARTSWITH , left , right );', ')', 'Expr']
# , tensor([0.8412, 0.2433, 0.1225, 0.0465, 0.0364], dtype=torch.float64)
# , tensor([ 5, 10, 11,  8,  1])
# ,['left', 'right', ':', '.', '<s>']
# ,tensor([-0.1289, -0.1203, -0.0169, -0.0037,  0.0000], dtype=torch.float64)
# ,tensor([3, 7, 2, 4, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static EBoolean startsWith(Expr<String> left, Expr<String> right) {
#         return factory.createBoolean(Ops.STARTSWITH, left, right);
#     }
#
# 旧代码代码：    public static EBoolean startsWith(Expr<String> left, Expr<String> right) {
#         return createBoolean(Ops.STARTSWITH, left, right);
#     }
#
# ['<s>', 'Creates', 'and', 'returns', 'a', 'new', 'comparison', 'object', 'for', 'the', 'SQL', '"', 'in', '"', 'operator', '.', '</s>', 'public final DBCompareColExpr in ( Collection <?> values )', '{', 'if ( values == null || values . isEmpty ())', 'return cmp ( DBCmpType . EQUAL , null );', '// create expression', 'return cmp ( DBCmpType . IN , values );', '}']
# 第28个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Creates', '// create expression', 'SQL', '"', '"']
# , tensor([0.2871, 0.2637, 0.1189, 0.1089, 0.0806], dtype=torch.float64)
# , tensor([ 1, 21, 10, 11, 13])
# ,['public final DBCompareColExpr in ( Collection <?> values )', 'return cmp ( DBCmpType . IN , values );', 'comparison', 'return cmp ( DBCmpType . EQUAL , null );', '{']
# ,tensor([-2.3713, -0.2294, -0.2107, -0.1682, -0.1365], dtype=torch.float64)
# ,tensor([17, 22,  6, 20, 18])
#
# 对比以下代码查看代码更改位置
# 新代码：    public final DBCompareColExpr in(Collection<?> values)
#     {
#         if (values==null || values.isEmpty())
#             return cmp(DBCmpType.EQUAL, null);
#         // create expression
#         return cmp(DBCmpType.IN, values);
#     }
#
#
# 旧代码代码：    public DBCompareColExpr in(Object value)
#     {
#         return cmp(DBCmpType.IN, listToArray(value));
#     }
#
# ['<s>', 'Returns', 'the', 'URL', 'where', 'you', 'should', 'redirect', 'your', 'users', 'to', 'authenticate', 'your', 'application', '.', '</s>', 'public String getAuthorizationUrl () {', 'return createAuthorizationUrlBuilder (). build ();', '}']
# 第29个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return createAuthorizationUrlBuilder (). build ();', 'public String getAuthorizationUrl () {', 'authenticate', 'where', 'your']
# , tensor([2.0637, 0.3792, 0.2050, 0.1460, 0.1046], dtype=torch.float64)
# , tensor([17, 16, 11,  4, 12])
# ,['redirect', 'URL', '<s>', '</s>', 'application']
# ,tensor([-0.0241, -0.0168,  0.0000,  0.0000,  0.0200], dtype=torch.float64)
# ,tensor([ 7,  3,  0, 15, 13])
#
# 对比以下代码查看代码更改位置
# 新代码：    public String getAuthorizationUrl() {
#         return createAuthorizationUrlBuilder().build();
#     }
#
# 旧代码代码：    public String getAuthorizationUrl() {
#         return getAuthorizationUrl(null, null, null);
#     }

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>0.991 (0.99)</b></text></td><td><text style="padding-right:2em"><b>pos</b></text></td><td><text style="padding-right:2em"><b>-1.84</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> Checks                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> if                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> flag                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> is                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> set                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> .                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> public boolean isFlagSet ( int flagsToCheck ) {                    </font></mark><mark style="background-color: hsl(0, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> return ( flags & flagsToCheck ) != 0 ;                    </font></mark><mark style="background-color: hsl(0, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>pos</b></text></td><td><text style="padding-right:2em"><b>1.36</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(120, 75%, 66%); opacity:1.0;                     line-height:1.75"><font color="black"> Returns                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> List                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.7 ...

# %%
AST_list = []
for i in range(60,100): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])
AST_list_old = []
for i in range(60,100): 
    AST_list_old.append(df_clean.loc[i,'old_code_raw'])   
    
comment_list = []
for i in range(60,100): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])

ground_lable = []
for i in range(60,100): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,\
attention_mask_all,token_type_ids_all,all_tokens_all = input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min,code,old_code,_,_ \
    = interpret_sentence_2(AST_list[i],comment_list[i],AST_list_old[i],input_ids_all[i],ref_input_ids_all[i],\
                           token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], all_tokens_all[i],\
                           ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
          {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    print('对比以下代码查看代码更改位置') 
    print(f'新代码：{code}')
    print(f'旧代码代码：{old_code}')
# Out:
# ['<s>', 'Method', 'for', 'getting', 'counts', 'using', 'named', 'filters', '</s>', 'public boolean equals ( Object obj ) {', 'if ( obj == null ) {', 'return false ;', '}', 'if ( obj == this ) {', 'return true ;', '}', 'if ( obj . getClass () != getClass ()) {', 'return false ;', '}', 'FiltersAggregation rhs = ( FiltersAggregation ) obj ;', 'return super . equals ( obj ) && Objects . equals ( bucketMap , rhs . bucketMap );', '}']
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['using', 'return false ;', 'if ( obj . getClass () != getClass ()) {', 'return false ;', '}']
# , tensor([0.6307, 0.5441, 0.3072, 0.3072, 0.3072], dtype=torch.float64)
# , tensor([ 5, 11, 16, 17, 18])
# ,['Method', 'for', 'getting', 'counts', '<s>']
# ,tensor([-0.2107, -0.1108, -0.1105, -0.1024,  0.0000], dtype=torch.float64)
# ,tensor([1, 2, 3, 4, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean equals(Object obj) {
#         if (obj == null) {
#             return false;
#         }
#         if (obj == this) {
#             return true;
#         }
#         if (obj.getClass() != getClass()) {
#             return false;
#         }
#
#         FiltersAggregation rhs = (FiltersAggregation) obj;
#         return super.equals(obj) && Objects.equals(bucketMap, rhs.bucketMap);
#     }
#
# 旧代码代码：    public boolean equals(Object obj) {
#         if (obj == null) {
#             return false;
#         }
#         if (obj == this) {
#             return true;
#         }
#         if (obj.getClass() != getClass()) {
#             return false;
#         }
#
#         FiltersAggregation rhs = (FiltersAggregation) obj;
#         return new EqualsBuilder()
#                 .appendSuper(super.equals(obj))
#                 .append(bucketMap, rhs.bucketMap)
#                 .isEquals();
#     }
#
# ['<s>', 'Returns', 'all', 'currently', 'displayed', 'sentences', 'in', 'string', 'buffer', ',', 'plain', 'text', 'form', '</s>', 'public String getMatchedSentences () {', 'StringBuilder sb = new StringBuilder ();', 'for ( int i = 0 , sz = list . getModel (). getSize (); i < sz ; i ++) {', 'String t = list . getModel (). getElementAt ( i ). getLabel (). getText ();', 'sb . append ( t );', 'sb . append ("\\n ");', '}', 'return sb . toString ();', '}']
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['currently', 'sb . append ( t );', 'plain', 'buffer', 'return sb . toString ();']
# , tensor([0.1007, 0.0993, 0.0774, 0.0656, 0.0437], dtype=torch.float64)
# , tensor([ 3, 18, 10,  8, 21])
# ,['form', 'sentences', 'displayed', 'for ( int i = 0 , sz = list . getModel (). getSize (); i < sz ; i ++) {', 'public String getMatchedSentences () {']
# ,tensor([-0.5463, -0.4750, -0.3753, -0.3597, -0.2345], dtype=torch.float64)
# ,tensor([12,  5,  4, 16, 14])
#
# 对比以下代码查看代码更改位置
# 新代码：  public String getMatchedSentences() {
#     StringBuilder sb = new StringBuilder();
#     for (int i = 0, sz = list.getModel().getSize(); i < sz; i++) {
#       String t = list.getModel().getElementAt(i).getLabel().getText();
#       sb.append(t);
#       sb.append("\n");
#     }
#     return sb.toString();
#   }
#
#
# 旧代码代码：  public StringBuffer getMatchedSentences() {
#     StringBuffer sb = new StringBuffer();
#     for(int i = 0; i < list.getModel().getSize(); i++) {
#       String t = ((TreeFromFile) list.getModel().getElementAt(i)).getLabel().getText();
#       sb.append(t);
#       sb.append("\n");
#     }
#     return sb;
#   }
#
# ['<s>', 'Returns', 'newest', 'checkmark', 'that', 'has', 'already', 'been', 'computed', '.', '</s>', 'protected Checkmark findNewest ()', '{', 'return new Select (). from ( Checkmark . class )', '. where (" habit = ?", habit . getId ())', '. and (" timestamp <= ?", DateUtils . getStartOfToday ())', '. orderBy (" timestamp desc ")', '. limit ( 1 )', '. executeSingle ();', '}']
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['protected Checkmark findNewest ()', 'checkmark', '. where (" habit = ?", habit . getId ())', '. and (" timestamp <= ?", DateUtils . getStartOfToday ())', '. orderBy (" timestamp desc ")']
# , tensor([0.8880, 0.6231, 0.6059, 0.6059, 0.6059], dtype=torch.float64)
# , tensor([11,  3, 14, 15, 16])
# ,['Returns', 'already', 'has', 'return new Select (). from ( Checkmark . class )', 'newest']
# ,tensor([-0.1635, -0.1509, -0.0911, -0.0487, -0.0408], dtype=torch.float64)
# ,tensor([ 1,  6,  5, 13,  2])
#
# 对比以下代码查看代码更改位置
# 新代码：    protected Checkmark findNewest()
#     {
#         return new Select().from(Checkmark.class)
#                 .where("habit = ?", habit.getId())
#                 .and("timestamp <= ?", DateUtils.getStartOfToday())
#                 .orderBy("timestamp desc")
#                 .limit(1)
#                 .executeSingle();
#     }
#
# 旧代码代码：    protected Checkmark findNewest()
#     {
#         return new Select().from(Checkmark.class)
#                 .where("habit = ?", habit.getId())
#                 .and("timestamp <= ?", DateHelper.getStartOfToday())
#                 .orderBy("timestamp desc")
#                 .limit(1)
#                 .executeSingle();
#     }
#
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public static List handleHTML ( HttpURLConnection httpCon ) throws IOException {', 'ContentHandler handler = new HTMLHandler ();', 'handler . parse ( httpCon . getInputStream ());', 'if ( handler . getRobotFollow ()) {', 'List links = handler . getLinks ();', 'return links ;', '}', 'return null ;', '}']
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static List handleHTML ( HttpURLConnection httpCon ) throws IOException {', 'DOCUMENT', 'List links = handler . getLinks ();', 'handler . parse ( httpCon . getInputStream ());', 'if ( handler . getRobotFollow ()) {']
# , tensor([1.1746, 0.6392, 0.5268, 0.4863, 0.3490], dtype=torch.float64)
# , tensor([5, 1, 9, 7, 8])
# ,['}', 'return null ;', '!', '<s>', '</s>']
# ,tensor([-0.2687, -0.2524, -0.0009,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([13, 12,  3,  0,  4])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static List handleHTML(HttpURLConnection httpCon) throws IOException {
#         ContentHandler handler = new HTMLHandler();
#         handler.parse(httpCon.getInputStream());
#
#         if (handler.getRobotFollow()) {
#             List links = handler.getLinks();
#             return links;
#         }
#
#         return null;
#     }
#
#
# 旧代码代码：    public static java.util.List handleHTML(HttpURLConnection httpCon)
#         throws java.io.IOException {
#         ContentHandler handler = new HTMLHandler();
#         handler.parse(httpCon.getInputStream());
#
#         if (handler.getRobotFollow()) {
#             java.util.List links = handler.getLinks();
#
#             return links;
#         }
#
#         return null;
#     }
#
# ['<s>', 'Searches', 'for', 'a', 'text', 'string', 'and', 'returns', 'true', 'if', 'the', 'searched', 'text', 'is', 'found', 'a', 'given', 'number', 'of', 'times', '.', '</s>', 'public boolean searchText ( String regex , int matches , boolean scroll ) {', 'return searcher . searchText ( regex , matches , scroll );', '}']
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['for', 'times', 'text', 'found', 'number']
# , tensor([0.5413, 0.2462, 0.1955, 0.1853, 0.1698], dtype=torch.float64)
# , tensor([ 2, 19,  4, 14, 17])
# ,['public boolean searchText ( String regex , int matches , boolean scroll ) {', 'returns', 'true', 'searched', '}']
# ,tensor([-0.7023, -0.3370, -0.2634, -0.1684, -0.1156], dtype=torch.float64)
# ,tensor([22,  7,  8, 11, 24])
#
# 对比以下代码查看代码更改位置
# 新代码：	public boolean searchText(String regex, int matches, boolean scroll) {
# 		return searcher.searchText(regex, matches, scroll);
# 	}
#
# 旧代码代码：	public boolean searchText(String search, int matches, boolean scroll) {
# 		return searcher.searchText(search, matches, scroll);
# 	}
#
# ['<s>', 'Returns', 'all', 'currently', 'displayed', 'sentences', 'in', 'plain', 'text', 'form', '.', '</s>', 'public StringBuffer getMatchedSentences () {', 'StringBuffer sb = new StringBuffer ();', 'for ( int i = 0 ; i < list . getModel (). getSize (); i ++) {', 'String t = (( TreeFromFile ) list . getModel (). getElementAt ( i )). getLabel (). getText ();', 'sb . append ( t );', 'sb . append ("\\n ");', '}', 'return sb ;', '}']
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['String t = (( TreeFromFile ) list . getModel (). getElementAt ( i )). getLabel (). getText ();', 'sentences', 'for ( int i = 0 ; i < list . getModel (). getSize (); i ++) {', 'sb . append ("\\n ");', 'in']
# , tensor([0.5902, 0.4916, 0.3941, 0.3698, 0.3367], dtype=torch.float64)
# , tensor([15,  5, 14, 17,  6])
# ,['}', 'return sb ;', 'public StringBuffer getMatchedSentences () {', 'text', 'currently']
# ,tensor([-0.4917, -0.4467, -0.4153, -0.1958, -0.1912], dtype=torch.float64)
# ,tensor([20, 19, 12,  8,  3])
#
# 对比以下代码查看代码更改位置
# 新代码：  public StringBuffer getMatchedSentences() {
#     StringBuffer sb = new StringBuffer();
#     for(int i = 0; i < list.getModel().getSize(); i++) {
#       String t = ((TreeFromFile) list.getModel().getElementAt(i)).getLabel().getText();
#       sb.append(t);
#       sb.append("\n");
#     }
#     return sb;
#   }
#
#
# 旧代码代码：  public String getMatchedSentences() {
#     StringBuilder sb = new StringBuilder();
#     for (int i = 0, sz = list.getModel().getSize(); i < sz; i++) {
#       String t = ((TreeFromFile) list.getModel().getElementAt(i)).getLabel().getText();
#       sb.append(t);
#       sb.append("\n");
#     }
#     return sb.toString();
#   }
# ['<s>', 'This', 'method', 'initializes', 'panelCommand', '</s>', 'private TableExportButton getExportButton () {', 'if ( exportButton == null ) {', 'exportButton = new TableExportButton ( getParamsTable ());', '}', 'return exportButton ;', '}']
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['exportButton = new TableExportButton ( getParamsTable ());', 'return exportButton ;', 'if ( exportButton == null ) {', 'This', 'private TableExportButton getExportButton () {']
# , tensor([0.3129, 0.2814, 0.2119, 0.1710, 0.1692], dtype=torch.float64)
# , tensor([ 8, 10,  7,  1,  6])
# ,['panelCommand', 'initializes', '<s>', '</s>', 'method']
# ,tensor([-0.4162, -0.3393,  0.0000,  0.0000,  0.0019], dtype=torch.float64)
# ,tensor([4, 3, 0, 5, 2])
#
# 对比以下代码查看代码更改位置
# 新代码：	private TableExportButton getExportButton() {
# 		if (exportButton == null) {
# 			exportButton = new TableExportButton(getParamsTable());
# 		}
# 		return exportButton;
# 	}
#
# 旧代码代码：	private JButton getExportButton() {
# 		JButton csvExportButton = new JButton(Constant.messages.getString("params.toolbar.button.export"));
# 		csvExportButton.setIcon(new ImageIcon(ParamsPanel.class.getResource("/resource/icon/16/115.png")));
# 		csvExportButton.addActionListener((new AbstractAction() {
# 			private static final long serialVersionUID = 1L;
#
# 			@Override
# 			public void actionPerformed(ActionEvent e) {
# 				WritableFileChooser chooser = new WritableFileChooser();
# 				chooser.setSelectedFile(new File(Constant.messages.getString("params.button.export.default.name")));
# 				if (chooser
# 						.showSaveDialog(View.getSingleton().getMainFrame()) == WritableFileChooser.APPROVE_OPTION) {
# 					String file = chooser.getSelectedFile().toString();
# 					if (!file.endsWith(".csv")) {
# 						file += ".csv";
# 					}
# 					try (CSVPrinter pw = new CSVPrinter(
# 							Files.newBufferedWriter(chooser.getSelectedFile().toPath(), StandardCharsets.UTF_8),
# 							CSVFormat.DEFAULT)) {
# 						pw.printRecord(((ParamsTableModel) paramsTable.getModel()).getColumnNames());
# 						int rowCount = paramsTable.getRowCount();
# 						int colCount = paramsTable.getColumnCount();
# 						for (int row = 0; row < rowCount; row++) {
# 							List<Object> valueOfRow = new ArrayList<Object>();
# 							for (int col = 0; col < colCount; col++) {
# 								valueOfRow.add(paramsTable.getValueAt(row, col));
# 							}
# 							pw.printRecord(valueOfRow);
# 						}
# 						JOptionPane.showMessageDialog(View.getSingleton().getMainFrame(),
# 								Constant.messages.getString("params.button.export.success"));
# 					} catch (Exception ex) {
# 						JOptionPane.showMessageDialog(View.getSingleton().getMainFrame(),
# 								Constant.messages.getString("params.button.export.error") + "\n"
# 										+ ex.getLocalizedMessage());
# 						LOGGER.error("Export Failed: " + ex);
# 					}
# 				}
# 			}
# 		}));
# 		return csvExportButton;
# 	}
#
# ['<s>', 'If', 'a', 'Schema', 'contains', 'a', 'reference', 'to', 'an', 'other', 'Schema', 'with', "'$", 'ref', "',", 'returns', 'the', 'referenced', 'Schema', 'or', 'the', 'actual', 'Schema', 'in', 'the', 'other', 'cases', '.', '</s>', 'public static Schema getReferencedSchema ( OpenAPI openAPI , Schema schema ) {', 'if ( schema != null && StringUtils . isNotEmpty ( schema . get $ ref ())) {', 'String name = getSimpleRef ( schema . get $ ref ());', 'Schema referencedSchema = getSchema ( openAPI , name );', 'if ( referencedSchema != null ) {', 'return referencedSchema ;', '}', '}', 'return schema ;', '}']
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static Schema getReferencedSchema ( OpenAPI openAPI , Schema schema ) {', 'if ( schema != null && StringUtils . isNotEmpty ( schema . get $ ref ())) {', 'Schema referencedSchema = getSchema ( openAPI , name );', 'String name = getSimpleRef ( schema . get $ ref ());', 'if ( referencedSchema != null ) {']
# , tensor([0.8027, 0.5698, 0.4755, 0.3136, 0.2468], dtype=torch.float64)
# , tensor([29, 30, 32, 31, 33])
# ,['}', 'return schema ;', 'If', 'to', '.']
# ,tensor([-0.1275, -0.1032, -0.0324, -0.0222, -0.0211], dtype=torch.float64)
# ,tensor([38, 37,  1,  7, 27])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static Schema getReferencedSchema(OpenAPI openAPI, Schema schema) {
#         if (schema != null && StringUtils.isNotEmpty(schema.get$ref())) {
#             String name = getSimpleRef(schema.get$ref());
#             Schema referencedSchema = getSchema(openAPI, name);
#             if(referencedSchema != null) {
#                 return referencedSchema;
#             }
#         }
#         return schema;
#     }
#
# 旧代码代码：    public static Schema getReferencedSchema(OpenAPI openAPI, Schema schema) {
#         if (schema != null && StringUtils.isNotEmpty(schema.get$ref())) {
#             String name = getSimpleRef(schema.get$ref());
#             return getSchema(openAPI, name);
#         }
#         return schema;
#     }
#
# ['<s>', 'Returns', 'a', 'List', 'of', 'the', 'GridViews', 'contained', 'in', 'the', 'current', 'Activity', '.', '</s>', 'public ArrayList < GridView > getCurrentGridViews () {', 'return getCurrentViews ( GridView . class );', '}']
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['}', 'GridViews', 'the', 'in', 'Returns']
# , tensor([0.2963, 0.2390, 0.1082, 0.0217, 0.0107], dtype=torch.float64)
# , tensor([16,  6,  5,  8,  1])
# ,['public ArrayList < GridView > getCurrentGridViews () {', 'return getCurrentViews ( GridView . class );', 'Activity', 'contained', 'List']
# ,tensor([-0.9096, -0.5841, -0.4513, -0.2639, -0.2471], dtype=torch.float64)
# ,tensor([14, 15, 11,  7,  3])
#
# 对比以下代码查看代码更改位置
# 新代码：	public ArrayList<GridView> getCurrentGridViews() {
# 		return getCurrentViews(GridView.class);
# 	}
#
# 旧代码代码：	public ArrayList<GridView> getCurrentGridViews() {
# 		ArrayList<GridView> gridViewList = new ArrayList<GridView>();
# 		ArrayList<View> viewList = getViews();
# 		for(View view : viewList){
# 			if (view instanceof android.widget.GridView)
# 				gridViewList.add((GridView) view);
# 		}
# 		return gridViewList;
# 	}
#
# ['<s>', 'Ensure', 'that', 'correct', 'implementation', 'is', 'used', 'for', 'the', 'component', '.', '</s>', 'public boolean updateComponent ( Widget component , UIDL uidl ,', 'boolean manageCaption ) {', '// Switch to correct implementation if neede', 'if (! widgetFactory . isCorrectImplementation ( component , uidl )) {', 'Layout parent = getParentLayout ( component );', 'if ( parent != null ) {', 'Widget w = widgetFactory . createWidget ( uidl );', 'registerPaintable ( uidl . getId (), ( Paintable ) w );', 'parent . replaceChildComponent ( component , w );', '(( Paintable ) w ). updateFromUIDL ( uidl , this );', 'return true ;', '}', '}', '// Set captions', '// TODO Manage Error messages', 'if ( manageCaption ) {', 'Layout parent = getParentLayout ( component );', 'if ( parent != null )', 'parent . updateCaption ( component , uidl );', '}', '// Visibility , Disabling and read - only status', 'if ( component instanceof FocusWidget )', '(( FocusWidget ) component ). setEnabled (! uidl', '. getBooleanAttribute (" disabled "));', 'boolean visible = ! uidl . getBooleanAttribute (" invisible ");', 'component . setVisible ( visible );', 'if (! visible )', 'return true ;', 'return false ;', '}']
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return true ;', 'if (! visible )', 'component . setVisible ( visible );', '}', 'boolean visible = ! uidl . getBooleanAttribute (" invisible ");']
# , tensor([1.1046, 1.1046, 1.1046, 1.1046, 1.1046], dtype=torch.float64)
# , tensor([39, 38, 37, 41, 36])
# ,['implementation', 'for', 'is', 'the', 'correct']
# ,tensor([-0.6713, -0.2657, -0.2599, -0.1477, -0.1172], dtype=torch.float64)
# ,tensor([4, 7, 5, 8, 3])
#
# 对比以下代码查看代码更改位置
# 新代码：	public boolean updateComponent(Widget component, UIDL uidl,
# 			boolean manageCaption) {
#
# 		// Switch to correct implementation if neede
# 		if (!widgetFactory.isCorrectImplementation(component, uidl)) {
# 			Layout parent = getParentLayout(component);
# 			if (parent != null) {
# 				Widget w = widgetFactory.createWidget(uidl);
# 				registerPaintable(uidl.getId(), (Paintable) w);
# 				parent.replaceChildComponent(component, w);
# 				((Paintable) w).updateFromUIDL(uidl, this);
# 				return true;
# 			}
# 		}
#
# 		// Set captions
# 		// TODO Manage Error messages
# 		if (manageCaption) {
# 			Layout parent = getParentLayout(component);
# 			if (parent != null)
# 				parent.updateCaption(component, uidl);
# 		}
#
# 		// Visibility, Disabling and read-only status
# 		if (component instanceof FocusWidget)
# 			((FocusWidget) component).setEnabled(!uidl
# 					.getBooleanAttribute("disabled"));
# 		boolean visible = !uidl.getBooleanAttribute("invisible");
# 		component.setVisible(visible);
# 		if (!visible)
# 			return true;
#
# 		return false;
# 	}
#
#
# 旧代码代码：	public boolean updateComponent(Widget component, UIDL uidl,
# 			boolean manageCaption) {
#
# 		if (manageCaption) {
# 			Layout parent = getParentLayout(component);
# 			if (parent != null)
# 				parent.updateCaption(component, uidl);
# 		}
#
# 		boolean visible = !uidl.getBooleanAttribute("invisible");
# 		component.setVisible(visible);
# 		if (!visible) return true;
#
# 		if (widgetFactory.isCorrectImplementation(component, uidl))
# 			return false;
# 		Layout parent = getParentLayout(component);
# 		if (parent == null)
# 			return false;
# 		Widget w = widgetFactory.createWidget(uidl);
# 		registerPaintable(uidl.getId(), (Paintable) w);
# 		parent.replaceChildComponent(component, w);
# 		((Paintable) w).updateFromUIDL(uidl, this);
#
# 		return true;
# 	}
# ['<s>', 'Gets', 'the', 'matching', 'http', 'session', 'for', 'a', 'particular', 'message', 'containing', 'a', 'list', 'of', 'cookies', '.', '</s>', 'private HttpSession getMatchingHttpSession ( List < HttpCookie > cookies , final HttpSessionTokensSet siteTokens ) {', 'Collection < HttpSession > sessionsCopy ;', 'synchronized ( sessions ) {', 'sessionsCopy = new ArrayList <>( sessions );', '}', 'return CookieBasedSessionManagementHelper . getMatchingHttpSession ( sessionsCopy , cookies , siteTokens );', '}']
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['sessionsCopy = new ArrayList <>( sessions );', 'return CookieBasedSessionManagementHelper . getMatchingHttpSession ( sessionsCopy , cookies , siteTokens );', 'matching', 'synchronized ( sessions ) {', 'message']
# , tensor([1.1140, 0.6693, 0.4484, 0.4398, 0.1596], dtype=torch.float64)
# , tensor([20, 22,  3, 19,  9])
# ,['http', 'private HttpSession getMatchingHttpSession ( List < HttpCookie > cookies , final HttpSessionTokensSet siteTokens ) {', 'Gets', 'for', 'particular']
# ,tensor([-0.6129, -0.2006, -0.1848, -0.1694, -0.1213], dtype=torch.float64)
# ,tensor([ 4, 17,  1,  6,  8])
#
# 对比以下代码查看代码更改位置
# 新代码：	private HttpSession getMatchingHttpSession(List<HttpCookie> cookies, final HttpSessionTokensSet siteTokens) {
# 		Collection<HttpSession> sessionsCopy;
# 		synchronized (sessions) {
# 			sessionsCopy = new ArrayList<>(sessions);
# 		}
# 		return CookieBasedSessionManagementHelper.getMatchingHttpSession(sessionsCopy, cookies, siteTokens);
# 	}
#
# 旧代码代码：	private HttpSession getMatchingHttpSession(List<HttpCookie> cookies, final HttpSessionTokensSet siteTokens) {
#
# 		return CookieBasedSessionManagementHelper.getMatchingHttpSession(sessions, cookies, siteTokens);
# 	}
#
# ['<s>', 'Return', 'the', 'GraphItem', 'representing', 'the', 'second', '(', 'target', ')', 'node', 'in', 'the', 'edge', '.', '</s>', 'public Node getSecondNode () {', 'return m _ node2 ;', '} //']
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Return', 'GraphItem', 'edge', 'representing', '.']
# , tensor([0.5102, 0.3016, 0.2106, 0.1398, 0.0674], dtype=torch.float64)
# , tensor([ 1,  3, 13,  4, 14])
# ,['return m _ node2 ;', 'public Node getSecondNode () {', '} //', 'second', 'node']
# ,tensor([-0.9728, -0.7365, -0.3419, -0.1566, -0.1531], dtype=torch.float64)
# ,tensor([17, 16, 18,  6, 10])
#
# 对比以下代码查看代码更改位置
# 新代码：	public Node getSecondNode() {
# 		return m_node2;
# 	} //
#
#
# 旧代码代码：	public NodeItem getSecondNode() {
# 		return m_node2;
# 	} //
#
# 解析错误
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Encodes', 'a', 'value', 'in', 'a', 'canonical', 'serialized', 'string', 'format', ',', 'for', 'use', 'in', 'a', 'URL', 'query', 'parameter', '.', '</s>', 'public static String encodeValue ( Value value ) {', 'return NTriplesUtil . toNTriplesString ( value );', '}']
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Encodes', 'query', 'public static String encodeValue ( Value value ) {', 'a', 'string']
# , tensor([0.5517, 0.1619, 0.0904, 0.0704, 0.0645], dtype=torch.float64)
# , tensor([ 1, 16, 20,  2,  8])
# ,['return NTriplesUtil . toNTriplesString ( value );', 'canonical', 'a', 'a', 'value']
# ,tensor([-0.3783, -0.0977, -0.0977, -0.0952, -0.0820], dtype=torch.float64)
# ,tensor([21,  6,  5, 14,  3])
#
# 对比以下代码查看代码更改位置
# 新代码：	public static String encodeValue(Value value) {
# 		return NTriplesUtil.toNTriplesString(value);
# 	}
#
#
# 旧代码代码：	public static String encodeValue(Value value) {
# 		if (value instanceof BNode) {
# 			// SES-2129 special treatment of blank node names to avoid problems with round-tripping.
# 			return "_:" + ((BNode)value).getID();
# 		}
#
# 		// for everything else we just use N-Triples serialization.
# 		return NTriplesUtil.toNTriplesString(value);
# 	}
#
# ['<s>', 'Loads', 'item', 'sprite', 'from', 'game', ',', 'makes', 'transparent', ',', 'and', 'generates', 'image', '</s>', 'private AsyncBufferedImage loadImage ( int itemId , int quantity , boolean stackable )', '{', 'AsyncBufferedImage img = new AsyncBufferedImage ( 36 , 32 , BufferedImage . TYPE _ INT _ ARGB );', 'clientThread . invokeLater (() ->', '{', 'if ( client . getGameState (). ordinal () < GameState . LOGIN _ SCREEN . ordinal ())', '{', 'return false ;', '}', 'SpritePixels sprite = client . createItemSprite ( itemId , quantity , 1 , SpritePixels . DEFAULT _ SHADOW _ COLOR ,', 'stackable ? 1 : 0 , false , CLIENT _ DEFAULT _ ZOOM );', 'if ( sprite == null )', '{', 'return false ;', '}', 'sprite . toBufferedImage ( img );', 'img . changed ();', 'return true ;', '});', 'return img ;', '}']
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['makes', 'from', ',', 'transparent', 'sprite']
# , tensor([0.4018, 0.3771, 0.3605, 0.3581, 0.3564], dtype=torch.float64)
# , tensor([7, 4, 6, 8, 3])
# ,['private AsyncBufferedImage loadImage ( int itemId , int quantity , boolean stackable )', 'Loads', 'image', 'return img ;', 'and']
# ,tensor([-0.8314, -0.2286, -0.1286, -0.1208, -0.0596], dtype=torch.float64)
# ,tensor([14,  1, 12, 33, 10])
#
# 对比以下代码查看代码更改位置
# 新代码：	private AsyncBufferedImage loadImage(int itemId, int quantity, boolean stackable)
# 	{
# 		AsyncBufferedImage img = new AsyncBufferedImage(36, 32, BufferedImage.TYPE_INT_ARGB);
# 		clientThread.invokeLater(() ->
# 		{
# 			if (client.getGameState().ordinal() < GameState.LOGIN_SCREEN.ordinal())
# 			{
# 				return false;
# 			}
# 			SpritePixels sprite = client.createItemSprite(itemId, quantity, 1, SpritePixels.DEFAULT_SHADOW_COLOR,
# 				stackable ? 1 : 0, false, CLIENT_DEFAULT_ZOOM);
# 			if (sprite == null)
# 			{
# 				return false;
# 			}
# 			sprite.toBufferedImage(img);
# 			img.changed();
# 			return true;
# 		});
# 		return img;
# 	}
#
# 旧代码代码：	private BufferedImage loadImage(int itemId, int quantity, boolean stackable)
# 	{
# 		SpritePixels sprite = client.createItemSprite(itemId, quantity, 1, SpritePixels.DEFAULT_SHADOW_COLOR,
# 			stackable ? 1 : 0, false, CLIENT_DEFAULT_ZOOM);
# 		return sprite.toBufferedImage();
# 	}
#
# ['<s>', 'Loads', 'the', 'JBossWebSocketHandler', 'using', 'reflection', 'as', 'it', 'imports', 'container', 'specific', 'classes', '.', '</s>', 'private HttpEventServlet newWebSocketHandler ( AtmosphereConfig config ) {', 'try {', 'return new JBossWebSocketHandler ( config );', '} catch ( Exception e ) {', 'logger . error (" Cannot instantiate JBossWebSocketHandler . Websocket events will not be handled .", e );', '}', 'return null ;', '}']
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['logger . error (" Cannot instantiate JBossWebSocketHandler . Websocket events will not be handled .", e );', '} catch ( Exception e ) {', '}', 'container', 'using']
# , tensor([0.7738, 0.3244, 0.3233, 0.1356, 0.1173], dtype=torch.float64)
# , tensor([18, 17, 21,  9,  4])
# ,['return null ;', 'return new JBossWebSocketHandler ( config );', 'specific', '}', 'try {']
# ,tensor([-0.2251, -0.1342, -0.0834, -0.0626, -0.0263], dtype=torch.float64)
# ,tensor([20, 16, 10, 19, 15])
#
# 对比以下代码查看代码更改位置
# 新代码：    private HttpEventServlet newWebSocketHandler(AtmosphereConfig config) {
#         try {
#             return new JBossWebSocketHandler(config);
#         } catch (Exception e) {
#             logger.error("Cannot instantiate JBossWebSocketHandler. Websocket events will not be handled.", e);
#         }
#
#         return null;
#     }
#
# 旧代码代码：    private HttpEventServlet newWebSocketHandler(AtmosphereConfig config) {
#         try {
#             Class<?> clazz = getClass().getClassLoader().loadClass(WEB_SOCKET_HANDLER);
#             Constructor<?> ctor = clazz.getDeclaredConstructor(new Class[] {AtmosphereConfig.class});
#             return HttpEventServlet.class.cast(ctor.newInstance(config));
#         } catch (Exception e) {
#             logger.error("Cannot instantiate JBossWebSocketHandler. Websocket events will not be handled.", e);
#         }
#
#         return null;
#     }
# 解析错误
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Returns', 'the', 'common', 'base', 'directory', 'between', 'a', 'current', 'base', 'directory', 'and', 'a', 'given', 'file', '.', '</s>', 'File getBaseDir ( final File file1 , final File file2 ) {', 'if ( file1 == null || file2 == null ) {', 'return null ;', '}', 'final Iterator bases = getParents ( file1 ). iterator ();', 'final Iterator fileParents = getParents ( file2 . getAbsoluteFile ()). iterator ();', 'File result = null ;', 'while ( bases . hasNext () && fileParents . hasNext ()) {', 'File next = ( File ) bases . next ();', 'if ( next . equals ( fileParents . next ())) {', 'result = next ;', '} else {', 'break ;', '}', '}', 'return result ;', '}']
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['between', 'directory', 'if ( file1 == null || file2 == null ) {', 'final Iterator fileParents = getParents ( file2 . getAbsoluteFile ()). iterator ();', '}']
# , tensor([0.4907, 0.4269, 0.3821, 0.3243, 0.2894], dtype=torch.float64)
# , tensor([ 6,  5, 18, 22, 33])
# ,['common', 'return result ;', '}', 'current', 'File next = ( File ) bases . next ();']
# ,tensor([-0.1847, -0.1768, -0.1561, -0.0774, -0.0424], dtype=torch.float64)
# ,tensor([ 3, 32, 30,  8, 25])
#
# 对比以下代码查看代码更改位置
# 新代码：    File getBaseDir(final File file1, final File file2) {
#         if (file1 == null || file2 == null) {
#             return null;
#         }
#         final Iterator bases = getParents(file1).iterator();
#         final Iterator fileParents = getParents(file2.getAbsoluteFile()).iterator();
#         File result = null;
#         while (bases.hasNext() && fileParents.hasNext()) {
#             File next = (File) bases.next();
#             if (next.equals(fileParents.next())) {
#                 result = next;
#             } else {
#                 break;
#             }
#         }
#         return result;
#     }
#
#
# 旧代码代码：    File getBaseDir(File base, File file) {
#         if (base == null) {
#             return file.getParentFile().getAbsoluteFile();
#         } else {
#             Iterator bases = getParents(base).iterator();
#             Iterator fileParents = getParents(file.getAbsoluteFile()).iterator();
#             File result = null;
#             while (bases.hasNext() && fileParents.hasNext()) {
#                 File next = (File) bases.next();
#                 if (next.equals(fileParents.next())) {
#                     result = next;
#                 } else {
#                     break;
#                 }
#             }
#             return result;
#         }
#     }
#
# ['<s>', 'Returns', 'an', 'ArrayList', 'of', 'the', 'RadioButtons', 'contained', 'in', 'the', 'current', 'Activity', '.', '</s>', 'public ArrayList < RadioButton > getCurrentRadioButtons () {', 'return viewFetcher . getCurrentViews ( RadioButton . class );', '}']
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['current', 'RadioButtons', 'the', 'in', 'Returns']
# , tensor([0.6196, 0.2292, 0.1968, 0.1696, 0.1653], dtype=torch.float64)
# , tensor([10,  6,  9,  8,  1])
# ,['return viewFetcher . getCurrentViews ( RadioButton . class );', 'public ArrayList < RadioButton > getCurrentRadioButtons () {', '.', 'Activity', '<s>']
# ,tensor([-1.0741, -1.0233, -0.4311, -0.2276,  0.0000], dtype=torch.float64)
# ,tensor([15, 14, 12, 11,  0])
#
# 对比以下代码查看代码更改位置
# 新代码：	public ArrayList<RadioButton> getCurrentRadioButtons() {
# 		return viewFetcher.getCurrentViews(RadioButton.class);
# 	}
#
# 旧代码代码：	public ArrayList<RadioButton> getCurrentRadioButtons() {
# 		return ensureArrayListOrNull(viewFetcher.getCurrentViews(RadioButton.class));
# 	}
#
# ['<s>', 'Does', 'this', 'time', 'interval', 'contain', 'the', 'specified', 'time', 'interval', 'completely', '.', '</s>', 'public boolean contains ( ReadableInterval interval ) {', 'if ( interval == null ) {', 'return containsNow ();', '}', 'long otherStart = interval . getStartMillis ();', 'long otherEnd = interval . getEndMillis ();', 'long thisStart = getStartMillis ();', 'long thisEnd = getEndMillis ();', 'return ( thisStart <= otherStart && otherStart < thisEnd && otherEnd <= thisEnd ) ||', '( thisStart == otherStart && thisEnd == otherEnd );', '}']
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public boolean contains ( ReadableInterval interval ) {', 'long otherStart = interval . getStartMillis ();', 'time', '.', 'specified']
# , tensor([0.5486, 0.1631, 0.1348, 0.1324, 0.1258], dtype=torch.float64)
# , tensor([13, 17,  3, 11,  7])
# ,['interval', 'return ( thisStart <= otherStart && otherStart < thisEnd && otherEnd <= thisEnd ) ||', 'if ( interval == null ) {', 'contain', 'long otherEnd = interval . getEndMillis ();']
# ,tensor([-0.6500, -0.4013, -0.3980, -0.3256, -0.1985], dtype=torch.float64)
# ,tensor([ 4, 21, 14,  5, 18])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean contains(ReadableInterval interval) {
#         if (interval == null) {
#             return containsNow();
#         }
#         long otherStart = interval.getStartMillis();
#         long otherEnd = interval.getEndMillis();
#         long thisStart = getStartMillis();
#         long thisEnd = getEndMillis();
#         return (thisStart <= otherStart && otherStart < thisEnd && otherEnd <= thisEnd) ||
#             (thisStart == otherStart && thisEnd == otherEnd);
#     }
#
# 旧代码代码：    public boolean contains(ReadableInterval interval) {
#         if (interval == null) {
#             return containsNow();
#         }
#         long otherStart = interval.getStartMillis();
#         long otherEnd = interval.getEndMillis();
#         long thisStart = getStartMillis();
#         long thisEnd = getEndMillis();
#         return (otherStart >= thisStart && otherStart < thisEnd && otherEnd <= thisEnd);
#     }
#
# ['<s>', 'Create', 'a', 'new', 'Template', 'expression', '</s>', 'public static StringExpression stringTemplate ( String template , Object ... args ) {', 'return new StringTemplate ( createTemplate ( template ), ImmutableList . copyOf ( args ));', '}']
# 第20个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['}', 'return new StringTemplate ( createTemplate ( template ), ImmutableList . copyOf ( args ));', 'public static StringExpression stringTemplate ( String template , Object ... args ) {', 'a', 'Template']
# , tensor([0.8861, 0.5776, 0.2860, 0.1265, 0.1144], dtype=torch.float64)
# , tensor([9, 8, 7, 2, 4])
# ,['<s>', '</s>', 'new', 'Create', 'expression']
# ,tensor([0.0000, 0.0000, 0.0439, 0.0525, 0.0892], dtype=torch.float64)
# ,tensor([0, 6, 3, 1, 5])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static StringExpression stringTemplate(String template, Object... args) {
#         return new StringTemplate(createTemplate(template), ImmutableList.copyOf(args));
#     }
#
# 旧代码代码：    public static StringExpression stringTemplate(String template, Object... args) {
#         return StringTemplate.create(template, args);
#     }
#
# 解析错误
# 第21个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'creates', 'an', 'XmlItem', 'this', 'route', 'creates', 'an', 'XmlItem', '</s>', 'public ApiResponse < Void > createXmlItemWithHttpInfo ( XmlItem xmlItem ) throws ApiException {', 'okhttp3 . Call localVarCall = createXmlItemValidateBeforeCall ( xmlItem , null , null );', 'return localVarApiClient . execute ( localVarCall );', '}']
# 第22个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['okhttp3 . Call localVarCall = createXmlItemValidateBeforeCall ( xmlItem , null , null );', 'return localVarApiClient . execute ( localVarCall );', 'this', 'an', 'route']
# , tensor([1.3942, 1.0459, 0.1865, 0.1664, 0.1446], dtype=torch.float64)
# , tensor([11, 12,  4,  7,  5])
# ,['public ApiResponse < Void > createXmlItemWithHttpInfo ( XmlItem xmlItem ) throws ApiException {', 'an', '<s>', '</s>', 'XmlItem']
# ,tensor([-0.5120, -0.0133,  0.0000,  0.0000,  0.0053], dtype=torch.float64)
# ,tensor([10,  2,  0,  9,  3])
#
# 对比以下代码查看代码更改位置
# 新代码：    public ApiResponse<Void> createXmlItemWithHttpInfo(XmlItem xmlItem) throws ApiException {
#         okhttp3.Call localVarCall = createXmlItemValidateBeforeCall(xmlItem, null, null);
#         return localVarApiClient.execute(localVarCall);
#     }
#
# 旧代码代码：    public ApiResponse<Void> createXmlItemWithHttpInfo(XmlItem xmlItem) throws ApiException {
#         okhttp3.Call call = createXmlItemValidateBeforeCall(xmlItem, null, null);
#         return apiClient.execute(call);
#     }
# ['<s>', 'Get', 'the', 'global', 'configuration', 'table', 'name', 'including', 'the', 'correct', 'escaped', 'schema', '</s>', 'private String getConfigurationTable ( Connection con ) {', 'try {', 'if ( StorageManager . getStorageImpl ( con . getMetaData (). getDatabaseProductName ()). requiresConfigSchema ()) {', 'if ( DatabaseConst . getConfigSchema (). endsWith ("."))', 'return DatabaseConst . getConfigSchema () + TBL _ GLOBAL _ CONFIG ;', 'else', 'return DatabaseConst . getConfigSchema () + "." + TBL _ GLOBAL _ CONFIG ;', '}', '} catch ( SQLException e ) {', 'LOG . warn ( e );', '}', 'return TBL _ GLOBAL _ CONFIG ;', '}']
# 第23个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['if ( StorageManager . getStorageImpl ( con . getMetaData (). getDatabaseProductName ()). requiresConfigSchema ()) {', 'return DatabaseConst . getConfigSchema () + TBL _ GLOBAL _ CONFIG ;', 'table', 'the', 'escaped']
# , tensor([0.7795, 0.5106, 0.4882, 0.3379, 0.3172], dtype=torch.float64)
# , tensor([15, 17,  5,  8, 10])
# ,['return TBL _ GLOBAL _ CONFIG ;', 'Get', 'global', '}', 'schema']
# ,tensor([-0.5127, -0.3595, -0.1536, -0.1051, -0.0820], dtype=torch.float64)
# ,tensor([24,  1,  3, 23, 11])
#
# 对比以下代码查看代码更改位置
# 新代码：    private String getConfigurationTable(Connection con) {
#         try {
#             if (StorageManager.getStorageImpl(con.getMetaData().getDatabaseProductName()).requiresConfigSchema()) {
#                 if (DatabaseConst.getConfigSchema().endsWith("."))
#                     return DatabaseConst.getConfigSchema() + TBL_GLOBAL_CONFIG;
#                 else
#                     return DatabaseConst.getConfigSchema() + "." + TBL_GLOBAL_CONFIG;
#             }
#         } catch (SQLException e) {
#             LOG.warn(e);
#         }
#         return TBL_GLOBAL_CONFIG;
#     }
#
#
# 旧代码代码：    private String getConfigurationTable(Connection con) {
#         try {
#             if (StorageManager.getStorageImpl(con.getMetaData().getDatabaseProductName()).escapeSchema())
#                 return "\"" + DatabaseConst.getConfigSchema() + "\"." + TBL_GLOBAL_CONFIG;
#         } catch (SQLException e) {
#             LOG.warn(e);
#         }
#         return DatabaseConst.getConfigSchema() + "." + TBL_GLOBAL_CONFIG;
#     }
#
# ['<s>', 'Returns', 'a', 'List', 'of', 'children', 'for', 'the', 'current', 'node', '.', '</s>', 'public List < Tree > getChildrenAsList () {', 'return new ArrayList <>( Arrays . asList ( children ()));', '}']
# 第24个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return new ArrayList <>( Arrays . asList ( children ()));', 'Returns', 'node', '}', '.']
# , tensor([0.9019, 0.4969, 0.3056, 0.2211, 0.1131], dtype=torch.float64)
# , tensor([13,  1,  9, 14, 10])
# ,['of', 'public List < Tree > getChildrenAsList () {', 'for', 'children', 'List']
# ,tensor([-0.3272, -0.1747, -0.1464, -0.1236, -0.0617], dtype=torch.float64)
# ,tensor([ 4, 12,  6,  5,  3])
#
# 对比以下代码查看代码更改位置
# 新代码：  public List<Tree> getChildrenAsList() {
#     return new ArrayList<>(Arrays.asList(children()));
#   }
#
# 旧代码代码：  public List<Tree> getChildrenAsList() {
#     return new ArrayList<Tree>(Arrays.asList(children()));
#   }
#
# ['<s>', 'Gets', 'the', 'total', 'number', 'of', 'bytes', 'uploaded', 'by', 'this', 'uploader', 'or', '0', 'for', 'direct', 'uploads', 'when', 'the', 'content', 'length', 'is', 'not', 'known', '.', '</s>', '@ Deprecated', 'public long getNumBytesUploaded () {', 'return totalBytesServerReceived ;', '}']
# 第25个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public long getNumBytesUploaded () {', 'return totalBytesServerReceived ;', '@ Deprecated', 'uploader', 'Gets']
# , tensor([1.1446, 1.1421, 0.9375, 0.3240, 0.2062], dtype=torch.float64)
# , tensor([26, 27, 25, 10,  1])
# ,['0', 'total', 'number', '<s>', '</s>']
# ,tensor([-0.1824, -0.1273, -0.0335,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([12,  3,  4,  0, 24])
#
# 对比以下代码查看代码更改位置
# 新代码：  @Deprecated
#   public long getNumBytesUploaded() {
#     return totalBytesServerReceived;
#   }
#
#
# 旧代码代码：  public long getNumBytesUploaded() {
#     return bytesUploaded;
#   }
#
# 解析错误
# 第26个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[1.3189e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Obtains', 'a', 'ISTextExpert', 'instance', 'for', 'processing', 'structured', 'text', 'with', 'the', 'specified', 'type', 'handler', 'and', 'the', 'specified', 'environment', '.', '</s>', 'static public IStructuredTextExpert getStatefulExpert ( StructuredTextTypeHandler handler , StructuredTextEnvironment environment ) {', 'if ( environment == null )', 'environment = StructuredTextEnvironment . DEFAULT ;', 'return new StructuredTextImpl ( handler , environment , true );', '}']
# 第27个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['ISTextExpert', 'Obtains', 'type', 'environment', 'environment = StructuredTextEnvironment . DEFAULT ;']
# , tensor([0.4605, 0.4345, 0.3181, 0.1696, 0.1529], dtype=torch.float64)
# , tensor([ 3,  1, 12, 17, 22])
# ,['return new StructuredTextImpl ( handler , environment , true );', 'handler', '.', 'and', '}']
# ,tensor([-0.1987, -0.1923, -0.0506, -0.0471, -0.0361], dtype=torch.float64)
# ,tensor([23, 13, 18, 14, 24])
#
# 对比以下代码查看代码更改位置
# 新代码：	static public IStructuredTextExpert getStatefulExpert(StructuredTextTypeHandler handler, StructuredTextEnvironment environment) {
# 		if (environment == null)
# 			environment = StructuredTextEnvironment.DEFAULT;
# 		return new StructuredTextImpl(handler, environment, true);
# 	}
#
#
# 旧代码代码：	static public ISTextExpert getStatefulExpert(STextTypeHandler handler, STextEnvironment environment) {
# 		if (environment == null)
# 			environment = STextEnvironment.DEFAULT;
# 		return new STextImpl(handler, environment, true);
# 	}
#
# ['<s>', 'Prints', 'a', 'ReadablePartial', 'to', 'a', 'new', 'String', '.', '</s>', 'public String print ( ReadablePartial partial ) {', 'StringBuilder builder = new StringBuilder ( requirePrinter (). estimatePrintedLength ());', 'try {', 'printTo ( builder , partial );', '} catch ( IOException e ) {', '// StringBuilder does not throw IOException', '}', 'return builder . toString ();', '}']
# 第28个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['// StringBuilder does not throw IOException', '} catch ( IOException e ) {', 'new', 'public String print ( ReadablePartial partial ) {', 'printTo ( builder , partial );']
# , tensor([0.2721, 0.2116, 0.1388, 0.1370, 0.1034], dtype=torch.float64)
# , tensor([15, 14,  6, 10, 13])
# ,['Prints', 'return builder . toString ();', '}', 'to', 'a']
# ,tensor([-0.3183, -0.1907, -0.1155, -0.0802, -0.0507], dtype=torch.float64)
# ,tensor([ 1, 17, 18,  4,  2])
#
# 对比以下代码查看代码更改位置
# 新代码：    public String print(ReadablePartial partial) {
#         StringBuilder builder = new StringBuilder(requirePrinter().estimatePrintedLength());
#         try {
#             printTo(builder, partial);
#         } catch (IOException e) {
#             // StringBuilder does not throw IOException
#         }
#         return builder.toString();
#     }
#
# 旧代码代码：    public String print(ReadablePartial partial) {
#         StringBuffer buf = new StringBuffer(requirePrinter().estimatePrintedLength());
#         printTo(buf, partial);
#         return buf.toString();
#     }
#
# ['<s>', 'Create', 'and', 'return', 'a', 'new', 'feature', 'service', 'with', 'the', 'default', 'server', 'URL', '.', '</s>', 'public FeatureService createFeatureService () {', 'return createFeatureService ( defaultEndpointUrl );', '}']
# 第29个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return createFeatureService ( defaultEndpointUrl );', '}', 'URL', 'server', '.']
# , tensor([0.9575, 0.3272, 0.2358, 0.1682, 0.1491], dtype=torch.float64)
# , tensor([16, 17, 12, 11, 13])
# ,['a', 'and', 'feature', 'Create', 'service']
# ,tensor([-0.3117, -0.1538, -0.1292, -0.0843, -0.0123], dtype=torch.float64)
# ,tensor([4, 2, 6, 1, 7])
#
# 对比以下代码查看代码更改位置
# 新代码：    public FeatureService createFeatureService() {
#         return createFeatureService(defaultEndpointUrl);
#     }
#
#
# 旧代码代码：    public FeatureService createFeatureService() {
#         return createFeatureService(defaultServerUrl);
#     }
# 解析错误
# 第30个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.3751e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'GET', '/', 'user', '/', 'username', '</s>', 'public User executeAs ( Function < Response , Response > handler ) {', 'Type type = new TypeToken < User >(){}. getType ();', 'return execute ( handler ). as ( type );', '}']
# 第31个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['username', '<s>', '</s>', '/', 'GET']
# , tensor([ 0.1541,  0.0000,  0.0000, -0.0261, -0.0441], dtype=torch.float64)
# , tensor([5, 0, 6, 4, 1])
# ,['public User executeAs ( Function < Response , Response > handler ) {', 'Type type = new TypeToken < User >(){}. getType ();', '}', 'return execute ( handler ). as ( type );', '/']
# ,tensor([-1.2645, -0.8235, -0.8035, -0.5092, -0.1213], dtype=torch.float64)
# ,tensor([ 7,  8, 10,  9,  2])
#
# 对比以下代码查看代码更改位置
# 新代码：        public User executeAs(Function<Response, Response> handler) {
#             Type type = new TypeToken<User>(){}.getType();
#             return execute(handler).as(type);
#         }
#
# 旧代码代码：        public User executeAs(Function<Response, Response> handler) {
#             Type type = new TypeToken<User>(){}.getType();
#             return getJSON().deserialize(execute(handler).asString(), type);
#         }
#
# ['<s>', 'Get', 'the', 'parent', 'cuboid', 'really', 'on', 'the', 'spanning', 'tree', '.', '</s>', 'public long findBestMatchCuboid ( long cuboid ) {', 'return findBestMatchCuboid1 ( cuboid );', '}']
# 第32个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return findBestMatchCuboid1 ( cuboid );', 'Get', '}', '.', 'the']
# , tensor([0.7939, 0.6360, 0.2614, 0.1158, 0.0787], dtype=torch.float64)
# , tensor([13,  1, 14, 10,  7])
# ,['public long findBestMatchCuboid ( long cuboid ) {', 'cuboid', 'parent', 'on', 'really']
# ,tensor([-0.1102, -0.0940, -0.0859, -0.0523, -0.0154], dtype=torch.float64)
# ,tensor([12,  4,  3,  6,  5])
#
# 对比以下代码查看代码更改位置
# 新代码：    public long findBestMatchCuboid(long cuboid) {
#         return findBestMatchCuboid1(cuboid);
#     }
#
# 旧代码代码：    public long findBestMatchCuboid(long child) {
#         long parent = getOnTreeParent(child);
#         while (parent > 0) {
#             if (cubeDesc.getAllCuboids().contains(parent)) {
#                 break;
#             }
#             parent = getOnTreeParent(parent);
#         }
#
#         if (parent <= 0) {
#             throw new IllegalStateException("Can't find valid parent for Cuboid " + child);
#         }
#         return parent;
#     }
#
# 解析错误
# 第33个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9998e-01, 1.5983e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'String', 'representation', 'of', 'the', 'signature', '.', '</s>', '@ Override', 'public String toString () {', 'if ( stringRep == null ) {', 'stringRep = toString ( true );', '}', 'return stringRep ;', '}']
# 第34个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['@ Override', 'public String toString () {', 'stringRep = toString ( true );', 'the', 'signature']
# , tensor([0.8927, 0.4126, 0.3181, 0.1329, 0.0677], dtype=torch.float64)
# , tensor([ 8,  9, 11,  4,  5])
# ,['if ( stringRep == null ) {', '}', 'return stringRep ;', 'of', '}']
# ,tensor([-0.3626, -0.0726, -0.0593, -0.0296, -0.0240], dtype=torch.float64)
# ,tensor([10, 12, 13,  3, 14])
#
# 对比以下代码查看代码更改位置
# 新代码：    @Override
#     public String toString() {
#         if (stringRep == null) {
#             stringRep = toString(true);
#         }
#     	return stringRep;
#     }
#
#
# 旧代码代码：    public String toString(boolean altMemberSep) {
#         StringBuffer s = new StringBuffer();
#         if ( className != null ) {
#             s.append(className);
#         }
#         if (memberName != null) {
#             if ( className != null ) {
#                 s.append(altMemberSep ? ALT_MEMBER_SEPARATOR : '.');
#             }
#             s.append(memberName);
#         }
#         if ( descriptor != null && (className == null || memberName != null) ) {
#             s.append(descriptor);
#         }
#         return s.toString();
#     }
#
# ['<s>', 'Returns', 'a', 'Button', 'which', 'shows', 'a', 'given', 'text', '.', '</s>', 'public Button getButton ( String text , boolean onlyVisible )', '{', 'return getter . getView ( Button . class , text , onlyVisible );', '}']
# 第35个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Returns', 'return getter . getView ( Button . class , text , onlyVisible );', 'public Button getButton ( String text , boolean onlyVisible )', 'shows', '{']
# , tensor([0.8487, 0.4637, 0.3298, 0.2542, 0.1452], dtype=torch.float64)
# , tensor([ 1, 13, 11,  5, 12])
# ,['which', 'text', 'a', 'given', 'a']
# ,tensor([-0.2184, -0.0620, -0.0572, -0.0529, -0.0078], dtype=torch.float64)
# ,tensor([4, 8, 6, 7, 2])
#
# 对比以下代码查看代码更改位置
# 新代码：	public Button getButton(String text, boolean onlyVisible)
# 	{
# 		return getter.getView(Button.class, text, onlyVisible);
# 	}
#
# 旧代码代码：	public Button getButton(String text, boolean onlyVisible)
# 	{
# 		return viewFetcher.getView(Button.class, text, onlyVisible);
# 	}
#
# ['<s>', 'Return', 'the', 'list', 'of', 'Cassandra', 'instances', 'ordered', 'by', 'position', 'on', 'ring', ',', 'indicated', 'by', 'token', '.', '</s>', '@ GET', 'public Set < CassandraInstance > findAll () {', 'return service . findAll ();', '}']
# 第36个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public Set < CassandraInstance > findAll () {', 'return service . findAll ();', '@ GET', '}', 'Cassandra']
# , tensor([1.7184, 0.4389, 0.3294, 0.2921, 0.2261], dtype=torch.float64)
# , tensor([19, 20, 18, 21,  5])
# ,['<s>', '</s>', 'the', 'list', 'on']
# ,tensor([0.0000, 0.0000, 0.0046, 0.0182, 0.0306], dtype=torch.float64)
# ,tensor([ 0, 17,  2,  3, 10])
#
# 对比以下代码查看代码更改位置
# 新代码：  @GET
#   public Set<CassandraInstance> findAll() {
#     return service.findAll();
#   }
#
#
# 旧代码代码：  @GET
#   public List<CassandraInstance> findAll() {
#     return service.findAll();
#   }
#
# ['<s>', 'Create', 'a', 'new', 'PathMetadata', 'for', 'property', 'access', '</s>', 'public static PathMetadata < String > forProperty ( Path <?> parent , String property ) {', 'return new PathMetadata < String >( parent , Assert . hasLength ( property ," property "), PathType . PROPERTY );', '}']
# 第37个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return new PathMetadata < String >( parent , Assert . hasLength ( property ," property "), PathType . PROPERTY );', 'public static PathMetadata < String > forProperty ( Path <?> parent , String property ) {', 'access', 'Create', 'a']
# , tensor([1.0664, 0.3897, 0.2733, 0.0742, 0.0212], dtype=torch.float64)
# , tensor([10,  9,  7,  1,  2])
# ,['new', 'property', '}', 'PathMetadata', 'for']
# ,tensor([-0.3650, -0.1510, -0.1065, -0.0767, -0.0005], dtype=torch.float64)
# ,tensor([ 3,  6, 11,  4,  5])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static PathMetadata<String> forProperty(Path<?> parent, String property) {
#         return new PathMetadata<String>(parent, Assert.hasLength(property,"property"), PathType.PROPERTY);
#     }
#
# 旧代码代码：    public static PathMetadata<String> forProperty(Path<?> parent, String property) {
#         return new PathMetadata<String>(parent, ConstantImpl.create(Assert.hasLength(property,"property"), true), PathType.PROPERTY);
#     }
#
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public String getReplicationDirectory () {', 'return this . replicationDirectory ;', '}']
# 第38个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['DOCUMENT', '}', 'public String getReplicationDirectory () {', 'ME', '<s>']
# , tensor([0.9720, 0.0912, 0.0587, 0.0444, 0.0000], dtype=torch.float64)
# , tensor([1, 7, 5, 2, 0])
# ,['return this . replicationDirectory ;', '!', '<s>', '</s>', 'ME']
# ,tensor([-0.4485, -0.0201,  0.0000,  0.0000,  0.0444], dtype=torch.float64)
# ,tensor([6, 3, 0, 4, 2])
#
# 对比以下代码查看代码更改位置
# 新代码：    public String getReplicationDirectory() {
#         return this.replicationDirectory;
#     }
#
#
# 旧代码代码：    public String getReplicationDirectory() {
#         return replicationDirectory;
#     }
# ['<s>', 'Override', 'with', 'any', 'special', 'handling', 'of', 'response', 'codes', '</s>', 'protected ApiResponse findMethodResponse ( ApiResponses responses ) {', 'String code = null ;', 'for ( String responseCode : responses . keySet ()) {', 'if ( responseCode . startsWith (" 2 ") || responseCode . equals (" default ")) {', 'if ( code == null || code . compareTo ( responseCode ) > 0 ) {', 'code = responseCode ;', '}', '}', '}', 'if ( code == null ) {', 'return null ;', '}', 'return responses . get ( code );', '}']
# 第39个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['protected ApiResponse findMethodResponse ( ApiResponses responses ) {', 'if ( responseCode . startsWith (" 2 ") || responseCode . equals (" default ")) {', 'for ( String responseCode : responses . keySet ()) {', 'if ( code == null ) {', 'handling']
# , tensor([0.9430, 0.5625, 0.2147, 0.1815, 0.1661], dtype=torch.float64)
# , tensor([10, 13, 12, 19,  5])
# ,['Override', '}', 'special', 'code = responseCode ;', 'codes']
# ,tensor([-0.2500, -0.1024, -0.0878, -0.0633, -0.0559], dtype=torch.float64)
# ,tensor([ 1, 23,  4, 15,  8])
#
# 对比以下代码查看代码更改位置
# 新代码：    protected ApiResponse findMethodResponse(ApiResponses responses) {
#         String code = null;
#         for (String responseCode : responses.keySet()) {
#             if (responseCode.startsWith("2") || responseCode.equals("default")) {
#                 if (code == null || code.compareTo(responseCode) > 0) {
#                     code = responseCode;
#                 }
#             }
#         }
#         if (code == null) {
#             return null;
#         }
#         return responses.get(code);
#     }
#
# 旧代码代码：    protected Response findMethodResponse(Map<String, Response> responses) {
#
#         String code = null;
#         for (String responseCode : responses.keySet()) {
#             if (responseCode.startsWith("2") || responseCode.equals("default")) {
#                 if (code == null || code.compareTo(responseCode) > 0) {
#                     code = responseCode;
#                 }
#             }
#         }
#         if (code == null) {
#             return null;
#         }
#         return responses.get(code);
#     }

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>nag</b></text></td><td><text style="padding-right:2em"><b>3.53</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> Method                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> for                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> getting                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> counts                    </font></mark><mark style="background-color: hsl(120, 75%, 69%); opacity:1.0;                     line-height:1.75"><font color="black"> using                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> named                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> filters                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> public boolean equals ( Object obj ) {                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> if ( obj == null ) {                    </font></mark><mark style="background-color: hsl(120, 75%, 73%); opacity:1.0;                     line-height:1.75"><font color="black"> return false ;                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> if ( obj == this ) {                    </font></mark><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> return true ;                    </font></mark><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> if ( obj . getClass () != getClass ()) {                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> return  ...

# %%
AST_list = []
for i in range(100,150): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])
    
AST_list_old = []   
for i in range(100,150): 
    AST_list_old.append(df_clean.loc[i,'old_code_raw'])   
    
comment_list = []
for i in range(100,150): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])

ground_lable = []
for i in range(100,150): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,\
attention_mask_all,token_type_ids_all,all_tokens_all = input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min,code,old_code,_,_ \
    = interpret_sentence_2(AST_list[i],comment_list[i],AST_list_old[i],input_ids_all[i],ref_input_ids_all[i],\
                           token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], all_tokens_all[i],\
                           ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
          {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    print('对比以下代码查看代码更改位置') 
    print(f'新代码：{code}')
    print(f'旧代码代码：{old_code}')
# Out:
# ['<s>', 'Get', 'entry', 'data', ',', 'read', 'directly', 'from', 'internal', 'data', 'structure', '.', '</s>', 'public String getValue ( String key ) throws NotFoundException , NotLeaderException {', 'if ( cluster . getLocalRole () != Role . LEADER ) {', 'throw new NotLeaderException ();', '}', 'if (! entries . containsKey ( key )) {', 'throw new NotFoundException ();', '}', 'String value = entries . get ( key );', 'logger . info ( String . format (" Get key % s : % s ", key , value ));', 'return value ;', '}']
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['if ( cluster . getLocalRole () != Role . LEADER ) {', 'throw new NotLeaderException ();', '}', 'if (! entries . containsKey ( key )) {', 'throw new NotFoundException ();']
# , tensor([2.1922, 2.1922, 2.1922, 2.1922, 2.1922], dtype=torch.float64)
# , tensor([14, 15, 16, 17, 18])
# ,[',', 'internal', 'Get', 'read', 'data']
# ,tensor([-0.4953, -0.3209, -0.1692, -0.0904, -0.0811], dtype=torch.float64)
# ,tensor([4, 8, 1, 5, 9])
#
# 对比以下代码查看代码更改位置
# 新代码：    public String getValue(String key) throws NotFoundException, NotLeaderException {
#         if (cluster.getLocalRole() != Role.LEADER) {
#             throw new NotLeaderException();
#         }
#         if (!entries.containsKey(key)) {
#             throw new NotFoundException();
#         }
#         String value = entries.get(key);
#         logger.info(String.format("Get key %s: %s", key, value));
#         return value;
#     }
#
#
# 旧代码代码：    public String getValue(String entryId) throws RecordNotFoundException {
#         if (!entries.containsKey(entryId)) {
#             throw new RecordNotFoundException();
#         }
#         return entries.get(entryId);
#     }
#
# ['<s>', 'Seeks', 'the', 'field', 'with', 'the', 'given', 'name', 'in', 'the', 'stream', 'and', 'positions', '(', 'and', 'returns', ')', 'the', 'parser', 'to', 'the', 'next', 'available', 'token', '(', 'value', 'or', 'not', ').', '</s>', 'public static Token seek ( String path , Parser parser ) {', '// return current token if no path is given', 'if (! StringUtils . hasText ( path )) {', 'return null ;', '}', 'List < String > tokens = StringUtils . tokenize ( path , "/");', 'return seek ( parser , tokens . toArray ( new String [ tokens . size ()]));', '}']
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return null ;', 'field', 'if (! StringUtils . hasText ( path )) {', 'with', 'name']
# , tensor([0.5266, 0.4181, 0.3929, 0.3897, 0.2916], dtype=torch.float64)
# , tensor([33,  3, 32,  4,  7])
# ,['given', 'and', 'the', 'Seeks', 'to']
# ,tensor([-0.1780, -0.0902, -0.0836, -0.0620, -0.0606], dtype=torch.float64)
# ,tensor([ 6, 11,  5,  1, 19])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static Token seek(String path, Parser parser) {
#         // return current token if no path is given
#         if (!StringUtils.hasText(path)) {
#             return null;
#         }
#
#         List<String> tokens = StringUtils.tokenize(path, "/");
#         return seek(parser, tokens.toArray(new String[tokens.size()]));
#     }
#
# 旧代码代码：    public static Token seek(String path, Parser parser) {
#         // return current token if no path is given
#         if (!StringUtils.hasText(path)) {
#             return null;
#         }
#
#         List<String> tokens = StringUtils.tokenize(path, "/");
#         ListIterator<String> li = tokens.listIterator();
#         return doSeekToken(li.next(), li, parser);
#     }
#
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public String getBackupDirectory () {', 'return this . backupDirectory ;', '}']
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['DOCUMENT', '!', '<s>', '</s>', 'ME']
# , tensor([ 1.4020,  0.0086,  0.0000,  0.0000, -0.0462], dtype=torch.float64)
# , tensor([1, 3, 0, 4, 2])
# ,['public String getBackupDirectory () {', 'return this . backupDirectory ;', '}', 'ME', '<s>']
# ,tensor([-0.8510, -0.3166, -0.1028, -0.0462,  0.0000], dtype=torch.float64)
# ,tensor([5, 6, 7, 2, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public String getBackupDirectory() {
#         return this.backupDirectory;
#     }
#
#
# 旧代码代码：    public String getBackupDirectory() {
#         return backupDirectory;
#     }
#
# ['<s>', 'Checks', 'if', 'this', 'potato', 'is', 'baked', '.', '</s>', 'public boolean isBaked () throws NotDeliciousException {', 'try {', 'long begin = System . currentTimeMillis ();', 'boolean isInOven = this . isPutIntoOven ();', 'long bakeTime = ( System . currentTimeMillis () - begin );', 'if ( bakeTime > 1100 ) throw new NotDeliciousException ( NotDeliciousReason . OVERCOOKED );', 'return isInOven ;', '} catch ( OvenException e ) {', 'return false ;', '}', '}']
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['long bakeTime = ( System . currentTimeMillis () - begin );', 'potato', 'long begin = System . currentTimeMillis ();', 'if ( bakeTime > 1100 ) throw new NotDeliciousException ( NotDeliciousReason . OVERCOOKED );', 'boolean isInOven = this . isPutIntoOven ();']
# , tensor([0.7686, 0.5393, 0.3276, 0.3134, 0.2176], dtype=torch.float64)
# , tensor([13,  4, 11, 14, 12])
# ,['public boolean isBaked () throws NotDeliciousException {', 'baked', 'return false ;', '}', '}']
# ,tensor([-0.4119, -0.1681, -0.1115, -0.0949, -0.0649], dtype=torch.float64)
# ,tensor([ 9,  6, 17, 19, 18])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean isBaked() throws NotDeliciousException {
#         try {
#             long begin = System.currentTimeMillis();
#             boolean isInOven = this.isPutIntoOven();
#             long bakeTime = (System.currentTimeMillis() - begin);
#             if (bakeTime > 1100) throw new NotDeliciousException(NotDeliciousReason.OVERCOOKED);
#             return isInOven;
#         } catch (OvenException e) {
#             return false;
#         }
#     }
#
# 旧代码代码：    public boolean isBaked() {
#         try {
#             return this.isPutIntoOven();
#         } catch (OvenException e) {
#             return false;
#         }
#     }
#
# 解析错误
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9998e-01, 2.4008e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Computes', 'the', 'row', 'type', 'of', 'an', 'Aggregate', 'before', 'it', 'exists', '.', '</s>', 'public boolean isValid ( Litmus litmus ) {', 'return super . isValid ( litmus )', '&& litmus . check ( Util . isDistinct ( getRowType (). getFieldNames ()),', '" distinct field names : {}", getRowType ());', '}']
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Aggregate', '&& litmus . check ( Util . isDistinct ( getRowType (). getFieldNames ()),', 'of', 'type', 'return super . isValid ( litmus )']
# , tensor([0.8782, 0.8516, 0.3478, 0.3263, 0.2532], dtype=torch.float64)
# , tensor([ 7, 15,  5,  4, 14])
# ,['Computes', '}', 'an', 'before', '<s>']
# ,tensor([-0.3914, -0.1482, -0.0862, -0.0111,  0.0000], dtype=torch.float64)
# ,tensor([ 1, 17,  6,  8,  0])
#
# 对比以下代码查看代码更改位置
# 新代码：  public boolean isValid(Litmus litmus) {
#     return super.isValid(litmus)
#         && litmus.check(Util.isDistinct(getRowType().getFieldNames()),
#             "distinct field names: {}", getRowType());
#   }
#
# 旧代码代码：  public boolean isValid(Litmus litmus) {
#     return super.isValid(litmus)
#         && litmus.check(Util.isDistinct(getRowType().getFieldNames()), getRowType());
#   }
#
# ['<s>', 'Returns', 'the', 'sibling', 'on', 'the', 'right', 'of', 'the', 'end', 'of', 'given', 'Treepath', '.', '</s>', 'public static Treepath getNextSibling ( Treepath treepath ) {', 'if ( treepath . getHeight () < 2 ) {', 'throw new IllegalArgumentException ( " Treepath must have minimum height of 2 " ) ;', '}', 'final Tree treeToMove = treepath . getBottom () ;', 'final Tree parent = treepath . getTreeAtHeight ( 1 ) ;', 'for ( int i = 0 ; i < parent . getChildCount () - 1 ; i ++ ) {', 'final Tree child = parent . getChildAt ( i ) ;', 'if ( child == treeToMove ) {', 'return Treepath . create ( treepath . getParent (), parent . getChildAt ( i + 1 ) ) ;', '}', '}', 'throw new IllegalArgumentException ( " No next sibling " ) ;', '}']
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['right', 'the', 'of', 'the', 'end']
# , tensor([0.4873, 0.4383, 0.3775, 0.3365, 0.2912], dtype=torch.float64)
# , tensor([6, 8, 7, 5, 9])
# ,['Treepath', 'public static Treepath getNextSibling ( Treepath treepath ) {', 'Returns', 'sibling', 'return Treepath . create ( treepath . getParent (), parent . getChildAt ( i + 1 ) ) ;']
# ,tensor([-0.1705, -0.1218, -0.0763, -0.0721, -0.0489], dtype=torch.float64)
# ,tensor([12, 15,  1,  3, 24])
#
# 对比以下代码查看代码更改位置
# 新代码：  public static Treepath getNextSibling( Treepath treepath ) {
#     if( treepath.getHeight() < 2 ) {
#       throw new IllegalArgumentException( "Treepath must have minimum height of 2" ) ;
#     }
#     final Tree treeToMove = treepath.getBottom() ;
#     final Tree parent = treepath.getTreeAtHeight( 1 ) ;
#     for( int i = 0 ; i < parent.getChildCount() - 1 ; i++ ) {
#       final Tree child = parent.getChildAt( i ) ;
#       if( child == treeToMove ) {
#         return Treepath.create( treepath.getParent(), parent.getChildAt( i + 1 ) ) ;
#       }
#     }
#     throw new IllegalArgumentException( "No next sibling" ) ;
#   }
#
#
# 旧代码代码：  public static Treepath getNextSibling( Treepath treepath ) {
#     throw new UnsupportedOperationException( "getNextSibling" ) ;
#   }
# ['<s>', 'Output', 'the', 'date', 'time', 'in', 'ISO8601', 'format', '(', 'yyyy', '-', 'MM', '-', 'ddTHH', ':', 'mm', ':', 'ss', '.', 'SSSZ', ').', '</s>', 'public String toString () {', 'return ISODateTimeFormat . getInstance (). dateTime (). print ( this );', '}']
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['ISO8601', 'Output', 'in', 'yyyy', 'time']
# , tensor([1.1416, 0.5403, 0.2659, 0.2059, 0.0975], dtype=torch.float64)
# , tensor([6, 1, 5, 9, 4])
# ,['}', '.', 'return ISODateTimeFormat . getInstance (). dateTime (). print ( this );', 'ddTHH', '<s>']
# ,tensor([-0.1260, -0.0054, -0.0047, -0.0047,  0.0000], dtype=torch.float64)
# ,tensor([24, 18, 23, 13,  0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public String toString() {
#         return ISODateTimeFormat.getInstance().dateTime().print(this);
#     }
#
# 旧代码代码：    public String toString() {
#         return ISODateTimeFormat.getInstance(getChronology()).dateTime().print(this);
#     }
#
# ['<s>', 'Evaluate', 'a', 'PLAIN', 'login', 'challenge', ',', 'returning', 'the', 'a', 'result', 'string', 'that', 'should', 'satisfy', 'the', 'clallenge', '.', '</s>', 'public byte [] evaluateChallenge ( byte [] challenge ) throws MessagingException {', 'try {', 'String result = "\\0 "+ username +"\\0 "+ password ;', 'if ( authzid != null && authzid . length () > 0 ) {', 'result = authzid + result ;', '}', 'complete = true ;', 'return result . getBytes (" UTF - 8 ");', '} catch ( UnsupportedEncodingException e ) {', '// got an error , fail this', 'throw new MessagingException (" Invalid encoding ");', '}', '}']
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['challenge', 'Evaluate', '}', 'a', '}']
# , tensor([0.4227, 0.3849, 0.3502, 0.1966, 0.1137], dtype=torch.float64)
# , tensor([ 5,  1, 31,  2, 30])
# ,['if ( authzid != null && authzid . length () > 0 ) {', 'the', 'public byte [] evaluateChallenge ( byte [] challenge ) throws MessagingException {', 'the', 'result = authzid + result ;']
# ,tensor([-0.4125, -0.3367, -0.2883, -0.1837, -0.1371], dtype=torch.float64)
# ,tensor([22, 15, 19,  8, 23])
#
# 对比以下代码查看代码更改位置
# 新代码：    public byte[] evaluateChallenge(byte[] challenge) throws MessagingException {
#         try {
#
#             String result = "\0"+username+"\0"+password;
#
#             if(authzid != null && authzid.length() > 0) {
#                 result = authzid+result;
#             }
#
#             complete = true;
#             return result.getBytes("UTF-8");
#
#         } catch (UnsupportedEncodingException e) {
#             // got an error, fail this
#             throw new MessagingException("Invalid encoding");
#         }
#     }
#
#
# 旧代码代码：    public byte[] evaluateChallenge(byte[] challenge) throws MessagingException {
#         try {
#             // get the username and password in an UTF-8 encoding to create the
#             // token
#             byte[] userBytes = username.getBytes("UTF-8");
#             byte[] passBytes = password.getBytes("UTF-8");
#
#             // our token has two copies of the username, one copy of the
#             // password, and nulls
#             // between
#             byte[] tokenBytes = new byte[(userBytes.length * 2) + passBytes.length + 2];
#
#             System.arraycopy(userBytes, 0, tokenBytes, 0, userBytes.length);
#             System.arraycopy(userBytes, 0, tokenBytes, userBytes.length + 1, userBytes.length);
#             System.arraycopy(passBytes, 0, tokenBytes, (userBytes.length * 2) + 2, passBytes.length);
#
#             complete = true;
#             return tokenBytes;
#
#         } catch (UnsupportedEncodingException e) {
#             // got an error, fail this
#             throw new MessagingException("Invalid encoding");
#         }
#     }
#
# ['<s>', 'Gets', 'the', 'given', 'start', 'and', 'end', 'view', 'positions', 'offset', 'to', 'a', 'header', '.', '</s>', 'public static int [] getViewToHeaderPosition ( JTextArea view , int start , int end ) {', 'validateView ( view );', 'validateStartEnd ( start , end );', 'if (! isValidStartEndForLength ( start , end , view . getDocument (). getLength ())) {', 'return INVALID _ POSITION ;', '}', 'return getViewToHeaderPositionImpl ( view , start , end );', '}']
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['if (! isValidStartEndForLength ( start , end , view . getDocument (). getLength ())) {', 'end', 'return INVALID _ POSITION ;', 'start', 'validateView ( view );']
# , tensor([1.0229, 0.8921, 0.6157, 0.4267, 0.2197], dtype=torch.float64)
# , tensor([18,  6, 19,  4, 16])
# ,['given', 'view', 'Gets', 'positions', 'offset']
# ,tensor([-0.1897, -0.1147, -0.1044, -0.0842, -0.0674], dtype=torch.float64)
# ,tensor([3, 7, 1, 8, 9])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static int[] getViewToHeaderPosition(JTextArea view, int start, int end) {
#         validateView(view);
#         validateStartEnd(start, end);
#
#         if (!isValidStartEndForLength(start, end, view.getDocument().getLength())) {
#             return INVALID_POSITION;
#         }
#
#         return getViewToHeaderPositionImpl(view, start, end);
#     }
#
# 旧代码代码：    public static int[] getViewToHeaderPosition(JTextArea view, int start, int end) {
#         validateView(view);
#         validateStartEnd(start, end, view.getDocument().getLength());
#         return getViewToHeaderPositionImpl(view, start, end);
#     }
#
# ['<s>', 'Return', 'XML', 'schema', 'for', 'the', 'specified', 'type', ',', 'suitable', 'for', 'insertion', 'into', 'the', '&', 'lt', ';', 'types', '&', 'gt', ';', 'element', 'of', 'a', 'WSDL', 'document', '.', '</s>', 'public Element writeSchema ( Class javaType , Types types ) throws Exception {', 'return null ;', '}']
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public Element writeSchema ( Class javaType , Types types ) throws Exception {', 'return null ;', 'insertion', 'WSDL', '}']
# , tensor([1.9008, 0.3771, 0.2770, 0.2686, 0.2506], dtype=torch.float64)
# , tensor([28, 29, 11, 24, 30])
# ,['for', 'type', 'types', 'specified', 'document']
# ,tensor([-0.4246, -0.1911, -0.0333, -0.0333, -0.0267], dtype=torch.float64)
# ,tensor([ 4,  7, 17,  6, 25])
#
# 对比以下代码查看代码更改位置
# 新代码：    public Element writeSchema(Class javaType, Types types) throws Exception {
#         return null;
#     }
#
#
# 旧代码代码：    public boolean writeSchema(Types types) throws Exception {
#         return false;
#     }
#
# ['<s>', 'Gets', 'the', 'quality', 'or', 'status', 'of', 'the', 'given', 'passive', 'scanner', '.', '</s>', 'public static String getPluginQuality ( PluginPassiveScanner scanner ) {', '// String scannerPackage = scanner . getClass (). getCanonicalName ();', 'String scannerName = scanner . getName ();', 'return ( getSpecificQuality ( scannerName , scanner ));', '}']
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return ( getSpecificQuality ( scannerName , scanner ));', 'or', 'of', 'scanner', 'the']
# , tensor([0.7534, 0.4903, 0.3573, 0.2632, 0.2609], dtype=torch.float64)
# , tensor([16,  4,  6, 10,  7])
# ,['passive', 'quality', 'given', '<s>', '</s>']
# ,tensor([-0.2487, -0.1632, -0.0479,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([ 9,  3,  8,  0, 12])
#
# 对比以下代码查看代码更改位置
# 新代码：	public static String getPluginQuality(PluginPassiveScanner scanner) {
# //        String scannerPackage = scanner.getClass().getCanonicalName();
#         String scannerName = scanner.getName();
#
#         return (getSpecificQuality(scannerName, scanner));
#
#         }
#
# 旧代码代码：	public static String getPluginQuality(PluginPassiveScanner scanner) {
#         String scannerPackage = scanner.getClass().getCanonicalName();
#         String scannerName = scanner.getName();
#
#         return (getSpecificQuality(scannerName, scannerPackage));
#
#         }
#
# ['<s>', 'Looks', 'up', 'a', 'field', 'with', 'a', 'given', 'name', 'and', 'if', 'found', 'returns', 'its', 'ordinal', '.', '</s>', 'public static RelDataTypeField lookupField (', 'final RelDataType rowType ,', 'String columnName )', '{', 'final RelDataTypeField [] fields = rowType . getFields ();', 'for ( int i = 0 ; i < fields . length ; i ++) {', 'RelDataTypeField field = fields [ i ];', 'if ( field . getName (). equals ( columnName )) {', 'return field ;', '}', '}', 'return null ;', '}']
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return field ;', 'given', 'public static RelDataTypeField lookupField (', 'ordinal', 'up']
# , tensor([0.2137, 0.2084, 0.1827, 0.1093, 0.0849], dtype=torch.float64)
# , tensor([25,  7, 17, 14,  2])
# ,['with', 'field', 'and', 'for ( int i = 0 ; i < fields . length ; i ++) {', 'if']
# ,tensor([-0.7276, -0.3958, -0.3231, -0.2817, -0.2498], dtype=torch.float64)
# ,tensor([ 5,  4,  9, 22, 10])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static RelDataTypeField lookupField(
#         final RelDataType rowType,
#         String columnName)
#     {
#         final RelDataTypeField [] fields = rowType.getFields();
#         for (int i = 0; i < fields.length; i++) {
#             RelDataTypeField field = fields[i];
#             if (field.getName().equals(columnName)) {
#                 return field;
#             }
#         }
#         return null;
#     }
#
#
# 旧代码代码：    public static int lookupField(
#         final RelDataType rowType,
#         String columnName)
#     {
#         final RelDataTypeField [] fields = rowType.getFields();
#         for (int i = 0; i < fields.length; i++) {
#             RelDataTypeField field = fields[i];
#             if (field.getName().equals(columnName)) {
#                 return i;
#             }
#         }
#         return -1;
#     }
# ['<s>', 'Expr', ':', 'left', '.', 'lastIndexOf', '(', 'right', ')', '</s>', 'public static ENumber < Integer > lastIndexOf ( Expr < String > left , String right ) {', 'return factory . createNumber ( Integer . class , Ops . LAST _ INDEX , left , factory . createConstant ( right ));', '}']
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return factory . createNumber ( Integer . class , Ops . LAST _ INDEX , left , factory . createConstant ( right ));', 'public static ENumber < Integer > lastIndexOf ( Expr < String > left , String right ) {', 'left', '(', '}']
# , tensor([1.0556, 0.6809, 0.4043, 0.2720, 0.2116], dtype=torch.float64)
# , tensor([11, 10,  3,  6, 12])
# ,['Expr', '<s>', '</s>', ')', ':']
# ,tensor([-0.5747,  0.0000,  0.0000,  0.0501,  0.1027], dtype=torch.float64)
# ,tensor([1, 0, 9, 8, 2])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static ENumber<Integer> lastIndexOf(Expr<String> left, String right) {
#         return factory.createNumber(Integer.class,Ops.LAST_INDEX, left, factory.createConstant(right));
#     }
#
# 旧代码代码：    public static ENumber<Integer> lastIndexOf(Expr<String> left, String right) {
#         return createNumber(Integer.class,Ops.LAST_INDEX, left, createConstant(right));
#     }
#
# ['<s>', 'Converts', 'the', 'given', 'object', 'into', 'a', 'JSON', 'AST', '.', '</s>', 'public static String asJson ( Object object ) throws IOException {', 'return JSON . writeValueAsString ( object );', '}']
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static String asJson ( Object object ) throws IOException {', 'return JSON . writeValueAsString ( object );', 'JSON', '}', 'object']
# , tensor([2.1799, 1.1646, 0.3982, 0.3698, 0.2034], dtype=torch.float64)
# , tensor([11, 12,  7, 13,  4])
# ,['given', '<s>', '</s>', 'the', '.']
# ,tensor([-0.0657,  0.0000,  0.0000,  0.0066,  0.1040], dtype=torch.float64)
# ,tensor([ 3,  0, 10,  2,  9])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static String asJson(Object object) throws IOException {
#         return JSON.writeValueAsString(object);
#     }
#
#
# 旧代码代码：    public static JsonNode asJson(Object object) throws IOException {
#         return JSON.writeValueAsTree(object);
#     }
#
# 解析错误
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.3868e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public ArrayList getImageSrcs () {', 'return this . img _ src ;', '}']
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return this . img _ src ;', 'public ArrayList getImageSrcs () {', 'ME', '<s>', '</s>']
# , tensor([0.8231, 0.6097, 0.1816, 0.0000, 0.0000], dtype=torch.float64)
# , tensor([6, 5, 2, 0, 4])
# ,['DOCUMENT', '}', '!', '<s>', '</s>']
# ,tensor([-0.4325, -0.0360, -0.0102,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([1, 7, 3, 0, 4])
#
# 对比以下代码查看代码更改位置
# 新代码：    public ArrayList getImageSrcs() {
#         return this.img_src;
#     }
#
#
# 旧代码代码：    public ArrayList getImageSrcs() {
#         return img_src;
#     }
#
# 解析错误
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Removes', 'the', 'content', 'source', 'from', 'this', 'channel', ',', 'if', 'it', 'exists', '.', '</s>', 'public RepoContentSource removeContentSource ( ContentSource contentSource ) {', 'if (( this . repoContentSources == null ) || ( contentSource == null )) {', 'return null ;', '}', 'RepoContentSource doomed = null ;', 'for ( RepoContentSource ccs : this . repoContentSources ) {', 'if ( contentSource . equals ( ccs . getRepoContentSourcePK (). getContentSource ())) {', 'doomed = ccs ;', 'break ;', '}', '}', 'if ( doomed != null ) {', 'this . repoContentSources . remove ( doomed );', '}', 'return doomed ;', '}']
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['channel', 'if (( this . repoContentSources == null ) || ( contentSource == null )) {', 'from', 'source', 'if']
# , tensor([0.6386, 0.4157, 0.4134, 0.3357, 0.2401], dtype=torch.float64)
# , tensor([ 7, 15,  5,  4,  9])
# ,['return doomed ;', '}', 'Removes', 'break ;', '.']
# ,tensor([-0.3225, -0.2644, -0.1473, -0.0960, -0.0529], dtype=torch.float64)
# ,tensor([28, 27,  1, 22, 12])
#
# 对比以下代码查看代码更改位置
# 新代码：    public RepoContentSource removeContentSource(ContentSource contentSource) {
#         if ((this.repoContentSources == null) || (contentSource == null)) {
#             return null;
#         }
#
#         RepoContentSource doomed = null;
#
#         for (RepoContentSource ccs : this.repoContentSources) {
#             if (contentSource.equals(ccs.getRepoContentSourcePK().getContentSource())) {
#                 doomed = ccs;
#                 break;
#             }
#         }
#
#         if (doomed != null) {
#             this.repoContentSources.remove(doomed);
#         }
#
#         return doomed;
#     }
#
#
# 旧代码代码：    public ChannelContentSource removeContentSource(ContentSource contentSource) {
#         if ((this.channelContentSources == null) || (contentSource == null)) {
#             return null;
#         }
#
#         ChannelContentSource doomed = null;
#
#         for (ChannelContentSource ccs : this.channelContentSources) {
#             if (contentSource.equals(ccs.getChannelContentSourcePK().getContentSource())) {
#                 doomed = ccs;
#                 break;
#             }
#         }
#
#         if (doomed != null) {
#             this.channelContentSources.remove(doomed);
#         }
#
#         return doomed;
#     }
#
# ['<s>', 'Returns', 'whether', 'an', 'instance', 'of', 'Chrome', 'is', 'currently', 'connected', '</s>', 'boolean hasClient () {', 'return listeningThread != null && listeningThread . hasClient && ! listeningThread . sockets . isEmpty ();', '}']
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Chrome', 'Returns', 'boolean hasClient () {', 'an', 'of']
# , tensor([0.6820, 0.4389, 0.1072, 0.0745, 0.0251], dtype=torch.float64)
# , tensor([ 6,  1, 11,  3,  5])
# ,['return listeningThread != null && listeningThread . hasClient && ! listeningThread . sockets . isEmpty ();', '}', 'whether', 'instance', 'is']
# ,tensor([-0.4120, -0.4120, -0.1492, -0.0799, -0.0298], dtype=torch.float64)
# ,tensor([12, 13,  2,  4,  7])
#
# 对比以下代码查看代码更改位置
# 新代码：  boolean hasClient() {
#     return listeningThread != null && listeningThread.hasClient && !listeningThread.sockets.isEmpty();
#   }
#
# 旧代码代码：  boolean hasClient() {
#     return listeningThread != null && listeningThread.hasClient;
#   }
#
# ['<s>', 'Returns', 'the', 'meta', 'object', 'for', 'the', 'containment', 'reference', "'", 'org', '.', 'eclipse', '.', 'mylyn', '.', 'reviews', '.', 'core', '.', 'model', '.', 'IChange', '#', 'getState', 'State', "'.", '</s>', 'public EAttribute getChange _ State () {', 'return ( EAttribute ) changeEClass . getEStructuralFeatures (). get ( 5 );', '}']
# 第20个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Returns', 'return ( EAttribute ) changeEClass . getEStructuralFeatures (). get ( 5 );', 'eclipse', '.', '}']
# , tensor([0.6963, 0.3109, 0.0862, 0.0404, 0.0363], dtype=torch.float64)
# , tensor([ 1, 29, 12, 11, 30])
# ,['for', 'object', 'public EAttribute getChange _ State () {', 'mylyn', 'the']
# ,tensor([-0.4955, -0.3723, -0.2727, -0.1051, -0.0822], dtype=torch.float64)
# ,tensor([ 5,  4, 28, 14,  6])
#
# 对比以下代码查看代码更改位置
# 新代码：	public EAttribute getChange_State() {
# 		return (EAttribute) changeEClass.getEStructuralFeatures().get(5);
# 	}
#
#
# 旧代码代码：	public EReference getChange_State() {
# 		return (EReference) changeEClass.getEStructuralFeatures().get(5);
# 	}
# ['<s>', 'Creates', 'a', 'new', 'UserFolder', ',', 'inflated', 'from', 'R', '.', 'layout', '.', 'user', '_', 'folder', '.', '</s>', 'static Folder fromXml ( Launcher launcher ) {', 'return ( Folder ) launcher . getLayoutInflater ()', '. inflate ( R . layout . user _ folder _ icon _ normalized , null );', '}']
# 第21个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['static Folder fromXml ( Launcher launcher ) {', 'return ( Folder ) launcher . getLayoutInflater ()', '. inflate ( R . layout . user _ folder _ icon _ normalized , null );', 'a', '}']
# , tensor([0.9933, 0.8665, 0.5343, 0.2901, 0.2091], dtype=torch.float64)
# , tensor([17, 18, 19,  2, 20])
# ,['new', 'R', 'Creates', 'folder', '.']
# ,tensor([-0.4504, -0.1632, -0.0714, -0.0544, -0.0407], dtype=torch.float64)
# ,tensor([ 3,  8,  1, 14,  9])
#
# 对比以下代码查看代码更改位置
# 新代码：    static Folder fromXml(Launcher launcher) {
#         return (Folder) launcher.getLayoutInflater()
#                 .inflate(R.layout.user_folder_icon_normalized, null);
#     }
#
# 旧代码代码：    static Folder fromXml(Launcher launcher) {
#         return (Folder) launcher.getLayoutInflater().inflate(
#                 FeatureFlags.LAUNCHER3_DISABLE_ICON_NORMALIZATION
#                         ? R.layout.user_folder : R.layout.user_folder_icon_normalized, null);
#     }
#
# ['<s>', 'Return', 'a', 'String', 'to', 'recreate', 'the', 'GRANTs', 'given', 'for', 'the', 'passed', 'table', '.', '</s>', 'public Collection < TableGrant > getTableGrants ( TableIdentifier table )', '{', 'Collection < TableGrant > result = new HashSet < TableGrant >();', 'ResultSet rs = null ;', 'try', '{', 'TableIdentifier tbl = table . createCopy ();', 'tbl . adjustCase ( this . dbConnection );', 'rs = this . metaData . getTablePrivileges ( tbl . getCatalog (), tbl . getSchema (), tbl . getTableName ());', 'while ( rs . next ())', '{', 'String from = rs . getString ( 4 );', 'String to = rs . getString ( 5 );', 'String what = rs . getString ( 6 );', 'boolean grantable = StringUtil . stringToBool ( rs . getString ( 7 ));', 'TableGrant grant = new TableGrant ( to , what , grantable );', 'result . add ( grant );', '}', '}', 'catch ( Exception e )', '{', 'LogMgr . logError (" DbMetadata . getTableGrants ()", " Error when retrieving table privileges ", e );', '}', 'finally', '{', 'try { rs . close (); } catch ( Throwable th ) {}', '}', 'return result ;', '}']
# 第22个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public Collection < TableGrant > getTableGrants ( TableIdentifier table )', 'try { rs . close (); } catch ( Throwable th ) {}', 'Collection < TableGrant > result = new HashSet < TableGrant >();', 'return result ;', 'rs = this . metaData . getTablePrivileges ( tbl . getCatalog (), tbl . getSchema (), tbl . getTableName ());']
# , tensor([0.2190, 0.1758, 0.1392, 0.1056, 0.1021], dtype=torch.float64)
# , tensor([15, 40, 17, 42, 23])
# ,['}', 'LogMgr . logError (" DbMetadata . getTableGrants ()", " Error when retrieving table privileges ", e );', 'GRANTs', '<s>', '</s>']
# ,tensor([-1.4713, -0.2629, -0.0421,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([37, 36,  7,  0, 14])
#
# 对比以下代码查看代码更改位置
# 新代码：	public Collection<TableGrant> getTableGrants(TableIdentifier table)
# 	{
# 		Collection<TableGrant> result = new HashSet<TableGrant>();
# 		ResultSet rs = null;
# 		try
# 		{
# 			TableIdentifier tbl = table.createCopy();
# 			tbl.adjustCase(this.dbConnection);
# 			rs = this.metaData.getTablePrivileges(tbl.getCatalog(), tbl.getSchema(), tbl.getTableName());
# 			while (rs.next())
# 			{
# 				String from = rs.getString(4);
# 				String to = rs.getString(5);
# 				String what = rs.getString(6);
# 				boolean grantable = StringUtil.stringToBool(rs.getString(7));
# 				TableGrant grant = new TableGrant(to, what, grantable);
# 				result.add(grant);
# 			}
# 		}
# 		catch (Exception e)
# 		{
# 			LogMgr.logError("DbMetadata.getTableGrants()", "Error when retrieving table privileges",e);
# 		}
# 		finally
# 		{
# 			try { rs.close(); } catch (Throwable th) {}
# 		}
# 		return result;
# 	}
#
#
# 旧代码代码：	public DataStore getTableGrants(TableIdentifier table)
# 	{
# 		String[] columns = new String[] { "TABLENAME", "GRANTOR", "GRANTEE", "PRIVILEGE", "GRANTABLE" };
# 		int[] colTypes = new int[] { Types.VARCHAR, Types.VARCHAR, Types.VARCHAR, Types.VARCHAR, Types.VARCHAR };
# 		DataStore result = new DataStore(columns, colTypes);
# 		ResultSet rs = null;
# 		try
# 		{
# 			TableIdentifier tbl = table.createCopy();
# 			tbl.adjustCase(this.dbConnection);
# 			rs = this.metaData.getTablePrivileges(tbl.getCatalog(), tbl.getSchema(), tbl.getTableName());
# 			while (rs.next())
# 			{
# 				int row = result.addRow();
# 				result.setValue(row, COLUMN_IDX_TABLE_GRANTS_OBJECT_NAME, rs.getString(3));
# 				result.setValue(row, COLUMN_IDX_TABLE_GRANTS_GRANTOR, rs.getString(4));
# 				result.setValue(row, COLUMN_IDX_TABLE_GRANTS_GRANTEE, rs.getString(5));
# 				result.setValue(row, COLUMN_IDX_TABLE_GRANTS_PRIV, rs.getString(6));
# 				result.setValue(row, COLUMN_IDX_TABLE_GRANTS_GRANTABLE, rs.getString(7));
# 			}
# 		}
# 		catch (Exception e)
# 		{
# 			LogMgr.logError("DbMetadata.getTableGrants()", "Error when retrieving table privileges",e);
# 			result.reset();
# 		}
# 		finally
# 		{
# 			try { rs.close(); } catch (Throwable th) {}
# 		}
# 		return result;
# 	}
#
# ['<s>', 'Disable', 'tiling', 'of', 'the', 'image', '.', '</s>', 'public ImageSource tilingDisabled () {', 'return setTiling ( false );', '}']
# 第23个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public ImageSource tilingDisabled () {', 'image', 'the', '.', '}']
# , tensor([0.3851, 0.1950, 0.1388, 0.1351, 0.0847], dtype=torch.float64)
# , tensor([ 8,  5,  4,  6, 10])
# ,['of', 'return setTiling ( false );', 'Disable', 'tiling', '<s>']
# ,tensor([-0.4266, -0.2110, -0.1990, -0.0371,  0.0000], dtype=torch.float64)
# ,tensor([3, 9, 1, 2, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public ImageSource tilingDisabled() {
#         return setTiling(false);
#     }
#
# 旧代码代码：    public ImageSource tilingDisabled() {
#         return tiling(false);
#     }
#
# 解析错误
# 第24个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# 解析错误
# 第25个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9998e-01, 2.2253e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Make', 'fully', 'qualified', 'URI', 'based', 'on', 'the', 'default', 'file', 'system', 'Scheme', 'and', 'Authority', '</s>', 'private static URI makeFullQualifiedURI ( String uriName ) throws IOException {', 'Path uriPath = new Path ( uriName );', 'if ( isNormalized ( uriName ) && uriPath . isUriPathAbsolute ()) {', '// add scheme and / or authority if either is missing', 'if (( uriPath . toUri (). getScheme () == null || uriPath . toUri (). getAuthority () == null )) {', 'URI defaultUri = FileSystem . getDefaultUri ( CONF );', 'uriPath = uriPath . makeQualified ( defaultUri , uriPath );', '}', 'return uriPath . toUri ();', '} else { // relative URI path is unacceptable', 'return null ;', '}', '}']
# 第26个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['system', 'URI defaultUri = FileSystem . getDefaultUri ( CONF );', '} else { // relative URI path is unacceptable', 'uriPath = uriPath . makeQualified ( defaultUri , uriPath );', 'if ( isNormalized ( uriName ) && uriPath . isUriPathAbsolute ()) {']
# , tensor([0.7169, 0.4194, 0.3259, 0.2958, 0.1970], dtype=torch.float64)
# , tensor([10, 20, 24, 21, 17])
# ,['private static URI makeFullQualifiedURI ( String uriName ) throws IOException {', 'default', 'and', 'URI', 'fully']
# ,tensor([-1.1414, -0.2125, -0.1348, -0.1038, -0.0846], dtype=torch.float64)
# ,tensor([15,  8, 12,  4,  2])
#
# 对比以下代码查看代码更改位置
# 新代码：  private static URI makeFullQualifiedURI(String uriName) throws IOException {
#     Path uriPath = new Path(uriName);
#     if (isNormalized(uriName) && uriPath.isUriPathAbsolute()) {
#       // add scheme and/or authority if either is missing
#       if ((uriPath.toUri().getScheme() == null || uriPath.toUri().getAuthority() == null)) {
#         URI defaultUri = FileSystem.getDefaultUri(CONF);
#         uriPath = uriPath.makeQualified(defaultUri, uriPath);
#       }
#       return uriPath.toUri();
#     } else { // relative URI path is unacceptable
#       return null;
#     }
#   }
#
#
# 旧代码代码：  private static URI makeFullQualifiedURI(String uriName) throws IOException, URISyntaxException {
#     Path uriPath = new Path(uriName);
#
#     if (uriPath.isAbsoluteAndSchemeAuthorityNull()) {
#
#       URI defaultUri = FileSystem.getDefaultUri(CONF);
#       uriPath = uriPath.makeQualified(defaultUri, uriPath);
#       return uriPath.toUri();
#     }
#
#     return new URI(uriName);
#   }
# ['<s>', 'Rotate', 'the', 'vertex', 'by', 'the', 'given', 'orientation', '</s>', 'public Vertex rotate ( int orientation )', '{', '// models are orientated north ( 1024 ) and there are 2048 angles total', 'orientation = ( orientation + 1024 ) % 2048 ;', 'if ( orientation == 0 )', '{', 'return this ;', '}', 'int sin = Perspective . SINE [ orientation ];', 'int cos = Perspective . COSINE [ orientation ];', 'return new Vertex (', 'x * cos + z * sin >> 16 ,', 'y ,', 'z * cos - x * sin >> 16', ');', '}']
# 第27个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['vertex', 'int cos = Perspective . COSINE [ orientation ];', 'x * cos + z * sin >> 16 ,', 'int sin = Perspective . SINE [ orientation ];', 'by']
# , tensor([0.5418, 0.3929, 0.3276, 0.3164, 0.3151], dtype=torch.float64)
# , tensor([ 3, 18, 20, 17,  4])
# ,['orientation', '{', 'given', 'Rotate', '}']
# ,tensor([-0.5510, -0.2639, -0.1616, -0.1446, -0.1380], dtype=torch.float64)
# ,tensor([ 7, 10,  6,  1, 24])
#
# 对比以下代码查看代码更改位置
# 新代码：	public Vertex rotate(int orientation)
# 	{
# 		// models are orientated north (1024) and there are 2048 angles total
# 		orientation = (orientation + 1024) % 2048;
#
# 		if (orientation == 0)
# 		{
# 			return this;
# 		}
#
# 		int sin = Perspective.SINE[orientation];
# 		int cos = Perspective.COSINE[orientation];
#
# 		return new Vertex(
# 			x * cos + z * sin >> 16,
# 			y,
# 			z * cos - x * sin >> 16
# 		);
# 	}
#
# 旧代码代码：	public Vertex rotate(int orientation)
# 	{
# 		int sin = Perspective.SINE[orientation];
# 		int cos = Perspective.COSINE[orientation];
#
# 		return new Vertex(
# 			x * cos + z * sin >> 16,
# 			y,
# 			z * cos - x * sin >> 16
# 		);
# 	}
#
# ['<s>', 'Returns', '</s>', 'public RollCycle getRollCycle () {', 'return queue . rollCycle ();', '}']
# 第28个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public RollCycle getRollCycle () {', 'Returns', '}', '<s>', '</s>']
# , tensor([0.1805, 0.0804, 0.0762, 0.0000, 0.0000], dtype=torch.float64)
# , tensor([3, 1, 5, 0, 2])
# ,['return queue . rollCycle ();', '<s>', '</s>', '}', 'Returns']
# ,tensor([-0.3441,  0.0000,  0.0000,  0.0762,  0.0804], dtype=torch.float64)
# ,tensor([4, 0, 2, 5, 1])
#
# 对比以下代码查看代码更改位置
# 新代码：	public RollCycle getRollCycle() {
# 		return queue.rollCycle();
# 	}
#
#
# 旧代码代码：	public RollCycle getRollCycle() {
# 		return rollCycle;
# 	}
#
# 解析错误
# 第29个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'Build', 'a', 'DruidDimensionsLoader', '.', '</s>', 'protected DimensionValueLoadTask buildDruidDimensionsLoader (', 'DruidWebService webService ,', 'PhysicalTableDictionary physicalTableDictionary ,', 'DimensionDictionary dimensionDictionary', ') {', 'DruidDimensionValueLoader druidDimensionRowProvider = new DruidDimensionValueLoader (', 'physicalTableDictionary ,', 'dimensionDictionary ,', 'webService', ');', 'return new DimensionValueLoadTask ( Collections . singletonList ( druidDimensionRowProvider ));', '}']
# 第30个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['DruidDimensionValueLoader druidDimensionRowProvider = new DruidDimensionValueLoader (', 'return new DimensionValueLoadTask ( Collections . singletonList ( druidDimensionRowProvider ));', 'protected DimensionValueLoadTask buildDruidDimensionsLoader (', 'physicalTableDictionary ,', ') {']
# , tensor([1.0593, 0.3319, 0.2714, 0.2381, 0.2072], dtype=torch.float64)
# , tensor([11, 16,  6, 12, 10])
# ,['DruidDimensionsLoader', 'webService', 'PhysicalTableDictionary physicalTableDictionary ,', 'a', '<s>']
# ,tensor([-0.8996, -0.1248, -0.0288, -0.0166,  0.0000], dtype=torch.float64)
# ,tensor([ 3, 14,  8,  2,  0])
#
# 对比以下代码查看代码更改位置
# 新代码：    protected DimensionValueLoadTask buildDruidDimensionsLoader(
#             DruidWebService webService,
#             PhysicalTableDictionary physicalTableDictionary,
#             DimensionDictionary dimensionDictionary
#     ) {
#         DruidDimensionValueLoader druidDimensionRowProvider = new DruidDimensionValueLoader(
#                 physicalTableDictionary,
#                 dimensionDictionary,
#                 webService
#         );
#         return new DimensionValueLoadTask(Collections.singletonList(druidDimensionRowProvider));
#     }
#
#
# 旧代码代码：    protected DruidDimensionsLoader buildDruidDimensionsLoader(
#             DruidWebService webService,
#             PhysicalTableDictionary physicalTableDictionary,
#             DimensionDictionary dimensionDictionary
#     ) {
#         return new DruidDimensionsLoader(
#                 physicalTableDictionary,
#                 dimensionDictionary,
#                 webService
#         );
#     }
#
# ['<s>', 'Does', 'this', 'time', 'interval', 'overlap', 'the', 'specified', 'time', 'interval', '.', '</s>', 'public boolean overlaps ( ReadableInterval interval ) {', 'if ( interval == null ) {', 'return containsNow ();', '}', 'long otherStart = interval . getStartMillis ();', 'long otherEnd = interval . getEndMillis ();', 'long thisStart = getStartMillis ();', 'long thisEnd = getEndMillis ();', 'return ( thisStart < otherEnd && otherStart < thisEnd );', '}']
# 第31个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['interval', 'return ( thisStart < otherEnd && otherStart < thisEnd );', 'overlap', 'public boolean overlaps ( ReadableInterval interval ) {', 'long otherEnd = interval . getEndMillis ();']
# , tensor([0.6185, 0.6024, 0.4068, 0.3800, 0.3528], dtype=torch.float64)
# , tensor([ 4, 20,  5, 12, 17])
# ,['specified', 'the', 'time', 'this', '.']
# ,tensor([-0.3071, -0.1067, -0.0752, -0.0626, -0.0379], dtype=torch.float64)
# ,tensor([ 7,  6,  3,  2, 10])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean overlaps(ReadableInterval interval) {
#         if (interval == null) {
#             return containsNow();
#         }
#         long otherStart = interval.getStartMillis();
#         long otherEnd = interval.getEndMillis();
#         long thisStart = getStartMillis();
#         long thisEnd = getEndMillis();
#         return (thisStart < otherEnd && otherStart < thisEnd);
#     }
#
# 旧代码代码：    public boolean overlaps(ReadableInterval interval) {
#         if (interval == null) {
#             throw new IllegalArgumentException("The time interval must not be null");
#         }
#         long otherStart = interval.getStartMillis();
#         long otherEnd = interval.getEndMillis();
#         long thisStart = getStartMillis();
#         long thisEnd = getEndMillis();
#         return (thisStart < otherEnd && otherStart < thisEnd);
#     }
#
# ['<s>', 'prepares', 'an', 'url', '-', 'encoded', 'HTTP', 'queryString', 'containing', 'the', 'group', '/', 'job', 'and', 'the', 'options', '.', '</s>', 'private NameValuePair [] prepareQueryString ( String groupPath , String jobName , Properties options ) {', 'List < NameValuePair > queryString = new ArrayList < NameValuePair >();', 'queryString . add ( new NameValuePair (" groupPath ", groupPath ));', 'queryString . add ( new NameValuePair (" jobName ", jobName ));', 'if ( options != null ) {', 'for ( Entry < Object , Object > option : options . entrySet ()) {', 'queryString . add ( new NameValuePair (" extra . command . option ." + option . getKey (),', 'String . valueOf ( option . getValue ())));', '}', '}', 'return queryString . toArray ( new NameValuePair [ queryString . size ()]);', '}']
# 第32个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['HTTP', 'encoded', '-', 'return queryString . toArray ( new NameValuePair [ queryString . size ()]);', '}']
# , tensor([0.3589, 0.1835, 0.1183, 0.0788, 0.0639], dtype=torch.float64)
# , tensor([ 6,  5,  4, 28, 26])
# ,['url', 'queryString', 'queryString . add ( new NameValuePair (" groupPath ", groupPath ));', '}', 'queryString . add ( new NameValuePair (" jobName ", jobName ));']
# ,tensor([-0.6856, -0.3615, -0.3252, -0.3124, -0.2698], dtype=torch.float64)
# ,tensor([ 3,  7, 20, 29, 21])
#
# 对比以下代码查看代码更改位置
# 新代码：    private NameValuePair[] prepareQueryString(String groupPath, String jobName, Properties options) {
#         List<NameValuePair> queryString = new ArrayList<NameValuePair>();
#
#         queryString.add(new NameValuePair("groupPath", groupPath));
#         queryString.add(new NameValuePair("jobName", jobName));
#
#         if (options != null) {
#             for (Entry<Object, Object> option : options.entrySet()) {
#                 queryString.add(new NameValuePair("extra.command.option." + option.getKey(),
#                                                   String.valueOf(option.getValue())));
#             }
#         }
#
#         return queryString.toArray(new NameValuePair[queryString.size()]);
#     }
#
#
# 旧代码代码：    private String prepareQueryString(String groupPath, String jobName, Properties options) {
#         List<NameValuePair> parameters = new ArrayList<NameValuePair>();
#
#         parameters.add(new BasicNameValuePair("groupPath", groupPath));
#         parameters.add(new BasicNameValuePair("jobName", jobName));
#
#         if (options != null) {
#             for (Entry<Object, Object> option : options.entrySet()) {
#                 parameters.add(new BasicNameValuePair("extra.command.option." + option.getKey(),
#                                                       String.valueOf(option.getValue())));
#             }
#         }
#
#         return URLEncodedUtils.format(parameters, HTTP.UTF_8);
#     }
# ['<s>', 'Gets', 'the', 'colorAccent', 'from', 'the', 'current', 'context', ',', 'if', 'possible', '/', 'available', '</s>', 'public static int getAccentColorFromThemeIfAvailable ( Context context ) {', 'TypedValue typedValue = new TypedValue ();', '// First , try the android : colorAccent', 'if ( Build . VERSION . SDK _ INT >= 21 ) {', 'context . getTheme (). resolveAttribute ( android . R . attr . colorAccent , typedValue , true );', 'return typedValue . data ;', '}', '// Next , try colorAccent from support lib', 'int colorAccentResId = context . getResources (). getIdentifier (" colorAccent ", " attr ", context . getPackageName ());', 'if ( colorAccentResId != 0 && context . getTheme (). resolveAttribute ( colorAccentResId , typedValue , true )) {', 'return typedValue . data ;', '}', '// Return the value in mdtp _ accent _ color', 'return ContextCompat . getColor ( context , R . color . mdtp _ accent _ color );', '}']
# 第33个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['colorAccent', 'return ContextCompat . getColor ( context , R . color . mdtp _ accent _ color );', '}', 'available', 'Gets']
# , tensor([0.2809, 0.2238, 0.1902, 0.1061, 0.0720], dtype=torch.float64)
# , tensor([ 3, 27, 28, 12,  1])
# ,['// First , try the android : colorAccent', 'context . getTheme (). resolveAttribute ( android . R . attr . colorAccent , typedValue , true );', 'from', 'the', 'if ( Build . VERSION . SDK _ INT >= 21 ) {']
# ,tensor([-0.6382, -0.4187, -0.3814, -0.3611, -0.3392], dtype=torch.float64)
# ,tensor([16, 18,  4,  5, 17])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static int getAccentColorFromThemeIfAvailable(Context context) {
#         TypedValue typedValue = new TypedValue();
#         // First, try the android:colorAccent
#         if (Build.VERSION.SDK_INT >= 21) {
#             context.getTheme().resolveAttribute(android.R.attr.colorAccent, typedValue, true);
#             return typedValue.data;
#         }
#         // Next, try colorAccent from support lib
# ...
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.1304e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.1304e-05]], grad_fn=<SoftmaxBackward0>)
# 解析错误
# 第36个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[3.0763e-04, 9.9969e-01]], grad_fn=<SoftmaxBackward0>)
# 解析错误
# 第37个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public ArrayList getAllLinkHRefs () {', 'return this . link _ href _ all ;', '}']
# 第38个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['DOCUMENT', '!', '<s>', '</s>', 'ME']
# , tensor([ 0.8960,  0.0288,  0.0000,  0.0000, -0.1085], dtype=torch.float64)
# , tensor([1, 3, 0, 4, 2])
# ,['public ArrayList getAllLinkHRefs () {', 'return this . link _ href _ all ;', '}', 'ME', '<s>']
# ,tensor([-0.6535, -0.3182, -0.1581, -0.1085,  0.0000], dtype=torch.float64)
# ,tensor([5, 6, 7, 2, 0])
#
# 对比以下代码查看代码更改位置
# 新代码：    public ArrayList getAllLinkHRefs() {
#         return this.link_href_all;
#     }
#
#
# 旧代码代码：    public ArrayList getAllLinkHRefs() {
#         return link_href_all;
#     }
#
# ['<s>', 'Creates', 'a', 'view', 'representing', 'a', 'shortcut', '.', '</s>', 'View createShortcut ( ShortcutInfo info ) {', 'return createShortcut ( R . layout . application ,', '( ViewGroup ) mWorkspace . getChildAt ( mWorkspace . getCurrentScreen ()), info );', '}']
# 第39个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['View createShortcut ( ShortcutInfo info ) {', 'Creates', 'view', '<s>', '</s>']
# , tensor([0.3778, 0.2911, 0.0439, 0.0000, 0.0000], dtype=torch.float64)
# , tensor([9, 1, 3, 0, 8])
# ,['( ViewGroup ) mWorkspace . getChildAt ( mWorkspace . getCurrentScreen ()), info );', 'return createShortcut ( R . layout . application ,', '}', 'representing', 'a']
# ,tensor([-1.7451, -0.6968, -0.3336, -0.1605, -0.0743], dtype=torch.float64)
# ,tensor([11, 10, 12,  4,  5])
#
# 对比以下代码查看代码更改位置
# 新代码：    View createShortcut(ShortcutInfo info) {
#         return createShortcut(R.layout.application,
#                 (ViewGroup) mWorkspace.getChildAt(mWorkspace.getCurrentScreen()), info);
#     }
#
# 旧代码代码：    View createShortcut(ShortcutInfo info) {
#         return createShortcut(R.layout.application,
#                 (ViewGroup) mWorkspace.getChildAt(mWorkspace.getCurrentPage()), info);
#     }
#
# ['<s>', 'Allocate', 'a', 'bitmap', 'with', 'the', 'specified', 'width', 'and', 'height', '.', '</s>', '@ Override', 'protected Bitmap alloc ( int size ) {', 'return Bitmap . createBitmap (', '1 ,', '( int ) Math . ceil ( size / ( double ) BitmapUtil . RGB _ 565 _ BYTES _ PER _ PIXEL ),', 'Bitmap . Config . RGB _ 565 );', '}']
# 第40个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['( int ) Math . ceil ( size / ( double ) BitmapUtil . RGB _ 565 _ BYTES _ PER _ PIXEL ),', 'Bitmap . Config . RGB _ 565 );', 'bitmap', 'with', 'return Bitmap . createBitmap (']
# , tensor([1.4086, 0.6690, 0.6433, 0.3974, 0.2586], dtype=torch.float64)
# , tensor([16, 17,  3,  4, 14])
# ,['specified', 'Allocate', 'width', 'a', '.']
# ,tensor([-0.1494, -0.1393, -0.1064, -0.0538, -0.0168], dtype=torch.float64)
# ,tensor([ 6,  1,  7,  2, 10])
#
# 对比以下代码查看代码更改位置
# 新代码：  @Override
#   protected Bitmap alloc(int size) {
#     return Bitmap.createBitmap(
#         1,
#         (int) Math.ceil(size / (double) BitmapUtil.RGB_565_BYTES_PER_PIXEL),
#         Bitmap.Config.RGB_565);
#   }
#
#
# 旧代码代码：  @Override
#   protected Bitmap alloc(int size) {
#     return Bitmap.createBitmap(1, size, Bitmaps.BITMAP_CONFIG);
#   }
# 解析错误
# 第41个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[3.2106e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'All', 'Paths', 'are', "'", 'tagged', "'", 'in', 'swagger', 'with', 'the', 'final', 'entity', 'type', 'name', 'in', 'the', 'path', '.', '</s>', 'private String getTag () {', 'if ( lineage . isEmpty ()) {', 'return name ;', '} else {', 'return lineage . get ( 0 ). getName ();', '}', '}']
# 第42个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['swagger', 'All', 'private String getTag () {', '}', 'if ( lineage . isEmpty ()) {']
# , tensor([1.0350, 0.3412, 0.2499, 0.1703, 0.1318], dtype=torch.float64)
# , tensor([ 8,  1, 20, 26, 21])
# ,['are', 'return lineage . get ( 0 ). getName ();', 'the', 'final', 'type']
# ,tensor([-0.1508, -0.1353, -0.0948, -0.0771, -0.0742], dtype=torch.float64)
# ,tensor([ 3, 24, 10, 11, 13])
#
# 对比以下代码查看代码更改位置
# 新代码：        private String getTag() {
#             if (lineage.isEmpty()) {
#                 return name;
#             } else {
#                 return lineage.get(0).getName();
#             }
#         }
#
#
# 旧代码代码：        private String getTag() {
#             return dictionary.getJsonAliasFor(type);
#         }
#
# ['<s>', 'Used', 'to', 'determine', 'if', 'the', 'broker', 'can', 'dispatch', 'to', 'the', 'consumer', '.', '</s>', 'public boolean isFull () {', 'return getPrefetchSize () == 0 ? prefetchExtension . get () == 0 : dispatched . size () - prefetchExtension . get () >= info . getPrefetchSize ();', '}']
# 第43个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return getPrefetchSize () == 0 ? prefetchExtension . get () == 0 : dispatched . size () - prefetchExtension . get () >= info . getPrefetchSize ();', 'public boolean isFull () {', 'the', 'the', 'if']
# , tensor([3.7797, 0.4448, 0.2261, 0.2055, 0.2051], dtype=torch.float64)
# , tensor([15, 14, 10,  5,  4])
# ,['determine', '}', 'can', 'to', 'to']
# ,tensor([-0.1699, -0.1697, -0.1562, -0.1312, -0.0508], dtype=torch.float64)
# ,tensor([ 3, 16,  7,  9,  2])
#
# 对比以下代码查看代码更改位置
# 新代码：    public boolean isFull() {
#         return getPrefetchSize() == 0 ? prefetchExtension.get() == 0 : dispatched.size() - prefetchExtension.get() >= info.getPrefetchSize();
#     }
#
# 旧代码代码：    public boolean isFull() {
#         return dispatched.size() - prefetchExtension.get() >= info.getPrefetchSize();
#     }
#
# ['<s>', 'Gets', 'the', 'element', 'for', 'the', 'method', 'corresponding', 'to', 'this', 'invocation', '.', '</s>', 'public static final Element elementFromUse ( ExpressionTree node ) {', 'return InternalUtils . symbol ( node );', '}']
# 第44个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static final Element elementFromUse ( ExpressionTree node ) {', 'return InternalUtils . symbol ( node );', '}', '.', 'Gets']
# , tensor([1.0684, 0.7135, 0.1958, 0.1260, 0.0552], dtype=torch.float64)
# , tensor([13, 14, 15, 11,  1])
# ,['element', 'for', 'method', 'to', 'the']
# ,tensor([-0.6902, -0.3199, -0.1094, -0.0307, -0.0268], dtype=torch.float64)
# ,tensor([3, 4, 6, 8, 5])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static final Element elementFromUse(ExpressionTree node) {
#         return InternalUtils.symbol(node);
#     }
#
#
# 旧代码代码：    public static final ExecutableElement elementFromUse(MethodInvocationTree node) {
#         return (ExecutableElement)TreeInfo.symbol((JCTree)node.getMethodSelect());
#     }
#
# ['<s>', 'Get', 'the', 'full', 'length', 'of', 'this', 'movie', '(', 'in', 'seconds', ').', '</s>', 'public float duration () {', 'float sec = gplayer . queryDuration (). toSeconds ();', 'float nanosec = gplayer . queryDuration (). getNanoSeconds ();', 'return sec + Video . nanoSecToSecFrac ( nanosec );', '}']
# 第45个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['return sec + Video . nanoSecToSecFrac ( nanosec );', 'of', 'this', 'Get', 'public float duration () {']
# , tensor([0.9353, 0.4395, 0.1709, 0.1676, 0.1527], dtype=torch.float64)
# , tensor([16,  5,  6,  1, 13])
# ,['length', 'full', 'float sec = gplayer . queryDuration (). toSeconds ();', 'float nanosec = gplayer . queryDuration (). getNanoSeconds ();', ').']
# ,tensor([-0.4711, -0.1709, -0.1314, -0.0870, -0.0586], dtype=torch.float64)
# ,tensor([ 4,  3, 14, 15, 11])
#
# 对比以下代码查看代码更改位置
# 新代码：  public float duration() {
#     float sec = gplayer.queryDuration().toSeconds();
#     float nanosec = gplayer.queryDuration().getNanoSeconds();
#     return sec + Video.nanoSecToSecFrac(nanosec);
#   }
#
# 旧代码代码：  public float duration() {
#     float sec = gplayer.queryDuration().toSeconds();
#     float nanosec = gplayer.queryDuration().getNanoSeconds();
#     return sec + GSVideo.nanoSecToSecFrac(nanosec);
#   }
#
# ['<s>', 'Converts', 'a', 'value', 'from', 'its', 'logical', 'format', '(', 'BigDecimal', ')', 'to', 'its', 'encoded', 'format', '-', 'a', 'struct', 'containing', 'the', 'scale', 'of', 'the', 'number', 'and', 'a', 'binary', 'representation', 'of', 'the', 'number', '.', '</s>', 'public static Struct fromLogical ( Schema schema , SpecialValueDecimal value ) {', 'return fromLogical ( schema , value . getDecimalValue (). orElse ( null ));', '}']
# 第46个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['public static Struct fromLogical ( Schema schema , SpecialValueDecimal value ) {', 'return fromLogical ( schema , value . getDecimalValue (). orElse ( null ));', 'format', 'struct', 'from']
# , tensor([2.0211, 1.7002, 0.1386, 0.1331, 0.1285], dtype=torch.float64)
# , tensor([33, 34, 14, 17,  4])
# ,['logical', 'its', 'Converts', '(', 'number']
# ,tensor([-0.3545, -0.0665, -0.0403, -0.0391, -0.0128], dtype=torch.float64)
# ,tensor([ 6,  5,  1,  8, 30])
#
# 对比以下代码查看代码更改位置
# 新代码：    public static Struct fromLogical(Schema schema, SpecialValueDecimal value) {
#         return fromLogical(schema, value.getDecimalValue().orElse(null));
#     }
#
# 旧代码代码：    public static Struct fromLogical(Schema schema, SpecialValueDecimal value) {
#         Struct result = new Struct(schema);
#         final BigDecimal decimalValue = value.getDecimalValue().orElse(null);
#         assert decimalValue != null : "Unable to encode special value";
#         result.put(VALUE_FIELD, decimalValue.unscaledValue().toByteArray());
#         result.put(SCALE_FIELD, decimalValue.scale());
#         return result;
#     }
#
# ['<s>', 'Get', 'a', 'Struct', 'representation', 'of', 'the', 'source', '#', 'partition', '(', 'String', ')', 'partition', 'and', '#', 'lastOffset', '(', 'String', ')', 'offset', 'information', '.', '</s>', 'public Struct offsetStructForEvent ( String replicaSetName , Document oplogEvent ) {', 'Position position = INITIAL _ POSITION ;', 'String namespace = "";', 'if ( oplogEvent != null ) {', 'BsonTimestamp ts = extractEventTimestamp ( oplogEvent );', 'Long opId = oplogEvent . getLong (" h ");', 'position = new Position ( ts , opId );', 'namespace = oplogEvent . getString (" ns ");', '}', 'positionsByReplicaSetName . put ( replicaSetName , position );', 'return offsetStructFor ( replicaSetName , CollectionId . parse ( replicaSetName + "." + namespace ), position , isInitialSyncOngoing ( replicaSetName ));', '}']
# 第47个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['Struct', '#', 'representation', 'and', 'lastOffset']
# , tensor([0.7174, 0.2976, 0.1088, 0.1032, 0.0937], dtype=torch.float64)
# , tensor([ 3, 15,  4, 14, 16])
# ,['return offsetStructFor ( replicaSetName , CollectionId . parse ( replicaSetName + "." + namespace ), position , isInitialSyncOngoing ( replicaSetName ));', 'information', 'namespace = oplogEvent . getString (" ns ");', '#', 'Position position = INITIAL _ POSITION ;']
# ,tensor([-0.2371, -0.2112, -0.2042, -0.1886, -0.1655], dtype=torch.float64)
# ,tensor([34, 21, 31,  8, 25])
#
# 对比以下代码查看代码更改位置
# 新代码：    public Struct offsetStructForEvent(String replicaSetName, Document oplogEvent) {
#         Position position = INITIAL_POSITION;
#         String namespace = "";
#         if (oplogEvent != null) {
#             BsonTimestamp ts = extractEventTimestamp(oplogEvent);
#             Long opId = oplogEvent.getLong("h");
#             position = new Position(ts, opId);
#             namespace = oplogEvent.getString("ns");
#         }
#         positionsByReplicaSetName.put(replicaSetName, position);
#         return offsetStructFor(replicaSetName, CollectionId.parse(replicaSetName + "." + namespace), position, isInitialSyncOngoing(replicaSetName));
#     }
#
# 旧代码代码：    public Struct offsetStructForEvent(String replicaSetName, Document oplogEvent) {
#         Position position = INITIAL_POSITION;
#         String namespace = "";
#         if (oplogEvent != null) {
#             BsonTimestamp ts = extractEventTimestamp(oplogEvent);
#             Long opId = oplogEvent.getLong("h");
#             position = new Position(ts, opId);
#             namespace = oplogEvent.getString("ns");
#         }
#         positionsByReplicaSetName.put(replicaSetName, position);
#         return offsetStructFor(replicaSetName, namespace, position, isInitialSyncOngoing(replicaSetName));
#     }
# 解析错误
# 第48个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
#
# 对比以下代码查看代码更改位置
# 新代码：tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# 旧代码代码：tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# ['<s>', 'When', 'initializing', 'the', 'profile', ',', 'Opera', 'rapidly', 'starts', ',', 'stops', ',', 'restarts', 'and', 'stops', 'again', ';', 'we', 'need', 'to', 'wait', 'a', 'bit', 'to', 'make', 'sure', 'the', 'file', 'lock', 'is', 'really', 'gone', '.', '</s>', 'private boolean makeSureFileLockRemainsGone ( File lock , long timeToWait ) {', 'for ( long start = System . currentTimeMillis (); System . currentTimeMillis () < start + timeToWait ;) {', 'AsyncExecute . sleepTight ( 500 );', 'if ( lock . exists ()) return false ;', '}', 'return ! lock . exists ();', '}']
# 第49个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#           ['AsyncExecute . sleepTight ( 500 );', '}', 'if ( lock . exists ()) return false ;', ';', 'stops']
# , tensor([0.5582, 0.3308, 0.3225, 0.2924, 0.2452], dtype=torch.float64)
# , tensor([36, 40, 37, 16, 10])
# ,['profile', ',', 'Opera', 'private boolean makeSureFileLockRemainsGone ( File lock , long timeToWait ) {', 'file']
# ,tensor([-0.3903, -0.3078, -0.3052, -0.3037, -0.1339], dtype=torch.float64)
# ,tensor([ 4,  5,  6, 34, 27])
#
# 对比以下代码查看代码更改位置
# 新代码：    private boolean makeSureFileLockRemainsGone(File lock, long timeToWait) {
#         for (long start = System.currentTimeMillis(); System.currentTimeMillis() < start + timeToWait;) {
#             AsyncExecute.sleepTight(500);
#             if (lock.exists()) return false;
#         }
#         return !lock.exists();
#     }
#
# 旧代码代码：    private boolean makeSureFileLockRemainsGone(File lock, long timeToWait) {
#         for (long start = System.currentTimeMillis(); System.currentTimeMillis() < start + timeToWait;) {
#             AsyncExecute.sleepTight(500);
#             if (lock.exists()) return false;
#         }
#         if (!lock.exists()) return true;
#         return false;
#     }

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>nag</b></text></td><td><text style="padding-right:2em"><b>22.24</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> Get                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> entry                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> data                    </font></mark><mark style="background-color: hsl(0, 75%, 81%); opacity:1.0;                     line-height:1.75"><font color="black"> ,                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> read                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> directly                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> from                    </font></mark><mark style="background-color: hsl(0, 75%, 88%); opacity:1.0;                     line-height:1.75"><font color="black"> internal                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> data                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> structure                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> .                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> public String getValue ( String key ) throws NotFoundException , NotLeaderException {                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> if ( cluster . getLocalRole () != Role . LEADER ) {                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> throw new NotLeaderException ();                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height: ...

# %% [markdown]
# 判断行级贡献值分布情况，将一些特殊语句变为一个具有代表性的词

# %%
# 单个示例获取各种statement 的函数
def get_ifstatement(code_line,attribution_num):
    code_contains_if = [(i, s) for i, s in enumerate(code_line) if 'if' in s]
    attr_contains_if = [attribution_num[code_contains_if[i][0]] for i in range(len(code_contains_if))]
    return code_contains_if,attr_contains_if
def get_forstatement(code_line,attribution_num):
    code_contains_for = [(i, s) for i, s in enumerate(code_line) if 'for' in s]
    attr_contains_for = [attribution_num[code_contains_for[i][0]] for i in range(len(code_contains_for))]
    return code_contains_for,attr_contains_for
def get_whilestatement(code_line,attribution_num):
    code_contains_while = [(i, s) for i, s in enumerate(code_line) if 'while' in s]
    attr_contains_while = [attribution_num[code_contains_while[i][0]] for i in range(len(code_contains_while))]
    return code_contains_while,attr_contains_while
def get_variableDeclaration(code_line,attribution_num):
    code_contains_new = [(i, s) for i, s in enumerate(code_line) if 'new' in s]
    attr_contains_new = [attribution_num[code_contains_new[i][0]] for i in range(len(code_contains_new))]
    return code_contains_new,attr_contains_new
def get_expression(code_line,attribution_num):
    code_contains_exp = [(i, s) for i, s in enumerate(code_line) if '=' in s]
    attr_contains_exp = [attribution_num[code_contains_exp[i][0]] for i in range(len(code_contains_exp))]
    return code_contains_exp,attr_contains_exp
def get_try_catch(code_line,attribution_num):
    code_contains_try_catch = [(i, s) for i, s in enumerate(code_line) if 'try' in s]
    attr_contains_try_catch = [attribution_num[code_contains_try_catch[i][0]] for i in range(len(code_contains_try_catch))]
    return code_contains_try_catch,attr_contains_try_catch
def get_return(code_line,attribution_num):
    code_contains_return = [(i, s) for i, s in enumerate(code_line) if 'return' in s]
    attr_contains_return = [attribution_num[code_contains_return[i][0]] for i in range(len(code_contains_return))]
    return code_contains_return,attr_contains_return
def get_MethodDeclaration(code_line,attribution_num):
    code_contains_Method = [code_line[0]]
    attr_contains_Method = [attribution_num[0]]
    return code_contains_Method,attr_contains_Method

# %%
# 集成到数据集中 , 对返回值进行数据分析 , 六个列表试着画小提琴图
def get_all_statement(code_line_list,attribution_num_list):
    ifstatement ,ifstatement_num = [],[]
    forstatement ,forstatement_num = [],[]
    whilestatement ,whilestatement_num = [],[]
    variableDeclaration ,variableDeclaration_num = [],[]
    expression ,expression_num = [],[]
    trystatement ,trystatement_num = [],[]
    returnstatement ,returnstatement_num = [],[]
    MethodDeclaration ,MethodDeclaration_num = [],[]
    for (code_line,attribution_num) in zip(code_line_list,attribution_num_list):
#         print(code_line,attribution_num)
        code_contains_if,attr_contains_if = get_ifstatement(code_line,attribution_num)
        code_contains_for,attr_contains_for = get_forstatement(code_line,attribution_num)
        code_contains_while,attr_contains_while = get_whilestatement(code_line,attribution_num)
        code_contains_new,attr_contains_new = get_variableDeclaration(code_line,attribution_num)
        code_contains_exp,attr_contains_exp = get_expression(code_line,attribution_num)
        code_contains_try_catch,attr_contains_try_catch = get_try_catch(code_line,attribution_num)
        code_contains_return,attr_contains_return = get_return(code_line,attribution_num)
        code_contains_Method,attr_contains_Method = get_MethodDeclaration(code_line,attribution_num)
        
        ifstatement.append(code_contains_if ) if code_contains_if != [] else None
        ifstatement_num.append(attr_contains_if ) if attr_contains_if != [] else None
        forstatement.append(code_contains_for ) if code_contains_for != [] else None
        forstatement_num.append(attr_contains_for) if attr_contains_for != [] else None
        whilestatement.append(code_contains_while ) if code_contains_while != [] else None
        whilestatement_num.append(attr_contains_while ) if attr_contains_while != [] else None
        variableDeclaration.append(code_contains_new ) if code_contains_new != [] else None
        variableDeclaration_num.append(attr_contains_new) if attr_contains_new != [] else None
        expression.append(code_contains_exp ) if code_contains_exp != [] else None
        expression_num.append(attr_contains_exp ) if attr_contains_exp != [] else None  
        
        trystatement.append(code_contains_try_catch ) if code_contains_try_catch != [] else None
        trystatement_num.append(attr_contains_try_catch ) if attr_contains_try_catch != [] else None 
        
        returnstatement.append(code_contains_return ) if code_contains_return != [] else None
        returnstatement_num.append(attr_contains_return ) if attr_contains_return != [] else None               
        MethodDeclaration.append(code_contains_Method ) if code_contains_Method != [] else None
        MethodDeclaration_num.append(attr_contains_Method ) if attr_contains_Method != [] else None
        
    return ifstatement_num,forstatement_num,whilestatement_num,variableDeclaration_num,expression_num,\
           trystatement_num,returnstatement_num,MethodDeclaration_num

# %%
# 展开内部列表,便于统计
def flattened_list(lst):
    flattened_lst = [item for sublist in lst for item in sublist]
    return flattened_lst

# %%
def analyse_line_attribution(df):
    code_list = df['new_code_raw']
    comment_list = df['old_comment_raw']
    code_list_old = df['old_code_raw']
    ground_lable = df['label']
    
    input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,\
    token_type_ids_all,all_tokens_all= input_data_list(code_list,comment_list)
    
    code_lineList_token_all = []
    attribute_num_code_all = []

    for i in range(len(code_list)): 
        _,_,_,_,_,_,_,_,code_lineList_token,attribute_num_code \
        = interpret_sentence_2(code_list[i],comment_list[i],\
                               code_list_old[i],input_ids_all[i],\
                               ref_input_ids_all[i], token_type_ids_all[i],\
                               position_ids_all[i],attention_mask_all[i], all_tokens_all[i], ground_lable[i],vis_data_records_ig)
        code_lineList_token_all.append(code_lineList_token)
        attribute_num_code_all.append(attribute_num_code)
    return code_lineList_token,attribute_num_code

# %%
code_lineList_token,attribute_num_code = analyse_line_attribution(df_clean)
# Out:
# ['<s>', 'Creates', 'elastic', 'node', 'as', 'single', 'member', 'of', 'a', 'cluster', '.', '</s>', 'private static EmbeddedElasticsearchNode create ( Settings settings ) {', '// ensure PainlessPlugin is installed or otherwise scripted fields would not work', 'Node node = new LocalNode ( settings , Arrays . asList ( Netty4Plugin . class , PainlessPlugin . class ));', 'return new EmbeddedElasticsearchNode ( node );', '}']
# ['<s>', 'Check', 'whether', 'any', 'insertion', 'or', 'deletion', 'actions', 'are', 'currently', 'queued', '.', '</s>', 'public boolean areInsertionsOrDeletionsQueued () {', 'return ( insertions . size () > 0 || ! unresolvedInsertions . isEmpty () || deletions . size () > 0 );', '}']
# ['<s>', 'Marshal', 'the', 'aggregator', 'values', 'of', 'to', 'a', 'JSONArray', 'that', 'will', 'later', 'be', 'aggregated', 'by', 'master', '.', '</s>', 'private byte [] marshalAggregatorValues ( long superstep ) {', 'if ( superstep == INPUT _ SUPERSTEP ) {', 'return new byte [ 0 ];', '}', 'ByteArrayOutputStream outputStream = new ByteArrayOutputStream ();', 'DataOutputStream output = new DataOutputStream ( outputStream );', 'for ( Entry < String , AggregatorWrapper < Writable >> entry :', 'getAggregatorMap (). entrySet ()) {', 'if ( entry . getValue (). isChanged ()) {', 'try {', 'output . writeUTF ( entry . getKey ());', 'entry . getValue (). getCurrentAggregatedValue (). write ( output );', '} catch ( IOException e ) {', 'throw new IllegalStateException (" Failed to marshall aggregator " +', '" with IOException " + entry . getKey (), e );', '}', '}', '}', 'if ( LOG . isInfoEnabled ()) {', 'LOG . info (', '" marshalAggregatorValues : Finished assembling aggregator values ");', '}', 'return outputStream . toByteArray ();', '}']
# ['<s>', 'Returns', 'a', 'list', 'of', 'the', 'types', 'of', 'the', 'fields', 'in', 'a', 'given', 'struct', 'type', '.', '</s>', 'public static List < RelDataType > getFieldTypeList ( final RelDataType type ) {', 'return Lists . transform ( type . getFieldList (), GET _ TYPE );', '}']
# ['<s>', 'Create', 'an', 'instance', 'based', 'on', 'current', 'maven', 'profile', '(', 'as', 'defined', 'by', '-', 'Pit', ').', '</s>', 'static MongoDatabasePolicy create () {', 'final MongoClient client ;', 'if ( MongoAssertions . useMongo ()) {', '// use to real client ( connects to mongo )', 'client = new MongoClient ();', '} else if ( MongoAssertions . useFongo ()) {', '// in - memory DB ( fake Mongo )', 'client = new Fongo ( MongoDatabasePolicy . class . getSimpleName ()). getMongo ();', '} else {', 'throw new UnsupportedOperationException (" I can only connect to Mongo or Fongo instances ");', '}', 'return new MongoDatabasePolicy ( client );', '}']
# ['<s>', 'Construct', 'the', 'value', 'of', 'the', 'data', 'attribute', 'of', 'CloudEvents', '.', '</s>', 'public Struct ceDataAttribute () {', 'return recordParser . data ();', '}']
# ['<s>', 'Returns', '</s>', 'public File getSinkFile () {', 'return queue . file ();', '}']
# ['<s>', 'This', 'method', 'initializes', 'txtPattern', '</s>', 'public ZapTextField getTxtPattern () {', 'if ( txtPattern == null ) {', 'txtPattern = new ZapTextField ();', '}', 'return txtPattern ;', '}']
# 解析错误
# ['<s>', 'Return', 'the', 'name', 'of', 'the', 'oneOf', 'schema', '</s>', 'public String toOneOfName ( List < String > names , ComposedSchema composedSchema ) {', 'Map < String , Object > exts = composedSchema . getExtensions ();', 'if ( exts != null && exts . containsKey (" x - oneOf - name ")) {', 'return ( String ) exts . get (" x - oneOf - name ");', '}', 'return " oneOf <" + String . join (",", names ) + ">";', '}']
# ['<s>', 'Returns', 'the', 'providers', 'that', 'are', 'bound', 'to', 'the', 'same', 'location', 'as', 'the', 'given', 'ISO', '3166', 'code', 'and', 'of', 'the', 'given', 'type', '.', '</s>', 'public static Iterable < ProviderMetadata > boundedByIso3166Code ( String iso3166Code ,', 'TypeToken <? extends Wrapper > contextWrappableAs ) {', 'return filter ( all (), Predicates . and ( ProviderPredicates . boundedByIso3166Code ( iso3166Code ), ProviderPredicates', '. contextWrappableAs ( contextWrappableAs )));', '}']
# 解析错误
# ['<s>', 'Only', 'the', 'views', 'are', 'mirrored', '.', '</s>', 'public boolean isMirrored () {', 'if (! fMirroringEnabled )', 'return false ;', 'Object property = getProperty ( MIRRORED );', 'return property instanceof Boolean && ( Boolean ) property ;', '}']
# ['<s>', 'HBase', 'region', 'cut', 'size', ',', 'in', 'GB', '</s>', 'public float getKylinHBaseRegionCut () {', 'return Float . valueOf ( getOptional (" kylin . hbase . region . cut ", " 5 . 0 "));', '}']
# ['<s>', 'Build', 'a', 'Ravioli', 'client', '</s>', 'public Lob build () {', 'return new Lob ( this );', '}']
# 解析错误
# ['<s>', 'Create', 'a', 'web', 'page', 'using', 'the', 'given', 'template', ',', 'SecurityContext', 'and', 'model', 'data', '.', '</s>', 'public static Viewable create ( final boolean authEnabled , final String templateName , final SecurityContext sc ) {', 'return new ViewableWithPermissions ( authEnabled , templateName , sc , true , null );', '}']
# ['<s>', 'Loads', 'item', 'sprite', 'from', 'game', ',', 'makes', 'transparent', ',', 'and', 'generates', 'image', '</s>', 'private BufferedImage loadImage ( int itemId , int quantity , boolean stackable )', '{', 'SpritePixels sprite = client . get (). createItemSprite ( itemId , quantity , 1 , SpritePixels . DEFAULT _ SHADOW _ COLOR ,', 'stackable ? 1 : 0 , false , CLIENT _ DEFAULT _ ZOOM );', 'return sprite . toBufferedImage ();', '}']
# 解析错误
# ['<s>', 'Given', 'a', 'Class', 'of', 'something', 'that', 'extends', 'AsyncSupport', ',', 'it', 'tries', 'to', 'return', 'an', 'instance', 'of', 'that', 'class', '.', '</s>', 'public AsyncSupport newCometSupport ( final Class <? extends AsyncSupport > targetClass ) {', 'try {', 'return ( AsyncSupport ) targetClass . getDeclaredConstructor ( new Class []{ AtmosphereConfig . class })', '. newInstance ( config );', '} catch ( final Exception e ) {', 'logger . error (" Failed to create comet support class : {}, error : {}", targetClass , e );', 'logger . error (" Switching to BlockingIO ");', 'return new BlockingIOCometSupport ( config );', '}', '}']
# ['<s>', 'Add', 'a', 'tag', 'to', 'the', 'set', 'of', 'filters', '</s>', 'public boolean add ( String tagId , String category ) {', 'return isCategoryValid ( category ) && mSelectedTopics . add ( tagId );', '}']
# ['<s>', 'Allow', 'to', 'print', 'directives', '.', '</s>', 'public Options includeDirectives ( boolean flag ) {', 'return new Options ( this . includeIntrospectionTypes , this . includeScalars , this . includeExtendedScalars , this . includeSchemaDefinition , this . useAstDefinitions , this . descriptionsAsHashComments , directive -> flag , this . comparatorRegistry );', '}']
# ['<s>', 'Return', 'the', 'list', 'of', 'module', 'prefixes', 'that', 'are', 'defined', 'for', 'this', 'web', 'application', ',', 'creating', 'it', 'if', 'necessary', '.', '</s>', 'public static String [] getModulePrefixes ( ServletContext context ) {', 'return ( String []) context . getAttribute ( Globals . MODULE _ PREFIXES _ KEY );', '}']
# ['<s>', 'Build', 'the', 'column', 'writer', ',', 'and', 'any', 'nested', 'content', ',', 'returning', 'the', 'built', 'column', 'writer', 'as', 'a', 'generic', 'object', 'writer', '.', '</s>', 'private ObjectWriter buildColumn ( ParentShim parent , ColumnMetadata colSchema ) {', 'if ( colSchema . isMultiList ()) {', 'return buildRepeatedList ( parent , colSchema );', '} else if ( colSchema . isMap ()) {', 'return buildMap ( parent , colSchema );', '} else if ( isSingleList ( colSchema )) {', 'return buildSingleList ( parent , colSchema );', '} else if ( colSchema . isVariant ()) {', 'return buildVariant ( parent , colSchema );', '} else if ( colSchema . isDict ()) {', 'return buildDict ( parent , colSchema );', '} else {', 'return buildPrimitive ( parent , colSchema );', '}', '}']
# 解析错误
# 解析错误
# ['<s>', 'Returns', 'true', 'if', ',', 'the', 'lockClient', 'is', 'keeping', 'the', 'lock', 'for', 'the', 'lockPath', '</s>', 'private boolean isKeepLock ( String serverName , String lockPath ) {', 'try {', 'if ( zkClient . checkExists (). forPath ( lockPath ) != null ) {', 'byte [] data = zkClient . getData (). forPath ( lockPath );', 'String lockServerName = new String ( data , Charset . forName (" UTF - 8 "));', 'return lockServerName . equalsIgnoreCase ( serverName );', '}', '} catch ( Exception e ) {', 'logger . error (" fail to get the serverName for the path : " + lockPath , e );', '}', 'return false ;', '}']
# ['<s>', 'Returns', 'the', 'difference', 'between', 'this', 'field', 'property', 'instant', 'and', 'the', 'one', 'passed', 'in', ',', 'in', 'the', 'units', 'of', 'this', 'field', '.', '</s>', 'public long getDifferenceAsLong ( ReadableInstant instant ) {', 'if ( instant == null ) {', 'return getField (). getDifferenceAsLong ( getMillis (), DateTimeUtils . currentTimeMillis ());', '}', 'return getField (). getDifferenceAsLong ( getMillis (), instant . getMillis ());', '}']
# ['<s>', 'Unsubscribes', 'the', 'resource', 'from', 'this', 'channel', ',', 'if', 'it', 'exists', '.', '</s>', 'public ResourceRepo removeResource ( Resource resource ) {', 'if (( this . resourceRepos == null ) || ( resource == null )) {', 'return null ;', '}', 'ResourceRepo doomed = null ;', 'for ( ResourceRepo rc : this . resourceRepos ) {', 'if ( resource . equals ( rc . getResourceRepoPK (). getResource ())) {', 'doomed = rc ;', 'break ;', '}', '}', 'if ( doomed != null ) {', 'this . resourceRepos . remove ( doomed );', '}', 'return doomed ;', '}']
# 解析错误
# ['<s>', 'Checks', 'if', 'a', 'flag', 'is', 'set', '.', '</s>', 'public boolean isFlagSet ( int flagsToCheck ) {', 'return ( flags & flagsToCheck ) != 0 ;', '}']
# 解析错误
# 解析错误
# 解析错误
# ['<s>', 'Returns', 'a', 'List', 'containing', 'all', 'the', 'child', 'nodes', 'of', 'this', 'node', '.', '</s>', 'protected final Vector getContents () {', 'return _ contents ;', '}']
# ['<s>', 'Constructs', 'a', 'new', 'PTBTokenizer', 'that', 'makes', 'CoreLabel', 'tokens', '.', '</s>', 'public static PTBTokenizer < CoreLabel > newPTBTokenizer ( Reader r , boolean tokenizeNLs , boolean invertible ) {', 'return new PTBTokenizer <>( r , tokenizeNLs , invertible , false , new CoreLabelTokenFactory ());', '}']
# 解析错误
# ['<s>', 'Expr', ':', 'left', '.', 'endsWith', '(', 'right', ')', '</s>', 'public static EBoolean endsWith ( Expr < String > left , String right ) {', 'return factory . createBoolean ( Ops . ENDSWITH , left , factory . createConstant ( right ));', '}']
# ['<s>', 'This', 'method', 'initializes', 'jTextArea', '</s>', 'private ZapTextArea getTxtSkipURL () {', 'if ( txtSkipURL == null ) {', 'txtSkipURL = new ZapTextArea ();', 'txtSkipURL . setFont ( new java . awt . Font (" Default ", java . awt . Font . PLAIN , 11 ));', 'if ( Model . getSingleton (). getOptionsParam (). getViewParam (). getWmUiHandlingOption () == 0 ) {', 'txtSkipURL . setSize ( new java . awt . Dimension ( 290 , 52 ));', '}', '}', 'return txtSkipURL ;', '}']
# 解析错误
# ['<s>', 'Determines', 'if', 'a', 'specified', 'set', 'of', 'columns', 'from', 'a', 'specified', 'relational', 'expression', 'are', 'unique', '.', '</s>', 'public static Boolean areColumnsUnique ( RelNode rel , BitSet columns ) {', 'final BuiltInMetadata . ColumnUniqueness metadata =', 'rel . metadata ( BuiltInMetadata . ColumnUniqueness . class );', 'return metadata . areColumnsUnique ( columns , false );', '}']
# ['<s>', 'Observes', 'connectivity', 'with', 'the', 'Internet', 'with', 'default', 'settings', '.', '</s>', 'public static Observable < Boolean > observeInternetConnectivity () {', 'return observeInternetConnectivity ( DEFAULT _ INITIAL _ PING _ INTERVAL _ IN _ MS ,', 'DEFAULT _ PING _ INTERVAL _ IN _ MS , DEFAULT _ PING _ HOST , DEFAULT _ PING _ PORT ,', 'DEFAULT _ PING _ TIMEOUT _ IN _ MS , new DefaultErrorHandler ());', '}']
# ['<s>', 'Expr', ':', 'left', '.', 'endsWith', '(', 'right', ')', '(', 'ignore', 'case', ')', '</s>', 'public static EBoolean endsWith ( Expr < String > left , String right ) {', 'return operationFactory . createBoolean ( Ops . ENDSWITH , left , exprFactory', '. createConstant ( right ));', '}']
# ['<s>', 'Create', 'RelNode', 'tree', 'that', 'produces', 'a', 'list', 'of', 'correlated', 'variables', '.', '</s>', 'private Frame getFrame ( RelNode r , boolean safe ) {', 'final Frame frame = map . get ( r );', 'if ( frame == null && safe ) {', 'return new Frame ( r , r , ImmutableSortedMap . of (),', 'identityMap ( r . getRowType (). getFieldCount ()));', '}', 'return frame ;', '}']
# ['<s>', 'The', '#', 'add', '(', 'Object', '...)', 'method', 'uses', 'Java', 'variable', '-', 'length', 'arguments', 'to', 'pass', 'a', 'row', 'of', 'values', '.', '</s>', 'public RowSetBuilder addSingleCol ( Object value ) {', 'return addRow ( new Object [] { value });', '}']
# ['<s>', 'Clone', 'the', 'state', 'of', 'this', 'query', 'to', 'a', 'new', 'JPAQuery', 'instance', 'with', 'the', 'given', 'EntityManager', '</s>', 'public JPAQuery clone ( EntityManager entityManager ){', 'return new JPAQuery ( new DefaultSessionHolder ( entityManager ), getTemplates (), getMetadata (). clone ());', '}']
# 解析错误
# ['<s>', 'Retrieve', 'the', 'fetch', 'descriptor', 'associated', 'with', 'the', 'given', 'entity', 'key', '.', '</s>', 'public SubselectFetch getSubselect ( EntityKey key ) {', 'return subselectsByEntityKey . get ( key );', '}']
# ['<s>', 'Adds', 'a', 'menu', 'item', 'to', 'the', 'bar', 'containing', 'SafeHtml', ',', 'that', 'will', 'fire', 'the', 'given', 'command', 'when', 'it', 'is', 'selected', '.', '</s>', 'public MenuItem addItem ( String text , boolean asHTML , Command cmd ) {', 'return addItem ( new MenuItem ( text , asHTML , cmd ));', '}']
# ['<s>', 'Provided', 'we', '#', 'supportsInsertSelectIdentity', ',', 'then', 'attach', 'the', '"', 'select', 'identity', '"', 'clause', 'to', 'the', 'insert', 'statement', '.', '</s>', 'public String appendIdentitySelectToInsert ( String insertString ) {', 'return getIdentityColumnSupport (). appendIdentitySelectToInsert ( insertString );', '}']
# 解析错误
# ['<s>', 'Create', 'and', 'return', 'a', 'new', 'Field', 'instance', 'that', 'is', 'a', 'copy', 'of', 'this', 'field', 'but', 'with', 'the', 'given', 'default', 'value', '.', '</s>', 'public Field withDefault ( boolean defaultValue ) {', 'return new Field ( name (), displayName (), type (), width , description (), importance (), dependents ,', '() -> Boolean . valueOf ( defaultValue ), validator , recommender );', '}']
# 解析错误
# ['<s>', 'Waits', 'for', 'a', 'given', 'view', '.', '</s>', 'public boolean waitForView ( View view , int timeout ){', 'return waitForView ( view , timeout , true , false );', '}']
# ['<s>', 'Checks', 'if', 'a', 'flag', 'is', 'set', '.', '</s>', 'public boolean isFlagSet ( int flagsToCheck ) {', 'return isFlagSet ( flags , flagsToCheck );', '}']
# ['<s>', 'Return', 'the', 'length', 'of', 'this', 'String', '</s>', 'public ENumber < Integer > length () {', 'if ( length == null ) {', 'length = ONumber . create ( Integer . class , Ops . STRING _ LENGTH , this );', '}', 'return length ;', '}']
# ['<s>', 'Parses', 'a', 'Specification', 'out', 'of', 'the', 'query', 'string', '.', '</s>', 'public static Query parse ( String queryString , BulletConfig config ) {', 'Query query = GSON . fromJson ( queryString , Query . class );', 'query . configure ( config );', 'return query ;', '}']
# ['<s>', 'Expr', ':', 'left', '.', 'startsWith', '(', 'right', ')', '</s>', 'public static EBoolean startsWith ( Expr < String > left , Expr < String > right ) {', 'return factory . createBoolean ( Ops . STARTSWITH , left , right );', '}']
# ['<s>', 'Creates', 'and', 'returns', 'a', 'new', 'comparison', 'object', 'for', 'the', 'SQL', '"', 'in', '"', 'operator', '.', '</s>', 'public final DBCompareColExpr in ( Collection <?> values )', '{', 'if ( values == null || values . isEmpty ())', 'return cmp ( DBCmpType . EQUAL , null );', '// create expression', 'return cmp ( DBCmpType . IN , values );', '}']
# ['<s>', 'Returns', 'the', 'URL', 'where', 'you', 'should', 'redirect', 'your', 'users', 'to', 'authenticate', 'your', 'application', '.', '</s>', 'public String getAuthorizationUrl () {', 'return createAuthorizationUrlBuilder (). build ();', '}']
# ['<s>', 'Method', 'for', 'getting', 'counts', 'using', 'named', 'filters', '</s>', 'public boolean equals ( Object obj ) {', 'if ( obj == null ) {', 'return false ;', '}', 'if ( obj == this ) {', 'return true ;', '}', 'if ( obj . getClass () != getClass ()) {', 'return false ;', '}', 'FiltersAggregation rhs = ( FiltersAggregation ) obj ;', 'return super . equals ( obj ) && Objects . equals ( bucketMap , rhs . bucketMap );', '}']
# ['<s>', 'Returns', 'all', 'currently', 'displayed', 'sentences', 'in', 'string', 'buffer', ',', 'plain', 'text', 'form', '</s>', 'public String getMatchedSentences () {', 'StringBuilder sb = new StringBuilder ();', 'for ( int i = 0 , sz = list . getModel (). getSize (); i < sz ; i ++) {', 'String t = list . getModel (). getElementAt ( i ). getLabel (). getText ();', 'sb . append ( t );', 'sb . append ("\\n ");', '}', 'return sb . toString ();', '}']
# ['<s>', 'Returns', 'newest', 'checkmark', 'that', 'has', 'already', 'been', 'computed', '.', '</s>', 'protected Checkmark findNewest ()', '{', 'return new Select (). from ( Checkmark . class )', '. where (" habit = ?", habit . getId ())', '. and (" timestamp <= ?", DateUtils . getStartOfToday ())', '. orderBy (" timestamp desc ")', '. limit ( 1 )', '. executeSingle ();', '}']
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public static List handleHTML ( HttpURLConnection httpCon ) throws IOException {', 'ContentHandler handler = new HTMLHandler ();', 'handler . parse ( httpCon . getInputStream ());', 'if ( handler . getRobotFollow ()) {', 'List links = handler . getLinks ();', 'return links ;', '}', 'return null ;', '}']
# ['<s>', 'Searches', 'for', 'a', 'text', 'string', 'and', 'returns', 'true', 'if', 'the', 'searched', 'text', 'is', 'found', 'a', 'given', 'number', 'of', 'times', '.', '</s>', 'public boolean searchText ( String regex , int matches , boolean scroll ) {', 'return searcher . searchText ( regex , matches , scroll );', '}']
# ['<s>', 'Returns', 'all', 'currently', 'displayed', 'sentences', 'in', 'plain', 'text', 'form', '.', '</s>', 'public StringBuffer getMatchedSentences () {', 'StringBuffer sb = new StringBuffer ();', 'for ( int i = 0 ; i < list . getModel (). getSize (); i ++) {', 'String t = (( TreeFromFile ) list . getModel (). getElementAt ( i )). getLabel (). getText ();', 'sb . append ( t );', 'sb . append ("\\n ");', '}', 'return sb ;', '}']
# ['<s>', 'This', 'method', 'initializes', 'panelCommand', '</s>', 'private TableExportButton getExportButton () {', 'if ( exportButton == null ) {', 'exportButton = new TableExportButton ( getParamsTable ());', '}', 'return exportButton ;', '}']
# ['<s>', 'If', 'a', 'Schema', 'contains', 'a', 'reference', 'to', 'an', 'other', 'Schema', 'with', "'$", 'ref', "',", 'returns', 'the', 'referenced', 'Schema', 'or', 'the', 'actual', 'Schema', 'in', 'the', 'other', 'cases', '.', '</s>', 'public static Schema getReferencedSchema ( OpenAPI openAPI , Schema schema ) {', 'if ( schema != null && StringUtils . isNotEmpty ( schema . get $ ref ())) {', 'String name = getSimpleRef ( schema . get $ ref ());', 'Schema referencedSchema = getSchema ( openAPI , name );', 'if ( referencedSchema != null ) {', 'return referencedSchema ;', '}', '}', 'return schema ;', '}']
# ['<s>', 'Returns', 'a', 'List', 'of', 'the', 'GridViews', 'contained', 'in', 'the', 'current', 'Activity', '.', '</s>', 'public ArrayList < GridView > getCurrentGridViews () {', 'return getCurrentViews ( GridView . class );', '}']
# ['<s>', 'Ensure', 'that', 'correct', 'implementation', 'is', 'used', 'for', 'the', 'component', '.', '</s>', 'public boolean updateComponent ( Widget component , UIDL uidl ,', 'boolean manageCaption ) {', '// Switch to correct implementation if neede', 'if (! widgetFactory . isCorrectImplementation ( component , uidl )) {', 'Layout parent = getParentLayout ( component );', 'if ( parent != null ) {', 'Widget w = widgetFactory . createWidget ( uidl );', 'registerPaintable ( uidl . getId (), ( Paintable ) w );', 'parent . replaceChildComponent ( component , w );', '(( Paintable ) w ). updateFromUIDL ( uidl , this );', 'return true ;', '}', '}', '// Set captions', '// TODO Manage Error messages', 'if ( manageCaption ) {', 'Layout parent = getParentLayout ( component );', 'if ( parent != null )', 'parent . updateCaption ( component , uidl );', '}', '// Visibility , Disabling and read - only status', 'if ( component instanceof FocusWidget )', '(( FocusWidget ) component ). setEnabled (! uidl', '. getBooleanAttribute (" disabled "));', 'boolean visible = ! uidl . getBooleanAttribute (" invisible ");', 'component . setVisible ( visible );', 'if (! visible )', 'return true ;', 'return false ;', '}']
# ['<s>', 'Gets', 'the', 'matching', 'http', 'session', 'for', 'a', 'particular', 'message', 'containing', 'a', 'list', 'of', 'cookies', '.', '</s>', 'private HttpSession getMatchingHttpSession ( List < HttpCookie > cookies , final HttpSessionTokensSet siteTokens ) {', 'Collection < HttpSession > sessionsCopy ;', 'synchronized ( sessions ) {', 'sessionsCopy = new ArrayList <>( sessions );', '}', 'return CookieBasedSessionManagementHelper . getMatchingHttpSession ( sessionsCopy , cookies , siteTokens );', '}']
# ['<s>', 'Return', 'the', 'GraphItem', 'representing', 'the', 'second', '(', 'target', ')', 'node', 'in', 'the', 'edge', '.', '</s>', 'public Node getSecondNode () {', 'return m _ node2 ;', '} //']
# 解析错误
# ['<s>', 'Encodes', 'a', 'value', 'in', 'a', 'canonical', 'serialized', 'string', 'format', ',', 'for', 'use', 'in', 'a', 'URL', 'query', 'parameter', '.', '</s>', 'public static String encodeValue ( Value value ) {', 'return NTriplesUtil . toNTriplesString ( value );', '}']
# ['<s>', 'Loads', 'item', 'sprite', 'from', 'game', ',', 'makes', 'transparent', ',', 'and', 'generates', 'image', '</s>', 'private AsyncBufferedImage loadImage ( int itemId , int quantity , boolean stackable )', '{', 'AsyncBufferedImage img = new AsyncBufferedImage ( 36 , 32 , BufferedImage . TYPE _ INT _ ARGB );', 'clientThread . invokeLater (() ->', '{', 'if ( client . getGameState (). ordinal () < GameState . LOGIN _ SCREEN . ordinal ())', '{', 'return false ;', '}', 'SpritePixels sprite = client . createItemSprite ( itemId , quantity , 1 , SpritePixels . DEFAULT _ SHADOW _ COLOR ,', 'stackable ? 1 : 0 , false , CLIENT _ DEFAULT _ ZOOM );', 'if ( sprite == null )', '{', 'return false ;', '}', 'sprite . toBufferedImage ( img );', 'img . changed ();', 'return true ;', '});', 'return img ;', '}']
# ['<s>', 'Loads', 'the', 'JBossWebSocketHandler', 'using', 'reflection', 'as', 'it', 'imports', 'container', 'specific', 'classes', '.', '</s>', 'private HttpEventServlet newWebSocketHandler ( AtmosphereConfig config ) {', 'try {', 'return new JBossWebSocketHandler ( config );', '} catch ( Exception e ) {', 'logger . error (" Cannot instantiate JBossWebSocketHandler . Websocket events will not be handled .", e );', '}', 'return null ;', '}']
# 解析错误
# ['<s>', 'Returns', 'the', 'common', 'base', 'directory', 'between', 'a', 'current', 'base', 'directory', 'and', 'a', 'given', 'file', '.', '</s>', 'File getBaseDir ( final File file1 , final File file2 ) {', 'if ( file1 == null || file2 == null ) {', 'return null ;', '}', 'final Iterator bases = getParents ( file1 ). iterator ();', 'final Iterator fileParents = getParents ( file2 . getAbsoluteFile ()). iterator ();', 'File result = null ;', 'while ( bases . hasNext () && fileParents . hasNext ()) {', 'File next = ( File ) bases . next ();', 'if ( next . equals ( fileParents . next ())) {', 'result = next ;', '} else {', 'break ;', '}', '}', 'return result ;', '}']
# ['<s>', 'Returns', 'an', 'ArrayList', 'of', 'the', 'RadioButtons', 'contained', 'in', 'the', 'current', 'Activity', '.', '</s>', 'public ArrayList < RadioButton > getCurrentRadioButtons () {', 'return viewFetcher . getCurrentViews ( RadioButton . class );', '}']
# ['<s>', 'Does', 'this', 'time', 'interval', 'contain', 'the', 'specified', 'time', 'interval', 'completely', '.', '</s>', 'public boolean contains ( ReadableInterval interval ) {', 'if ( interval == null ) {', 'return containsNow ();', '}', 'long otherStart = interval . getStartMillis ();', 'long otherEnd = interval . getEndMillis ();', 'long thisStart = getStartMillis ();', 'long thisEnd = getEndMillis ();', 'return ( thisStart <= otherStart && otherStart < thisEnd && otherEnd <= thisEnd ) ||', '( thisStart == otherStart && thisEnd == otherEnd );', '}']
# ['<s>', 'Create', 'a', 'new', 'Template', 'expression', '</s>', 'public static StringExpression stringTemplate ( String template , Object ... args ) {', 'return new StringTemplate ( createTemplate ( template ), ImmutableList . copyOf ( args ));', '}']
# 解析错误
# ['<s>', 'creates', 'an', 'XmlItem', 'this', 'route', 'creates', 'an', 'XmlItem', '</s>', 'public ApiResponse < Void > createXmlItemWithHttpInfo ( XmlItem xmlItem ) throws ApiException {', 'okhttp3 . Call localVarCall = createXmlItemValidateBeforeCall ( xmlItem , null , null );', 'return localVarApiClient . execute ( localVarCall );', '}']
# ['<s>', 'Get', 'the', 'global', 'configuration', 'table', 'name', 'including', 'the', 'correct', 'escaped', 'schema', '</s>', 'private String getConfigurationTable ( Connection con ) {', 'try {', 'if ( StorageManager . getStorageImpl ( con . getMetaData (). getDatabaseProductName ()). requiresConfigSchema ()) {', 'if ( DatabaseConst . getConfigSchema (). endsWith ("."))', 'return DatabaseConst . getConfigSchema () + TBL _ GLOBAL _ CONFIG ;', 'else', 'return DatabaseConst . getConfigSchema () + "." + TBL _ GLOBAL _ CONFIG ;', '}', '} catch ( SQLException e ) {', 'LOG . warn ( e );', '}', 'return TBL _ GLOBAL _ CONFIG ;', '}']
# ['<s>', 'Returns', 'a', 'List', 'of', 'children', 'for', 'the', 'current', 'node', '.', '</s>', 'public List < Tree > getChildrenAsList () {', 'return new ArrayList <>( Arrays . asList ( children ()));', '}']
# ['<s>', 'Gets', 'the', 'total', 'number', 'of', 'bytes', 'uploaded', 'by', 'this', 'uploader', 'or', '0', 'for', 'direct', 'uploads', 'when', 'the', 'content', 'length', 'is', 'not', 'known', '.', '</s>', '@ Deprecated', 'public long getNumBytesUploaded () {', 'return totalBytesServerReceived ;', '}']
# 解析错误
# ['<s>', 'Obtains', 'a', 'ISTextExpert', 'instance', 'for', 'processing', 'structured', 'text', 'with', 'the', 'specified', 'type', 'handler', 'and', 'the', 'specified', 'environment', '.', '</s>', 'static public IStructuredTextExpert getStatefulExpert ( StructuredTextTypeHandler handler , StructuredTextEnvironment environment ) {', 'if ( environment == null )', 'environment = StructuredTextEnvironment . DEFAULT ;', 'return new StructuredTextImpl ( handler , environment , true );', '}']
# ['<s>', 'Prints', 'a', 'ReadablePartial', 'to', 'a', 'new', 'String', '.', '</s>', 'public String print ( ReadablePartial partial ) {', 'StringBuilder builder = new StringBuilder ( requirePrinter (). estimatePrintedLength ());', 'try {', 'printTo ( builder , partial );', '} catch ( IOException e ) {', '// StringBuilder does not throw IOException', '}', 'return builder . toString ();', '}']
# ['<s>', 'Create', 'and', 'return', 'a', 'new', 'feature', 'service', 'with', 'the', 'default', 'server', 'URL', '.', '</s>', 'public FeatureService createFeatureService () {', 'return createFeatureService ( defaultEndpointUrl );', '}']
# 解析错误
# ['<s>', 'GET', '/', 'user', '/', 'username', '</s>', 'public User executeAs ( Function < Response , Response > handler ) {', 'Type type = new TypeToken < User >(){}. getType ();', 'return execute ( handler ). as ( type );', '}']
# ['<s>', 'Get', 'the', 'parent', 'cuboid', 'really', 'on', 'the', 'spanning', 'tree', '.', '</s>', 'public long findBestMatchCuboid ( long cuboid ) {', 'return findBestMatchCuboid1 ( cuboid );', '}']
# 解析错误
# ['<s>', 'String', 'representation', 'of', 'the', 'signature', '.', '</s>', '@ Override', 'public String toString () {', 'if ( stringRep == null ) {', 'stringRep = toString ( true );', '}', 'return stringRep ;', '}']
# ['<s>', 'Returns', 'a', 'Button', 'which', 'shows', 'a', 'given', 'text', '.', '</s>', 'public Button getButton ( String text , boolean onlyVisible )', '{', 'return getter . getView ( Button . class , text , onlyVisible );', '}']
# ['<s>', 'Return', 'the', 'list', 'of', 'Cassandra', 'instances', 'ordered', 'by', 'position', 'on', 'ring', ',', 'indicated', 'by', 'token', '.', '</s>', '@ GET', 'public Set < CassandraInstance > findAll () {', 'return service . findAll ();', '}']
# ['<s>', 'Create', 'a', 'new', 'PathMetadata', 'for', 'property', 'access', '</s>', 'public static PathMetadata < String > forProperty ( Path <?> parent , String property ) {', 'return new PathMetadata < String >( parent , Assert . hasLength ( property ," property "), PathType . PROPERTY );', '}']
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public String getReplicationDirectory () {', 'return this . replicationDirectory ;', '}']
# ['<s>', 'Override', 'with', 'any', 'special', 'handling', 'of', 'response', 'codes', '</s>', 'protected ApiResponse findMethodResponse ( ApiResponses responses ) {', 'String code = null ;', 'for ( String responseCode : responses . keySet ()) {', 'if ( responseCode . startsWith (" 2 ") || responseCode . equals (" default ")) {', 'if ( code == null || code . compareTo ( responseCode ) > 0 ) {', 'code = responseCode ;', '}', '}', '}', 'if ( code == null ) {', 'return null ;', '}', 'return responses . get ( code );', '}']
# ['<s>', 'Get', 'entry', 'data', ',', 'read', 'directly', 'from', 'internal', 'data', 'structure', '.', '</s>', 'public String getValue ( String key ) throws NotFoundException , NotLeaderException {', 'if ( cluster . getLocalRole () != Role . LEADER ) {', 'throw new NotLeaderException ();', '}', 'if (! entries . containsKey ( key )) {', 'throw new NotFoundException ();', '}', 'String value = entries . get ( key );', 'logger . info ( String . format (" Get key % s : % s ", key , value ));', 'return value ;', '}']
# ['<s>', 'Seeks', 'the', 'field', 'with', 'the', 'given', 'name', 'in', 'the', 'stream', 'and', 'positions', '(', 'and', 'returns', ')', 'the', 'parser', 'to', 'the', 'next', 'available', 'token', '(', 'value', 'or', 'not', ').', '</s>', 'public static Token seek ( String path , Parser parser ) {', '// return current token if no path is given', 'if (! StringUtils . hasText ( path )) {', 'return null ;', '}', 'List < String > tokens = StringUtils . tokenize ( path , "/");', 'return seek ( parser , tokens . toArray ( new String [ tokens . size ()]));', '}']
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public String getBackupDirectory () {', 'return this . backupDirectory ;', '}']
# ['<s>', 'Checks', 'if', 'this', 'potato', 'is', 'baked', '.', '</s>', 'public boolean isBaked () throws NotDeliciousException {', 'try {', 'long begin = System . currentTimeMillis ();', 'boolean isInOven = this . isPutIntoOven ();', 'long bakeTime = ( System . currentTimeMillis () - begin );', 'if ( bakeTime > 1100 ) throw new NotDeliciousException ( NotDeliciousReason . OVERCOOKED );', 'return isInOven ;', '} catch ( OvenException e ) {', 'return false ;', '}', '}']
# 解析错误
# ['<s>', 'Computes', 'the', 'row', 'type', 'of', 'an', 'Aggregate', 'before', 'it', 'exists', '.', '</s>', 'public boolean isValid ( Litmus litmus ) {', 'return super . isValid ( litmus )', '&& litmus . check ( Util . isDistinct ( getRowType (). getFieldNames ()),', '" distinct field names : {}", getRowType ());', '}']
# ['<s>', 'Returns', 'the', 'sibling', 'on', 'the', 'right', 'of', 'the', 'end', 'of', 'given', 'Treepath', '.', '</s>', 'public static Treepath getNextSibling ( Treepath treepath ) {', 'if ( treepath . getHeight () < 2 ) {', 'throw new IllegalArgumentException ( " Treepath must have minimum height of 2 " ) ;', '}', 'final Tree treeToMove = treepath . getBottom () ;', 'final Tree parent = treepath . getTreeAtHeight ( 1 ) ;', 'for ( int i = 0 ; i < parent . getChildCount () - 1 ; i ++ ) {', 'final Tree child = parent . getChildAt ( i ) ;', 'if ( child == treeToMove ) {', 'return Treepath . create ( treepath . getParent (), parent . getChildAt ( i + 1 ) ) ;', '}', '}', 'throw new IllegalArgumentException ( " No next sibling " ) ;', '}']
# ['<s>', 'Output', 'the', 'date', 'time', 'in', 'ISO8601', 'format', '(', 'yyyy', '-', 'MM', '-', 'ddTHH', ':', 'mm', ':', 'ss', '.', 'SSSZ', ').', '</s>', 'public String toString () {', 'return ISODateTimeFormat . getInstance (). dateTime (). print ( this );', '}']
# ['<s>', 'Evaluate', 'a', 'PLAIN', 'login', 'challenge', ',', 'returning', 'the', 'a', 'result', 'string', 'that', 'should', 'satisfy', 'the', 'clallenge', '.', '</s>', 'public byte [] evaluateChallenge ( byte [] challenge ) throws MessagingException {', 'try {', 'String result = "\\0 "+ username +"\\0 "+ password ;', 'if ( authzid != null && authzid . length () > 0 ) {', 'result = authzid + result ;', '}', 'complete = true ;', 'return result . getBytes (" UTF - 8 ");', '} catch ( UnsupportedEncodingException e ) {', '// got an error , fail this', 'throw new MessagingException (" Invalid encoding ");', '}', '}']
# ['<s>', 'Gets', 'the', 'given', 'start', 'and', 'end', 'view', 'positions', 'offset', 'to', 'a', 'header', '.', '</s>', 'public static int [] getViewToHeaderPosition ( JTextArea view , int start , int end ) {', 'validateView ( view );', 'validateStartEnd ( start , end );', 'if (! isValidStartEndForLength ( start , end , view . getDocument (). getLength ())) {', 'return INVALID _ POSITION ;', '}', 'return getViewToHeaderPositionImpl ( view , start , end );', '}']
# ['<s>', 'Return', 'XML', 'schema', 'for', 'the', 'specified', 'type', ',', 'suitable', 'for', 'insertion', 'into', 'the', '&', 'lt', ';', 'types', '&', 'gt', ';', 'element', 'of', 'a', 'WSDL', 'document', '.', '</s>', 'public Element writeSchema ( Class javaType , Types types ) throws Exception {', 'return null ;', '}']
# ['<s>', 'Gets', 'the', 'quality', 'or', 'status', 'of', 'the', 'given', 'passive', 'scanner', '.', '</s>', 'public static String getPluginQuality ( PluginPassiveScanner scanner ) {', '// String scannerPackage = scanner . getClass (). getCanonicalName ();', 'String scannerName = scanner . getName ();', 'return ( getSpecificQuality ( scannerName , scanner ));', '}']
# ['<s>', 'Looks', 'up', 'a', 'field', 'with', 'a', 'given', 'name', 'and', 'if', 'found', 'returns', 'its', 'ordinal', '.', '</s>', 'public static RelDataTypeField lookupField (', 'final RelDataType rowType ,', 'String columnName )', '{', 'final RelDataTypeField [] fields = rowType . getFields ();', 'for ( int i = 0 ; i < fields . length ; i ++) {', 'RelDataTypeField field = fields [ i ];', 'if ( field . getName (). equals ( columnName )) {', 'return field ;', '}', '}', 'return null ;', '}']
# ['<s>', 'Expr', ':', 'left', '.', 'lastIndexOf', '(', 'right', ')', '</s>', 'public static ENumber < Integer > lastIndexOf ( Expr < String > left , String right ) {', 'return factory . createNumber ( Integer . class , Ops . LAST _ INDEX , left , factory . createConstant ( right ));', '}']
# ['<s>', 'Converts', 'the', 'given', 'object', 'into', 'a', 'JSON', 'AST', '.', '</s>', 'public static String asJson ( Object object ) throws IOException {', 'return JSON . writeValueAsString ( object );', '}']
# 解析错误
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public ArrayList getImageSrcs () {', 'return this . img _ src ;', '}']
# 解析错误
# ['<s>', 'Removes', 'the', 'content', 'source', 'from', 'this', 'channel', ',', 'if', 'it', 'exists', '.', '</s>', 'public RepoContentSource removeContentSource ( ContentSource contentSource ) {', 'if (( this . repoContentSources == null ) || ( contentSource == null )) {', 'return null ;', '}', 'RepoContentSource doomed = null ;', 'for ( RepoContentSource ccs : this . repoContentSources ) {', 'if ( contentSource . equals ( ccs . getRepoContentSourcePK (). getContentSource ())) {', 'doomed = ccs ;', 'break ;', '}', '}', 'if ( doomed != null ) {', 'this . repoContentSources . remove ( doomed );', '}', 'return doomed ;', '}']
# ['<s>', 'Returns', 'whether', 'an', 'instance', 'of', 'Chrome', 'is', 'currently', 'connected', '</s>', 'boolean hasClient () {', 'return listeningThread != null && listeningThread . hasClient && ! listeningThread . sockets . isEmpty ();', '}']
# ['<s>', 'Returns', 'the', 'meta', 'object', 'for', 'the', 'containment', 'reference', "'", 'org', '.', 'eclipse', '.', 'mylyn', '.', 'reviews', '.', 'core', '.', 'model', '.', 'IChange', '#', 'getState', 'State', "'.", '</s>', 'public EAttribute getChange _ State () {', 'return ( EAttribute ) changeEClass . getEStructuralFeatures (). get ( 5 );', '}']
# ['<s>', 'Creates', 'a', 'new', 'UserFolder', ',', 'inflated', 'from', 'R', '.', 'layout', '.', 'user', '_', 'folder', '.', '</s>', 'static Folder fromXml ( Launcher launcher ) {', 'return ( Folder ) launcher . getLayoutInflater ()', '. inflate ( R . layout . user _ folder _ icon _ normalized , null );', '}']
# ['<s>', 'Return', 'a', 'String', 'to', 'recreate', 'the', 'GRANTs', 'given', 'for', 'the', 'passed', 'table', '.', '</s>', 'public Collection < TableGrant > getTableGrants ( TableIdentifier table )', '{', 'Collection < TableGrant > result = new HashSet < TableGrant >();', 'ResultSet rs = null ;', 'try', '{', 'TableIdentifier tbl = table . createCopy ();', 'tbl . adjustCase ( this . dbConnection );', 'rs = this . metaData . getTablePrivileges ( tbl . getCatalog (), tbl . getSchema (), tbl . getTableName ());', 'while ( rs . next ())', '{', 'String from = rs . getString ( 4 );', 'String to = rs . getString ( 5 );', 'String what = rs . getString ( 6 );', 'boolean grantable = StringUtil . stringToBool ( rs . getString ( 7 ));', 'TableGrant grant = new TableGrant ( to , what , grantable );', 'result . add ( grant );', '}', '}', 'catch ( Exception e )', '{', 'LogMgr . logError (" DbMetadata . getTableGrants ()", " Error when retrieving table privileges ", e );', '}', 'finally', '{', 'try { rs . close (); } catch ( Throwable th ) {}', '}', 'return result ;', '}']
# ['<s>', 'Disable', 'tiling', 'of', 'the', 'image', '.', '</s>', 'public ImageSource tilingDisabled () {', 'return setTiling ( false );', '}']
# 解析错误
# 解析错误
# ['<s>', 'Make', 'fully', 'qualified', 'URI', 'based', 'on', 'the', 'default', 'file', 'system', 'Scheme', 'and', 'Authority', '</s>', 'private static URI makeFullQualifiedURI ( String uriName ) throws IOException {', 'Path uriPath = new Path ( uriName );', 'if ( isNormalized ( uriName ) && uriPath . isUriPathAbsolute ()) {', '// add scheme and / or authority if either is missing', 'if (( uriPath . toUri (). getScheme () == null || uriPath . toUri (). getAuthority () == null )) {', 'URI defaultUri = FileSystem . getDefaultUri ( CONF );', 'uriPath = uriPath . makeQualified ( defaultUri , uriPath );', '}', 'return uriPath . toUri ();', '} else { // relative URI path is unacceptable', 'return null ;', '}', '}']
# ['<s>', 'Rotate', 'the', 'vertex', 'by', 'the', 'given', 'orientation', '</s>', 'public Vertex rotate ( int orientation )', '{', '// models are orientated north ( 1024 ) and there are 2048 angles total', 'orientation = ( orientation + 1024 ) % 2048 ;', 'if ( orientation == 0 )', '{', 'return this ;', '}', 'int sin = Perspective . SINE [ orientation ];', 'int cos = Perspective . COSINE [ orientation ];', 'return new Vertex (', 'x * cos + z * sin >> 16 ,', 'y ,', 'z * cos - x * sin >> 16', ');', '}']
# ['<s>', 'Returns', '</s>', 'public RollCycle getRollCycle () {', 'return queue . rollCycle ();', '}']
# 解析错误
# ['<s>', 'Build', 'a', 'DruidDimensionsLoader', '.', '</s>', 'protected DimensionValueLoadTask buildDruidDimensionsLoader (', 'DruidWebService webService ,', 'PhysicalTableDictionary physicalTableDictionary ,', 'DimensionDictionary dimensionDictionary', ') {', 'DruidDimensionValueLoader druidDimensionRowProvider = new DruidDimensionValueLoader (', 'physicalTableDictionary ,', 'dimensionDictionary ,', 'webService', ');', 'return new DimensionValueLoadTask ( Collections . singletonList ( druidDimensionRowProvider ));', '}']
# ['<s>', 'Does', 'this', 'time', 'interval', 'overlap', 'the', 'specified', 'time', 'interval', '.', '</s>', 'public boolean overlaps ( ReadableInterval interval ) {', 'if ( interval == null ) {', 'return containsNow ();', '}', 'long otherStart = interval . getStartMillis ();', 'long otherEnd = interval . getEndMillis ();', 'long thisStart = getStartMillis ();', 'long thisEnd = getEndMillis ();', 'return ( thisStart < otherEnd && otherStart < thisEnd );', '}']
# ['<s>', 'prepares', 'an', 'url', '-', 'encoded', 'HTTP', 'queryString', 'containing', 'the', 'group', '/', 'job', 'and', 'the', 'options', '.', '</s>', 'private NameValuePair [] prepareQueryString ( String groupPath , String jobName , Properties options ) {', 'List < NameValuePair > queryString = new ArrayList < NameValuePair >();', 'queryString . add ( new NameValuePair (" groupPath ", groupPath ));', 'queryString . add ( new NameValuePair (" jobName ", jobName ));', 'if ( options != null ) {', 'for ( Entry < Object , Object > option : options . entrySet ()) {', 'queryString . add ( new NameValuePair (" extra . command . option ." + option . getKey (),', 'String . valueOf ( option . getValue ())));', '}', '}', 'return queryString . toArray ( new NameValuePair [ queryString . size ()]);', '}']
# ['<s>', 'Gets', 'the', 'colorAccent', 'from', 'the', 'current', 'context', ',', 'if', 'possible', '/', 'available', '</s>', 'public static int getAccentColorFromThemeIfAvailable ( Context context ) {', 'TypedValue typedValue = new TypedValue ();', '// First , try the android : colorAccent', 'if ( Build . VERSION . SDK _ INT >= 21 ) {', 'context . getTheme (). resolveAttribute ( android . R . attr . colorAccent , typedValue , true );', 'return typedValue . data ;', '}', '// Next , try colorAccent from support lib', 'int colorAccentResId = context . getResources (). getIdentifier (" colorAccent ", " attr ", context . getPackageName ());', 'if ( colorAccentResId != 0 && context . getTheme (). resolveAttribute ( colorAccentResId , typedValue , true )) {', 'return typedValue . data ;', '}', '// Return the value in mdtp _ accent _ color', 'return ContextCompat . getColor ( context , R . color . mdtp _ accent _ color );', '}']
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public String getTreeAuthoringPath () {', 'return this . treeAuthoringPath ;', '}']
# 解析错误
# 解析错误
# 解析错误
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public ArrayList getAllLinkHRefs () {', 'return this . link _ href _ all ;', '}']
# ['<s>', 'Creates', 'a', 'view', 'representing', 'a', 'shortcut', '.', '</s>', 'View createShortcut ( ShortcutInfo info ) {', 'return createShortcut ( R . layout . application ,', '( ViewGroup ) mWorkspace . getChildAt ( mWorkspace . getCurrentScreen ()), info );', '}']
# ['<s>', 'Allocate', 'a', 'bitmap', 'with', 'the', 'specified', 'width', 'and', 'height', '.', '</s>', '@ Override', 'protected Bitmap alloc ( int size ) {', 'return Bitmap . createBitmap (', '1 ,', '( int ) Math . ceil ( size / ( double ) BitmapUtil . RGB _ 565 _ BYTES _ PER _ PIXEL ),', 'Bitmap . Config . RGB _ 565 );', '}']
# 解析错误
# ['<s>', 'All', 'Paths', 'are', "'", 'tagged', "'", 'in', 'swagger', 'with', 'the', 'final', 'entity', 'type', 'name', 'in', 'the', 'path', '.', '</s>', 'private String getTag () {', 'if ( lineage . isEmpty ()) {', 'return name ;', '} else {', 'return lineage . get ( 0 ). getName ();', '}', '}']
# ['<s>', 'Used', 'to', 'determine', 'if', 'the', 'broker', 'can', 'dispatch', 'to', 'the', 'consumer', '.', '</s>', 'public boolean isFull () {', 'return getPrefetchSize () == 0 ? prefetchExtension . get () == 0 : dispatched . size () - prefetchExtension . get () >= info . getPrefetchSize ();', '}']
# ['<s>', 'Gets', 'the', 'element', 'for', 'the', 'method', 'corresponding', 'to', 'this', 'invocation', '.', '</s>', 'public static final Element elementFromUse ( ExpressionTree node ) {', 'return InternalUtils . symbol ( node );', '}']
# ['<s>', 'Get', 'the', 'full', 'length', 'of', 'this', 'movie', '(', 'in', 'seconds', ').', '</s>', 'public float duration () {', 'float sec = gplayer . queryDuration (). toSeconds ();', 'float nanosec = gplayer . queryDuration (). getNanoSeconds ();', 'return sec + Video . nanoSecToSecFrac ( nanosec );', '}']
# ['<s>', 'Converts', 'a', 'value', 'from', 'its', 'logical', 'format', '(', 'BigDecimal', ')', 'to', 'its', 'encoded', 'format', '-', 'a', 'struct', 'containing', 'the', 'scale', 'of', 'the', 'number', 'and', 'a', 'binary', 'representation', 'of', 'the', 'number', '.', '</s>', 'public static Struct fromLogical ( Schema schema , SpecialValueDecimal value ) {', 'return fromLogical ( schema , value . getDecimalValue (). orElse ( null ));', '}']
# ['<s>', 'Get', 'a', 'Struct', 'representation', 'of', 'the', 'source', '#', 'partition', '(', 'String', ')', 'partition', 'and', '#', 'lastOffset', '(', 'String', ')', 'offset', 'information', '.', '</s>', 'public Struct offsetStructForEvent ( String replicaSetName , Document oplogEvent ) {', 'Position position = INITIAL _ POSITION ;', 'String namespace = "";', 'if ( oplogEvent != null ) {', 'BsonTimestamp ts = extractEventTimestamp ( oplogEvent );', 'Long opId = oplogEvent . getLong (" h ");', 'position = new Position ( ts , opId );', 'namespace = oplogEvent . getString (" ns ");', '}', 'positionsByReplicaSetName . put ( replicaSetName , position );', 'return offsetStructFor ( replicaSetName , CollectionId . parse ( replicaSetName + "." + namespace ), position , isInitialSyncOngoing ( replicaSetName ));', '}']
# 解析错误
# ['<s>', 'When', 'initializing', 'the', 'profile', ',', 'Opera', 'rapidly', 'starts', ',', 'stops', ',', 'restarts', 'and', 'stops', 'again', ';', 'we', 'need', 'to', 'wait', 'a', 'bit', 'to', 'make', 'sure', 'the', 'file', 'lock', 'is', 'really', 'gone', '.', '</s>', 'private boolean makeSureFileLockRemainsGone ( File lock , long timeToWait ) {', 'for ( long start = System . currentTimeMillis (); System . currentTimeMillis () < start + timeToWait ;) {', 'AsyncExecute . sleepTight ( 500 );', 'if ( lock . exists ()) return false ;', '}', 'return ! lock . exists ();', '}']
# ['<s>', 'Returns', 'the', 'providers', 'that', 'have', 'at', 'least', 'one', 'common', 'ISO', '3166', 'code', 'and', 'are', 'of', 'the', 'given', 'type', '.', '</s>', 'public static Iterable < ProviderMetadata > collocatedWith ( ProviderMetadata providerMetadata ,', 'TypeToken <? extends Wrapper > contextWrappableAs ) {', 'return filter ( all (), Predicates . and ( ProviderPredicates . intersectingIso3166Code ( providerMetadata ),', 'ProviderPredicates . contextWrappableAs ( contextWrappableAs )));', '}']
# ['<s>', 'Get', 'the', 'days', 'field', 'type', '.', '</s>', 'public static DurationFieldType days () {', 'return DAYS _ TYPE ;', '}']
# ['<s>', 'Creates', 'a', 'UserAdapter', 'if', 'there', 'is', 'more', 'than', 'one', 'profile', 'on', 'the', 'device', '.', '</s>', 'public static UserSpinnerAdapter createUserSpinnerAdapter ( UserManager userManager ,', 'Context context ) {', 'List < UserHandle > userProfiles = userManager . getUserProfiles ();', 'if ( userProfiles . size () < 2 ) {', 'return null ;', '}', 'UserHandle myUserHandle = new UserHandle ( UserHandle . myUserId ());', '// The first option should be the current profile', 'userProfiles . remove ( myUserHandle );', 'userProfiles . add ( 0 , myUserHandle );', 'ArrayList < UserDetails > userDetails = new ArrayList < UserDetails >( userProfiles . size ());', 'final int count = userProfiles . size ();', 'for ( int i = 0 ; i < count ; i ++) {', 'userDetails . add ( new UserDetails ( userProfiles . get ( i ), userManager , context ));', '}', 'return new UserSpinnerAdapter ( context , userDetails );', '}']
# ...
# ['<s>', 'Creates', 'the', 'Jenkins', 'Job', 'name', 'for', 'the', 'given', 'buildConfigName', '</s>', 'public static String jenkinsJobName ( String namespace , String buildConfigName , String defaultNamespace ) {', 'if ( namespace == null || namespace . length () == 0 || namespace . equals ( defaultNamespace )) {', 'return buildConfigName ;', '}', 'return namespace + "-" + buildConfigName ;', '}']
# ['<s>', 'Get', 'the', 'ISO', '8601', 'formatted', 'representation', 'of', 'the', 'given', 'java', '.', 'util', '.', 'Date', 'or', 'one', 'of', 'its', 'JDBC', 'subclasses', ',', 'using', 'the', 'supplied', 'timezone', 'information', '.', '</s>', 'public static String toIsoString ( java . util . Date timestamp , ZoneId zoneId , TemporalAdjuster adjuster ) {', 'if ( timestamp instanceof java . sql . Timestamp ) {', 'return toIsoString (( java . sql . Timestamp ) timestamp , zoneId , adjuster );', '}', 'if ( timestamp instanceof java . sql . Date ) {', 'return toIsoString (( java . sql . Date ) timestamp , zoneId , adjuster );', '}', 'if ( timestamp instanceof java . sql . Time ) {', 'return toIsoString (( java . sql . Time ) timestamp , zoneId , adjuster );', '}', 'return timestamp . toInstant (). atZone ( zoneId ). format ( FORMATTER );', '}']
# 解析错误
# ['<s>', 'Build', 'the', 'bootstrap', 'registry', '.', '</s>', 'public BootstrapServiceRegistry build () {', 'final ClassLoaderServiceImpl classLoaderService = new ClassLoaderServiceImpl (', 'applicationClassLoader ,', 'resourcesClassLoader ,', 'hibernateClassLoader ,', 'environmentClassLoader', ');', 'final IntegratorServiceImpl integratorService = new IntegratorServiceImpl (', 'providedIntegrators ,', 'classLoaderService', ');', 'return new BootstrapServiceRegistryImpl ( classLoaderService , integratorService );', '}']
# ['<s>', 'Executes', 'a', 'collection', 'of', 'updates', 'in', 'a', 'single', 'batch', 'RPC', '.', '</s>', 'protected long [] executeBatchInternal () throws SQLException {', 'for ( int i = 0 ; i < connection . maxRetriesPerExecute ; i ++) {', 'try {', 'return connection . prepareAndUpdateBatch ( this , batchedSql ). updateCounts ;', '} catch ( NoSuchStatementException e ) {', 'resetStatement ();', '}', '}', 'throw new RuntimeException (" Failed to successfully execute batch update after "', '+ connection . maxRetriesPerExecute + " attempts ");', '}']
# ['<s>', 'Return', 'the', 'ApplicationConfig', 'object', 'is', 'it', 'exists', ',', 'null', 'otherwise', '.', '</s>', 'public static ModuleConfig getModuleConfig ( PageContext pageContext ) {', 'ModuleConfig moduleConfig = ( ModuleConfig )', 'pageContext . getRequest (). getAttribute ( Globals . MODULE _ KEY );', 'if ( moduleConfig == null ) { // Backwards compatibility hack', 'moduleConfig = ( ModuleConfig )', 'pageContext . getServletContext (). getAttribute ( Globals . MODULE _ KEY );', '}', 'return moduleConfig ;', '}']
# ['<s>', 'Check', 'if', 'two', '"', 'core', '"', 'types', 'are', 'the', 'same', ',', 'ignoring', 'subtypes', 'and', 'children', '.', '</s>', 'public static boolean isSameType ( MajorType type1 , MajorType type2 ) {', 'return isSameTypeAndMode ( type1 , type2 ) &&', 'type1 . getScale () == type2 . getScale () &&', 'type1 . getPrecision () == type2 . getPrecision ();', '}']
# ['<s>', 'Returns', 'the', 'int', 'representing', 'this', 'operation', 'code', '.', '</s>', 'public byte toOrdinal () {', 'return this . opCode ;', '}']
# ['<s>', 'Gets', 'the', 'overall', 'timeframe', 'of', 'the', 'selected', 'habits', '.', '</s>', 'private Timestamp [] getTimeframe ()', '{', 'Timestamp oldest = Timestamp . ZERO . plus ( 1000000 );', 'Timestamp newest = Timestamp . ZERO ;', 'for ( Habit h : selectedHabits )', '{', 'if ( h . getRepetitions (). getOldest () == null || h . getRepetitions (). getNewest () == null )', 'continue ;', 'Timestamp currOld = h . getRepetitions (). getOldest (). getTimestamp ();', 'Timestamp currNew = h . getRepetitions (). getNewest (). getTimestamp ();', 'oldest = currOld . isOlderThan ( oldest ) ? oldest : currOld ;', 'newest = currNew . isNewerThan ( newest ) ? newest : currNew ;', '}', 'return new Timestamp []{ oldest , newest };', '}']
# ['<s>', 'Calculate', 'skill', 'levels', 'required', 'for', 'increasing', 'combat', 'level', ',', 'meant', 'for', 'all', 'combat', 'skills', 'besides', 'ranged', 'and', 'magic', '.', '</s>', 'static int calcLevels ( double start , int end , double multiple )', '{', 'return ( int ) Math . ceil ( calcMultipliedLevels ( start , end , multiple ));', '}']
# ['<s>', 'Get', 'the', 'millis', 'duration', 'field', 'for', 'this', 'chronology', '.', '</s>', 'public DurationField millis () {', 'return UnsupportedDurationField . getInstance ( DurationFieldType . millis ());', '}']
# ['<s>', 'Creates', 'an', 'AsyncAppenderBase', 'of', 'type', 'IAccessEvent', '.', '</s>', '@ Override', 'public AsyncAppenderBase < IAccessEvent > build () {', 'return new AsyncAppenderBase < IAccessEvent >() {', '@ Override', 'protected void preprocess ( IAccessEvent event ) {', 'event . prepareForDeferredProcessing ();', '}', '};', '}']
# ['<s>', 'Waits', 'for', 'a', 'text', 'to', 'be', 'shown', '.', '</s>', 'public boolean waitForText ( String text , int matches , long timeout , boolean scroll )', '{', 'long now = System . currentTimeMillis ();', 'final long endTime = now + timeout ;', 'while (! searcher . searchFor ( TextView . class , text , matches , scroll ) && ! searcher . searchForEditText ( text , scroll ) && now < endTime ) {', 'now = System . currentTimeMillis ();', '}', 'final boolean timedOut = now > endTime ;', 'return ! timedOut ;', '}']
# ['<s>', 'Expr', ':', 'left', '.', 'substring', '(', 'beginIndex', ',', 'endIndex', ')', '</s>', 'public static EString substring ( Expr < String > left , int right ) {', 'return operationFactory . createString ( Ops . SUBSTR1ARG , left , exprFactory', '. createConstant ( right ));', '}']
# ['<s>', 'Calculate', 'the', 'ratio', 'of', 'similarity', 'between', '2', 'strings', 'using', 'LCS', '</s>', 'public double getMatchRatio ( String strA , String strB ) {', 'if ( strA == null && strB == null ) {', 'return MAX _ RATIO ;', '} else if ( strA == null || strB == null ) {', 'return MIN _ RATIO ;', '}', 'if ( strA . isEmpty () && strB . isEmpty ()) {', 'return MAX _ RATIO ;', '} else if ( strA . isEmpty () || strB . isEmpty ()) {', 'return MIN _ RATIO ;', '}', '// get the percentage match against the longer of the 2 strings', 'return ( double ) getLCS ( strA , strB ). length () / Math . max ( strA . length (), strB . length ());', '}']
# ['<s>', 'Returns', 'the', 'wrapped', 'LockableMGraph', 'if', 'the', 'caller', 'has', 'all', 'access', 'rights', ',', 'otherwise', 'an', 'AccessControlException', 'is', 'thrown', '.', '</s>', 'public LockableMGraph getUnsecuredMGraph () {', 'try {', 'checkWrite ();', 'return wrapped ;', '} catch ( AccessControlException ex ) {', 'checkRead ();', 'return new WriteBlockedMGraph ( wrapped );', '}', '}']
# ['<s>', 'Determines', 'if', 'the', 'specified', 'element', 'is', 'visible', '.', '</s>', 'public boolean isVisible ( String locator ) {', 'return (( RenderedWebElement ) elementFinder . findElement ( driver , locator )). isDisplayed ();', '}']
# 解析错误
# ['<s>', 'This', 'allows', 'you', 'to', 'morph', 'a', 'type', 'into', 'a', 'more', 'specialized', 'form', 'yet', 'return', 'the', 'same', 'parent', 'and', 'non', '-', 'null', 'ness', ',', 'for', 'example', 'taking', 'a', 'GraphQLInterfaceType', 'and', 'turning', 'it', 'into', 'a', 'specific', 'graphql', '.', 'schema', '.', 'GraphQLObjectType', 'after', 'type', 'resolution', 'has', 'occurred', '</s>', 'public ExecutionInfo treatAs ( GraphQLType newType ) {', 'return new ExecutionInfo ( unwrapNonNull ( newType ), fieldDefinition , field , path , this . parentInfo , this . typeIsNonNull , arguments );', '}']
# ['<s>', 'Selects', 'the', 'best', 'candidate', 'to', 'be', 'evicted', '.', '</s>', 'public < C extends EvictionCandidate < A , E >> Iterable < C > evaluate ( Iterable < C > evictionCandidates ) {', 'C selectedEvictionCandidate = null ;', 'long now = Clock . currentTimeMillis ();', 'for ( C currentEvictionCandidate : evictionCandidates ) {', 'if ( selectedEvictionCandidate == null ) {', 'selectedEvictionCandidate = currentEvictionCandidate ;', '} else {', 'E evictable = currentEvictionCandidate . getEvictable ();', 'if ( isExpired ( now , evictable )) {', 'return returnEvictionCandidate ( currentEvictionCandidate );', '}', 'int comparisonResult = evictionPolicyComparator . compare ( selectedEvictionCandidate , currentEvictionCandidate );', 'if ( comparisonResult == EvictionPolicyComparator . SECOND _ ENTRY _ HAS _ HIGHER _ PRIORITY _ TO _ BE _ EVICTED ) {', 'selectedEvictionCandidate = currentEvictionCandidate ;', '}', '}', '}', 'return returnEvictionCandidate ( selectedEvictionCandidate );', '}']
# ['<s>', 'Gets', 'the', 'job', 'output', 'key', 'schema', '.', '</s>', 'public static Schema getOutputKeySchema ( Configuration conf ) {', 'String schemaString = conf . get ( CONF _ OUTPUT _ KEY _ SCHEMA );', 'return schemaString != null ? new Schema . Parser (). parse ( schemaString ) : null ;', '}']
# ['<s>', 'An', 'api', 'to', 'fetch', 'count', 'of', 'the', 'batch', 'instance', 'table', 'for', 'a', 'given', 'status', 'list', 'and', 'batch', 'priority', 'and', 'current', 'user', 'required', '</s>', '@ Transactional ( readOnly = true )', '@ Override', 'public int getCount ( final List < BatchInstanceStatus > batchInstStatusList , final List < BatchPriority > batchPriorities ,', 'final boolean isCurrUsrNotReq , final String currentUser , final Set < String > userRoles , EphesoftUser ephesoftUser ) {', 'return batchInstanceDao', '. getCount ( batchInstStatusList , batchPriorities , isCurrUsrNotReq , userRoles , currentUser , ephesoftUser );', '}']
# ['<s>', 'Control', 'the', 'max', 'length', 'for', 'request', 'and', 'response', 'content', 'that', 'will', 'be', 'retained', '.', '</s>', 'public ChuckInterceptor maxContentLength ( long max ) {', 'this . maxContentLength = max ;', 'return this ;', '}']
# 解析错误
# 解析错误
# ['<s>', 'Returns', 'the', 'sibling', 'on', 'the', 'left', 'of', 'the', 'end', 'of', 'given', 'Treepath', '.', '</s>', 'public static Treepath getPreviousSibling ( Treepath treepath ) throws IllegalArgumentException {', 'if ( treepath . getHeight () < 2 ) {', 'throw new IllegalArgumentException ( " Treepath must have minimum height of 2 " ) ;', '}', 'final Tree treeToMove = treepath . getBottom () ;', 'final Tree parent = treepath . getTreeAtHeight ( 1 ) ;', 'for ( int i = parent . getChildCount () - 1 ; i > 0 ; i -- ) {', 'final Tree child = parent . getChildAt ( i ) ;', 'if ( child == treeToMove ) {', 'return Treepath . create ( treepath . getParent (), parent . getChildAt ( i - 1 ) ) ;', '}', '}', 'throw new IllegalArgumentException ( " No previous sibling " ) ;', '}']
# 解析错误
# ['<s>', 'Visits', 'the', 'given', 'implementation', 'type', 'and', 'calls', 'back', 'to', 'org', '.', 'apache', '.', 'tuscany', '.', 'core', '.', 'extension', '.', 'config', '.', 'ImplementationProcessors', 'registered', 'with', 'this', 'introspector', 'to', 'build', 'up', 'a', 'ComponentInfo', '</s>', 'public ComponentType introspect ( Class <?> implClass ) throws ConfigurationLoadException {', 'ComponentType compType = factory . createComponentType ();', 'return introspect ( implClass , compType );', '}']
# 解析错误
# ['<s>', 'Returns', 'the', 'entity', 'as', 'an', 'input', 'stream', '.', '</s>', 'public final Entity getEntity () {', 'return entity ;', '}']
# ['<s>', 'Tags', 'the', 'Words', 'in', 'each', 'Sentence', 'in', 'the', 'given', 'List', 'with', 'their', 'grammatical', 'part', '-', 'of', '-', 'speech', '.', '</s>', 'public List < List < TaggedWord >> process ( List <? extends List <? extends HasWord >> sentences ) {', 'List < List < TaggedWord >> taggedSentences = Generics . newArrayList ();', 'TestSentence testSentence = new TestSentence ( this );', 'for ( List <? extends HasWord > sentence : sentences ) {', 'taggedSentences . add ( testSentence . tagSentence ( sentence , false ));', '}', 'return taggedSentences ;', '}']
# ['<s>', 'Returns', 'true', 'if', 'the', 'query', 'window', 'is', 'closed', 'and', 'you', 'should', 'emit', 'the', 'result', 'at', 'this', 'time', '.', '</s>', '@ Override', 'public boolean isClosed () {', 'return mode == Mode . PARTITION ? window . isClosedForPartition () : window . isClosed ();', '}']
# ['<s>', 'Configures', 'and', 'returns', 'a', 'new', 'OperaDriverService', 'using', 'the', 'default', 'configuration', '.', '</s>', 'public static OperaDriverService createDefaultService () {', 'return new Builder (). build ();', '}']
# ['<s>', 'Returns', 'the', 'android', '.', 'telecomm', '.', 'Connection', '.', 'VideoProvider', 'for', 'the', 'connection', '.', '</s>', 'public android . telecom . Connection . VideoProvider getVideoProvider () {', 'return mVideoProvider ;', '}']
# ['<s>', 'Get', 'the', 'hour', 'of', 'day', '(', 'offset', 'to', '1', '-', '24', ')', 'field', 'type', '.', '</s>', 'public static DateTimeFieldType clockhourOfDay () {', 'return CLOCKHOUR _ OF _ DAY _ TYPE ;', '}']
# ['<s>', 'DOCUMENT', 'ME', '!', '</s>', 'public String getLivePath () {', 'return this . livePath ;', '}']
# ['<s>', 'Creates', 'a', 'publisher', 'for', 'the', 'specified', 'topic', '.', '</s>', 'public TopicPublisher createPublisher ( Topic topic ) throws JMSException {', 'checkClosed ();', 'if ( topic instanceof CustomDestination ) {', 'CustomDestination customDestination = ( CustomDestination ) topic ;', 'return customDestination . createPublisher ( this );', '}', 'int timeSendOut = connection . getSendTimeout ();', 'return new ActiveMQTopicPublisher ( this , ActiveMQMessageTransformation . transformDestination ( topic ), timeSendOut );', '}']
# ['<s>', 'Obtain', 'an', 'editor', 'for', 'the', 'identified', 'table', 'or', ',', 'if', 'there', 'is', 'no', 'such', 'table', ',', 'create', 'an', 'editor', 'with', 'the', 'specified', 'ID', '.', '</s>', 'public TableEditor editOrCreateTable ( TableId tableId ) {', 'Table table = forTable ( tableId );', 'return table == null ? Table . editor (). tableId ( tableId ) : table . edit ();', '}']
# ['<s>', 'Searches', 'for', 'a', 'text', 'string', 'in', 'the', 'edit', 'texts', 'located', 'in', 'the', 'current', 'activity', '.', '</s>', 'public boolean searchEditText ( String search ) {', 'boolean found = soloSearch . searchEditText ( search );', 'return found ;', '}']
# ['<s>', 'Deserializes', 'an', 'Object', 'from', 'the', 'specified', 'stream', '.', 'The', 'stream', 'will', 'be', 'closed', 'once', 'the', 'object', 'is', 'written', '.', '</s>', 'public static Object deserialize ( InputStream inputStream ) throws SerializationException {', 'return deserialize ( inputStream , Thread . currentThread (). getContextClassLoader () );', '}']
# 解析错误
# ['<s>', 'Deserializes', 'the', 'previously', 'serialized', 'TokenStream', 'using', 'the', 'provided', 'AttributeSerializer', '(', 's', ').', '</s>', 'public final TwitterTokenStream deserialize ( final byte [] data ,', 'final CharSequence charSequence ) throws IOException {', 'return deserialize ( data , 0 , data . length , charSequence );', '}']
# ['<s>', 'Get', 'user', 'by', 'user', 'name', '</s>', 'public User getUserByName ( String username ) throws ApiException {', 'ApiResponse < User > localVarResp = getUserByNameWithHttpInfo ( username );', 'return localVarResp . getData ();', '}']
# ['<s>', 'Reads', 'class', 'byte', 'array', 'info', 'from', 'the', 'given', 'input', 'stream', '.', '</s>', 'public static byte [] readByteCode ( ZipInputStream zip ) throws IOException {', 'ByteArrayOutputStream bout = new ByteArrayOutputStream ();', 'InputStream in = new BufferedInputStream ( zip );', 'int b ;', 'while ( ( b = in . read () ) != - 1 ) {', 'bout . write ( b );', '}', 'return bout . toByteArray ();', '}']

# %%
code_lineList_token

# %%
ifstatement_num,forstatement_num,whilestatement_num,variableDeclaration_num,\
expression_num,trystatement_num,returnstatement_num,MethodDeclaration_num = get_all_statement(code_lineList_token,attribute_num_code)

# %%
ifstatement_num = flattened_list(ifstatement_num)
forstatement_num = flattened_list(forstatement_num)
whilestatement_num = flattened_list(whilestatement_num)
variableDeclaration_num = flattened_list(variableDeclaration_num)
expression_num = flattened_list(expression_num)
trystatement_num = flattened_list(trystatement_num)
returnstatement_num = flattened_list(returnstatement_num)
MethodDeclaration_num = flattened_list(MethodDeclaration_num)

# %%
data = [ifstatement_num,forstatement_num,whilestatement_num,variableDeclaration_num,\
        expression_num,trystatement_num,returnstatement_num,MethodDeclaration_num ]
keys = ['ifstatement_num', 'forstatement_num', 'whilestatement_num', 'variableDeclaration_num',
        'expression_num', 'trystatement_num', 'returnstatement_num', 'MethodDeclaration_num']

# %%
df = pd.DataFrame()

# 将数据添加到DataFrame中
for key, values in zip(keys, data):
    temp_df = pd.DataFrame()
    temp_df['value'] = values
    temp_df['key'] = key
    df = pd.concat([df, temp_df])
df = df.reset_index(drop=True)

# %%
# 使用seaborn绘制小提琴图
plt.figure(figsize=(20,7))
sns.violinplot(x='key', y='value', data=df)
plt.show()
