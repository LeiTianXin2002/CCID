# %% [markdown]
# 此  .ipynb  挑选最有代表性的代码注释对

# %%
import javalang
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

import torch
import torch.nn as nn
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import AdamW, get_linear_schedule_with_warmup
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, TensorDataset


from captum.attr import visualization as viz
from captum.attr import LayerConductance, LayerIntegratedGradients
from captum.attr import configure_interpretable_embedding_layer, remove_interpretable_embedding_layer

# 解决服务器挂掉的问题
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device( "cpu")

# %%
MAX_LEN = 1024
MAX_EPOCHS = 10
BATCH_SIZE = 4
LEARNING_RATE = 1e-5
NUM_CLASSES = 2
WEIGTH_DECAY = 1e-3

# %%
def retrieve_test_data():
    test_param = pd.read_json("D:/BERT_learing/code_comment_inconsistency_detection/data/param/test.json")
    test_return = pd.read_json("D:/BERT_learing/code_comment_inconsistency_detection/data/return/test.json")
    test_summary = pd.read_json("D:/BERT_learing/code_comment_inconsistency_detection/data/summary/test.json")
    test_df = pd.concat([test_summary,test_param, test_return], axis=0)
    test_df = test_df.reset_index(drop=True)
    return test_df
test_df = retrieve_test_data()

# %%
len(test_df)
# Out:
# 3944

# %%
# 用这个，这个对了
def get_blocks_improved_BFS_code(root):
    queue = []
    nodes = []
    queue.append(root)
    level = 0
    while queue:
        level = level + 1
        for i in range(len(queue)):
            node = queue.pop(0)
            nodes.append(node)
            if hasattr(node, 'children'):
                for child in node.children:
                    queue.append(child)
            else:
                try:
                    len_node = len(node)
                    for i in range(len_node):
                        if hasattr(node[i], 'children'):
                            for child in node[i].children:
                                 queue.append(child)
                except Exception as e:
                    continue
    for node in nodes:
        if isinstance(node, javalang.tree.Node):
            index = nodes.index(node)
            nodes[index] = type(node).__name__
        if isinstance(node, list):
            for no in node:
                if isinstance(no, javalang.tree.Node):
                    index = node.index(no)
                    node[index] = type(no).__name__

            
    return level,nodes

# %%
# 使用javalang解析数据，将AST的层数,和ASTnodes(ast层次遍历结果)  变为dataframe中的一列，返回新的dataframe

def get_BFS_df(df):

    error_index = []
    asts = []
    levels = []
    nodes = []
    for i in range(len(df)):
        tokens_t = javalang.tokenizer.tokenize(df.loc[i]['new_code_raw'])
        try:
            parser = javalang.parse.Parser(tokens_t)
        except Exception as e:
            error_index.append(i)
            continue
        asts.append(parser)  

    for i in range(len(asts)):
        try:
            # 尝试解析Java代码
            test = asts[i].parse_member_declaration()
            depth,node = get_blocks_improved_BFS_code(test)
            levels.append(depth) 
            nodes.append(node)
        except javalang.parser.JavaSyntaxError:
            # 如果出现JavaSyntaxError，打印错误并跳过
            error_index.append(i)
            print(f"解析错误索引为ast[{i}]，跳过有问题的代码")
            continue 
            
    for i in error_index:
        df.drop(i, inplace=True)
    df = df.reset_index(drop=True)
    
    df['AST_level'] = levels
    df['AST_BFSnodes'] = nodes
    return df
test_df_ast = get_BFS_df(test_df)
test_df_ast.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  AST_level  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...          8
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...          7
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...         13
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...          5
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...         10
#
#                                         AST_BFSnodes
# 0  [MethodDeclaration, None, {private, static}, [...
# 1  [MethodDeclaration, None, {public}, [], None, ...
# 2  [MethodDeclaration, None, {private}, [], None,...
# 3  [MethodDeclaration, None, {static, public}, []...
# 4  [MethodDeclaration, None, {static}, [], None, ...

# %%
# 这个前序遍历 不能和层序遍历  在一个函数中连着使用 ， 最后用的是这个

def preorder_traversal_a(node,pre_nodes):
    if hasattr(node, 'children'):
        for child_node in node.children:
            pre_nodes.append(child_node)
            preorder_traversal_a(child_node,pre_nodes)
    else:
        try:
            len_node = len(node)
            for i in range(len_node):
                if hasattr(node[i], 'children'):
                    for child in node[i].children:
                        pre_nodes.append(child)
                        preorder_traversal_a(child,pre_nodes)
        except Exception as e:
            pass
    return pre_nodes

# %%
# 这个前序遍历 不能和层序遍历  在一个函数中连着使用 ， 最后用的是这个

def preorder_traversal_a_n(node,pre_nodes,depth=0):
    if depth == 0:
        pre_nodes.append(node)

    if hasattr(node, 'children'):
        for child_node in node.children:
            pre_nodes.append(child_node)
            preorder_traversal_a_n(child_node,pre_nodes,depth+1)
    else:
        try:
            len_node = len(node)
            for i in range(len_node):
                if hasattr(node[i], 'children'):
                    for child in node[i].children:
                        pre_nodes.append(child)
                        preorder_traversal_a_n(child,pre_nodes,depth+1)
        except Exception as e:
            pass
    return pre_nodes

# %%
# 获得前序遍历

def get_PFS_df(df):
    
    asts = []
    nodes_pfs = []
    for i in range(len(df)):
        tokens_t = javalang.tokenizer.tokenize(df.loc[i]['new_code_raw'])
        parser = javalang.parse.Parser(tokens_t)

        asts.append(parser)  

    for i in range(len(asts)):  
        try:
            # 尝试解析Java代码
#             print(i)
            test = asts[i].parse_member_declaration()

            pre_nodes_test = []
            node_p = preorder_traversal_a_n(test,pre_nodes_test)
            
            for node in node_p:   # 处理 node_p  
                if isinstance(node, javalang.tree.Node):
                    index = node_p.index(node)
                    node_p[index] = type(node).__name__
                if isinstance(node, list):
                    for no in node:
                        if isinstance(no, javalang.tree.Node):
                            index = node.index(no)
                            node[index] = type(no).__name__
                            
            nodes_pfs.append(node_p)
        except javalang.parser.JavaSyntaxError:
            continue 
    
    df['AST_PFSnodes'] = nodes_pfs

    return df
test_df_ast = get_PFS_df(test_df_ast)
test_df_ast.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  AST_level  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...          8
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...          7
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...         13
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...          5
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...         10
#
#                                         AST_BFSnodes  \
# 0  [MethodDeclaration, None, {private, static}, [...
# 1  [MethodDeclaration, None, {public}, [], None, ...
# 2  [MethodDeclaration, None, {private}, [], None,...
# 3  [MethodDeclaration, None, {static, public}, []...
# 4  [MethodDeclaration, None, {static}, [], None, ...
#
#                                         AST_PFSnodes
# 0  [MethodDeclaration, None, {private, static}, [...
# 1  [MethodDeclaration, None, {public}, [], None, ...
# 2  [MethodDeclaration, None, {private}, [], None,...
# 3  [MethodDeclaration, None, {static, public}, []...
# 4  [MethodDeclaration, None, {static}, [], None, ...

# %%
test_df_ast.loc[0]['AST_PFSnodes']
# Out:
# ['MethodDeclaration',
#  None,
#  {'private', 'static'},
#  [],
#  None,
#  'ReferenceType',
#  'EmbeddedElasticsearchNode',
#  [],
#  None,
#  None,
#  'create',
#  ['FormalParameter'],
#  set(),
#  [],
#  'ReferenceType',
#  'Settings',
#  [],
#  None,
#  None,
#  'settings',
#  False,
#  None,
#  ['LocalVariableDeclaration', 'ReturnStatement'],
#  set(),
#  [],
#  'ReferenceType',
#  'Node',
#  [],
#  None,
#  None,
#  ['VariableDeclarator'],
#  'node',
#  [],
#  'ClassCreator',
#  [],
#  [],
#  None,
#  [],
#  'ReferenceType',
#  'LocalNode',
#  None,
#  None,
#  None,
#  None,
#  ['MemberReference', 'MethodInvocation'],
#  [],
#  [],
#  '',
#  [],
#  'settings',
#  [],
#  [],
#  'Arrays',
#  [],
#  None,
#  ['ClassReference', 'ClassReference'],
#  [],
#  [],
#  '',
#  [],
#  'ReferenceType',
#  'Netty4Plugin',
#  None,
#  None,
#  None,
#  [],
#  [],
#  '',
#  [],
#  'ReferenceType',
#  'PainlessPlugin',
#  None,
#  None,
#  None,
#  'asList',
#  None,
#  None,
#  'ClassCreator',
#  [],
#  [],
#  None,
#  [],
#  'ReferenceType',
#  'EmbeddedElasticsearchNode',
#  None,
#  None,
#  None,
#  None,
#  ['MemberReference'],
#  [],
#  [],
#  '',
#  [],
#  'node',
#  None]

# %%
len(test_df_ast.loc[0]['AST_PFSnodes'])
# Out:
# 95

# %%
test_df_ast.loc[1]['AST_PFSnodes']
# Out:
# ['MethodDeclaration',
#  None,
#  {'public'},
#  [],
#  None,
#  'BasicType',
#  'boolean',
#  [],
#  'areInsertionsOrDeletionsQueued',
#  [],
#  None,
#  ['ReturnStatement'],
#  None,
#  'BinaryOperation',
#  '||',
#  'BinaryOperation',
#  '||',
#  'BinaryOperation',
#  '>',
#  'MethodInvocation',
#  [],
#  [],
#  'insertions',
#  [],
#  None,
#  [],
#  'size',
#  'Literal',
#  [],
#  [],
#  None,
#  [],
#  '0',
#  'MethodInvocation',
#  ['!'],
#  [],
#  'unresolvedInsertions',
#  [],
#  None,
#  [],
#  'isEmpty',
#  'BinaryOperation',
#  '>',
#  'MethodInvocation',
#  [],
#  [],
#  'deletions',
#  [],
#  None,
#  [],
#  'size',
#  'Literal',
#  [],
#  [],
#  None,
#  [],
#  '0']

# %%
len(test_df_ast.loc[1]['AST_PFSnodes'])
# Out:
# 57

# %%
# 可以把这个和下面的合并在一块
def get_clean_list(lst):
    lst = [x for x in lst if x is not None]
    lst = [x for x in lst if x != []]
    lst = [x for x in lst if x != '']
    return lst
# 去除多余的元素
def flatten_to_string(lst):
    result = []
    for i in lst:
        if isinstance(i, list):
            result.extend(flatten_to_string(i))
        elif isinstance(i, set):
            result.extend(flatten_to_string(list(i)))
        elif not isinstance(i, bool):
            result.append(i)
    return result

# %%
# 整理一下 将 里面的列表括号 和 多余元素删除  ( AST_PFSnodes 列和 AST_BFSnodes 列 )
def clean_ASTNodes(df):
    AST_BFSnodes = []
    AST_PFSnodes = []
    for node in df['AST_PFSnodes']:
        PFS_nodes = get_clean_list(node)
        PFS_nodes = flatten_to_string(PFS_nodes)
        AST_PFSnodes.append(PFS_nodes)
    for node in df['AST_BFSnodes']:
        BFS_nodes = get_clean_list(node)
        BFS_nodes = flatten_to_string(BFS_nodes)
        AST_BFSnodes.append(BFS_nodes)    
    
    df['AST_BFSnodes'] = AST_BFSnodes
    df['AST_PFSnodes'] = AST_PFSnodes
    return df
cleaned_test_df_ast = clean_ASTNodes(test_df_ast)
cleaned_test_df_ast.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  AST_level  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...          8
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...          7
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...         13
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...          5
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...         10
#
#                                         AST_BFSnodes  \
# 0  [MethodDeclaration, private, static, Reference...
# 1  [MethodDeclaration, public, BasicType, areInse...
# 2  [MethodDeclaration, private, BasicType, marsha...
# 3  [MethodDeclaration, static, public, ReferenceT...
# 4  [MethodDeclaration, static, ReferenceType, cre...
#
#                                         AST_PFSnodes
# 0  [MethodDeclaration, private, static, Reference...
# 1  [MethodDeclaration, public, BasicType, boolean...
# 2  [MethodDeclaration, private, BasicType, byte, ...
# 3  [MethodDeclaration, static, public, ReferenceT...
# 4  [MethodDeclaration, static, ReferenceType, Mon...

# %%
cleaned_test_df_ast.AST_PFSnodes.apply(len).mean()
# Out:
# 137.96272819472617

# %%
(cleaned_test_df_ast.AST_PFSnodes.apply(len) < 100).sum()
# Out:
# 2771

# %%
len(cleaned_test_df_ast.loc[0]['AST_PFSnodes'])
# Out:
# 35

# %%
cleaned_test_df_ast.loc[0]['AST_PFSnodes']
# Out:
# ['MethodDeclaration',
#  'private',
#  'static',
#  'ReferenceType',
#  'EmbeddedElasticsearchNode',
#  'create',
#  'FormalParameter',
#  'ReferenceType',
#  'Settings',
#  'settings',
#  'LocalVariableDeclaration',
#  'ReturnStatement',
#  'ReferenceType',
#  'Node',
#  'VariableDeclarator',
#  'node',
#  'ClassCreator',
#  'ReferenceType',
#  'LocalNode',
#  'MemberReference',
#  'MethodInvocation',
#  'settings',
#  'Arrays',
#  'ClassReference',
#  'ClassReference',
#  'ReferenceType',
#  'Netty4Plugin',
#  'ReferenceType',
#  'PainlessPlugin',
#  'asList',
#  'ClassCreator',
#  'ReferenceType',
#  'EmbeddedElasticsearchNode',
#  'MemberReference',
#  'node']

# %%
len(cleaned_test_df_ast.loc[0]['AST_BFSnodes'])
# Out:
# 35

# %%
cleaned_test_df_ast.loc[0]['AST_BFSnodes']
# Out:
# ['MethodDeclaration',
#  'private',
#  'static',
#  'ReferenceType',
#  'create',
#  'FormalParameter',
#  'LocalVariableDeclaration',
#  'ReturnStatement',
#  'EmbeddedElasticsearchNode',
#  'ReferenceType',
#  'settings',
#  'ReferenceType',
#  'VariableDeclarator',
#  'ClassCreator',
#  'Settings',
#  'Node',
#  'node',
#  'ClassCreator',
#  'ReferenceType',
#  'MemberReference',
#  'ReferenceType',
#  'MemberReference',
#  'MethodInvocation',
#  'EmbeddedElasticsearchNode',
#  'node',
#  'LocalNode',
#  'settings',
#  'Arrays',
#  'ClassReference',
#  'ClassReference',
#  'asList',
#  'ReferenceType',
#  'ReferenceType',
#  'Netty4Plugin',
#  'PainlessPlugin']

# %%
len(cleaned_test_df_ast.loc[2]['AST_PFSnodes'])
# Out:
# 124

# %%
average_AST_level = cleaned_test_df_ast['AST_level'].mean()
average_AST_level
# Out:
# 8.218813387423936

# %%
import re
import string

def split_punctuation(s):
    # 使用正则表达式匹配连续的标点符号或者字母和标点符号之间的位置
    splits = re.finditer(r'(?<=\w)(?=[{}])|(?<=[{}])(?=\w)'.format(string.punctuation, string.punctuation), s)
    
    # 获取所有分割位置
    split_positions = [match.start() for match in splits]
    
    # 在分割位置插入空格
    for pos in reversed(split_positions):
        s = s[:pos] + ' ' + s[pos:]
        
    s = s.replace("< s >", "<s>")
    s = s.replace("</ s >", "</s>")
    return s

# %%
# 获得父节点对应孩子的个数

def get_Child_Node_count(df):
    
    asts = []
    codes = []
    child_Node_count = []
    for i in range(len(df)):
        tokens_t = javalang.tokenizer.tokenize(df.loc[i]['new_code_raw'])
        parser = javalang.parse.Parser(tokens_t)
        
        codes.append(df.loc[i]['new_code_raw'])
        asts.append(parser)  

    for i in range(len(asts)):  
        try:
            # 尝试解析Java代码
#             print(i)
            test = asts[i].parse_member_declaration()

            pre_nodes_test = []
            node_p = preorder_traversal_a_n(test,pre_nodes_test)
            
            code = codes[i]
            tokens = split_punctuation(code)
            tokens = ' '.join(tokens.split()).split()
            
            pre_child_num = []
            for nodes in node_p:
                if hasattr(nodes, 'children'):
                    num = 0
                    for child_node in nodes.children:
                        if isinstance(child_node, javalang.tree.Node):
                            num = num + 1
                        elif isinstance(child_node, list):
                            num = num + len(child_node)
                        elif isinstance(child_node, set):
                            num = num + len(child_node)
                        elif child_node in tokens:
                            num = num + 1
                    pre_child_num.append(num)
                else:
                    try:
                        len_node = len(nodes)
                        for i in range(len_node):
                            if hasattr(nodes[i], 'children'):
                                num = 0
                                for child_node in nodes[i].children:
                                    if isinstance(child_node, javalang.tree.Node):
                                        num = num + 1
                                    elif isinstance(child_node, list):
                                        num = num + len(child_node)
                                    elif isinstance(child_node, set):
                                        num = num + len(child_node)
                                    elif child_node in tokens:
                                        num = num + 1
                                pre_child_num.append(num)
                    except Exception as e:
                        pass
            # 父节点的个数 + 子节点的个数 为树节点的个数
            # print(len(pre_child_num) )
            child_Node_count.append(pre_child_num)
        except javalang.parser.JavaSyntaxError:
            continue 
    
    df['Child_Node_count'] = child_Node_count

    return df
cleaned_test_df_ast_after_get_child = get_Child_Node_count(cleaned_test_df_ast)
cleaned_test_df_ast_after_get_child.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  AST_level  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...          8
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...          7
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...         13
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...          5
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...         10
#
#                                         AST_BFSnodes  \
# 0  [MethodDeclaration, private, static, Reference...
# 1  [MethodDeclaration, public, BasicType, areInse...
# 2  [MethodDeclaration, private, BasicType, marsha...
# 3  [MethodDeclaration, static, public, ReferenceT...
# 4  [MethodDeclaration, static, ReferenceType, cre...
#
#                                         AST_PFSnodes  \
# 0  [MethodDeclaration, private, static, Reference...
# 1  [MethodDeclaration, public, BasicType, boolean...
# 2  [MethodDeclaration, private, BasicType, byte, ...
# 3  [MethodDeclaration, static, public, ReferenceT...
# 4  [MethodDeclaration, static, ReferenceType, Mon...
#
#                                     Child_Node_count
# 0  [7, 1, 2, 1, 2, 1, 1, 2, 3, 1, 1, 4, 1, 1, 1, ...
# 1               [4, 1, 1, 3, 3, 3, 2, 1, 3, 3, 2, 1]
# 2  [10, 2, 2, 1, 2, 2, 2, 2, 2, 1, 3, 1, 0, 1, 1,...
# 3                     [6, 2, 1, 1, 3, 1, 1, 4, 2, 0]
# 4  [6, 1, 3, 3, 1, 1, 1, 2, 1, 1, 3, 1, 1, 1, 3, ...

# %%
df_clean = cleaned_test_df_ast_after_get_child
df_clean.head()
# Out:
#                                               id  label comment_type  \
# 0             apache_calcite-896-FirstSentence-0      1      Summary
# 1   hibernate_hibernate_orm-1601-FirstSentence-0      0      Summary
# 2    apache_giraph-33-Associations-FirstSentence      1      Summary
# 3             apache_calcite-677-FirstSentence-0      0      Summary
# 4  apache_calcite-315-Associations-FirstSentence      1      Summary
#
#                                      old_comment_raw  \
# 0  Creates elastic node as single member of a clu...
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of to a JSONArra...
# 3  Returns a list of the types of the fields in a...
# 4  Create an instance based on current maven prof...
#
#                                old_comment_subtokens  \
# 0  [creates, elastic, node, as, single, member, o...
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, to, a, ...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [create, an, instance, based, on, current, mav...
#
#                                      new_comment_raw  \
# 0         Creates an instance with existing settings
# 1  Check whether any insertion or deletion action...
# 2  Marshal the aggregator values of the worker to...
# 3  Returns a list of the types of the fields in a...
# 4  Creates an instance based on current maven pro...
#
#                                new_comment_subtokens  \
# 0  [creates, an, instance, with, existing, settings]
# 1  [check, whether, any, insertion, or, deletion,...
# 2  [marshal, the, aggregator, values, of, the, wo...
# 3  [returns, a, list, of, the, types, of, the, fi...
# 4  [creates, an, instance, based, on, current, ma...
#
#                  span_minimal_diff_comment_subtokens  \
# 0  [<REPLACE_OLD>, elastic, node, as, single, mem...
# 1                                                 []
# 2  [<INSERT_OLD_KEEP_BEFORE>, of, <INSERT_NEW_KEE...
# 3                                                 []
# 4  [<REPLACE_OLD>, create, <REPLACE_NEW>, creates...
#
#                                         old_code_raw  \
# 0    public static EmbeddedElasticsearchNode crea...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private JSONArray marshalAggregatorValues(lo...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabaseRule create() {\n    fin...
#
#                                   old_code_subtokens  \
# 0  [public, static, embedded, elasticsearch, node...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, jsonarray, marshal, aggregator, valu...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, rule, create, (, ), ...
#
#                                         new_code_raw  \
# 0    private static EmbeddedElasticsearchNode cre...
# 1  \tpublic boolean areInsertionsOrDeletionsQueue...
# 2    private byte[] marshalAggregatorValues(long ...
# 3    public static List<RelDataType> getFieldType...
# 4    static MongoDatabasePolicy create() {\n    f...
#
#                                   new_code_subtokens  \
# 0  [private, static, embedded, elasticsearch, nod...
# 1  [public, boolean, are, insertions, or, deletio...
# 2  [private, byte, [, ], marshal, aggregator, val...
# 3  [public, static, list, <, rel, data, type, >, ...
# 4  [static, mongo, database, policy, create, (, )...
#
#                             span_diff_code_subtokens  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...
# 1  [<KEEP>, public, boolean, are, insertions, or,...
# 2  [<KEEP>, private, <KEEP_END>, <REPLACE_OLD>, j...
# 3  [<KEEP>, public, static, list, <, rel, data, t...
# 4  [<KEEP>, static, mongo, database, <KEEP_END>, ...
#
#                            token_diff_code_subtokens  AST_level  \
# 0  [<REPLACE_OLD>, public, <REPLACE_NEW>, private...          8
# 1  [<KEEP>, public, <KEEP>, boolean, <KEEP>, are,...          7
# 2  [<KEEP>, private, <REPLACE_OLD>, jsonarray, <R...         13
# 3  [<KEEP>, public, <KEEP>, static, <KEEP>, list,...          5
# 4  [<KEEP>, static, <KEEP>, mongo, <KEEP>, databa...         10
#
#                                         AST_BFSnodes  \
# 0  [MethodDeclaration, private, static, Reference...
# 1  [MethodDeclaration, public, BasicType, areInse...
# 2  [MethodDeclaration, private, BasicType, marsha...
# 3  [MethodDeclaration, static, public, ReferenceT...
# 4  [MethodDeclaration, static, ReferenceType, cre...
#
#                                         AST_PFSnodes  \
# 0  [MethodDeclaration, private, static, Reference...
# 1  [MethodDeclaration, public, BasicType, boolean...
# 2  [MethodDeclaration, private, BasicType, byte, ...
# 3  [MethodDeclaration, static, public, ReferenceT...
# 4  [MethodDeclaration, static, ReferenceType, Mon...
#
#                                     Child_Node_count
# 0  [7, 1, 2, 1, 2, 1, 1, 2, 3, 1, 1, 4, 1, 1, 1, ...
# 1               [4, 1, 1, 3, 3, 3, 2, 1, 3, 3, 2, 1]
# 2  [10, 2, 2, 1, 2, 2, 2, 2, 2, 1, 3, 1, 0, 1, 1,...
# 3                     [6, 2, 1, 1, 3, 1, 1, 4, 2, 0]
# 4  [6, 1, 3, 3, 1, 1, 1, 2, 1, 1, 3, 1, 1, 1, 3, ...

# %%
len(df_clean)
# Out:
# 3944

# %% [markdown]
# 把数据写出到一个json中，便于挑数据

# %%
df_clean.to_json('data_CheckAST_df.json',orient='records')

# %%
# model = torch.load('save_GCBmodel.pt',map_location=torch.device('cuda:0'))
model = torch.load('D:/BERT_learing/CCDP/for_captum/save_model/save_GCBmodel.pt',map_location=torch.device('cpu'))

model.to(device)
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())  #输出为True，则安装无误
# Out:
# 2.3.1+cpu
# None
# False

# %%
device
# Out:
# device(type='cpu')

# %%
tokenizer = RobertaTokenizer.from_pretrained("D:/BERT_learing/code_comment_inconsistency_detection/graphcodebert")

# %%
model.roberta.embeddings
# Out:
# RobertaEmbeddings(
#   (word_embeddings): Embedding(50265, 768, padding_idx=1)
#   (position_embeddings): Embedding(514, 768, padding_idx=1)
#   (token_type_embeddings): Embedding(1, 768)
#   (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
model.roberta.encoder.layer[0]
# Out:
# RobertaLayer(
#   (attention): RobertaAttention(
#     (self): RobertaSelfAttention(
#       (query): Linear(in_features=768, out_features=768, bias=True)
#       (key): Linear(in_features=768, out_features=768, bias=True)
#       (value): Linear(in_features=768, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (output): RobertaSelfOutput(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (intermediate): RobertaIntermediate(
#     (dense): Linear(in_features=768, out_features=3072, bias=True)
#     (intermediate_act_fn): GELUActivation()
#   )
#   (output): RobertaOutput(
#     (dense): Linear(in_features=3072, out_features=768, bias=True)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
input_embeddings = model.get_input_embeddings()

# %%
# predict和squad_pos_forward_func可以合成一个
def predict(inputs, position_ids=None, attention_mask=None):
    output = model(inputs,
                   position_ids=position_ids,
                  attention_mask=attention_mask )
    
    prediction = output.logits
    prediction_1 = nn.functional.softmax(prediction, dim=1)
    prediction = prediction_1.max(1).values
    out = torch.argmax(prediction_1, dim=-1)
    # prediction：每个输入样本的最大预测概率。
    # out：预测的类别标签。
    # prediction_1：所有类别的预测概率。    
    return prediction,out,prediction_1

# %%
def squad_pos_forward_func(inputs,position_ids=None, attention_mask=None, position=0):
    pred ,_,_= predict(inputs,
                     position_ids=position_ids,
                   attention_mask=attention_mask)
    return pred

# %%
ref_token_id = tokenizer.pad_token_id # 0
sep_token_id = tokenizer.sep_token_id # 101
cls_token_id = tokenizer.cls_token_id # 102
ref_token_id,sep_token_id,cls_token_id
# Out:
# (1, 2, 0)

# %%
# 注意长度
def truncate(ids,len_tru = 512):
    return ids[:len_tru] if len(ids) > len_tru else ids

# %%
# 这是单个数据的处理方式，应该要想数据集应该怎么处理
def construct_input_ref_pair(comment,AST_type,  ref_token_id, sep_token_id, cls_token_id):
    comment = tokenizer.encode(comment, add_special_tokens=False,truncation=True,max_length=512)
    AST_type = tokenizer.encode(AST_type, add_special_tokens=False,truncation=True,max_length=512)
    # construct input token ids
    input_ids = [cls_token_id] + comment + [sep_token_id] + AST_type + [sep_token_id]

    # construct reference token ids 
    ref_input_ids = [cls_token_id] + [ref_token_id] * len(comment) + [sep_token_id] + \
        [ref_token_id] * len(AST_type) + [sep_token_id]
    input_ids = truncate(input_ids)
    ref_input_ids = truncate(ref_input_ids)
    return torch.tensor([input_ids], device=device), torch.tensor([ref_input_ids], device=device), len(comment)

def construct_input_ref_token_type_pair(input_ids, sep_ind=0):
    seq_len = input_ids.size(1)
    token_type_ids = torch.tensor([[0 if i <= sep_ind else 1 for i in range(seq_len)]], device=device)
    ref_token_type_ids = torch.zeros_like(token_type_ids, device=device)# * -1
    return token_type_ids, ref_token_type_ids

def construct_input_ref_pos_id_pair(input_ids):
    seq_length = input_ids.size(1)
    position_ids = torch.arange(seq_length, dtype=torch.long, device=device)
    # we could potentially also use random permutation with `torch.randperm(seq_length, device=device)`
    ref_position_ids = torch.zeros(seq_length, dtype=torch.long, device=device)

    position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
    ref_position_ids = ref_position_ids.unsqueeze(0).expand_as(input_ids)
    return position_ids, ref_position_ids

def construct_attention_mask(input_ids):
    return torch.ones_like(input_ids)

def construct_whole_bert_embeddings(input_ids, ref_input_ids, \
                                    token_type_ids=None, ref_token_type_ids=None, \
                                    position_ids=None, ref_position_ids=None):
    input_embeddings = model.roberta.embeddings(input_ids, token_type_ids=token_type_ids, position_ids=position_ids)
    ref_input_embeddings = model.roberta.embeddings(ref_input_ids, token_type_ids=ref_token_type_ids, position_ids=ref_position_ids)
    
    return input_embeddings, ref_input_embeddings

# %%
# 构建树，用于计算父节点归因值
class Node:
    def __init__(self, data):
        self.data = data
        self.children = []

def build_tree(attribution_num, child_num):
    # 初始化一个栈
    stack = []
    #  attribution_num [index]
    index = 0
    # 创建根节点并入栈
    root = Node(attribution_num[0])
    # 收集所有的父节点
    parents = [root]  
    
    stack.append((root, child_num[index]))
    index += 1
    # 遍历 attribution_num
    for i in range(1, len(attribution_num)):
        
        # 创建一个新的节点
        node = Node(attribution_num[i])
        
        # 如果栈顶的节点还有子节点的位置，那么将新的节点添加为栈顶节点的子节点
        if stack[-1][1] > 0 and attribution_num[i] != 0 :
            stack[-1][0].children.append(node)
            stack[-1] = (stack[-1][0], stack[-1][1] - 1)
            
        # 如果新的节点是一个父节点，那么将其压入栈中
        if attribution_num[i] == 0 and stack[-1][1] > 0 and index < len(child_num):
            
            stack[-1][0].children.append(node)
            stack[-1] = (stack[-1][0], stack[-1][1] - 1)
            
            parents.append(node)
            stack.append((node, child_num[index]))
            index += 1
            
        # 如果栈顶的节点没有子节点的位置了，那么将其从栈中移除
        while stack and stack[-1][1] == 0:
            stack.pop()
    return root,parents

# 计算父节点归因值 ，这个对，用这个
def calculate_parent_value(node):
    if node.children:
        node.data = sum(calculate_parent_value(child) for child in node.children)
    return node.data

# %%
# 前k个贡献最高的word 和 token_type 和 position
# return value为归因贡献值  indices为词对应的索引  top_tokens为 词或位置或token_type
def get_topk_attributed_tokens(attrs,all_token_t, k=5):
    values_max, indices_max = torch.topk(attrs, k)
    top_tokens_max = [all_token_t[idx] for idx in indices_max]
    values_min, indices_min = torch.topk(attrs, k, largest=False)
    top_tokens_min = [all_token_t[idx] for idx in indices_min] 
    
    return top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min

# %%
# list_t_1 = token
# list_t_2 = attribute

# list_t_1 为 已经转化token的单词， list_t_2 为 attribute
def get_ast_num(nodes,list_t_1,list_t_2):
    attr = []    
    for node in nodes:
        try:
            index = list_t_1.index(node)       
            del list_t_1[index]
            
            attr.append(list_t_2[index])
            del list_t_2[index]

        except Exception as e:
            attr.append(0)
    return nodes,attr

# %%
# 从 all_tokens 还原为 原单词 ，并且计算归因值
def get_restore_words(code,comment,input_ids,all_tokens,attribution_num):
    all_tokens_decode = tokenizer.decode(input_ids)
    len_all_tokens_decode = len(all_tokens_decode) + 4
    # 使用decode获得的序列，去掉分词之后的空格    例 ' a' -> 'a'
    all_tokens_clean = []
    for token in all_tokens:
        s_without_leading_space = token.lstrip()
        all_tokens_clean.append(s_without_leading_space)
#     print('all_tokens_clean:\n',all_tokens_clean)
#     print('all_tokens_clean:\n',len(all_tokens_clean))
    

    # 获得 code_comment_baseline
    code = tokenizer.encode(code, add_special_tokens=False,truncation=True,max_length=512)
    comment = tokenizer.encode(comment, add_special_tokens=False,truncation=True,max_length=512)
    code_decode = tokenizer.decode(code)
    comment_decode = tokenizer.decode(comment)
    code_comment_baseline = tokenizer.decode(tokenizer.cls_token_id) + ' '+ comment_decode + ' '+ tokenizer.decode(tokenizer.sep_token_id) + ' ' + code_decode + ' ' + tokenizer.decode(tokenizer.sep_token_id)
    code_comment_baseline = code_comment_baseline[:len_all_tokens_decode]
    code_comment_baseline = split_punctuation(code_comment_baseline)
    code_comment_baseline = code_comment_baseline.split()

#     print('code_comment_baseline:\n',code_comment_baseline)
#     print('code_comment_baseline_len:\n',len(code_comment_baseline))

    
    # 获得 相邻有几个token合并在一块的列表times  为了以后再计算attribute时求和
    times = []
    token_index = 0
    for code_comment in code_comment_baseline:
        temp = ''
        time = 0
        while temp != code_comment:
            temp = temp + all_tokens_clean[token_index]
            token_index = token_index + 1
            time = time + 1
        times.append(time)
#     print('times:\n',times)
    
    attribute_sum = []
    start = 0
    for time in times:
        end = start + time
        attribute = sum(attribution_num[start:end])
        attribute_sum.append(attribute)
        start = end
#     print('attribute_sum:\n',attribute_sum)
    return code_comment_baseline ,attribute_sum

# %%
from captum.attr import LayerIntegratedGradients
from captum.attr import visualization as viz

lig = LayerIntegratedGradients(squad_pos_forward_func,input_embeddings)

vis_data_records_ig = []

def interpret_sentence(code,comment,PFS,child_num,input_ids,ref_input_ids, token_type_ids, \
                       position_ids, attention_mask, all_tokens, ground_lable,vis_data_records):
    pre ,out,_ = predict(input_ids, \
                position_ids=position_ids,
                attention_mask=attention_mask)
    if out == 1:
        sen_type = 'pos'
    else:
        sen_type = 'nag'
    pre = pre.item()
    pre = "{:.3f}".format(pre)
    pre = float(pre) 
    pre ,sen_type
    
    attributions_ig, delta_ig = lig.attribute(input_ids, baselines=ref_input_ids,\
                           additional_forward_args=(position_ids,attention_mask,0),return_convergence_delta=True,internal_batch_size=8)
    
    attributions = attributions_ig.sum(dim=2).squeeze(0)
    attributions = attributions / torch.norm(attributions)

    all_tokens ,attributions = get_restore_words(code,comment,input_ids[0],all_tokens,attributions)     # 合并为一个单词
    attributions = torch.tensor(attributions)
#     print(all_tokens)

    add_attributions_to_visualizer(attributions, all_tokens, pre, ground_lable, sen_type, delta_ig, vis_data_records)

    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min = get_topk_attributed_tokens(attributions,all_tokens)
    attributions_copy = attributions.tolist()
    all_tokens_copy = all_tokens
    nodes,attr = get_ast_num(PFS,all_tokens_copy,attributions_copy)  
#     print(len(nodes),len(attr))  # nodes为AST节点，attr为归因值
    attr = [round(num, 5) for num in attr]

    root,parents = build_tree(attr, child_num)
    parent_values = []
    calculate_parent_value(root)
    # 返回所有父节点的值
    parent_values = [node.data for node in parents]
    
    # 找到parent_value对应的字符，例如 MethodDeclaration：320
    parent_node_name = [nodes[i] for i in range(len(nodes)) if attr[i] == 0]

    return top_tokens_max, values_max, indices_max,top_tokens_min,values_min,indices_min, nodes,attr,parent_node_name,parent_values

def add_attributions_to_visualizer(attributions, all_tokens, pre, ground_lable, sen_type, delta, vis_data_records):

    # storing couple samples in an array for visualization purposes
    vis_data_records.append(viz.VisualizationDataRecord(
                            attributions,
                            pre,
                            pre,
                            ground_lable,
                            sen_type,
                            attributions.sum(),
                            all_tokens,
                            delta))

# %%
def interpret_sentence_2(code,comment,PFS,child_num,input_ids,ref_input_ids, token_type_ids,\
                         position_ids, attention_mask, all_tokens, ground_lable,vis_data_records):
    pre ,out,_ = predict(input_ids, position_ids=position_ids, attention_mask=attention_mask)
    if out == 1:
        sen_type = 'pos'
    else:
        sen_type = 'nag'
    pre = pre.item()
    pre = "{:.3f}".format(pre)
    pre = float(pre) 
    pre ,sen_type
    
    attributions_ig, delta_ig = lig.attribute(input_ids, baselines=ref_input_ids,\
                           additional_forward_args=(position_ids,attention_mask,0),return_convergence_delta=True,internal_batch_size=8)
    
    attributions = attributions_ig.sum(dim=2).squeeze(0)
    attributions = attributions / torch.norm(attributions)
#     print(delta_ig)
#     print(attributions)
    try:
        all_tokens ,attributions = get_restore_words(code,comment,input_ids[0],all_tokens,attributions)     # 合并为一个单词
        attributions = torch.tensor(attributions)
#         print(all_tokens)
        add_attributions_to_visualizer(attributions, all_tokens, pre, ground_lable, sen_type, delta_ig, vis_data_records)

        top_tokens_max, values_max, indices_max,top_tokens_min,\
        values_min,indices_min = get_topk_attributed_tokens(attributions,all_tokens)
        
        attributions_copy = attributions.tolist()
        all_tokens_copy = all_tokens

        nodes,attr = get_ast_num(PFS,all_tokens_copy,attributions_copy)
        # 保留5为小数
        attr = [round(num.item(), 5) for num in attr]    # 一部分数据没有变为5位小数，试着用一下item()能不能把所有都变为五位小数
        
        root,parents = build_tree(attr, child_num)
        parent_values = []
        calculate_parent_value(root)
        # 返回所有父节点的值
        parent_values = [node.data for node in parents]

        # 找到parent_value对应的字符，例如 MethodDeclaration：320
        parent_node_name = [nodes[i] for i in range(len(nodes)) if attr[i] == 0]
        
        return top_tokens_max, values_max, indices_max,top_tokens_min,values_min,\
               indices_min,nodes,attr,parent_node_name,parent_values
    except Exception as e:
        print("解析错误")
        return _, _, _,_,_,_,_,_,_,_

def add_attributions_to_visualizer(attributions, all_tokens, pre, ground_lable, sen_type, delta, vis_data_records):

    # storing couple samples in an array for visualization purposes
    vis_data_records.append(viz.VisualizationDataRecord(
                            attributions,
                            pre,
                            pre,
                            ground_lable,
                            sen_type,
                            attributions.sum(),
                            all_tokens,
                            delta))

# %%
def get_input_list_for_model(df,num,count=20):
    AST_list = []
    comment_list = []
    PFS_list = []
    child_num_list = []
    ground_lable = []
    index = []
    for i in range(num, num + count):
        # 对行数进行统计分析  , 暂定为 3  或6 行
        if df.loc[i,'line_counts'] > 5:
            index.append(i)
            code_list.append(df.loc[i,'new_code_raw'])
            comment_list.append(df.loc[i,'old_comment_raw'])
            PFS_list.append(df.loc[i,'AST_PFSnodes'])    
            child_num_list.append(df.loc[i,'Child_Node_count'])    
            ground_lable.append(df.loc[i,'label'])

    return AST_list,comment_list,PFS_list,child_num_list,ground_lable,index
AST_list,comment_list,PFS_list,child_num_list,ground_lable,index = get_input_list_for_model(df_clean,0)

# %%
AST_list = []
for i in range(10): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])

comment_list = []
for i in range(10): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])
    
PFS_list = []
for i in range(10): 
    PFS_list.append(df_clean.loc[i,'AST_PFSnodes'])

child_num_list = []
for i in range(10): 
    child_num_list.append(df_clean.loc[i,'Child_Node_count'])
    
ground_lable = []
for i in range(10): 
    ground_lable.append(df_clean.loc[i,'label'])

print(AST_list[2])
print(comment_list[2])
print(ground_lable[2])

def input_data_list(AST_list,comment_list):
    input_ids_all = []
    ref_input_ids_all = []
    position_ids_all = []
    attention_mask_all = []
    token_type_ids_all = []
    all_tokens_all = []
    for i in range(len(AST_list)):
        input_ids, ref_input_ids, comment_len = construct_input_ref_pair(comment_list[i],AST_list[i], ref_token_id, \
                                                                         sep_token_id, cls_token_id)
        token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, comment_len)
        position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
        attention_mask = construct_attention_mask(input_ids)
        
        indices = input_ids[0].detach().tolist()
        
        all_tokens = []                                       ###
        for _, token in enumerate(indices):
            all_tokens.append(tokenizer.decode([token]))
        
        input_ids_all.append(input_ids)
        ref_input_ids_all.append(ref_input_ids)
        position_ids_all.append(position_ids)
        attention_mask_all.append(attention_mask)
        token_type_ids_all.append(token_type_ids)
        all_tokens_all.append(all_tokens)

    return input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,token_type_ids_all,all_tokens_all
# Out:
#   private byte[] marshalAggregatorValues(long superstep) {
#     if (superstep == INPUT_SUPERSTEP) {
#       return new byte[0];
#     }
#
#     ByteArrayOutputStream outputStream = new ByteArrayOutputStream();
#     DataOutputStream output = new DataOutputStream(outputStream);
#     for (Entry<String, AggregatorWrapper<Writable>> entry :
#         getAggregatorMap().entrySet()) {
#       if (entry.getValue().isChanged()) {
#         try {
#           output.writeUTF(entry.getKey());
#           entry.getValue().getCurrentAggregatedValue().write(output);
#         } catch (IOException e) {
#           throw new IllegalStateException("Failed to marshall aggregator " +
#               "with IOException " + entry.getKey(), e);
#         }
#       }
#     }
#
#     if (LOG.isInfoEnabled()) {
#       LOG.info(
#           "marshalAggregatorValues: Finished assembling aggregator values");
#     }
#     return outputStream.toByteArray();
#   }
#
#
# Marshal the aggregator values of to a JSONArray that will later be aggregated by master.
# 1

# %%
input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,\
token_type_ids_all,all_tokens_all= input_data_list(AST_list,comment_list)
# print(input_ids_all[1])
# print(ref_input_ids_all[1])
# print(input_ids_all[1])

# %%
vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,\
    indices_min,nodes,attr,parent_node_name,parent_values \
    = interpret_sentence_2(AST_list[i],comment_list[i],PFS_list[i],child_num_list[i],input_ids_all[i],\
                           ref_input_ids_all[i], token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], \
                           all_tokens_all[i], ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
    {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_PFS_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的先序遍历序列 和 归因贡献值 \n{nodes}\n, {attr}\n')
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_parent_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的父节点 和 归因贡献值 \n{parent_node_name}\n, {parent_values}\n')
# Out:
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['</s>', 'node', 'as', 'Creates', '}']
# , tensor([0.5144, 0.5053, 0.3350, 0.2292, 0.2088], dtype=torch.float64)
# , tensor([60,  3,  4,  1, 59])
# ,[',', '//', '.', '.', 'EmbeddedElasticsearchNode']
# ,tensor([-0.1592, -0.1212, -0.0780, -0.0716, -0.0704], dtype=torch.float64)
# ,tensor([48, 21, 46, 42, 14])
#
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', ');', 'isEmpty', '}', '.']
# , tensor([0.3312, 0.2676, 0.2267, 0.1973, 0.1785], dtype=torch.float64)
# , tensor([13, 38, 29, 39, 11])
# ,['currently', 'are', 'unresolvedInsertions', 'queued', 'deletion']
# ,tensor([-0.4641, -0.3795, -0.3676, -0.1887, -0.1276], dtype=torch.float64)
# ,tensor([ 9,  8, 27, 10,  6])
#
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['"', '}', '}', '}', '}']
# , tensor([0.3687, 0.1585, 0.1559, 0.1277, 0.1078], dtype=torch.float64)
# , tensor([145, 159, 133, 131, 153])
# ,['JSONArray', 'aggregator', 'to', 'that', 'a']
# ,tensor([-0.6067, -0.3445, -0.3417, -0.2660, -0.2607], dtype=torch.float64)
# ,tensor([8, 3, 6, 9, 7])
#
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     [');', ')', '}', 'Returns', '{']
# , tensor([0.2908, 0.2840, 0.2771, 0.2655, 0.2601], dtype=torch.float64)
# , tensor([42, 28, 43,  1, 29])
# ,['of', 'types', 'fields', 'of', 'transform']
# ,tensor([-0.5202, -0.3841, -0.2053, -0.1404, -0.1075], dtype=torch.float64)
# ,tensor([ 4,  6,  9,  7, 33])
#
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['-', 'MongoAssertions', 'instance', 'profile', 'MongoDatabasePolicy']
# , tensor([0.3418, 0.2648, 0.2589, 0.1711, 0.1462], dtype=torch.float64)
# , tensor([13, 52,  3,  8, 18])
# ,['maven', 'Pit', 'on', 'final', '{']
# ,tensor([-0.7654, -0.6907, -0.1489, -0.1350, -0.0532], dtype=torch.float64)
# ,tensor([ 7, 14,  5, 22, 21])
#
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['ceDataAttribute', 'Struct', 'return', 'public', 'attribute']
# , tensor([0.7696, 0.4876, 0.3402, 0.2908, 0.2736], dtype=torch.float64)
# , tensor([14, 13, 17, 12,  7])
# ,['of', 'value', '<s>', '</s>', '</s>']
# ,tensor([-0.0818, -0.0782,  0.0000,  0.0000,  0.0007], dtype=torch.float64)
# ,tensor([ 8,  3,  0, 11, 23])
#
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'public', 'getSinkFile', 'Returns', '</s>']
# , tensor([0.5785, 0.3495, 0.2830, 0.2577, 0.2400], dtype=torch.float64)
# , tensor([ 8,  3,  5,  1, 14])
# ,['}', 'file', '<s>', '</s>', 'File']
# ,tensor([-0.8578, -0.2451,  0.0000,  0.0000,  0.0409], dtype=torch.float64)
# ,tensor([13, 11,  0,  2,  4])
#
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['This', 'return', 'txtPattern', 'method', 'ZapTextField']
# , tensor([0.8433, 0.2549, 0.2215, 0.2109, 0.1607], dtype=torch.float64)
# , tensor([ 1, 24,  4,  2,  7])
# ,['();', 'public', 'getTxtPattern', '(', 'txtPattern']
# ,tensor([-0.0498, -0.0497, -0.0474, -0.0270, -0.0265], dtype=torch.float64)
# ,tensor([22,  6,  8, 12, 13])
#
# 解析错误
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[2.5423e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[2.5423e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[2.5423e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.5423e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.5423e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.5423e-05, 9.9997e-01]], grad_fn=<SoftmaxBackward0>)
#
# 解析错误
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.4156e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4156e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4156e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4156e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4156e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4156e-05]], grad_fn=<SoftmaxBackward0>)

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>nag</b></text></td><td><text style="padding-right:2em"><b>2.70</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> Creates                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> elastic                    </font></mark><mark style="background-color: hsl(120, 75%, 75%); opacity:1.0;                     line-height:1.75"><font color="black"> as                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> single                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> member                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> cluster                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> .                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> (                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> )                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> {                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> //                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ensure                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> is                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> installed                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1. ...

# %%
# 理解了代码和注释的语义，但是由于缺少上下文 导致预测结果出错
# 可以使用
df_clean.loc[9]
# Out:
# id                                     OpenAPITools_openapi_generator-2184-FirstSente...
# label                                                                                  0
# comment_type                                                                     Summary
# old_comment_raw                                      Return the name of the oneOf schema
# old_comment_subtokens                      [return, the, name, of, the, one, of, schema]
# new_comment_raw                                      Return the name of the oneOf schema
# new_comment_subtokens                      [return, the, name, of, the, one, of, schema]
# span_minimal_diff_comment_subtokens                                                   []
# old_code_raw                               public String toOneOfName(List<String> nam...
# old_code_subtokens                     [public, string, to, one, of, name, (, list, <...
# new_code_raw                               public String toOneOfName(List<String> nam...
# new_code_subtokens                     [public, string, to, one, of, name, (, list, <...
# span_diff_code_subtokens               [<KEEP>, public, string, to, one, of, name, (,...
# token_diff_code_subtokens              [<KEEP>, public, <KEEP>, string, <KEEP>, to, <...
# AST_level                                                                              8
# AST_BFSnodes                           [MethodDeclaration, public, ReferenceType, toO...
# AST_PFSnodes                           [MethodDeclaration, public, ReferenceType, Str...
# Child_Node_count                       [8, 1, 2, 2, 2, 1, 1, 1, 2, 2, 1, 3, 1, 1, 1, ...
# Name: 9, dtype: object

# %%
AST_list = []
for i in range(10,30): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])

comment_list = []
for i in range(10,30): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])

PFS_list = []
for i in range(10,30): 
    PFS_list.append(df_clean.loc[i,'AST_PFSnodes'])

child_num_list = []
for i in range(10,30): 
    child_num_list.append(df_clean.loc[i,'Child_Node_count'])
ground_lable = []
for i in range(10,30): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,\
token_type_ids_all,all_tokens_all= input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,\
    indices_min,nodes,attr,parent_node_name,parent_values \
    = interpret_sentence_2(AST_list[i],comment_list[i],PFS_list[i],child_num_list[i],input_ids_all[i],\
                           ref_input_ids_all[i], token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], \
                           all_tokens_all[i], ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
    {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_PFS_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的先序遍历序列 和 归因贡献值 \n{nodes}\n, {attr}\n')
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_parent_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的父节点 和 归因贡献值 \n{parent_node_name}\n, {parent_values}\n')
# Out:
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Returns', 'same', 'bound', 'return', 'and']
# , tensor([0.4571, 0.3224, 0.3072, 0.2825, 0.2677], dtype=torch.float64)
# , tensor([ 1,  9,  6, 43, 17])
# ,['ISO', '3166', 'as', 'boundedByIso3166Code', 'are']
# ,tensor([-0.2619, -0.1956, -0.1707, -0.1657, -0.1283], dtype=torch.float64)
# ,tensor([14, 15, 11, 30,  5])
#
# 解析错误
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0851e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['if', '(!', 'public', 'views', ')']
# , tensor([0.7519, 0.3925, 0.2077, 0.0821, 0.0811], dtype=torch.float64)
# , tensor([13, 14,  8,  3, 16])
# ,['fMirroringEnabled', 'mirrored', 'isMirrored', 'MIRRORED', 'return']
# ,tensor([-0.7003, -0.3492, -0.2411, -0.2258, -0.1898], dtype=torch.float64)
# ,tensor([15,  5, 10, 25, 27])
#
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['kylin', 'return', 'public', '"));', 'valueOf']
# , tensor([0.5149, 0.4341, 0.4069, 0.3236, 0.2947], dtype=torch.float64)
# , tensor([21, 14,  9, 33, 17])
# ,['GB', 'getKylinHBaseRegionCut', 'HBase', ',', 'region']
# ,tensor([-0.3601, -0.1820, -0.1782, -0.0656, -0.0384], dtype=torch.float64)
# ,tensor([ 7, 11,  1,  5,  2])
#
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Ravioli', 'Lob', 'Lob', 'build', 'client']
# , tensor([0.4121, 0.3317, 0.2362, 0.2067, 0.1617], dtype=torch.float64)
# , tensor([ 3, 13,  7,  8,  4])
# ,['Build', 'return', '}', '()', 'a']
# ,tensor([-0.6778, -0.4261, -0.1896, -0.0367, -0.0339], dtype=torch.float64)
# ,tensor([ 1, 11, 17,  9,  2])
#
# 解析错误
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9990e-01, 1.0221e-04]], grad_fn=<SoftmaxBackward0>)
#
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['SecurityContext', 'SecurityContext', 'and', 'templateName', 'ViewableWithPermissions']
# , tensor([0.6211, 0.6207, 0.2363, 0.1886, 0.1429], dtype=torch.float64)
# , tensor([10, 30, 11, 40, 36])
# ,['using', 'given', 'Viewable', 'the', 'final']
# ,tensor([-0.2963, -0.2077, -0.2008, -0.1010, -0.0899], dtype=torch.float64)
# ,tensor([ 5,  7, 18,  6, 25])
#
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['sprite', 'from', 'makes', 'transparent', 'stackable']
# , tensor([0.5283, 0.4187, 0.3333, 0.3172, 0.2685], dtype=torch.float64)
# , tensor([ 3,  4,  7,  8, 51])
# ,['BufferedImage', '_', 'itemId', 'sprite', '(']
# ,tensor([-0.2442, -0.0991, -0.0978, -0.0720, -0.0512], dtype=torch.float64)
# ,tensor([15, 48, 19, 29, 17])
#
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['for', 'type', 'WSDL', 'the', 'element']
# , tensor([0.5590, 0.2954, 0.2341, 0.2320, 0.2194], dtype=torch.float64)
# , tensor([ 4,  7, 17,  5, 14])
# ,['insertion', 'if', 'generate', 'WSDL', 'Return']
# ,tensor([-0.5346, -0.2367, -0.2060, -0.1350, -0.1196], dtype=torch.float64)
# ,tensor([ 11, 200,  38,  39,   1])
#
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['AsyncSupport', 'AtmosphereConfig', 'instance', '.', 'something']
# , tensor([0.3617, 0.2022, 0.1927, 0.1718, 0.1639], dtype=torch.float64)
# , tensor([38, 47, 15, 51,  5])
# ,['extends', 'AsyncSupport', 'newCometSupport', 'a', 'final']
# ,tensor([-0.7854, -0.0843, -0.0634, -0.0498, -0.0254], dtype=torch.float64)
# ,tensor([ 7, 22, 23,  2, 25])
#
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'mSelectedTopics', '&&', 'return', 'boolean']
# , tensor([1.0610, 0.7363, 0.1328, 0.1089, 0.1079], dtype=torch.float64)
# , tensor([10, 27, 26, 21, 11])
# ,['to', 'String', 'String', 'tag', 'Add']
# ,tensor([-0.2543, -0.1911, -0.1056, -0.0821, -0.0707], dtype=torch.float64)
# ,tensor([ 4, 17, 14,  3,  1])
#
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Allow', 'directives', 'includeSchemaDefinition', 'public', '}']
# , tensor([0.6700, 0.5714, 0.3099, 0.3047, 0.2345], dtype=torch.float64)
# , tensor([ 1,  4, 33,  7, 51])
# ,['includeDirectives', 'to', ',', '(', 'Options']
# ,tensor([-0.1062, -0.0869, -0.0594, -0.0330, -0.0310], dtype=torch.float64)
# ,tensor([ 9,  2, 34, 10, 17])
#
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['context', ');', '}', 'static', 'String']
# , tensor([0.1472, 0.1310, 0.1090, 0.0919, 0.0691], dtype=torch.float64)
# , tensor([28, 46, 47, 22, 33])
# ,['ServletContext', 'public', 'KEY', '(', 'getAttribute']
# ,tensor([-0.4006, -0.2219, -0.1269, -0.1173, -0.0943], dtype=torch.float64)
# ,tensor([27, 21, 45, 26, 37])
#
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['writer', 'a', 'object', 'buildRepeatedList', 'returning']
# , tensor([0.3572, 0.3554, 0.2678, 0.1608, 0.1538], dtype=torch.float64)
# , tensor([ 4, 17, 19, 42, 11])
# ,['nested', ',', 'writer', 'buildColumn', 'writer']
# ,tensor([-0.4292, -0.3095, -0.2349, -0.1808, -0.1584], dtype=torch.float64)
# ,tensor([ 8,  5, 15, 25, 20])
#
# 解析错误
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# , tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# , tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.0061, 0.9939]], grad_fn=<SoftmaxBackward0>)
#
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['.', 'A', 'SimpleType', 'alternate', 'constrains']
# , tensor([1.4437, 0.1891, 0.1780, 0.1731, 0.1695], dtype=torch.float64)
# , tensor([211,   1, 200,   9, 148])
# ,['findDeclaration', '()', 'accepts', 'static', 'but']
# ,tensor([-0.6633, -0.4761, -0.3732, -0.2526, -0.2243], dtype=torch.float64)
# ,tensor([ 4,  5,  7, 14,  6])
#
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['the', 'the', 'keeping', 'the', 'lockPath']
# , tensor([0.6909, 0.3591, 0.3551, 0.2327, 0.1746], dtype=torch.float64)
# , tensor([ 5,  9,  8, 12, 36])
# ,['lockClient', 'Returns', ',', 'return', 'lock']
# ,tensor([-0.1936, -0.1583, -0.1417, -0.1371, -0.1328], dtype=torch.float64)
# ,tensor([  6,   1,   4, 104,  10])
#
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'public', 'in', 'getDifferenceAsLong', '}']
# , tensor([0.3578, 0.2169, 0.1277, 0.1252, 0.1153], dtype=torch.float64)
# , tensor([38, 23, 15, 41, 61])
# ,['units', 'instant', 'getDifferenceAsLong', 'the', 'property']
# ,tensor([-0.7685, -0.4177, -0.2992, -0.1823, -0.1470], dtype=torch.float64)
# ,tensor([17, 33, 25, 16,  7])
#
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['from', 'channel', 'resource', 'this', 'the']
# , tensor([0.4935, 0.4718, 0.4108, 0.3161, 0.1858], dtype=torch.float64)
# , tensor([4, 6, 3, 5, 2])
# ,['public', '.', 'return', '}', '}']
# ,tensor([-0.3021, -0.1858, -0.1529, -0.1263, -0.1058], dtype=torch.float64)
# ,tensor([13, 11, 92, 95, 39])
#
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['ASG', 'periodically', 'the', 'task', 'updates']
# , tensor([0.9776, 0.3504, 0.3423, 0.2238, 0.0847], dtype=torch.float64)
# , tensor([7, 9, 6, 3, 5])
# ,['asgCache', 'shouldUseAwsAsgApi', 'that', 'return', '//']
# ,tensor([-0.4610, -0.2997, -0.2451, -0.2126, -0.1997], dtype=torch.float64)
# ,tensor([103,  35,   4,  48,  38])

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>nag</b></text></td><td><text style="padding-right:2em"><b>3.12</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(120, 75%, 78%); opacity:1.0;                     line-height:1.75"><font color="black"> Returns                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> providers                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> that                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> are                    </font></mark><mark style="background-color: hsl(120, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> bound                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> to                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> same                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> location                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> as                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> given                    </font></mark><mark style="background-color: hsl(0, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> ISO                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> 3166                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> code                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height: ...

# %%
len(vis_data_records_ig)
# Out:
# 17

# %%
AST_list = []
for i in range(30,60): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])

comment_list = []
for i in range(30,60): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])
    
PFS_list = []
for i in range(30,60): 
    PFS_list.append(df_clean.loc[i,'AST_PFSnodes'])
child_num_list = []
for i in range(30,60): 
    child_num_list.append(df_clean.loc[i,'Child_Node_count'])   
ground_lable = []
for i in range(30,60): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,\
token_type_ids_all,all_tokens_all= input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,\
    indices_min,nodes,attr,parent_node_name,parent_values \
    = interpret_sentence_2(AST_list[i],comment_list[i],PFS_list[i],child_num_list[i],input_ids_all[i],\
                           ref_input_ids_all[i], token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], \
                           all_tokens_all[i], ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
    {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_PFS_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的先序遍历序列 和 归因贡献值 \n{nodes}\n, {attr}\n')
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_parent_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的父节点 和 归因贡献值 \n{parent_node_name}\n, {parent_values}\n')
# Out:
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['flagsToCheck', 'flagsToCheck', 'flags', '(', 'isFlagSet']
# , tensor([0.1986, 0.1742, 0.1431, 0.1390, 0.1232], dtype=torch.float64)
# , tensor([21, 14, 19, 18, 11])
# ,['public', 'return', 'int', '}', 'boolean']
# ,tensor([-1.2209, -0.4367, -0.3293, -0.3055, -0.2012], dtype=torch.float64)
# ,tensor([ 9, 17, 13, 25, 10])
#
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['TimeUnit', '60', 'configuration', 'configuration', 'or']
# , tensor([0.5300, 0.4342, 0.2597, 0.1384, 0.0394], dtype=torch.float64)
# , tensor([95, 93, 89, 85, 40])
# ,['Client', '()', 'instance', '"', 'public']
# ,tensor([-0.6236, -0.4888, -0.4465, -0.4456, -0.4120], dtype=torch.float64)
# ,tensor([ 3, 10,  4, 44,  7])
#
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['IType', 'IASTName', 'an', 'static', 'createType']
# , tensor([0.4009, 0.3172, 0.2641, 0.1782, 0.1670], dtype=torch.float64)
# , tensor([11,  6,  5, 10, 12])
# ,['while', 'IASTNode', 'IASTDeclarator', '.', 'IASTDeclSpecifier']
# ,tensor([-0.1689, -0.1660, -0.1605, -0.1357, -0.1344], dtype=torch.float64)
# ,tensor([30, 23, 34,  7, 18])
#
# 解析错误
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0814e-05]], grad_fn=<SoftmaxBackward0>)
#
# 解析错误
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[1.0520e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0520e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0520e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0520e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0520e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0520e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
#
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Constructs', 'PTBTokenizer', 'that', 'public', ')']
# , tensor([0.6486, 0.4316, 0.2584, 0.2279, 0.1599], dtype=torch.float64)
# , tensor([ 1,  4,  5, 11, 27])
# ,['PTBTokenizer', 'false', 'boolean', ',', ',']
# ,tensor([-0.1025, -0.0714, -0.0592, -0.0479, -0.0454], dtype=torch.float64)
# ,tensor([31, 39, 25, 40, 38])
#
# 解析错误
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0701e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'ENDSWITH', 'right', 'left', 'public']
# , tensor([0.5625, 0.4741, 0.4696, 0.4616, 0.4534], dtype=torch.float64)
# , tensor([25, 32,  7,  3, 10])
# ,['endsWith', 'factory', 'Expr', 'right', '.']
# ,tensor([-0.3600, -0.1342, -0.1227, -0.0858, -0.0796], dtype=torch.float64)
# ,tensor([ 5, 26,  1, 40,  4])
#
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['ZapTextArea', 'private', 'txtSkipURL', 'null', 'getWmUiHandlingOption']
# , tensor([0.3467, 0.2106, 0.0414, 0.0400, 0.0340], dtype=torch.float64)
# , tensor([21,  6, 62, 15, 56])
# ,['jTextArea', 'initializes', 'getSingleton', 'ZapTextArea', 'txtSkipURL']
# ,tensor([-0.6774, -0.3844, -0.3510, -0.3387, -0.2275], dtype=torch.float64)
# ,tensor([ 4,  3, 50,  7, 23])
#
# 解析错误
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[4.4367e-05, 9.9996e-01]], grad_fn=<SoftmaxBackward0>)
#
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['ColumnUniqueness', 'rel', '</s>', 'return', 'if']
# , tensor([0.8563, 0.2316, 0.1867, 0.1643, 0.1495], dtype=torch.float64)
# , tensor([41, 35, 55, 45,  2])
# ,['ColumnUniqueness', 'columns', 'specified', 'relational', 'set']
# ,tensor([-0.1686, -0.1375, -0.0837, -0.0733, -0.0531], dtype=torch.float64)
# ,tensor([32,  7,  4, 11,  5])
#
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['}', 'public', 'Observable', '</s>', 'DEFAULT']
# , tensor([0.4639, 0.3968, 0.3603, 0.3176, 0.2045], dtype=torch.float64)
# , tensor([70, 11, 13, 71, 57])
# ,['observeInternetConnectivity', 'observeInternetConnectivity', 'default', 'Boolean', 'settings']
# ,tensor([-0.6661, -0.3416, -0.1942, -0.1924, -0.1024], dtype=torch.float64)
# ,tensor([21, 17,  7, 15,  8])
#
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['left', 'public', 'right', 'endsWith', '(']
# , tensor([0.4439, 0.4136, 0.2750, 0.2489, 0.2360], dtype=torch.float64)
# , tensor([ 3, 14,  7,  5,  6])
# ,['.', 'Expr', '}', 'EBoolean', 'Expr']
# ,tensor([-0.4454, -0.4323, -0.2651, -0.1143, -0.0645], dtype=torch.float64)
# ,tensor([41,  1, 46, 16, 19])
#
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['that', 'RelNode', 'correlated', 'safe', 'safe']
# , tensor([0.3787, 0.3721, 0.3138, 0.2657, 0.2650], dtype=torch.float64)
# , tensor([ 4, 17,  9, 21, 40])
# ,['ImmutableSortedMap', 'tree', '&&', 'a', 'variables']
# ,tensor([-0.2826, -0.2792, -0.2205, -0.1562, -0.1361], dtype=torch.float64)
# ,tensor([51,  3, 39,  6, 10])
#
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['variable', 'add', '-', 'arguments', '...)']
# , tensor([0.2750, 0.1325, 0.1157, 0.0922, 0.0820], dtype=torch.float64)
# , tensor([10,  3, 11, 13,  6])
# ,['RowSetBuilder', 'addRow', 'addSingleCol', 'uses', 'method']
# ,tensor([-0.6628, -0.4737, -0.4329, -0.2885, -0.2685], dtype=torch.float64)
# ,tensor([23, 31, 24,  8,  7])
#
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['</s>', 'Clone', 'return', 'JPAQuery', 'EntityManager']
# , tensor([0.3880, 0.3852, 0.3681, 0.3481, 0.3058], dtype=torch.float64)
# , tensor([40,  1, 24, 26, 15])
# ,['state', 'to', 'query', 'clone', '<s>']
# ,tensor([-0.4289, -0.0487, -0.0334, -0.0033,  0.0000], dtype=torch.float64)
# ,tensor([ 3,  7,  6, 19,  0])
#
# 解析错误
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[2.7687e-04, 9.9972e-01]], grad_fn=<SoftmaxBackward0>)
#
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Retrieve', 'fetch', ');', 'subselectsByEntityKey', '.']
# , tensor([0.9182, 0.2320, 0.1413, 0.1263, 0.0647], dtype=torch.float64)
# , tensor([ 1,  3, 27, 22, 11])
# ,['getSubselect', 'descriptor', '(', 'SubselectFetch', 'public']
# ,tensor([-0.1054, -0.0460, -0.0451, -0.0347, -0.0298], dtype=torch.float64)
# ,tensor([15,  4, 16, 14, 13])
#
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['</s>', 'SafeHtml', ',', 'MenuItem', 'containing']
# , tensor([0.3604, 0.2906, 0.2116, 0.1859, 0.1474], dtype=torch.float64)
# , tensor([50,  9, 10, 41,  8])
# ,['item', 'MenuItem', 'asHTML', 'Command', 'cmd']
# ,tensor([-0.4040, -0.3371, -0.2391, -0.2121, -0.2099], dtype=torch.float64)
# ,tensor([ 4, 24, 45, 33, 34])
#
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     [',', 'statement', ');', 'appendIdentitySelectToInsert', '</s>']
# , tensor([0.1141, 0.0841, 0.0838, 0.0802, 0.0723], dtype=torch.float64)
# , tensor([ 5, 17, 34, 22, 36])
# ,['supportsInsertSelectIdentity', '#', 'getIdentityColumnSupport', 'return', 'String']
# ,tensor([-1.5098, -0.4313, -0.2764, -0.1305, -0.0839], dtype=torch.float64)
# ,tensor([ 4,  3, 29, 28, 21])
#
# 解析错误
# 第20个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.0504e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
#
# 第21个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'Boolean', 'given', 'return', 'validator']
# , tensor([0.3071, 0.2783, 0.1045, 0.1040, 0.0941], dtype=torch.float64)
# , tensor([23, 51, 18,  3, 57])
# ,['boolean', 'withDefault', 'with', 'instance', 'default']
# ,tensor([-0.6173, -0.5425, -0.2412, -0.2180, -0.2030], dtype=torch.float64)
# ,tensor([27, 25, 16,  7, 19])
# 解析错误
# 第22个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4017e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第23个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', '}', 'return', '.', ',']
# , tensor([0.6989, 0.3654, 0.2414, 0.1115, 0.0857], dtype=torch.float64)
# , tensor([ 8, 29, 18,  6, 14])
# ,['waitForView', 'waitForView', 'View', 'a', 'view']
# ,tensor([-0.3404, -0.3360, -0.2306, -0.1954, -0.1238], dtype=torch.float64)
# ,tensor([10, 19, 12,  3, 13])
#
# 第24个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['}', '</s>', '(', 'isFlagSet', 'flags']
# , tensor([0.2391, 0.2096, 0.2049, 0.2044, 0.1772], dtype=torch.float64)
# , tensor([24, 25, 19, 18, 20])
# ,['a', 'Checks', 'is', 'isFlagSet', ');']
# ,tensor([-0.4287, -0.4109, -0.3230, -0.2665, -0.1940], dtype=torch.float64)
# ,tensor([ 3,  1,  5, 11, 23])
#
# 第25个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['ONumber', '.', 'public', 'length', 'class']
# , tensor([0.3686, 0.1653, 0.0890, 0.0778, 0.0625], dtype=torch.float64)
# , tensor([25, 26,  8, 23, 31])
# ,['Ops', 'ENumber', 'String', ',', 'return']
# ,tensor([-0.3876, -0.2152, -0.1264, -0.1069, -0.0506], dtype=torch.float64)
# ,tensor([33,  9,  6, 32, 42])
#
# 第26个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'Specification', 'Query', 'of', 'fromJson']
# , tensor([0.6951, 0.5471, 0.3584, 0.2613, 0.2552], dtype=torch.float64)
# , tensor([11,  3, 23,  5, 28])
# ,['return', '}', 'Parses', 'a', 'GSON']
# ,tensor([-0.3489, -0.3094, -0.2589, -0.1860, -0.1278], dtype=torch.float64)
# ,tensor([42, 45,  1,  2, 26])
#
# 第27个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['startsWith', 'factory', 'createBoolean', 'String', 'left']
# , tensor([0.8412, 0.3318, 0.2754, 0.2649, 0.2048], dtype=torch.float64)
# , tensor([ 5, 29, 31, 23, 19])
# ,['STARTSWITH', 'Ops', 'startsWith', 'left', 'right']
# ,tensor([-0.3541, -0.2494, -0.1523, -0.1289, -0.1203], dtype=torch.float64)
# ,tensor([35, 33, 13,  3,  7])
#
# 第28个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Creates', '//', 'SQL', '"', '())']
# , tensor([0.2871, 0.2041, 0.1189, 0.1089, 0.0913], dtype=torch.float64)
# , tensor([ 1, 46, 10, 11, 36])
# ,['public', 'DBCompareColExpr', 'final', 'comparison', 'return']
# ,tensor([-0.6881, -0.6447, -0.4181, -0.2107, -0.2078], dtype=torch.float64)
# ,tensor([17, 19, 18,  6, 37])
#
# 第29个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['createAuthorizationUrlBuilder', 'return', 'String', 'build', 'getAuthorizationUrl']
# , tensor([0.9255, 0.5691, 0.4843, 0.3639, 0.2843], dtype=torch.float64)
# , tensor([22, 21, 17, 24, 18])
# ,['public', '{', '().', '</s>', 'redirect']
# ,tensor([-0.3733, -0.0826, -0.0388, -0.0253, -0.0241], dtype=torch.float64)
# ,tensor([16, 20, 23, 27,  7])

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>0.991 (0.99)</b></text></td><td><text style="padding-right:2em"><b>pos</b></text></td><td><text style="padding-right:2em"><b>-1.55</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> Checks                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> if                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> flag                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> is                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> set                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> .                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> (                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> )                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> {                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> return                    </font></mark><mark style="background-color: hsl(0, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> (                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> )!=                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ;                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> }                    </font></mark><mark style="background-color: hsl(0, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></t ...

# %%
AST_list = []
for i in range(60,100): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])

comment_list = []
for i in range(60,100): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])
PFS_list = []
for i in range(60,100): 
    PFS_list.append(df_clean.loc[i,'AST_PFSnodes'])
    
child_num_list = []
for i in range(60,100): 
    child_num_list.append(df_clean.loc[i,'Child_Node_count']) 

ground_lable = []
for i in range(60,100): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,\
token_type_ids_all,all_tokens_all= input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,\
    indices_min,nodes,attr,parent_node_name,parent_values \
    = interpret_sentence_2(AST_list[i],comment_list[i],PFS_list[i],child_num_list[i],input_ids_all[i],\
                           ref_input_ids_all[i], token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], \
                           all_tokens_all[i], ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
    {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_PFS_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的先序遍历序列 和 归因贡献值 \n{nodes}\n, {attr}\n')
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_parent_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的父节点 和 归因贡献值 \n{parent_node_name}\n, {parent_values}\n')
# Out:
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['using', 'return', '}', 'obj', '}']
# , tensor([0.6307, 0.5217, 0.3431, 0.2976, 0.2140], dtype=torch.float64)
# , tensor([ 5, 24, 78, 14, 38])
# ,['return', 'Method', 'Object', 'if', 'boolean']
# ,tensor([-0.2887, -0.2107, -0.1963, -0.1815, -0.1299], dtype=torch.float64)
# ,tensor([60,  1, 13, 17, 10])
#
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['sb', 'String', 'sz', 'currently', 'sz']
# , tensor([0.1728, 0.1040, 0.1018, 0.1007, 0.0857], dtype=torch.float64)
# , tensor([20, 47, 42,  3, 32])
# ,['form', 'sentences', 'displayed', 'getLabel', 'StringBuilder']
# ,tensor([-0.5463, -0.4750, -0.3753, -0.1557, -0.1067], dtype=torch.float64)
# ,tensor([12,  5,  4, 58, 19])
#
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['protected', 'checkmark', 'that', 'findNewest', '.']
# , tensor([0.8514, 0.6231, 0.3965, 0.1438, 0.1349], dtype=torch.float64)
# , tensor([11,  3,  4, 13, 50])
# ,['Returns', 'already', '}', '()', 'has']
# ,tensor([-0.1635, -0.1509, -0.1065, -0.1048, -0.0911], dtype=torch.float64)
# ,tensor([ 1,  6, 58, 14,  5])
#
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'DOCUMENT', 'getRobotFollow', 'handleHTML', 'getLinks']
# , tensor([0.8667, 0.6392, 0.3203, 0.2320, 0.2219], dtype=torch.float64)
# , tensor([ 5,  1, 34,  8, 42])
# ,['}', 'return', ';', 'IOException', 'HTMLHandler']
# ,tensor([-0.2687, -0.2036, -0.0877, -0.0797, -0.0795], dtype=torch.float64)
# ,tensor([51, 48, 50, 14, 20])
#
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['for', 'searcher', 'times', 'text', 'found']
# , tensor([0.5413, 0.4422, 0.2462, 0.1955, 0.1853], dtype=torch.float64)
# , tensor([ 2, 37, 19,  4, 14])
# ,['returns', 'true', 'return', 'searched', 'scroll']
# ,tensor([-0.3370, -0.2634, -0.1806, -0.1684, -0.1591], dtype=torch.float64)
# ,tensor([ 7,  8, 36, 11, 33])
#
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['sentences', 'sb', 'in', '((', 'sb']
# , tensor([0.4916, 0.3498, 0.3367, 0.2411, 0.2395], dtype=torch.float64)
# , tensor([ 5, 65,  6, 44, 59])
# ,['getMatchedSentences', '}', 'return', 'TreeFromFile', 'text']
# ,tensor([-0.6227, -0.4917, -0.2918, -0.2590, -0.1958], dtype=torch.float64)
# ,tensor([14, 74, 71, 45,  8])
#
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['TableExportButton', 'exportButton', 'This', 'return', '}']
# , tensor([0.2635, 0.1738, 0.1710, 0.1629, 0.1221], dtype=torch.float64)
# , tensor([ 7, 18,  1, 26, 25])
# ,['panelCommand', 'initializes', '()', 'getExportButton', '());']
# ,tensor([-0.4162, -0.3393, -0.1062, -0.0709, -0.0204], dtype=torch.float64)
# ,tensor([ 4,  3,  9,  8, 24])
#
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'if', 'OpenAPI', 'openAPI', 'if']
# , tensor([0.5089, 0.4355, 0.3846, 0.3254, 0.3014], dtype=torch.float64)
# , tensor([29, 41, 34, 74, 78])
# ,['openAPI', 'return', '</s>', '}', 'referencedSchema']
# ,tensor([-0.2309, -0.1884, -0.1730, -0.1275, -0.0626], dtype=torch.float64)
# ,tensor([35, 90, 94, 93, 80])
#
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['}', 'GridViews', 'the', '{', '<']
# , tensor([0.2963, 0.2390, 0.1082, 0.0970, 0.0570], dtype=torch.float64)
# , tensor([29,  6,  5, 21, 16])
# ,['getCurrentGridViews', 'Activity', 'contained', 'ArrayList', 'List']
# ,tensor([-0.5957, -0.4513, -0.2639, -0.2573, -0.2471], dtype=torch.float64)
# ,tensor([19, 11,  7, 15,  3])
#
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['false', 'return', ';', '))', '}']
# , tensor([0.4579, 0.2250, 0.1575, 0.1287, 0.1235], dtype=torch.float64)
# , tensor([188, 187, 189,  42, 190])
# ,['implementation', 'for', 'is', 'the', 'correct']
# ,tensor([-0.6713, -0.2657, -0.2599, -0.1477, -0.1172], dtype=torch.float64)
# ,tensor([4, 7, 5, 8, 3])
#
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['sessionsCopy', 'matching', 'synchronized', 'message', '<>(']
# , tensor([0.6441, 0.4484, 0.3436, 0.1596, 0.1528], dtype=torch.float64)
# , tensor([43,  3, 38,  9, 47])
# ,['http', 'Gets', 'getMatchingHttpSession', 'HttpCookie', 'for']
# ,tensor([-0.6129, -0.1848, -0.1839, -0.1790, -0.1694], dtype=torch.float64)
# ,tensor([ 4,  1, 19, 23,  6])
#
# 解析错误
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[1.9349e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.9349e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.9349e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.9349e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.9349e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.9349e-05, 9.9998e-01]], grad_fn=<SoftmaxBackward0>)
#
# 解析错误
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9998e-01, 2.0615e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Encodes', 'return', 'query', ');', 'a']
# , tensor([0.5517, 0.2487, 0.1619, 0.0729, 0.0704], dtype=torch.float64)
# , tensor([ 1, 29, 16, 35,  2])
# ,['toNTriplesString', 'canonical', 'a', 'a', 'value']
# ,tensor([-0.8174, -0.0977, -0.0977, -0.0952, -0.0820], dtype=torch.float64)
# ,tensor([32,  6,  5, 14,  3])
#
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['makes', 'from', ',', 'transparent', 'sprite']
# , tensor([0.4018, 0.3771, 0.3605, 0.3581, 0.3564], dtype=torch.float64)
# , tensor([7, 4, 6, 8, 3])
# ,['private', 'AsyncBufferedImage', 'Loads', 'image', 'return']
# ,tensor([-0.4334, -0.3788, -0.2286, -0.1286, -0.1268], dtype=torch.float64)
# ,tensor([ 14,  15,   1,  12, 134])
#
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['logger', '}', '</s>', 'container', 'using']
# , tensor([0.4275, 0.3233, 0.2270, 0.1356, 0.1173], dtype=torch.float64)
# , tensor([37, 58, 59,  9,  4])
# ,['return', 'return', 'HttpEventServlet', 'newWebSocketHandler', 'specific']
# ,tensor([-0.2715, -0.2297, -0.2008, -0.0971, -0.0834], dtype=torch.float64)
# ,tensor([55, 24, 15, 16, 10])
#
# 解析错误
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2456e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['between', 'directory', '}', 'a', 'directory']
# , tensor([0.4907, 0.4269, 0.2894, 0.2669, 0.2602], dtype=torch.float64)
# , tensor([  6,   5, 118,   7,  10])
# ,['common', '}', 'return', 'current', ';']
# ,tensor([-0.1847, -0.1561, -0.1516, -0.0774, -0.0639], dtype=torch.float64)
# ,tensor([  3, 113, 115,   8,  42])
#
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['current', 'RadioButtons', 'the', 'in', 'Returns']
# , tensor([0.6196, 0.2292, 0.1968, 0.1696, 0.1653], dtype=torch.float64)
# , tensor([10,  6,  9,  8,  1])
# ,['.', 'RadioButton', 'RadioButton', 'viewFetcher', 'getCurrentViews']
# ,tensor([-0.4311, -0.2401, -0.2395, -0.2366, -0.2318], dtype=torch.float64)
# ,tensor([12, 27, 17, 23, 25])
#
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'long', '(', 'time', '.']
# , tensor([0.6376, 0.2439, 0.2228, 0.1348, 0.1324], dtype=torch.float64)
# , tensor([13, 32, 71,  3, 11])
# ,['interval', 'contain', 'if', 'containsNow', 'long']
# ,tensor([-0.6500, -0.3256, -0.2890, -0.1302, -0.1291], dtype=torch.float64)
# ,tensor([ 4,  5, 21, 29, 46])
#
# 第20个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['}', 'ImmutableList', 'StringExpression', 'args', 'stringTemplate']
# , tensor([0.8861, 0.4027, 0.2968, 0.2113, 0.1743], dtype=torch.float64)
# , tensor([34, 28,  9, 32, 10])
# ,['public', '));', 'copyOf', 'args', 'Object']
# ,tensor([-0.2569, -0.2556, -0.2423, -0.1255, -0.0906], dtype=torch.float64)
# ,tensor([ 7, 33, 30, 17, 15])
#
# 解析错误
# 第21个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9996e-01, 4.4107e-05]], grad_fn=<SoftmaxBackward0>)
# 第22个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'okhttp3', 'localVarCall', 'ApiResponse', 'createXmlItemWithHttpInfo']
# , tensor([0.6028, 0.5028, 0.3705, 0.3222, 0.2597], dtype=torch.float64)
# , tensor([36, 23, 26, 11, 15])
# ,['public', 'ApiException', 'Void', '<', '(']
# ,tensor([-0.9456, -0.1408, -0.0979, -0.0268, -0.0251], dtype=torch.float64)
# ,tensor([10, 21, 13, 12, 16])
#
# 第23个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['table', 'requiresConfigSchema', 'the', 'escaped', 'return']
# , tensor([0.4882, 0.4496, 0.3379, 0.3172, 0.2068], dtype=torch.float64)
# , tensor([ 5, 35,  8, 10, 46])
# ,['Get', 'return', '_', 'global', '}']
# ,tensor([-0.3595, -0.2846, -0.1623, -0.1536, -0.1051], dtype=torch.float64)
# ,tensor([ 1, 88, 92,  3, 87])
#
# 第24个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Returns', '<>(', '</s>', 'node', '}']
# , tensor([0.4969, 0.4539, 0.4023, 0.3056, 0.2211], dtype=torch.float64)
# , tensor([ 1, 23, 31,  9, 30])
# ,['of', 'getChildrenAsList', 'for', 'children', 'asList']
# ,tensor([-0.3272, -0.1586, -0.1464, -0.1236, -0.0948], dtype=torch.float64)
# ,tensor([ 4, 17,  6,  5, 26])
#
# 第25个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['totalBytesServerReceived', 'getNumBytesUploaded', '@', 'Deprecated', 'uploader']
# , tensor([0.7882, 0.7075, 0.4767, 0.4608, 0.3240], dtype=torch.float64)
# , tensor([33, 29, 25, 26, 10])
# ,['0', 'total', '{', 'number', '<s>']
# ,tensor([-0.1824, -0.1273, -0.0528, -0.0335,  0.0000], dtype=torch.float64)
# ,tensor([12,  3, 31,  4,  0])
#
# 第26个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['uninstall', 'the', 'the', 'to', 'UninstallationResult']
# , tensor([0.6643, 0.2836, 0.1363, 0.0995, 0.0795], dtype=torch.float64)
# , tensor([ 6,  2,  7,  5, 15])
# ,['add', 'ons', 'uninstallations', 'List', 'uninstallations']
# ,tensor([-0.4848, -0.2726, -0.1722, -0.1570, -0.1543], dtype=torch.float64)
# ,tensor([  9,  11, 174,  25, 139])
#
# 第27个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['StructuredTextEnvironment', 'ISTextExpert', 'Obtains', 'type', 'StructuredTextEnvironment']
# , tensor([0.6020, 0.4605, 0.4345, 0.3181, 0.2723], dtype=torch.float64)
# , tensor([40,  3,  1, 12, 28])
# ,['environment', 'handler', 'getStatefulExpert', 'return', 'static']
# ,tensor([-0.2662, -0.1923, -0.1514, -0.1483, -0.1375], dtype=torch.float64)
# ,tensor([38, 13, 23, 44, 20])
#
# 第28个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', '//', 'new', 'builder', 'estimatePrintedLength']
# , tensor([0.2186, 0.1627, 0.1388, 0.1205, 0.0917], dtype=torch.float64)
# , tensor([10, 43,  6, 32, 26])
# ,['Prints', 'return', '}', 'printTo', 'StringBuilder']
# ,tensor([-0.3183, -0.1975, -0.1155, -0.1130, -0.0831], dtype=torch.float64)
# ,tensor([ 1, 50, 55, 30, 22])
#
# 第29个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', '}', 'defaultEndpointUrl', 'createFeatureService', 'createFeatureService']
# , tensor([0.4838, 0.3272, 0.2928, 0.2882, 0.2431], dtype=torch.float64)
# , tensor([20, 25, 23, 17, 21])
# ,['public', 'a', 'and', 'feature', ');']
# ,tensor([-0.4523, -0.3117, -0.1538, -0.1292, -0.1008], dtype=torch.float64)
# ,tensor([15,  4,  2,  6, 24])
#
# 第30个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['pump', 'log', 'applyAPSRequest', 'if', 'expect']
# , tensor([0.3565, 0.0940, 0.0790, 0.0667, 0.0654], dtype=torch.float64)
# , tensor([ 13, 167, 171,  37,   1])
# ,['absolute', 'allow', 'based', 'both', 'percent']
# ,tensor([-0.6574, -0.4324, -0.2167, -0.2117, -0.1545], dtype=torch.float64)
# ,tensor([ 7,  5, 11,  6,  9])
#
# 第31个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['username', '<', 'getType', 'execute', 'User']
# , tensor([0.1541, 0.1514, 0.1230, 0.1225, 0.0586], dtype=torch.float64)
# , tensor([ 5, 25, 28, 31, 26])
# ,['}', 'public', 'TypeToken', 'Type', 'return']
# ,tensor([-0.8035, -0.7050, -0.4816, -0.4194, -0.2786], dtype=torch.float64)
# ,tensor([39,  7, 24, 20, 30])
#
# 第32个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Get', 'return', '}', 'findBestMatchCuboid1', '</s>']
# , tensor([0.6360, 0.3865, 0.2614, 0.2183, 0.1577], dtype=torch.float64)
# , tensor([ 1, 20, 25, 21, 26])
# ,['findBestMatchCuboid', 'cuboid', 'parent', 'long', 'cuboid']
# ,tensor([-0.1255, -0.0940, -0.0859, -0.0693, -0.0690], dtype=torch.float64)
# ,tensor([14,  4,  3, 16, 17])
#
# 第33个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['wrapping', 'file', 'the', 'in', 'the']
# , tensor([0.7008, 0.3636, 0.3332, 0.2729, 0.2282], dtype=torch.float64)
# , tensor([11,  9,  8,  7, 12])
# ,['lines', 'generated', 'Returns', '}', 'this']
# ,tensor([-0.2220, -0.0841, -0.0594, -0.0364, -0.0358], dtype=torch.float64)
# ,tensor([  6,  13,   1, 138, 114])
#
# 第34个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Override', 'public', 'stringRep', 'toString', 'the']
# , tensor([0.9072, 0.2172, 0.1678, 0.1500, 0.1329], dtype=torch.float64)
# , tensor([ 9, 10, 22, 12,  4])
# ,[')', 'if', '}', 'stringRep', '{']
# ,tensor([-0.0936, -0.0881, -0.0726, -0.0717, -0.0632], dtype=torch.float64)
# ,tensor([20, 15, 28, 17, 21])
#
# 第35个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Returns', 'shows', 'onlyVisible', '{', 'getButton']
# , tensor([0.8487, 0.2542, 0.2139, 0.1452, 0.1448], dtype=torch.float64)
# , tensor([ 1,  5, 33, 21, 13])
# ,['which', ',', 'String', 'text', 'a']
# ,tensor([-0.2184, -0.1105, -0.0747, -0.0620, -0.0572], dtype=torch.float64)
# ,tensor([ 4, 32, 15,  8,  6])
#
# 第36个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['CassandraInstance', 'public', 'Set', '@', '}']
# , tensor([0.5150, 0.5029, 0.4255, 0.4187, 0.2921], dtype=torch.float64)
# , tensor([23, 20, 21, 18, 33])
# ,['GET', '</s>', '.', '<s>', '</s>']
# ,tensor([-0.0893, -0.0103, -0.0003,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([19, 34, 30,  0, 17])
#
# 第37个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'forProperty', 'access', 'parent', '<']
# , tensor([0.5265, 0.2937, 0.2733, 0.2062, 0.1821], dtype=torch.float64)
# , tensor([25, 15,  7, 31, 28])
# ,['public', 'Assert', 'new', 'property', ',']
# ,tensor([-0.6509, -0.4084, -0.3650, -0.1510, -0.1431], dtype=torch.float64)
# ,tensor([ 9, 33,  3,  6, 32])
#
# 第38个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['DOCUMENT', '}', 'ME', 'public', '{']
# , tensor([0.9720, 0.0912, 0.0444, 0.0366, 0.0254], dtype=torch.float64)
# , tensor([ 1, 15,  2,  5,  9])
# ,['return', 'String', ';', '!', '.']
# ,tensor([-4.3076e-01, -2.8664e-02, -2.4036e-02, -2.0068e-02, -2.7422e-04],
#        dtype=torch.float64)
# ,tensor([10,  6, 14,  3, 12])
#
# 第39个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['protected', 'if', 'ApiResponses', 'if', 'handling']
# , tensor([0.6753, 0.2551, 0.2233, 0.1767, 0.1661], dtype=torch.float64)
# , tensor([10, 33, 14, 72,  5])
# ,['Override', '}', 'special', 'codes', 'code']
# ,tensor([-0.2500, -0.1024, -0.0878, -0.0559, -0.0523], dtype=torch.float64)
# ,tensor([ 1, 90,  4,  8, 65])

# %%
print('Visualize attributions based on Integrated Gradients')
_ = viz.visualize_text(vis_data_records_ig)
# Out:
# Visualize attributions based on Integrated Gradients
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>1.0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>nag</b></text></td><td><text style="padding-right:2em"><b>2.12</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #s                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> Method                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> for                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> getting                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> counts                    </font></mark><mark style="background-color: hsl(120, 75%, 69%); opacity:1.0;                     line-height:1.75"><font color="black"> using                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> named                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> filters                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> #/s                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> (                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> )                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> {                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> if                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> (                    </font></mark><mark style="background-color: hsl(120, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> )                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> {                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> return                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> ;                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color ...

# %%
AST_list = []
for i in range(100,150): 
    AST_list.append(df_clean.loc[i,'new_code_raw'])

comment_list = []
for i in range(100,150): 
    comment_list.append(df_clean.loc[i,'old_comment_raw'])
PFS_list = []
for i in range(100,150): 
    PFS_list.append(df_clean.loc[i,'AST_PFSnodes'])

child_num_list = []
for i in range(100,150): 
    child_num_list.append(df_clean.loc[i,'Child_Node_count']) 
    
ground_lable = []
for i in range(100,150): 
    ground_lable.append(df_clean.loc[i,'label'])

input_ids_all,ref_input_ids_all,position_ids_all,attention_mask_all,\
token_type_ids_all,all_tokens_all= input_data_list(AST_list,comment_list)

vis_data_records_ig = []
for i in range(len(AST_list)):    
    top_tokens_max, values_max, indices_max,top_tokens_min,values_min,\
    indices_min,nodes,attr,parent_node_name,parent_values \
    = interpret_sentence_2(AST_list[i],comment_list[i],PFS_list[i],child_num_list[i],input_ids_all[i],\
                           ref_input_ids_all[i], token_type_ids_all[i], position_ids_all[i], attention_mask_all[i], \
                           all_tokens_all[i], ground_lable[i],vis_data_records_ig)
    print(f'第{i}个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值\n\
    {top_tokens_max}\n, {values_max}\n, {indices_max}\n,{top_tokens_min}\n,{values_min}\n,{indices_min}\n')
    
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_PFS_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的先序遍历序列 和 归因贡献值 \n{nodes}\n, {attr}\n')
# 将 nodes 和 attr 写入到 txt 文件中
    with open('AST_parent_attribution.txt', 'a',encoding='utf-8') as f:
        f.write(f'第{i}个代码的父节点 和 归因贡献值 \n{parent_node_name}\n, {parent_values}\n')
# Out:
# 第0个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'throw', 'NotLeaderException', 'getValue', 'logger']
# , tensor([0.8517, 0.3793, 0.2382, 0.2208, 0.1900], dtype=torch.float64)
# , tensor([13, 36, 38, 15, 64])
# ,[',', 'internal', 'Get', 'read', '(']
# ,tensor([-0.4953, -0.3209, -0.1692, -0.0904, -0.0863], dtype=torch.float64)
# ,tensor([ 4,  8,  1,  5, 16])
#
# 第1个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'field', 'with', 'name', '}']
# , tensor([0.4479, 0.4181, 0.3897, 0.2916, 0.2893], dtype=torch.float64)
# , tensor([60,  3,  4,  7, 93])
# ,['given', 'and', 'the', 'String', 'Seeks']
# ,tensor([-0.1780, -0.0902, -0.0836, -0.0664, -0.0620], dtype=torch.float64)
# ,tensor([ 6, 11,  5, 35,  1])
#
# 第2个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['DOCUMENT', '.', '{', '</s>', '!']
# , tensor([1.4020, 0.1048, 0.0292, 0.0180, 0.0086], dtype=torch.float64)
# , tensor([ 1, 12,  9, 16,  3])
# ,['getBackupDirectory', 'backupDirectory', 'public', 'String', '}']
# ,tensor([-0.4439, -0.2665, -0.2499, -0.1713, -0.1028], dtype=torch.float64)
# ,tensor([ 7, 13,  5,  6, 15])
#
# 第3个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['potato', 'bakeTime', 'long', 'NotDeliciousException', 'is']
# , tensor([0.5393, 0.2571, 0.2516, 0.2246, 0.2063], dtype=torch.float64)
# , tensor([ 4, 33, 32, 14,  5])
# ,['boolean', 'isBaked', '}', 'baked', 'public']
# ,tensor([-0.3465, -0.3417, -0.1911, -0.1681, -0.1164], dtype=torch.float64)
# ,tensor([10, 11, 60,  6,  9])
#
# 第4个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['RenderScriptThunker', 'allocation', 'RenderScript', 'from', 'int']
# , tensor([0.7559, 0.3545, 0.2978, 0.2117, 0.2089], dtype=torch.float64)
# , tensor([34,  4, 14,  5, 23])
# ,['bitmap', 'RenderScriptThunker', 'drawBitmap', 'c', 'Creates']
# ,tensor([-0.5095, -0.2552, -0.2241, -0.0908, -0.0906], dtype=torch.float64)
# ,tensor([  7,  38, 139, 137,   1])
#
# 第5个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Aggregate', 'of', 'type', 'row', 'public']
# , tensor([0.8782, 0.3478, 0.3263, 0.2521, 0.2263], dtype=torch.float64)
# , tensor([ 7,  5,  4,  3, 13])
# ,['Computes', '}', 'Litmus', 'boolean', 'an']
# ,tensor([-0.3914, -0.1482, -0.1227, -0.1154, -0.0862], dtype=torch.float64)
# ,tensor([ 1, 49, 17, 14,  6])
#
# 解析错误
# 第6个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.4324e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4324e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.4324e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4324e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4324e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.4324e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第7个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['ISO8601', 'Output', 'in', 'ISODateTimeFormat', 'yyyy']
# , tensor([1.1416, 0.5403, 0.2659, 0.2061, 0.2059], dtype=torch.float64)
# , tensor([ 6,  1,  5, 28,  9])
# ,['}', ');', '</s>', 'getInstance', 'this']
# ,tensor([-0.1260, -0.0760, -0.0673, -0.0597, -0.0422], dtype=torch.float64)
# ,tensor([38, 37, 39, 30, 36])
#
# 第8个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['challenge', 'Evaluate', '}', 'a', 'public']
# , tensor([0.4227, 0.3849, 0.3502, 0.1966, 0.1365], dtype=torch.float64)
# , tensor([ 5,  1, 99,  2, 19])
# ,['the', 'evaluateChallenge', 'the', 'PLAIN', 'complete']
# ,tensor([-0.3367, -0.2297, -0.1837, -0.1081, -0.1062], dtype=torch.float64)
# ,tensor([15, 22,  8,  3, 64])
#
# 第9个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['end', 'start', 'return', '</s>', 'isValidStartEndForLength']
# , tensor([0.8921, 0.4267, 0.3427, 0.2759, 0.2342], dtype=torch.float64)
# , tensor([ 6,  4, 56, 72, 43])
# ,['given', 'JTextArea', 'view', 'return', 'Gets']
# ,tensor([-0.1897, -0.1702, -0.1147, -0.1055, -0.1044], dtype=torch.float64)
# ,tensor([ 3, 21,  7, 62,  1])
#
# 第10个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['writeSchema', 'public', 'insertion', 'WSDL', '}']
# , tensor([0.5422, 0.4726, 0.2770, 0.2686, 0.2506], dtype=torch.float64)
# , tensor([30, 28, 11, 24, 44])
# ,['for', 'type', ')', 'types', 'specified']
# ,tensor([-0.4246, -0.1911, -0.0378, -0.0333, -0.0333], dtype=torch.float64)
# ,tensor([ 4,  7, 37, 17,  6])
#
# 第11个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['or', 'return', 'of', 'scanner', 'the']
# , tensor([0.4903, 0.4377, 0.3573, 0.2632, 0.2609], dtype=torch.float64)
# , tensor([ 4, 39,  6, 10,  7])
# ,['passive', 'quality', 'scannerPackage', 'getCanonicalName', 'public']
# ,tensor([-0.2487, -0.1632, -0.0905, -0.0897, -0.0879], dtype=torch.float64)
# ,tensor([ 9,  3, 24, 30, 13])
#
# 第12个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['given', 'return', 'ordinal', 'RelDataTypeField', 'up']
# , tensor([0.2084, 0.2052, 0.1093, 0.0869, 0.0849], dtype=torch.float64)
# , tensor([ 7, 73, 14, 19,  2])
# ,['with', 'field', 'and', 'if', 'a']
# ,tensor([-0.7276, -0.3958, -0.3231, -0.2498, -0.1436], dtype=torch.float64)
# ,tensor([ 5,  4,  9, 10,  6])
#
# 第13个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'left', '</s>', '(', 'INDEX']
# , tensor([0.4812, 0.4043, 0.2999, 0.2720, 0.2204], dtype=torch.float64)
# , tensor([10,  3, 52,  6, 41])
# ,['Expr', '(', 'ENumber', 'String', 'factory']
# ,tensor([-0.5747, -0.1524, -0.0787, -0.0725, -0.0655], dtype=torch.float64)
# ,tensor([ 1, 48, 12, 24, 29])
#
# 第14个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'writeValueAsString', 'JSON', '}', 'static']
# , tensor([0.6238, 0.4833, 0.3982, 0.3698, 0.3536], dtype=torch.float64)
# , tensor([11, 25,  7, 29, 12])
# ,['given', 'object', 'object', '<s>', '</s>']
# ,tensor([-0.0657, -0.0567, -0.0024,  0.0000,  0.0000], dtype=torch.float64)
# ,tensor([ 3, 27, 17,  0, 10])
#
# 第15个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['JXTable', 'private', '()', 'initializes', 'tableExt']
# , tensor([0.5391, 0.4265, 0.2954, 0.2322, 0.1281], dtype=torch.float64)
# , tensor([ 7,  6,  9,  3, 23])
# ,['This', 'tableAuth', 'if', 'if', 'extDescription']
# ,tensor([-0.3138, -0.1966, -0.1732, -0.1678, -0.1588], dtype=torch.float64)
# ,tensor([  1,   4, 137, 183, 175])
#
# 解析错误
# 第16个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[0.9706, 0.0294]], grad_fn=<SoftmaxBackward0>)
# , tensor([[0.9706, 0.0294]], grad_fn=<SoftmaxBackward0>)
# , tensor([[0.9706, 0.0294]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.9706, 0.0294]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.9706, 0.0294]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[0.9706, 0.0294]], grad_fn=<SoftmaxBackward0>)
#
# 解析错误
# 第17个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.2162e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第18个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['channel', 'from', 'source', 'if', 'content']
# , tensor([0.6386, 0.4134, 0.3357, 0.2401, 0.2106], dtype=torch.float64)
# , tensor([7, 5, 4, 9, 3])
# ,['return', '}', 'Removes', 'break', 'doomed']
# ,tensor([-0.2862, -0.2644, -0.1473, -0.0987, -0.0590], dtype=torch.float64)
# ,tensor([93, 92,  1, 73, 90])
#
# 第19个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Chrome', 'Returns', '}', '</s>', 'listeningThread']
# , tensor([0.6820, 0.4389, 0.2288, 0.1581, 0.0902], dtype=torch.float64)
# , tensor([ 6,  1, 30, 31, 20])
# ,['sockets', 'return', 'whether', 'listeningThread', 'hasClient']
# ,tensor([-0.2478, -0.2069, -0.1492, -0.1208, -0.1107], dtype=torch.float64)
# ,tensor([26, 15,  2, 24, 22])
#
# 第20个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Returns', 'changeEClass', 'eclipse', 'return', ');']
# , tensor([0.6963, 0.0981, 0.0862, 0.0670, 0.0664], dtype=torch.float64)
# , tensor([ 1, 39, 12, 35, 46])
# ,['for', 'object', 'EAttribute', 'mylyn', 'the']
# ,tensor([-0.4955, -0.3723, -0.2752, -0.1051, -0.0822], dtype=torch.float64)
# ,tensor([ 5,  4, 29, 14,  6])
#
# 第21个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['inflate', 'user', 'a', 'static', 'return']
# , tensor([0.3545, 0.3149, 0.2901, 0.2772, 0.2750], dtype=torch.float64)
# , tensor([34, 40,  2, 17, 25])
# ,['new', 'R', 'R', 'folder', '(']
# ,tensor([-0.4504, -0.1906, -0.1632, -0.0955, -0.0877], dtype=torch.float64)
# ,tensor([ 3, 36,  8, 42, 20])
#
# 第22个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['}', 'return', 'try', 'TableIdentifier', '{']
# , tensor([0.0881, 0.0841, 0.0822, 0.0644, 0.0597], dtype=torch.float64)
# , tensor([185, 186, 172,  44, 171])
# ,['}', ');', 'e', 'GRANTs', 'privileges']
# ,tensor([-1.4713, -0.2826, -0.1239, -0.0421, -0.0224], dtype=torch.float64)
# ,tensor([169, 168, 167,   7, 165])
# 第23个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['ImageSource', 'public', 'image', '</s>', 'the']
# , tensor([0.7417, 0.2721, 0.1950, 0.1869, 0.1388], dtype=torch.float64)
# , tensor([ 9,  8,  5, 19,  4])
# ,['of', 'tilingDisabled', 'return', 'Disable', '()']
# ,tensor([-0.4266, -0.3446, -0.2858, -0.1990, -0.1898], dtype=torch.float64)
# ,tensor([ 3, 10, 13,  1, 11])
#
# 解析错误
# 第24个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# , tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[1.3039e-05, 9.9999e-01]], grad_fn=<SoftmaxBackward0>)
#
# 第25个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['int', 'for', 'for', '//', 'int']
# , tensor([0.3514, 0.2819, 0.1704, 0.1469, 0.1279], dtype=torch.float64)
# , tensor([165, 174, 188, 123, 156])
# ,['corner', 'the', 'to', 'left', 'which']
# ,tensor([-0.6432, -0.3491, -0.2803, -0.2600, -0.1919], dtype=torch.float64)
# ,tensor([11,  8,  7, 10, 17])
#
# 第26个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['system', 'if', 'FileSystem', 'unacceptable', 'Scheme']
# , tensor([0.7169, 0.2338, 0.1917, 0.1684, 0.1659], dtype=torch.float64)
# , tensor([ 10,  57,  81, 111,  11])
# ,['makeFullQualifiedURI', 'URI', 'default', 'getAuthority', 'uriName']
# ,tensor([-0.4038, -0.2482, -0.2125, -0.1572, -0.1571], dtype=torch.float64)
# ,tensor([18, 17,  8, 72, 21])
#
# 第27个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['vertex', 'by', 'return', 'int', 'x']
# , tensor([0.5418, 0.3151, 0.2351, 0.1685, 0.1459], dtype=torch.float64)
# , tensor([ 3,  4, 48, 61, 74])
# ,['orientation', '{', 'given', 'Rotate', '}']
# ,tensor([-0.5510, -0.2639, -0.1616, -0.1446, -0.1380], dtype=torch.float64)
# ,tensor([ 7, 16,  6,  1, 96])
#
# 第28个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['</s>', 'public', 'RollCycle', '();', 'Returns']
# , tensor([0.4821, 0.2952, 0.1602, 0.1177, 0.0804], dtype=torch.float64)
# , tensor([14,  3,  4, 12,  1])
# ,['rollCycle', 'getRollCycle', 'queue', '{', '.']
# ,tensor([-0.3835, -0.2136, -0.0970, -0.0622, -0.0471], dtype=torch.float64)
# ,tensor([11,  5,  9,  7, 10])
#
# 解析错误
# 第29个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1363e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第30个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['druidDimensionRowProvider', 'DruidDimensionValueLoader', 'physicalTableDictionary', 'DimensionValueLoadTask', 'DruidWebService']
# , tensor([0.3948, 0.3712, 0.2421, 0.2251, 0.2119], dtype=torch.float64)
# , tensor([21, 20, 26,  7, 10])
# ,['DruidDimensionsLoader', 'webService', 'buildDruidDimensionsLoader', 'webService', '</s>']
# ,tensor([-0.8996, -0.1248, -0.1222, -0.0336, -0.0330], dtype=torch.float64)
# ,tensor([ 3, 30,  8, 11, 43])
#
# 第31个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['interval', 'public', 'overlap', 'return', 'long']
# , tensor([0.6185, 0.4157, 0.4068, 0.2092, 0.1792], dtype=torch.float64)
# , tensor([ 4, 12,  5, 55, 45])
# ,['specified', 'long', 'the', '(', 'time']
# ,tensor([-0.3071, -0.1737, -0.1067, -0.0812, -0.0752], dtype=torch.float64)
# ,tensor([ 7, 31,  6, 15,  3])
#
# 第32个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['HTTP', 'encoded', '</s>', '-', 'return']
# , tensor([0.3589, 0.1835, 0.1224, 0.1183, 0.0984], dtype=torch.float64)
# , tensor([  6,   5, 129,   4, 116])
# ,['url', 'queryString', '}', 'containing', 'queryString']
# ,tensor([-0.6856, -0.3615, -0.3124, -0.2485, -0.1994], dtype=torch.float64)
# ,tensor([  3,   7, 128,   8,  55])
#
# 第33个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['colorAccent', '}', 'return', 'getAccentColorFromThemeIfAvailable', 'available']
# , tensor([0.2809, 0.1902, 0.1647, 0.1506, 0.1061], dtype=torch.float64)
# , tensor([  3, 152, 135,  17,  12])
# ,['colorAccent', 'from', 'the', 'current', 'context']
# ,tensor([-0.4881, -0.3814, -0.3611, -0.2493, -0.2081], dtype=torch.float64)
# ,tensor([36,  4,  5,  6, 50])
#
# 第34个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['DOCUMENT', '}', 'public', 'ME', '()']
# , tensor([1.0858, 0.0965, 0.0230, 0.0218, 0.0188], dtype=torch.float64)
# , tensor([ 1, 15,  5,  2,  8])
# ,['return', ';', 'String', 'getTreeAuthoringPath', '!']
# ,tensor([-0.3874, -0.0595, -0.0497, -0.0442, -0.0351], dtype=torch.float64)
# ,tensor([10, 14,  6,  7,  3])
#
# 第35个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['current', 'the', 'throw', '}', '"']
# , tensor([0.5556, 0.3729, 0.2262, 0.1789, 0.1572], dtype=torch.float64)
# , tensor([  7,   6, 191, 214, 201])
# ,['platform', 'chromeBinaryLocation', 'protected', 'chromeBinaryLocation', 'executable']
# ,tensor([-0.6370, -0.1550, -0.0879, -0.0647, -0.0602], dtype=torch.float64)
# ,tensor([ 8, 37, 11, 55,  4])
#
# 第36个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['final', 'generateParseException', '!', 'ME', 'la1tokens']
# , tensor([0.6741, 0.6224, 0.3600, 0.3382, 0.3252], dtype=torch.float64)
# , tensor([ 5,  8,  3,  2, 42])
# ,['}', '}', 'this', 'if', 'for']
# ,tensor([-0.1710, -0.1447, -0.1280, -0.1251, -0.0964], dtype=torch.float64)
# ,tensor([156, 157, 181, 174, 160])
#
# 解析错误
# 第37个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.0358e-05]], grad_fn=<SoftmaxBackward0>)
#
# 解析错误
# 第38个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9969e-01, 3.1490e-04]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9969e-01, 3.1490e-04]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9969e-01, 3.1490e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9969e-01, 3.1490e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9969e-01, 3.1490e-04]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9969e-01, 3.1490e-04]], grad_fn=<SoftmaxBackward0>)
#
# 第39个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['View', 'Creates', ',', '</s>', '(']
# , tensor([0.5415, 0.2911, 0.1756, 0.1019, 0.0892], dtype=torch.float64)
# , tensor([ 9,  1, 24, 39, 11])
# ,['mWorkspace', '}', '(', 'mWorkspace', 'getCurrentScreen']
# ,tensor([-0.3802, -0.3336, -0.3228, -0.2592, -0.2570], dtype=torch.float64)
# ,tensor([28, 38, 25, 32, 34])
#
# 第40个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['bitmap', 'Bitmap', 'with', 'PIXEL', 'BitmapUtil']
# , tensor([0.6433, 0.6264, 0.3974, 0.3419, 0.2688], dtype=torch.float64)
# , tensor([ 3, 53,  4, 51, 41])
# ,['specified', 'Allocate', 'width', '.', 'double']
# ,tensor([-0.1494, -0.1393, -0.1064, -0.1000, -0.0986], dtype=torch.float64)
# ,tensor([ 6,  1,  7, 56, 39])
#
# 第41个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['public', 'Mono', '(', ')', 'body']
# , tensor([1.0292, 0.0608, 0.0568, 0.0317, 0.0185], dtype=torch.float64)
# , tensor([11, 12, 17, 20, 19])
# ,['quot', 'testClientModel', 'apiClient', '//', 'Object']
# ,tensor([-0.3195, -0.2434, -0.2105, -0.1988, -0.1948], dtype=torch.float64)
# ,tensor([  7,  16, 178,  29,  24])
#
# 第42个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['swagger', 'All', 'getTag', '}', '.']
# , tensor([1.0350, 0.3412, 0.1861, 0.1703, 0.1167], dtype=torch.float64)
# , tensor([ 8,  1, 22, 48, 18])
# ,['are', 'return', 'the', 'final', 'type']
# ,tensor([-0.1508, -0.0956, -0.0948, -0.0771, -0.0742], dtype=torch.float64)
# ,tensor([ 3, 38, 10, 11, 13])
#
# 第43个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'getPrefetchSize', 'prefetchExtension', 'public', '==']
# , tensor([0.5692, 0.5341, 0.3667, 0.3361, 0.2269], dtype=torch.float64)
# , tensor([19, 44, 25, 14, 29])
# ,['determine', '}', 'can', 'to', 'to']
# ,tensor([-0.1699, -0.1697, -0.1562, -0.1312, -0.0508], dtype=torch.float64)
# ,tensor([ 3, 46,  7,  9,  2])
#
# 第44个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['return', 'node', 'InternalUtils', '}', 'elementFromUse']
# , tensor([0.5089, 0.2730, 0.1960, 0.1958, 0.1908], dtype=torch.float64)
# , tensor([23, 28, 24, 30, 17])
# ,['element', 'symbol', 'for', 'method', '.']
# ,tensor([-0.6902, -0.3927, -0.3199, -0.1094, -0.0341], dtype=torch.float64)
# ,tensor([ 3, 26,  4,  6, 25])
# 第45个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['nanoSecToSecFrac', 'of', 'float', 'this', 'Get']
# , tensor([0.5873, 0.4395, 0.2409, 0.1709, 0.1676], dtype=torch.float64)
# , tensor([41,  5, 27,  6,  1])
# ,['length', 'nanosec', 'full', 'gplayer', 'gplayer']
# ,tensor([-0.4711, -0.3756, -0.1709, -0.1438, -0.1291], dtype=torch.float64)
# ,tensor([ 4, 28,  3, 30, 21])
#
# 第46个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['getDecimalValue', 'public', 'fromLogical', 'Struct', 'return']
# , tensor([0.5273, 0.3901, 0.3654, 0.3600, 0.3046], dtype=torch.float64)
# , tensor([52, 33, 36, 35, 45])
# ,['logical', 'its', 'Converts', '(', ',']
# ,tensor([-0.3545, -0.0665, -0.0403, -0.0391, -0.0168], dtype=torch.float64)
# ,tensor([ 6,  5,  1,  8, 49])
#
# 第47个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['Struct', '#', 'public', 'return', 'representation']
# , tensor([0.7174, 0.2976, 0.1341, 0.1243, 0.1088], dtype=torch.float64)
# , tensor([ 3, 15, 24, 95,  4])
# ,['information', '#', 'String', 'replicaSetName', '}']
# ,tensor([-0.2112, -0.1886, -0.1492, -0.1459, -0.1224], dtype=torch.float64)
# ,tensor([ 21,   8,  18,  29, 116])
#
# 解析错误
# 第48个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# , tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
# ,tensor([[9.9999e-01, 1.1167e-05]], grad_fn=<SoftmaxBackward0>)
#
# 第49个top：分别为贡献最大，贡献最大值，token值，贡献最小，贡献最小值
#     ['AsyncExecute', '}', ';', 'stops', 'restarts']
# , tensor([0.4081, 0.3308, 0.2924, 0.2452, 0.2351], dtype=torch.float64)
# , tensor([64, 86, 16, 10, 12])
# ,['profile', ',', 'Opera', 'file', 'When']
# ,tensor([-0.3903, -0.3078, -0.3052, -0.1339, -0.1245], dtype=torch.float64)
# ,tensor([ 4,  5,  6, 27,  1])
