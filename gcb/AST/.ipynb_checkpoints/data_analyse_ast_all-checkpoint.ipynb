# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ast_pre_false = pd.read_json('ast_pre_false.json')
ast_pre_true = pd.read_json('ast_pre_true.json')

astlevel_attribution_false = pd.read_json('astlevel_attribution_false.json')
astlevel_attribution_true = pd.read_json('astlevel_attribution_true.json')
astlevel_attribution_false['value'] = astlevel_attribution_false['value'] * 10
astlevel_attribution_true['value'] = astlevel_attribution_true['value'] * 10

# %%
len(ast_pre_false),len(astlevel_attribution_false)
# Out:
# (1011, 24630)

# %%
len(ast_pre_true),len(astlevel_attribution_true)
# Out:
# (2349, 71011)

# %%
def get_list_print_df(df, name):
    col_list = []
    for i in range(len(df)):
        if df.loc[i]['key'] == name:
            attr = df.loc[i]['value']
            col_list.append(attr)
    df = pd.DataFrame(col_list, columns=[name])
    return df

# %%
def get_all_df_ast(df):
    unique_values = df['key'].value_counts().index
    plt.figure(figsize=(20,5))

    for i in range(len(unique_values)//4):
        uniq = unique_values[i]
        attr = get_list_print_df(df, uniq)

        sns.kdeplot(data=attr, x=uniq, label=uniq, bw_adjust=8)

        xticks = np.arange(min(attr[uniq]), max(attr[uniq]), step=0.5)
        plt.xticks(xticks)
        # 添加图例
    plt.legend()
    plt.axvline(x=0, color='r', linestyle='--')  # 在 x=0 的位置添加一条红色的虚线
    plt.show()
    
    plt.figure(figsize=(20,5))
    for i in range(len(unique_values)//4,(len(unique_values)//4)*2):
        uniq = unique_values[i]
        attr = get_list_print_df(df, uniq)

        sns.kdeplot(data=attr, x=uniq, label=uniq, bw_adjust=10)

        xticks = np.arange(min(attr[uniq]), max(attr[uniq]), step=0.5)
        plt.xticks(xticks)
        # 添加图例
    plt.legend()
    plt.axvline(x=0, color='r', linestyle='--')  # 在 x=0 的位置添加一条红色的虚线
    plt.show()

    plt.figure(figsize=(20,5))
    for i in range((len(unique_values)//4)*2,(len(unique_values)//4)*2+len(unique_values)//4):
        uniq = unique_values[i]
        attr = get_list_print_df(df, uniq)

        sns.kdeplot(data=attr, x=uniq, label=uniq, bw_adjust=10)

        xticks = np.arange(min(attr[uniq]), max(attr[uniq]), step=0.5)
        plt.xticks(xticks)
        # 添加图例
    plt.legend()
    plt.axvline(x=0, color='r', linestyle='--')  # 在 x=0 的位置添加一条红色的虚线
    plt.show()
    
    plt.figure(figsize=(20,5))
    for i in range((len(unique_values)//4)*2+len(unique_values)//4,len(unique_values)):
        uniq = unique_values[i]
        attr = get_list_print_df(df, uniq)

        sns.kdeplot(data=attr, x=uniq, label=uniq, bw_adjust=10)

        xticks = np.arange(min(attr[uniq]), max(attr[uniq]), step=0.5)
        plt.xticks(xticks)
        # 添加图例
    plt.legend()
    plt.axvline(x=0, color='r', linestyle='--')  # 在 x=0 的位置添加一条红色的虚线
    plt.show()

# %%
get_all_df_ast(astlevel_attribution_true)
# Out:
# C:\Users\TEA\AppData\Local\Temp\ipykernel_17792\2211059224.py:51: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=attr, x=uniq, label=uniq, bw_adjust=10)

# %%
after_filter_name = ['IfStatement', 'ForStatement', 'WhileStatement', 'VariableDeclarator',
        'StatementExpression', 'TryStatement', 'ReturnStatement', 'MethodDeclaration']

Not_delet_AST_token_type = ['FormalParameter','ClassReference', 'BasicType', 'InterfaceDeclaration',
                            'CatchClauseParameter', 'MethodInvocation', 'SuperMethodInvocation', 
                            'SuperMemberReference', 'ConstructorDeclaration', 'ReferenceType',
                            'MethodDeclaration', 'VariableDeclarator', 'IfStatement',
                            'WhileStatement', 'DoStatement', 'ForStatement', 'AssertStatement', 
                            'BreakStatement', 'ContinueStatement', 'ReturnStatement', 'ThrowStatement',
                            'SynchronizedStatement', 'TryStatement', 'SwitchStatement', 'BlockStatement', 
                            'StatementExpression', 'TryResource', 'CatchClause', 'CatchClauseParameter',
                            'SwitchStatementCase', 'ForControl', 'EnhancedForControl','BinaryOperation',
                            'UnaryOperation','TernaryExpression','SynchronizedStatement']

# %%
def get_clean_attribution(df,filter_list):
    for i in range(len(df)):
        if df.loc[i]['key'] not in filter_list:
            df = df.drop(index=i)
    df = df.reset_index(drop=True)
    return df

def get_list_print_df_filter_ast(df, name,filter_list):
    col_list = []
    for i in range(len(df)):
        if df.loc[i]['key'] in filter_list:
            if df.loc[i]['key'] == name:
                attr = df.loc[i]['value']
                col_list.append(attr)
    df = pd.DataFrame(col_list, columns=[name])
    return df

def get_all_df_ast_fliter(df,filter_list):
    unique_values = df['key'].value_counts().index
    plt.figure(figsize=(20,5))

    for i in range(len(unique_values)):
        uniq = unique_values[i]
        attr = get_list_print_df_filter_ast(df, uniq,filter_list)

        sns.kdeplot(data=attr, x=uniq, label=uniq, bw_adjust=8)

        xticks = np.arange(min(attr[uniq]), max(attr[uniq]), step=0.5)
        plt.xticks(xticks)
        # 添加图例
    plt.legend()
    plt.axvline(x=0, color='r', linestyle='--')  # 在 x=0 的位置添加一条红色的虚线
    plt.show()

# %%
filter_astlevel_attribution_true = get_clean_attribution(astlevel_attribution_true,after_filter_name)
get_all_df_ast_fliter(filter_astlevel_attribution_true,after_filter_name)

# %%
filter_astlevel_attribution_true.head()
# Out:
#                  key     value
# 0  MethodDeclaration -0.006580
# 1    ReturnStatement -0.005020
# 2  MethodDeclaration  0.542879
# 3    ReturnStatement  0.264125
# 4  MethodDeclaration  0.087545

# %%
def get_all_colunm_df(df):
    unique_values = df['key'].value_counts().index
    result = pd.DataFrame()

    for uniq in unique_values:
        attr = get_list_print_df(df, uniq)
        result = pd.concat([result, attr], axis=1)
        
    return result

# %%
filter_astlevel_attribution_true_df = get_all_colunm_df(filter_astlevel_attribution_true)
filter_astlevel_attribution_true_df.head()
# Out:
#    StatementExpression  VariableDeclarator  ReturnStatement  IfStatement  \
# 0             0.137233            0.042800        -0.005020     0.243033
# 1             0.011839            0.948085         0.264125     0.054713
# 2            -0.014333            0.026383         0.332400     0.029267
# 3            -0.000061           -0.024433         0.072867     0.017851
# 4            -0.000061            0.000950         0.051300     0.028088
#
#    MethodDeclaration  ForStatement  TryStatement  WhileStatement
# 0          -0.006580      0.022375      0.359115        0.113625
# 1           0.542879      0.035200      0.297831        0.010764
# 2           0.087545      0.035200     -0.022173       -2.428344
# 3           0.041953      0.121367     -0.127756        0.011725
# 4           0.049525     -0.058325     -0.010600        0.242242

# %%
# 绘制箱线图
plt.figure(figsize=(20, 20))
sns.boxplot(data=filter_astlevel_attribution_true_df)

plt.xlabel('Category')
plt.ylabel('Values')

plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
# 数据 x 10  小提琴图
plt.figure(figsize=(20,20))
sns.violinplot(data=filter_astlevel_attribution_true_df)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
abs_df = filter_astlevel_attribution_true_df.abs()
mean_abs_values = abs_df.mean()
mean_abs_values
# Out:
# StatementExpression    0.086522
# VariableDeclarator     0.108795
# ReturnStatement        0.174157
# IfStatement            0.081089
# MethodDeclaration      0.252673
# ForStatement           0.088587
# TryStatement           0.095050
# WhileStatement         0.121879
# dtype: float64

# %%
mean_value = filter_astlevel_attribution_true_df.mean()
mean_value
# Out:
# StatementExpression   -0.004626
# VariableDeclarator     0.001787
# ReturnStatement        0.001248
# IfStatement            0.004117
# MethodDeclaration      0.025818
# ForStatement          -0.004633
# TryStatement           0.002136
# WhileStatement        -0.009475
# dtype: float64

# %%
std_value = filter_astlevel_attribution_true_df.std()
std_value
# Out:
# StatementExpression    0.213621
# VariableDeclarator     0.237374
# ReturnStatement        0.381601
# IfStatement            0.147854
# MethodDeclaration      0.418508
# ForStatement           0.149887
# TryStatement           0.215099
# WhileStatement         0.336815
# dtype: float64

# %%
# 画出和论文一样的图
def get_paper_picture(df):
    
    # 图形大小，随时改
    plt.figure(figsize=(40, 8))

    # 定义颜色
    palette = sns.color_palette('pastel')

    # 画图
    for i, col in enumerate(df.columns):
        # 小提琴
        sns.violinplot(x=np.full(len(df), i), y=df[col], inner=None, hue=np.full(len(df), i), palette=[palette[i]], legend=False)
        # 散点图
        sns.stripplot(x=np.full(len(df), i) - 0.5, y=df[col], color=palette[i], alpha=0.5, jitter=0.2, legend=False)
        # 箱线图
        sns.boxplot(x=np.full(len(df), i), y=df[col], width=0.2, showcaps=True, showfliers=False,  # 不显示异常值
                    boxprops=dict(facecolor='none', edgecolor='black', linewidth=1.5),  # 更改边框线条粗细
                    whiskerprops=dict(color='black', linewidth=2), 
                    capprops=dict(color='black', linewidth=2), 
                    medianprops=dict(color='#8B8B83', linewidth=2), 
                    flierprops=dict(marker='o', color='red', alpha=0.5))
    # 均值线
    mean_value = df.mean()
    print(mean_value)
    new_mean_value = [item for item in mean_value for _ in range(2)]
    for i in range(len(new_mean_value)):
        if i % 2 == 0:
            plt.plot([i - 0.5, i + 0.5], [new_mean_value[i], new_mean_value[i]], color='blue', linestyle='--', linewidth=2)
        else:
            plt.plot([i - 0.3, i + 0.3], [new_mean_value[i], new_mean_value[i]], color='blue', linestyle='--', linewidth=2)



    # 横坐标标签
    label_name = [item for sublist in [[x, f'{x}_num'] for x in df.columns] for item in sublist]
    ax = plt.gca()
    ax.set_xticks(np.arange(len(label_name)))  # 设置标签的位置
    ax.set_xticklabels(label_name)

    plt.ylabel('value')

    plt.show()

# %%
get_paper_picture(filter_astlevel_attribution_true_df)
# Out:
# StatementExpression   -0.004626
# VariableDeclarator     0.001787
# ReturnStatement        0.001248
# IfStatement            0.004117
# MethodDeclaration      0.025818
# ForStatement          -0.004633
# TryStatement           0.002136
# WhileStatement        -0.009475
# dtype: float64

# %%
# 画出和论文一样的图
def get_paper_picture_other_color(df):
    
    # 图形大小，随时改
    plt.figure(figsize=(40, 8))

    # 使用 'viridis' colormap
    colormap = plt.colormaps['viridis']
    palette = [colormap(i) for i in np.linspace(0, 1, len(df.columns))]
    
    # 画图
    for i, col in enumerate(df.columns):
        # 小提琴
        sns.violinplot(x=np.full(len(df), i), y=df[col], inner=None, hue=np.full(len(df), i), palette=[palette[i]], legend=False)
        # 散点图
        sns.stripplot(x=np.full(len(df), i) - 0.5, y=df[col], color=palette[i], alpha=0.5, jitter=0.2, legend=False)
        # 箱线图
        sns.boxplot(x=np.full(len(df), i), y=df[col], width=0.2, showcaps=True, showfliers=False,  # 不显示异常值
                    boxprops=dict(facecolor='none', edgecolor='black', linewidth=1.5),  # 更改边框线条粗细
                    whiskerprops=dict(color='black', linewidth=2), 
                    capprops=dict(color='black', linewidth=2), 
                    medianprops=dict(color='#8B8B83', linewidth=2), 
                    flierprops=dict(marker='o', color='red', alpha=0.5))
    # 均值线
    mean_value = df.mean()
    print(mean_value)
    new_mean_value = [item for item in mean_value for _ in range(2)]
    for i in range(len(new_mean_value)):
        if i % 2 == 0:
            plt.plot([i - 0.5, i + 0.5], [new_mean_value[i], new_mean_value[i]], color='#FF00FF', linestyle='--', linewidth=2)
        else:
            plt.plot([i - 0.3, i + 0.3], [new_mean_value[i], new_mean_value[i]], color='#FF00FF', linestyle='--', linewidth=2)



    # 横坐标标签
    label_name = [item for sublist in [[x, f'{x}_num'] for x in df.columns] for item in sublist]
    ax = plt.gca()
    ax.set_xticks(np.arange(len(label_name)))  # 设置标签的位置
    ax.set_xticklabels(label_name)

    plt.ylabel('value')

    plt.show()

# %%
# 原数据  * 100  ，按照道理数据分布应不会变
filter_astlevel_attribution_true_df_copy = filter_astlevel_attribution_true_df.copy() * 10
get_paper_picture_other_color(filter_astlevel_attribution_true_df_copy)
# Out:
# StatementExpression   -0.046255
# VariableDeclarator     0.017871
# ReturnStatement        0.012480
# IfStatement            0.041165
# MethodDeclaration      0.258179
# ForStatement          -0.046330
# TryStatement           0.021357
# WhileStatement        -0.094746
# dtype: float64

# %% [markdown]
# false

# %%
get_all_df_ast(astlevel_attribution_false)
# Out:
# C:\Users\TEA\AppData\Local\Temp\ipykernel_17792\2211059224.py:51: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=attr, x=uniq, label=uniq, bw_adjust=10)

# %%
filter_astlevel_attribution_false = get_clean_attribution(astlevel_attribution_false,after_filter_name)
get_all_df_ast_fliter(filter_astlevel_attribution_false,after_filter_name)

# %%
filter_astlevel_attribution_false_df = get_all_colunm_df(filter_astlevel_attribution_false)
filter_astlevel_attribution_false_df.head()
# Out:
#    VariableDeclarator  ReturnStatement  StatementExpression  IfStatement  \
# 0           -0.716429        -0.155400            -0.047608    -0.106500
# 1           -0.182800        -0.061833            -0.047608    -0.176867
# 2           -0.334475        -0.291900            -0.134933    -0.051950
# 3            0.003300        -2.213250             0.000000     0.101210
# 4           -0.152411        -1.186200            -0.164550     0.144325
#
#    MethodDeclaration  ForStatement  TryStatement  WhileStatement
# 0           0.024898     -0.101633     -0.054336        0.064745
# 1          -0.180215      0.036594      0.091388       -0.096238
# 2          -0.759112      0.000750      0.210334        0.013096
# 3           0.388700     -0.391250      0.004875        0.031400
# 4           0.167360      0.052839     -0.013621        0.046905

# %%
# 绘制箱线图
plt.figure(figsize=(20, 20))
sns.boxplot(data=filter_astlevel_attribution_false_df)

plt.xlabel('Category')
plt.ylabel('Values')

plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
# 数据 x 10  小提琴图
plt.figure(figsize=(20,20))
sns.violinplot(data=filter_astlevel_attribution_false_df)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
abs_df = filter_astlevel_attribution_false_df.abs()
mean_abs_values = abs_df.mean()
mean_abs_values
# Out:
# VariableDeclarator     0.111276
# ReturnStatement        0.215287
# StatementExpression    0.085702
# IfStatement            0.084435
# MethodDeclaration      0.283174
# ForStatement           0.120108
# TryStatement           0.095979
# WhileStatement         0.092024
# dtype: float64

# %%
mean_value = filter_astlevel_attribution_false_df.mean()
mean_value
# Out:
# VariableDeclarator     0.000271
# ReturnStatement       -0.007804
# StatementExpression   -0.002475
# IfStatement            0.006851
# MethodDeclaration      0.007732
# ForStatement          -0.000446
# TryStatement           0.045196
# WhileStatement        -0.022661
# dtype: float64

# %%
# 画出和论文一样的图
def get_paper_picture(df):
    
    # 图形大小，随时改
    plt.figure(figsize=(40, 8))

    # 定义颜色
    palette = sns.color_palette('pastel')

    # 画图
    for i, col in enumerate(df.columns):
        # 小提琴
        sns.violinplot(x=np.full(len(df), i), y=df[col], inner=None, hue=np.full(len(df), i), palette=[palette[i]], legend=False)
        # 散点图
        sns.stripplot(x=np.full(len(df), i) - 0.5, y=df[col], color=palette[i], alpha=0.5, jitter=0.2, legend=False)
        # 箱线图
        sns.boxplot(x=np.full(len(df), i), y=df[col], width=0.2, showcaps=True, showfliers=False,  # 不显示异常值
                    boxprops=dict(facecolor='none', edgecolor='black', linewidth=1.5),  # 更改边框线条粗细
                    whiskerprops=dict(color='black', linewidth=2), 
                    capprops=dict(color='black', linewidth=2), 
                    medianprops=dict(color='#8B8B83', linewidth=2), 
                    flierprops=dict(marker='o', color='red', alpha=0.5))
    # 均值线
    mean_value = df.mean()
    print(mean_value)
    new_mean_value = [item for item in mean_value for _ in range(2)]
    for i in range(len(new_mean_value)):
        if i % 2 == 0:
            plt.plot([i - 0.5, i + 0.5], [new_mean_value[i], new_mean_value[i]], color='blue', linestyle='--', linewidth=2)
        else:
            plt.plot([i - 0.3, i + 0.3], [new_mean_value[i], new_mean_value[i]], color='blue', linestyle='--', linewidth=2)



    # 横坐标标签
    label_name = [item for sublist in [[x, f'{x}_num'] for x in df.columns] for item in sublist]
    ax = plt.gca()
    ax.set_xticks(np.arange(len(label_name)))  # 设置标签的位置
    ax.set_xticklabels(label_name)

    plt.ylabel('value')

    plt.show()

# %%
get_paper_picture(filter_astlevel_attribution_false_df)
# Out:
# VariableDeclarator     0.000271
# ReturnStatement       -0.007804
# StatementExpression   -0.002475
# IfStatement            0.006851
# MethodDeclaration      0.007732
# ForStatement          -0.000446
# TryStatement           0.045196
# WhileStatement        -0.022661
# dtype: float64

# %%
# 画出和论文一样的图
def get_paper_picture_other_color(df):
    
    # 图形大小，随时改
    plt.figure(figsize=(40, 8))

    # 使用 'viridis' colormap
    colormap = plt.colormaps['viridis']
    palette = [colormap(i) for i in np.linspace(0, 1, len(df.columns))]
    
    # 画图
    for i, col in enumerate(df.columns):
        # 小提琴
        sns.violinplot(x=np.full(len(df), i), y=df[col], inner=None, hue=np.full(len(df), i), palette=[palette[i]], legend=False)
        # 散点图
        sns.stripplot(x=np.full(len(df), i) - 0.5, y=df[col], color=palette[i], alpha=0.5, jitter=0.2, legend=False)
        # 箱线图
        sns.boxplot(x=np.full(len(df), i), y=df[col], width=0.2, showcaps=True, showfliers=False,  # 不显示异常值
                    boxprops=dict(facecolor='none', edgecolor='black', linewidth=1.5),  # 更改边框线条粗细
                    whiskerprops=dict(color='black', linewidth=2), 
                    capprops=dict(color='black', linewidth=2), 
                    medianprops=dict(color='#8B8B83', linewidth=2), 
                    flierprops=dict(marker='o', color='red', alpha=0.5))
    # 均值线
    mean_value = df.mean()
    print(mean_value)
    new_mean_value = [item for item in mean_value for _ in range(2)]
    for i in range(len(new_mean_value)):
        if i % 2 == 0:
            plt.plot([i - 0.5, i + 0.5], [new_mean_value[i], new_mean_value[i]], color='#FF00FF', linestyle='--', linewidth=2)
        else:
            plt.plot([i - 0.3, i + 0.3], [new_mean_value[i], new_mean_value[i]], color='#FF00FF', linestyle='--', linewidth=2)



    # 横坐标标签
    label_name = [item for sublist in [[x, f'{x}_num'] for x in df.columns] for item in sublist]
    ax = plt.gca()
    ax.set_xticks(np.arange(len(label_name)))  # 设置标签的位置
    ax.set_xticklabels(label_name)

    plt.ylabel('value')

    plt.show()

# %%
# 原数据  * 100  ，按照道理数据分布应不会变
filter_astlevel_attribution_false_df_copy = filter_astlevel_attribution_false_df.copy() * 10
get_paper_picture_other_color(filter_astlevel_attribution_false_df_copy)
# Out:
# VariableDeclarator     0.002707
# ReturnStatement       -0.078044
# StatementExpression   -0.024751
# IfStatement            0.068509
# MethodDeclaration      0.077319
# ForStatement          -0.004460
# TryStatement           0.451961
# WhileStatement        -0.226607
# dtype: float64
